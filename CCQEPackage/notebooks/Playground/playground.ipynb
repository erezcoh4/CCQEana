# %%
import sys; sys.path.insert(0, '../'); sys.path.insert(0, 'analysis_notes/mupClassification/'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
# %matplotlib inline

# %% [markdown]
# # ovrelay cosmic vs. $CC1p0\pi$ for colab. meeting April 25, 2016

# %%
ovrelay = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/ccqe_candidates/prodgenie_bnb_nu_uboone_overlay_mcc8_v4_2018_04_22_vertices.csv')

# %%
_, ovarlaySamples = load_MCbnbDATAcosmicSamples(filename='prodgenie_bnb_nu_uboone_overlay_mcc8_v4_2018_04_22_vertices')
# Out:
# 27468 pairs from MC-BNB + cosmic DATA overlay
# 18136 pairs in FV
# 5060 are 1mu-1p, 27.9%
# 4071 are other pairs, 22.4%
# 9005 are cosmic, 49.7%
# --------------------------------------------------------------
# 2389 are CC 1p 0pi, 13.2%

# %%
fig,ax=plt.subplots(figsize=(10,8))
for sam,slabel,scolor in zip([ovarlaySamples['cosmic'],ovarlaySamples['CC 1p 0pi']]
                             ,['cosmic data',r'$CC1p0\pi$ MC']
                             ,['red','blue']):
    PIDa = sam[sam['pidcali_PIDa_pCandidate']<1000]['pidcali_PIDa_pCandidate']
    plt.hist(PIDa,bins=linspace(0,40,51),color=scolor,linewidth=3,histtype='step')
    plt.plot([0,0],[0,0],color=scolor,linewidth=3,label=slabel)
set_axes(ax,r'$PID_a$ of the proton candidate','counts',do_add_grid=True,do_add_legend=False)

# %%
fig,ax=plt.subplots(figsize=(10,8))
for sam,slabel,scolor in zip([ovarlaySamples['cosmic'],ovarlaySamples['CC 1p 0pi']]
                             ,['cosmic data',r'$CC1p0\pi$ MC']
                             ,['red','blue']):
    N_PE = sam['ClosestFlash_TotalPE']
    dYZ = sam['ClosestFlash_YZdistance']
    plt.scatter(N_PE,dYZ,color=scolor,s=25)
set_axes(ax,r'$N_{PE}$ in closest flash','distance to closest flash [cm]'
         ,do_add_grid=True,do_add_legend=False
         ,xlim=(0,3000),ylim=(0,400))

# %%
fig,ax=plt.subplots(figsize=(10,8))
for sam,slabel,scolor in zip([ovarlaySamples['cosmic'],ovarlaySamples['CC 1p 0pi']]
                             ,['cosmic data',r'$CC1p0\pi$ MC']
                             ,['red','blue']):
    l_mu = sam['l_muCandidate']
    l_p = sam['l_pCandidate']
    plt.hist(l_mu-l_p,bins=linspace(-300,300,51),color=scolor,linewidth=3,histtype='step')
    plt.plot([0,0],[0,0],color=scolor,linewidth=3,label=slabel)
set_axes(ax,r'$l_{\mu-candidate} - l_{p-candidate}$ [cm]','counts',do_add_grid=True,do_add_legend=False)

# %%
fig,ax=plt.subplots(figsize=(10,8))
for sam,slabel,scolor in zip([ovarlaySamples['cosmic'],ovarlaySamples['CC 1p 0pi']]
                             ,['cosmic data',r'$CC1p0\pi$ MC']
                             ,['red','blue']):
    theta_12 = sam['theta_12']
    plt.hist(theta_12,bins=linspace(0,180,51),color=scolor,linewidth=3,histtype='step')
    plt.plot([0,0],[0,0],color=scolor,linewidth=3,label=slabel)
set_axes(ax,r'$\theta_{1,2}$ [deg.]','counts',do_add_grid=True,do_add_legend=False)

# %%
fig,ax=plt.subplots(figsize=(10,8))
for sam,slabel,scolor in zip([ovarlaySamples['cosmic'],ovarlaySamples['CC 1p 0pi']]
                             ,['cosmic data',r'$CC1p0\pi$ MC']
                             ,['red','blue']):
    delta_phi = sam['delta_phi']
    plt.hist(delta_phi,bins=linspace(0,360,51),color=scolor,linewidth=3,histtype='step')
    plt.plot([0,0],[0,0],color=scolor,linewidth=3,label=slabel)
set_axes(ax,r'$\Delta \phi$ [deg.]','counts',do_add_grid=True,do_add_legend=False)

# %%
fig,ax=plt.subplots(figsize=(10,8))
for sam,slabel,scolor in zip([ovarlaySamples['cosmic'],ovarlaySamples['CC 1p 0pi']]
                             ,['cosmic data',r'$CC1p0\pi$ MC']
                             ,['red','blue']):
    reco_Pt = sam['reco_Pt']
    plt.hist(reco_Pt,bins=linspace(0,1.6,51),color=scolor,linewidth=3,histtype='step')
    plt.plot([0,0],[0,0],color=scolor,linewidth=3,label=slabel)
set_axes(ax,r'reconstructed $p_t$ [GeV/c]','counts',do_add_grid=True,do_add_legend=False)

# %% [markdown]
# # PIDa

# %%
default_uB_tracks = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_cosmic_uboone_mcc8.7_reco2_dev_tracks.csv')
overlay_v4_tracks = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_uboone_overlay_mcc8_v4_tracks.csv')
overlay_v5_tracks = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_uboone_overlay_mcc8_v5_tracks.csv')
overlay_v6_tracks = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_uboone_overlay_mcc8_v6_tracks.csv')
overlay_v7_tracks = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_uboone_overlay_mcc8_v7_tracks.csv')
overlay_v9_tracks = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_uboone_overlay_mcc8_v9_tracks.csv')
overlay_v8_tracks = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_uboone_overlay_mcc8_v8_tracks.csv')

# %%
overlay_v4_proton_tracks = overlay_v4_tracks[overlay_v4_tracks['pdg']==2212]
print len(overlay_v4_proton_tracks),'proton tracks in overlay v4'

overlay_v5_proton_tracks = overlay_v5_tracks[overlay_v5_tracks['pdg']==2212]
print len(overlay_v5_proton_tracks),'proton tracks in overlay v5'


overlay_v6_proton_tracks = overlay_v6_tracks[overlay_v6_tracks['pdg']==2212]
print len(overlay_v6_proton_tracks),'proton tracks in overlay v6'


overlay_v7_proton_tracks = overlay_v7_tracks[overlay_v7_tracks['pdg']==2212]
print len(overlay_v7_proton_tracks),'proton tracks in overlay v7'



overlay_v8_proton_tracks = overlay_v8_tracks[overlay_v8_tracks['pdg']==2212]
print len(overlay_v8_proton_tracks),'proton tracks in overlay v8'



overlay_v9_proton_tracks = overlay_v9_tracks[overlay_v9_tracks['pdg']==2212]
print len(overlay_v9_proton_tracks),'proton tracks in overlay v9'



default_uB_proton_tracks = default_uB_tracks[default_uB_tracks['pdg']==2212]
print len(default_uB_proton_tracks),'proton tracks in default uB sample'


# overlay_muon_tracks = overlay_tracks[np.abs(overlay_tracks['pdg'])==13]
# print len(overlay_muon_tracks),'proton tracks'
# Out:
# 450 proton tracks in overlay v4
# 808 proton tracks in overlay v5
# 1410 proton tracks in overlay v6
# 1173 proton tracks in overlay v7
# 1527 proton tracks in overlay v8
# 1479 proton tracks in overlay v9
# 415 proton tracks in default uB sample

# %%
fig=plt.figure(figsize=(15,9))

ax = fig.add_subplot(111)
for PIDa,vlabel,color in zip([overlay_v8_proton_tracks['pid_PIDaYplane'],overlay_v9_proton_tracks['pid_PIDaYplane'],overlay_v9_proton_tracks['calipid_PIDaYplane']]
                            ,['v8 (no DetSim gain) - calo','v9 (with DetSim gain) - calo','v9 (with DetSim gain) - cali']
                            ,['black','royalblue','tomato','forestgreen']):
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=vlabel)
set_axes(ax,r'$PID_a$ (truth protons)','counts',do_add_grid=True,do_add_legend=True)

# %%
fig=plt.figure(figsize=(24,12))

ax = fig.add_subplot(2,3,1)
for var,vlabel,color in zip(['pid_PIDaYplane','calipid_PIDaYplane']                    
                            ,['calo','cali']
                            ,['black','royalblue','tomato','forestgreen']):
    PIDa = default_uB_proton_tracks[var]
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=vlabel)
set_axes(ax,r'$PID_a$ (truth protons)','counts',do_add_grid=True,do_add_legend=True
         ,title='default $\\mu$B sample') #prodgenie_bnb_nu_cosmic_uboone_mcc8.7_reco2_dev

ax = fig.add_subplot(2,3,2)
for var,vlabel,color in zip(['pid_PIDaYplane','calipid_PIDaYplane']                    
                            ,['calo','cali']
                            ,['tomato','forestgreen']):
    PIDa = overlay_v4_proton_tracks[var]
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=vlabel)
set_axes(ax,r'$PID_a$ (truth protons)','',do_add_grid=True,do_add_legend=True,legend_loc='upper left'
         ,title='overlay v4')



ax = fig.add_subplot(2,3,3)
for var,vlabel,color in zip(['pid_PIDaYplane','calipid_PIDaYplane']                    
                            ,['calo','cali']
                            ,['tomato','forestgreen']):
    PIDa = overlay_v6_proton_tracks[var]
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=vlabel)
set_axes(ax,r'$PID_a$ (truth protons)','',do_add_grid=True,do_add_legend=True,legend_loc='upper left'
         ,title='overlay v6')
plt.tight_layout()


ax = fig.add_subplot(2,3,4)
for var,vlabel,color in zip(['pid_PIDaYplane','calipid_PIDaYplane']                    
                            ,['calo','cali']
                            ,['tomato','forestgreen']):
    PIDa = overlay_v7_proton_tracks[var]
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=vlabel)
set_axes(ax,r'$PID_a$ (truth protons)','',do_add_grid=True,do_add_legend=True,legend_loc='upper left'
         ,title='overlay v7') #prodgenie_bnb_nu_uboone_overlay_mcc8_v7_reco2
plt.tight_layout()





ax = fig.add_subplot(2,3,5)
for var,vlabel,color in zip(['pid_PIDaYplane','calipid_PIDaYplane']                    
                            ,['calo','cali']
                            ,['tomato','forestgreen']):
    PIDa = overlay_v8_proton_tracks[var]
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=vlabel)
set_axes(ax,r'$PID_a$ (truth protons)','',do_add_grid=True,do_add_legend=True,legend_loc='upper left'
         ,title='overlay v8')



ax = fig.add_subplot(2,3,6)
for var,vlabel,color in zip(['pid_PIDaYplane','calipid_PIDaYplane']                    
                            ,['calo','cali']
                            ,['tomato','forestgreen']):
    PIDa = overlay_v9_proton_tracks[var]
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=vlabel)
set_axes(ax,r'$PID_a$ (truth protons)','',do_add_grid=True,do_add_legend=True,legend_loc='upper left'
         ,title='overlay v9') #prodgenie_bnb_nu_uboone_overlay_mcc8_v7_reco2
plt.tight_layout()

# %%
fig=plt.figure(figsize=(20,8))
ax = fig.add_subplot(1,2,1)
for var,vlabel,color in zip(['pid_PIDaYplane','calipid_PIDaYplane']
                            ,['pandoraNupid','pandoraNucalipid']
                            ,['black','royalblue','tomato','forestgreen']):
    PIDa = muon_tracks[var]
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=vlabel)
set_axes(ax,r'$PID_a$ (truth muons)','counts',do_add_grid=True,do_add_legend=True)    

ax = fig.add_subplot(1,2,2)
for var,vlabel,color in zip(['pid_PIDaYplane','calipid_PIDaYplane']                    
                            ,['pandoraNupid','pandoraNucalipid']
                            ,['black','royalblue','tomato','forestgreen']):
    PIDa = proton_tracks[var]
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=vlabel)
set_axes(ax,r'$PID_a$ (truth protons)','counts',do_add_grid=True,do_add_legend=True)    
plt.tight_layout()

# fig=plt.figure(figsize=(20,8))
# ax = fig.add_subplot(1,2,1)
# for stracks,tlabel,color in zip([muon_tracks,proton_tracks]
#                             ,['truth muons','truth protons']
#                             ,['tomato','forestgreen']):
#     Chi2 = stracks['calipid_Chi2MuonYplane']
#     plt.hist(Chi2,bins=linspace(0,100,41),histtype='step',color=color,linewidth=3)
#     plt.plot([0,0],[0,0],color=color,linewidth=3,label=tlabel)
# set_axes(ax,r'$\chi^2_{\mu-hypothesis}$','counts',do_add_grid=True,do_add_legend=True)    

# ax = fig.add_subplot(1,2,2)
# for stracks,tlabel,color in zip([muon_tracks,proton_tracks]
#                             ,['truth muons','truth protons']
#                             ,['tomato','forestgreen']):
#     Chi2 = stracks['calipid_Chi2ProtonYplane']
#     plt.hist(Chi2,bins=linspace(0,100,41),histtype='step',color=color,linewidth=3)
#     plt.plot([0,0],[0,0],color=color,linewidth=3,label=tlabel)
# set_axes(ax,r'$\chi^2_{p-hypothesis}$','counts',do_add_grid=True,do_add_legend=True)    

# plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-73739896885d> in <module>()
#       4                             ,['pandoraNupid','pandoraNucalipid']
#       5                             ,['black','royalblue','tomato','forestgreen']):
# ----> 6     PIDa = muon_tracks[var]
#       7     plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
#       8     plt.plot([0,0],[0,0],color=color,linewidth=3,label=vlabel)
#
# NameError: name 'muon_tracks' is not defined

# %%
proton_tracks_PIDa_push_up = proton_tracks[(proton_tracks['calipid_PIDaYplane'] - proton_tracks['pid_PIDaYplane'] > 5) & (np.abs(proton_tracks['calipid_PIDaYplane']-22)<1)]
proton_tracks_PIDa_push_up[['run','subrun','event','track_id']]
# Out:
#        run  subrun  event  track_id
# 627   7006      17    892         0
# 2120  7006     547  27355         3
# 4563  7006     436  21810         0
# 4635  7006     436  21827         2

# %% [markdown]
# # pmtrack vs. pandoraNu

# %%
tracks_pandoraNu = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/tracks/prodgenie_bnb_nu_uboone_overlay_mcc8_v4_2018_04_18_tracks.csv')
tracks_pmtrack = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/tracks/prodgenie_bnb_nu_uboone_ovrelay_v4_pmtracks_tracks.csv')

# %%
var = 'PIDa'
fig,ax=plt.subplots(figsize=(12,8))
for sample,slabel,color in zip([tracks_pandoraNu,tracks_pmtrack]
                               ,['pandoraNu','pmtrack']
                               ,['black','royalblue','tomato','forestgreen']):
    sample_protons = sample[sample['pdg']==2212]
    PIDa = sample_protons[sample_protons[var]>0][var]
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=slabel)
set_axes(ax,r'calibrated $PID_a (proton-candidate)$','counts',do_add_grid=True,do_add_legend=True)

# %%
Overlay_pandoraNu = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/ccqe_candidates/prodgenie_bnb_nu_uboone_overlay_mcc8_v4_2018_04_18_vertices.csv')
Overlay_pmtrack = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/ccqe_candidates/prodgenie_bnb_nu_uboone_ovrelay_v4_pmtracks_vertices.csv')

# %%
Overlay_pandoraNu['pidcali_PIDaCaliYplane_pCandidate'] = Overlay_pandoraNu['pandoraNucalipidCaliYplane_assigned_proton']

# %%
var = 'pidcali_PIDaCaliYplane_pCandidate'
fig,ax=plt.subplots(figsize=(12,8))
for sample,slabel,color in zip([Overlay_pandoraNu,Overlay_pmtrack]
                               ,['pandoraNu','pmtrack']
                               ,['black','royalblue','tomato','forestgreen']):
    sample_protons = sample[sample['pdg_large_PIDa']==2212]
    PIDa = sample_protons[sample_protons[var]>0][var]
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=slabel)
set_axes(ax,r'calibrated $PID_a (proton-candidate)$','counts',do_add_grid=True,do_add_legend=True)

# %% [markdown]
# # my calculation of PIDa vs. pandoraNupid calculation of PIDa

# %%
# OffBeam = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/ccqe_candidates/prod_reco_optfilter_bnb_v12_unblind_mcc8_05_2018_04_18_vertices.csv')
Overlay = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_uboone_ovrelay_v4_vertices.csv')
# proton_tracks = Overlay[Overlay['pdg']==2212]
# print len(proton_tracks),'protons'
# muon_tracks = Overlay[Overlay['pdg']==13]
# print len(muon_tracks),'muons'

# %%
fig,ax=plt.subplots(figsize=(12,8))
for var,vlabel,color in zip(['PIDa_pCandidate','PIDaCali_pCandidate','PIDaCaliYplane_pCandidate','pidcali_PIDa_pCandidate','pidcali_PIDaYplane_pCandidate']
                           ,['uncalibrated mean PIDa (best plane)','mean PIDa (best plane)','mean PIDa (Y plane)','median (pNuCali) PIDa (best plane)','median (pNuCali) PIDa (Y plane)']
                            ,['black','royalblue','tomato','forestgreen']):
#     PIDa = OffBeam[OffBeam[var]>0][var]
    PIDa = Overlay[Overlay[var]>0][var]
    plt.hist(PIDa,bins=linspace(0,40,41),histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=vlabel)
set_axes(ax,r'calibrated $PID_a (proton-candidate)$','counts',do_add_grid=True,do_add_legend=True)

# %% [markdown]
# # fit Gaussian to histogram

# %%
import ROOT
# Out:
# Welcome to ROOTaaS 6.06/02

# %%
gauss = ROOT.TF1("gaussian","exp(-(x-0)**2/(2*(1**2)))",-3,3)
gauss.SetParameters(0.,1.,3);
c = ROOT.TCanvas("myCanvas","Canvas Title",800,600)
gauss.Draw()
c.Draw()

# %%
# Create Gaussian Dataset
mu=0
sigma=1

x = np.random.normal(mu,sigma,2000)
h,bins = np.histogram(x,bins=linspace(-3,3,30))
mid = 0.5*(bins[1:]+bins[:-1])


plt.bar(mid,h,width=(mid[1]-mid[0]))
# Out:
# <Container object of 29 artists>

# %%
from scipy.optimize import leastsq
from scipy.stats import norm                                                                                                                                                                                                                                                                                                                                                                                                                   
from scipy.optimize import curve_fit

# %%
mu=0
sigma=1

x = np.random.normal(mu,sigma,2000)
h,bins = np.histogram(x,bins=100,normed=1)
mid = 0.5*(bins[1:]+bins[:-1])

# %%
fitfunc  = lambda p, x: p[0]*exp(-0.5*((x-p[1])/p[2])**2)+p[3]
errfunc  = lambda p, x, y: (y - fitfunc(p, x))

# %%
fig,ax=plt.subplots(figsize=(12,6))
plt.bar(mid,h,width=mid[1]-mid[0])
xdata = mid
ydata = h
pars, cov = curve_fit(lambda x, mu, sig : norm.pdf(x, loc=mu, scale=sig), xdata, ydata, p0=[0.2,2.])  
ax.plot(xdata, norm.pdf(xdata,*pars), 'k--',linewidth = 2, label='fit before')    
set_axes(ax,'x',title=r'$\mu=%.3f \pm %.3f, \sigma=%.3f \pm %.3f$'%(pars[0],np.sqrt(cov[0,0]), pars[1], np.sqrt(cov[1,1 ])))

# %%
import kafe
import numpy as np
from kafe.function_library import gauss
# Out:
# /usr/local/lib/python2.7/site-packages/kafe/__init__.py:87: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py", line 162, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/usr/local/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python2.7/site-packages/traitlets/config/application.py", line 596, in launch_instance
#     app.start()
# ...

# %%
# Create Gaussian Dataset
hdataset = kafe.Dataset(title="Data for example 9",
                        axis_labels=['x', 'entries'])
mu=0
sigma=1

x = np.random.normal(mu,sigma,2000)
h,bins = np.histogram(x,bins=100)
mid = 0.5*(bins[1:]+bins[:-1])
hdataset = kafe.Dataset(data=[mid,h]);
# hdataset.read_from_file('hdataset.dat')


# error for bins with zero contents is set to 1.
covmat = hdataset.get_cov_mat('y')
for i in range(0, len(covmat)):
    if covmat[i, i] == 0.:
        covmat[i, i] = 1.
hdataset.set_cov_mat('y', covmat) # write it back

# Create the Fit instance
hfit = kafe.Fit(hdataset, gauss, fit_label="Fit of a Gaussian to histogram data")

# perform an initial fit with temporary errors (minimal output)
hfit.call_minimizer(final_fit=False, verbose=False)

#re-set errors using model at pre-fit parameter values:
#        sigma_i^2=cov[i, i]=n(x_i)
fdata=hfit.fit_function.evaluate(hfit.xdata, hfit.current_parameter_values)
np.fill_diagonal(covmat, fdata)
hfit.current_cov_mat = covmat  # write back new covariance matrix

# now do final fit with full output
hfit.do_fit(quiet=True)

hplot = kafe.Plot(hfit)
hplot.plot_all()
hplot.show()

mu,sigma,a0 = hfit.get_parameter_values(rounding=True)
mu_err,sigma_err,a0_err = hfit.get_parameter_errors(rounding=True)
print 'mu,sigma,a0:',mu,sigma,a0
print 'mu_err,sigma_err,a0_err:',mu_err,sigma_err,a0_err
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-1b24cf7f8ce2> in <module>()
#      36
#      37 hplot = kafe.Plot(hfit)
# ---> 38 hplot.plot_all()
#      39 hplot.show()
#      40
#
# /usr/local/lib/python2.7/site-packages/kafe/plot.pyc in plot_all(self, show_info_for, show_data_for, show_function_for, show_band_for)
#     450
#     451                 self.plot(p_id, show_data=_show_data_flags[p_id],
# --> 452                   show_function=_show_function_flags[p_id], show_band=_draw_band)
#     453
#     454         if self.show_legend:
#
# /usr/local/lib/python2.7/site-packages/kafe/plot.pyc in plot(self, p_id, show_data, show_function, show_band)
#     799
#     800         # draw everything so positions are known
# --> 801         self.figure.canvas.draw()
#     802
#     803     def show(self):
#
# ...

# %% [markdown]
# # Cali ovemrlay by Adi, March-31, 2018

# %%
CaliTracks = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/tracks/prodgenie_bnb_nu_uboone_ovrelay_v4_tracks.csv')
proton_tracks = CaliTracks[CaliTracks['pdg']==2212]
print len(proton_tracks),'protons'
muon_tracks = CaliTracks[CaliTracks['pdg']==13]
print len(muon_tracks),'muons'
# Out:
# 28318 protons
# 37362 muons

# %%
len(CaliTracks)
# Out:
# 303106

# %%
fig=plt.figure(figsize=(16,8))
ax = fig.add_subplot(1,2,1)
tracks = proton_tracks
tracks = tracks[(tracks['PIDa']<100)&(tracks['PIDaCali']<100)]
# plt.scatter(tracks['PIDa'],tracks['PIDaCali']);
plot_2d_hist(tracks['PIDa'],tracks['PIDaCali'],bins=np.linspace(0,40,51),ax=ax);
plt.plot([13,13],ax.get_ylim(),'--',ax.get_xlim(),[13,13],'--',color='black')
set_axes(ax,r'$PID_a$',r'calibrated $PID_a$',title='truth protons tracks')

ax = fig.add_subplot(1,2,2)
tracks = muon_tracks
tracks = tracks[(tracks['PIDa']<100)&(tracks['PIDaCali']<100)]
# plt.scatter(tracks['PIDa'],tracks['PIDaCali']);
plot_2d_hist(tracks['PIDa'],tracks['PIDaCali'],bins=np.linspace(0,20,51),ax=ax);
plt.plot([13,13],ax.get_ylim(),'--',ax.get_xlim(),[13,13],'--',color='black')
set_axes(ax,r'$PID_a$',r'calibrated $PID_a$',title='truth muon tracks')

plt.tight_layout()

# %% [markdown]
# # trunctated dE/dx

# %%
generic = lambda x: ast.literal_eval(x)
tracks = dict()
proton_event69352 = dict()
for rad in [0,1,5,10]:
    ftracks = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/tracks/adi_prodgenie_bnb_nu_uboone_overlay_cosmic_data_100K_reco2_tracks_rad%d.csv'%rad
                                ,converters={'ResRange_Y':generic,'dEdx_Y':generic,'Truncated_dEdx_Y':generic}
                               )
    tracks['rad%d'%rad] = ftracks
    print "len(tracks['rad%d']):"%rad,len(ftracks)
    proton_event69352['rad%d'%rad] = ftracks[(ftracks['pdg']==2212)&(ftracks['event']==69352)]
    print proton_event69352['rad%d'%rad]
# Out:
# len(tracks['rad0']): 294
#       run  subrun  event  track_id  start_x  start_y  start_z    end_x  \
# 161  7004    1387  69352         3  232.897  53.2675  814.933  217.137
#
#        end_y    end_z                        ...                          \
# 161  32.2253  849.623                        ...
#
#      PIDaCali   pdg         origin    purity  max_dQinTruthMatchedHits  \
# 161        -1  2212  beam neutrino  0.977055                   53255.0
#
#      dQinAllHits Ratio_max_dQinTruthMatchedHits_dQinAllHits  \
# 161      53255.0                                        1.0
#
#                                             ResRange_Y  \
# 161  [0.111714, 0.335143, 0.632305, 1.05905, 1.5076...
#
#                                                 dEdx_Y  \
# 161  [4.72834, 26.547, 42.365, 31.1222, 22.0469, 18...
#
#                                       Truncated_dEdx_Y
# 161  [4.72834, 26.547, 42.365, 31.1222, 22.0469, 18...
#
# [1 rows x 24 columns]
# len(tracks['rad1']): 294
# ...

# %%
protons = tracks[tracks['pdg']==2212]
muons = tracks[tracks['pdg']==13]
pions = tracks[tracks['pdg']==211]
print len(protons),'protons',len(muons),'muons',len(pions),'pi+'
# Out:
# 21 protons 36 muons 4 pi+

# %%
fig,ax = plt.subplots(figsize=(20,12))
for i,particle in proton_event69352['rad%d'%rad].iterrows():
    dEdx_Y = particle['dEdx_Y']
    ResRange_Y = particle['ResRange_Y']
    #     plot_2d_hist(ResRange_Y,dEdx_Y,bins=(np.linspace(0,20,41),np.linspace(0,20,101)),ax=ax,cmap='hot_r');
ax.plot(ResRange_Y,dEdx_Y,'--o',markersize=10,color='black',label='regular dE/dx');
        
for rad in [0,1,5,10]:
    for i,particle in proton_event69352['rad%d'%rad].iterrows():
        Truncated_dEdx_Y = particle['Truncated_dEdx_Y']
#         ax.scatter(ResRange_Y,Truncated_dEdx_Y,s=50,label='truncated dE/dx, rad=%d'%rad);        
        ax.plot(ResRange_Y,Truncated_dEdx_Y,'-',markersize=10,label='truncated dE/dx, rad=%d cm'%rad);        
        
set_axes(ax,r'residual range [cm]',r'dE/dx [MeV/cm]',title='proton track',do_add_grid=True,do_add_legend=True,xlim=(-1,25))

# %% [markdown]
# # RdQ around vertex - in a sphere of radius r [cm]

# %%
pairs = pd.read_csv("/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/adi_prodgenie_bnb_nu_uboone_overlay_cosmic_data_100K_reco2_vertices.csv")
print len(pairs),'pairs'
cosmic_pairs = pairs[pairs['cosmic']==True]
mup_pairs = pairs[pairs['1mu-1p']==True]
CC1p0pi_pairs = pairs[pairs['CC 1p 0pi']==True]
# Out:
# 2623 pairs

# %%
r=6.0 # [cm]
fig=plt.figure(figsize=(24,8))
for i,(sample,s_label) in enumerate(zip([cosmic_pairs,mup_pairs,CC1p0pi_pairs]
                              ,['cosmic',r'$\mu p$',r'$CC 1p 0\pi$'])):
    ax = fig.add_subplot(1,3,i+1)
    plane = 2
#     plt.hist(sample['RdQaroundVertex[plane %d][r=%.1fcm]'%(plane,r)],bins=np.linspace(-0.1,1.1,30));
    plot_2d_hist(sample['RdQaroundVertex[plane 2][r=%.1fcm]'%r],sample['RdQaroundVertex[plane 1][r=%.1fcm]'%r]
                 ,bins=np.linspace(-0.1,1.1,41),ax=ax,norm='log');
#     plt.scatter(sample['RdQaroundVertex[plane 1][r=%.1fcm]'%r],sample['RdQaroundVertex[plane 2][r=%.1fcm]'%r])
    set_axes(ax,r'$R_{\Delta Q}^{plane-1}(r=%.1f$ cm$)$'%(r),r'$R_{\Delta Q}^{plane-2}(r=%.1f$ cm$)$'%(r)
             ,title=s_label+" (%d pairs)"%len(sample)
             ,xlim=(-0.1,1.1),ylim=(-0.1,1.1),xticks=[0,0.3,0.6,0.9]
            )
    
plt.tight_layout()

# %% [markdown]
# # can we improve the flash-cuts?
# Check by ploting the cuts-figure after all other detection cuts

# %%
reduced = dict()
PIDa_p_min = 13
delta_theta_12 = 55
r_max_RdQ_CC1p0pi = 0.33
opt_box=(50,100)
box_str='[%d wires x %d ticks]'%(opt_box[0],opt_box[1])
Ru,Rv,Ry = 'RdQaroundVertex[plane 0]'+box_str,'RdQaroundVertex[plane 1]'+box_str,'RdQaroundVertex[plane 2]'+box_str

fig = plt.figure(figsize=(28,16))
bins=(np.linspace(0,4,30),np.linspace(0,400,30))
minPEcut = 0.1
maxdYZcut = 200


for i,(pair_type,label,cmap,color) in enumerate(zip(pair_types,MClabels,MCcmaps,MCcolors)):
    sam = MCbnbDATAcosmicSamples[pair_type]
    sam = sam[(sam['PIDa_assigned_proton']>PIDa_p_min)&(sam['Nflashes']>0)]
    reduced[pair_type] = sam[(sam['PIDa_long'] < sam['PIDa_short'])                             
                             &(np.abs(sam['theta_12']-90)<delta_theta_12)                             
                             &((sam[Ru]==1) | (sam[Rv]==1) | (sam[Ry]==1)                                                                           
                               | (np.sqrt( np.square(sam[Ru]-1) + np.square(sam[Rv]-1) + np.square(sam[Ry]-1) )                                
                                  <= r_max_RdQ_CC1p0pi))
                            ]
    for i_sample,sample in enumerate([sam,reduced[pair_type]]):
        ax = fig.add_subplot(2,4,i+1+4*i_sample)
        plot_2d_hist(0.001*sample['ClosestFlash_TotalPE'], sample['ClosestFlash_YZdistance'], ax=ax,bins=bins,cmap=cmap)
        set_axes(ax,r'$N_{closest-flash}^{PE}$ [kPE]',r'$d_{closest-flash}^{YZ-plane}$ [cm]' if i==0 else '',fontsize=45
                 ,xticks=[1,2,3,4],yticks=[0,100,200,300]
                )
        ax.set_title(label,fontsize=45,y=1.02,color=color)
        ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%.0f'))
        ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.0f') if i==0 else ticker.NullFormatter())    
    
        ax.plot([minPEcut,minPEcut],[np.min(ax.get_ylim()),maxdYZcut],'-'
                ,[minPEcut,np.max(ax.get_xlim())],[maxdYZcut,maxdYZcut],'-',color='black')
        
plt.tight_layout()

# %% [markdown]
# # PIDa calibrated vs. uncalibrated

# %%
tracks_mcc86 = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/tracks/prodgenie_bnb_nu_uboone_mcc8.6_reco2_dev_tracks.csv')
proton_tracks = tracks_mcc86[tracks_mcc86['pdg']==2212]
muon_tracks = tracks_mcc86[tracks_mcc86['pdg']==13]

# %%
fig=plt.figure(figsize=(20,8))
ax = fig.add_subplot(1,2,1)
plot_2d_hist(proton_tracks['PIDa'],proton_tracks['PIDaCali']
             ,bins=(np.linspace(0,30,61),np.linspace(0,30,61)),ax=ax);
ax.plot([0,30],[0,30],'--',color='black')
set_axes(ax,r'uncalibrated $PID_a^{p}$',r'calibrated $PID_a^{p}$',do_add_grid=True,title='truth-protons')

ax = fig.add_subplot(1,2,2)
plot_2d_hist(muon_tracks['PIDa'],muon_tracks['PIDaCali']
             ,bins=(np.linspace(0,15,61),np.linspace(0,15,61)),ax=ax);
ax.plot([0,30],[0,30],'--',color='black')
set_axes(ax,r'uncalibrated $PID_a^{\mu}$',r'calibrated $PID_a^{\mu}$',do_add_grid=True,title='truth-muons')

plt.tight_layout()
plt.savefig('/Users/erezcohen/Desktop/stopped_muons_protons_cali_uncali_PIDa.pdf')

# %% [markdown]
# # flash information

# %%
fig=plt.figure(figsize=(18,8))
for sample,color,s_label in zip(['cosmic','CC 1p 0pi']
                                ,['tomato','royalblue']
                                ,['Cosmic pairs',r'$CC 1p 0\pi$ pairs']):
    sam = MCbnbDATAcosmicSamples[sample]
    sam = sam[sam['PIDa_assigned_proton']>12]
    print len(sam),sample,'pairs'
    ax=fig.add_subplot(1,2,1)
    plt.hist(sam['Nflashes'],bins=[0,1,2,3,4,5]
             ,color=color,histtype='step',linewidth=3,label=s_label);
    set_axes(ax,r'$N_{flashes}$',do_add_grid=True,do_add_legend=True,xticks=[0,1,2,3,4])
    print len(sam[sam['Nflashes']>0]),sample,'pairs in event with at least one flash'
    
    ax=fig.add_subplot(1,2,2)
    plt.hist(sam['ClosestFlash_Time'],bins=np.linspace(-1,11,21)
             ,color=color,histtype='step',linewidth=3,label=s_label);
    set_axes(ax,r'$t_{flash}$ [$\mu$sec]',do_add_grid=True)
# Out:
# 1587 cosmic pairs
# 1173 cosmic pairs in event with at least one flash
# 1733 CC 1p 0pi pairs
# 1727 CC 1p 0pi pairs in event with at least one flash

# %% [markdown]
# # games w/ pairs

# %% [markdown]
# # pairs of tracks at close proximity

# %%
MCbnbDATAcosmicPairsFV, MCbnbDATAcosmicSamples = load_MCbnbDATAcosmicSamples()
# Out:
# 50939 pairs from MC-BNB + cosmic DATA overlay
# 30377 pairs in FV
# 3814 are 1mu-1p, 12.6%
# 4001 are other pairs, 13.2%
# 22562 are cosmic, 74.3%
# --------------------------------------------------------------
# 1234 are CC 1p 0pi, 4.1%

# %%
MCbnbMCcosmicPairsFV, MCbnbMCcosmicSamples = load_MCbnbMCcosmicSamples()
# Out:
# 138749 pairs from MC-BNB + cosmic MC overlay
# 95676 pairs in FV
# 19573 are 1mu-1p, 20.5%
# 16269 are other pairs, 17.0%
# 59944 are cosmic, 62.7%
# --------------------------------------------------------------
# 7561 are CC 1p 0pi, 7.9%

# %%
pureff_MCbnbDATAcosmic,pureff_MCbnbDATAcosmic_numbers,pureff_MCbnbMCcosmic,pureff_MCbnbMCcosmic_numbers = apply_cuts()

# %% [markdown]
# # $PID_a$ for cosmic muons vs. muons from the neutrino interaction: this is valid only for MC/MC overlay

# %%
muons_from_beam = MCbnbMCcosmicSamples['1mu-1p'][MCbnbMCcosmicSamples['1mu-1p']['pdg_long']==13]
muons_from_cosmic = MCbnbMCcosmicSamples['cosmic'][MCbnbMCcosmicSamples['cosmic']['pdg_long']==13]

# %%
fig,ax=plt.subplots(figsize=(12,8))
bins=np.linspace(0,20,31)
for sample,color,label in zip([muons_from_beam,muons_from_cosmic]
                              ,['royalblue','tomato']
                              ,['beam-induced muons','cosmic-induced muons']):
    plt.hist(sample['PIDa_assigned_muon'],bins=bins,histtype='step',color=color,linewidth=3)
    plt.plot([0,0],[0,0],color=color,linewidth=3,label=label)
set_axes(ax,r'$PID_a^{\mu}$',do_add_legend=True,title='comparison of truth-muons from different origins')

fig=plt.figure(figsize=(16,8))
bins=(np.linspace(0.1,1.5,51),np.linspace(0,12,51))
for i,(sample,cmap,label) in enumerate(zip([muons_from_beam,muons_from_cosmic]
                                          ,['Blues','Reds']
                                          ,['beam-induced muons','cosmic-induced muons'])):
    ax = fig.add_subplot(1,2,i+1)
    plt.hist2d(sample['truth_Pmu'],sample['PIDa_assigned_muon'],bins=bins,cmap=cmap)
    set_axes(ax,r'$p_{\mu}$ [GeV/c]',r'$PID_a^{\mu}$',do_add_legend=True,title=label)
plt.tight_layout()

# %% [markdown]
# # $\Delta \phi$

# %%
sam = MCbnbMCcosmicSamples['1mu-1p']
plt.hist(sam['delta_phi'],bins=100);
sam = MCbnbMCcosmicSamples['CC 1p 0pi']
plt.hist(sam['delta_phi'],bins=100);

# %%
sam = MCbnbDATAcosmicSamples['1mu-1p']
sam['truth_Pp_theta'] = np.arccos( sam['truth_Pp_z'] / sam['truth_Pp'] )
sam['truth_Pmu_theta'] = np.arccos( sam['truth_Pmu_z'] / sam['truth_Pmu'] )

fig = plt.figure(figsize=(16,8))
ax=fig.add_subplot(1,2,1)
plot_2d_hist(sam['truth_Pp'],180/np.pi*sam['truth_Pp_theta'],bins=(np.linspace(0,1.5,50),np.linspace(0,180,50)),ax=ax);
set_axes(ax,r'$p_p$ [GeV/c]',r'$\theta_p$ [deg.]',title='MC-BNB / DATA cosmic')
ax=fig.add_subplot(1,2,2)
plot_2d_hist(sam['truth_Pmu'],180/np.pi*sam['truth_Pmu_theta'],bins=(np.linspace(0,1.5,50),np.linspace(0,180,50)),ax=ax);
set_axes(ax,r'$p_\mu$ [GeV/c]',r'$\theta_\mu$ [deg.]',title='MC-BNB / DATA cosmic')
plt.tight_layout()


sam = MCbnbMCcosmicSamples['1mu-1p']
sam['truth_Pp_theta'] = np.arccos( sam['truth_Pp_z'] / sam['truth_Pp'] )
sam['truth_Pmu_theta'] = np.arccos( sam['truth_Pmu_z'] / sam['truth_Pmu'] )

fig = plt.figure(figsize=(16,8))
ax=fig.add_subplot(1,2,1)
plot_2d_hist(sam['truth_Pp'],180/np.pi*sam['truth_Pp_theta'],bins=(np.linspace(0,1.5,50),np.linspace(0,180,50)),ax=ax);
set_axes(ax,r'$p_p$ [GeV/c]',r'$\theta_p$ [deg.]',title='MC-BNB / MC cosmic')
ax=fig.add_subplot(1,2,2)
plot_2d_hist(sam['truth_Pmu'],180/np.pi*sam['truth_Pmu_theta'],bins=(np.linspace(0,1.5,50),np.linspace(0,180,50)),ax=ax);
set_axes(ax,r'$p_\mu$ [GeV/c]',r'$\theta_\mu$ [deg.]',title='MC-BNB / MC cosmic')
plt.tight_layout()
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sample = MCbnbMCcosmicSamples['1mu-1p']
# plot_2d_hist(sample['reco_Pmu_z'],sample['truth_Pmu_z'],bins=(np.linspace(-1.,1.,50),np.linspace(-.5,1.,50)));
flipped_muons = sample[np.abs(sample['reco_Pmu_z'] + sample['truth_Pmu_z']) < 0.05]
plot_2d_hist(flipped_muons['reco_Pmu_z'],flipped_muons['truth_Pmu_z'],bins=(np.linspace(-1.,1.,50),np.linspace(-.5,1.,50)));

# %% [markdown]
# # $p_t$ vs. $p_{miss}$

# %%
# small_overlay_sample = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_uboone_overlay_mcc8_reco2_vertices.csv')
small_overlay_sample = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/ccqe_candidates/prodgenie_bnb_nu_uboone_overlay_mcc8_reco2_vertices.csv')

# %%
samples = dict()
samples['1mu-1p'] = small_overlay_sample[small_overlay_sample['1mu-1p']==True]
samples['CC 1p 0pi'] = small_overlay_sample[small_overlay_sample['CC 1p 0pi']==True]

# %%
fig = plt.figure(figsize=(28,12))
bins=(np.linspace(0,1.0,35),np.linspace(0,1.0,35))
for i,index in enumerate([0,3]):
    pair_type = pair_types[index]
    label = MClabels[index]; cmap = MCcmaps[index]; color = MCcolors[index]
    sam = samples[pair_type]
    ax = fig.add_subplot(1,2,i+1)
    ax.set_title(label,fontsize=45,y=1.02,color=color)
    plot_2d_hist(sam['reco_Pmiss'], 
                 sam['reco_Pt'],
                 ax=ax,fontsize=25,ticks_color='black',bins=bins,cmap=cmap,norm='')            
    set_axes(ax,x_label=r'$p_{miss}$ [GeV/c]', y_label=r'$p_{t}$ [GeV/c]' if i==0 else ''
             ,xticks=[0.2,0.4,0.6,0.8]
             ,fontsize=45,do_add_grid=True)
    ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f') if i==0 else ticker.NullFormatter())    
plt.tight_layout()
fig.savefig('/Users/erezcohen/Desktop/Projects/uBoone/write-ups/mupClassification/Appendices/ResponseToReviewers/Figures/Pmiss_vs_Pt.pdf')

# %%
fig = plt.figure(figsize=(28,12))
bins=(np.linspace(0,1.0,35),np.linspace(0,1.0,35))
for i,index in enumerate([0,3]):
    pair_type = pair_types[index]
    label = MClabels[index]; cmap = MCcmaps[index]; color = MCcolors[index]
    sam = samples[pair_type]
    ax = fig.add_subplot(1,2,i+1)
    ax.set_title(label,fontsize=45,y=1.02,color=color)
    plt.scatter(sam['reco_Pmiss_t'], 
                 sam['reco_Pt'])
#     plot_2d_hist(sam['reco_Pmiss_t'], 
#                  sam['reco_Pt'],
#                  ax=ax,fontsize=25,ticks_color='black',bins=bins,cmap=cmap,norm='')            
    set_axes(ax,x_label=r'$(p_{miss})_t$ [GeV/c]', y_label=r'$p_{t}$ [GeV/c]' if i==0 else ''
#              ,xticks=[0.5,1.,1.5,2.]
             ,fontsize=45,do_add_grid=True)
    ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f') if i==0 else ticker.NullFormatter())    
plt.tight_layout()

# %% [markdown]
# # new sample

# %%
new_samlpe = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_uboone_overlay_mcc8.4_reco2_vertices.csv')

# %%
new_samlpe['pdg_long']
# Out:
# 0    -9999
# 1    -9999
# 2    -9999
# 3    -9999
# 4    -9999
# 5    -9999
# 6    -9999
# 7    -9999
# 8    -9999
# 9    -9999
# 10   -9999
# 11   -9999
# 12   -9999
# 13   -9999
# 14   -9999
# 15   -9999
# 16   -9999
# 17   -9999
# Name: pdg_long, dtype: int64
