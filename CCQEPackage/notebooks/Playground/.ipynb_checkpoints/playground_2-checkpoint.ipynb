# %%
import sys; sys.path.insert(0, '../'); sys.path.insert(0, 'analysis_notes/mupClassification/'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
# %matplotlib inline

# %% [markdown]
# # WTF is wrong with $l_\mu$?

# %%
overlay = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/ccqe_candidates/2018_05_11/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_05_11_vertices.csv')
mup = overlay[overlay['1mu-1p']==True]

# %%
for col in mup_bad_l_mu.columns: print col
# Out:
# Unnamed: 0
# run
# subrun
# event
# vertex_id
# x
# y
# z
# track_id
# PIDa_muCandidate
# PIDa_pCandidate
# l_muCandidate
# l_pCandidate
# l_mu-l_p
# pid_PIDa_muCandidate
# pid_PIDa_pCandidate
# pid_PIDaYplane_muCandidate
# pid_PIDaYplane_pCandidate
# pidcali_PIDa_muCandidate
# pidcali_PIDa_pCandidate
# pidcali_PIDaYplane_muCandidate
# pidcali_PIDaYplane_pCandidate
# pidcali_Chi2ProtonYplane_muCandidate
# pidcali_Chi2ProtonYplane_pCandidate
# pidcali_Chi2MuonYplane_muCandidate
# pidcali_Chi2MuonYplane_pCandidate
# ClosestFlash_YZdistance_muCandidate
# ClosestFlash_YZdistance_pCandidate
# ClosestFlash_TotalPE_muCandidate
# ClosestFlash_TotalPE_pCandidate
# startx_muCandidate
# starty_muCandidate
# startz_muCandidate
# startx_pCandidate
# starty_pCandidate
# startz_pCandidate
# endx_muCandidate
# endy_muCandidate
# endz_muCandidate
# endx_pCandidate
# endy_pCandidate
# endz_pCandidate
# distance
# delta_phi
# delta_theta
# theta_12
# reco_Ev
# reco_Q2
# reco_Xb
# reco_y
# reco_W2
# reco_Pt
# reco_theta_pq
# reco_Pmu
# reco_Pmu_x
# reco_Pmu_y
# reco_Pmu_z
# reco_Pmu_theta
# reco_Pmu_phi
# reco_Pp
# reco_Pp_x
# reco_Pp_y
# reco_Pp_z
# reco_Pp_theta
# reco_Pp_phi
# PmuHypothesisCalc
# PpHypothesisCalc
# reco_Pmiss
# reco_Pmiss_x
# reco_Pmiss_y
# reco_Pmiss_z
# reco_Pmiss_t
# truth_l_muCandidate
# truth_l_pCandidate
# truth_purity_muCandidate
# truth_purity_pCandidate
# truth_Pmu
# truth_Pmu_x
# truth_Pmu_y
# truth_Pmu_z
# truth_Pmu_theta
# truth_Pmu_phi
# truth_Pp
# truth_Pp_x
# truth_Pp_y
# truth_Pp_z
# truth_Pp_theta
# truth_Pp_phi
# genie_distance
# truth_Ev
# truth_Q2
# truth_Xb
# truth_y
# truth_W2
# truth_Pt
# truth_theta_pq
# genie_mode
# closest_genie_distance
# closest_genie_Ev
# closest_genie_Q2
# closest_genie_Xb
# closest_genie_y
# closest_genie_W2
# closest_genie_Pt
# closest_genie_theta_pq
# closest_genie_mode
# truth_delta_phi
# pdg_long
# pdg_short
# pdg_small_PIDa
# pdg_large_PIDa
# RdQaroundVertex[plane 0][5 wires x 10 ticks]
# RdQaroundVertex[plane 1][5 wires x 10 ticks]
# RdQaroundVertex[plane 2][5 wires x 10 ticks]
# RdQaroundVertex[plane 0][10 wires x 20 ticks]
# RdQaroundVertex[plane 1][10 wires x 20 ticks]
# RdQaroundVertex[plane 2][10 wires x 20 ticks]
# RdQaroundVertex[plane 0][15 wires x 30 ticks]
# RdQaroundVertex[plane 1][15 wires x 30 ticks]
# RdQaroundVertex[plane 2][15 wires x 30 ticks]
# RdQaroundVertex[plane 0][20 wires x 40 ticks]
# RdQaroundVertex[plane 1][20 wires x 40 ticks]
# RdQaroundVertex[plane 2][20 wires x 40 ticks]
# RdQaroundVertex[plane 0][25 wires x 50 ticks]
# RdQaroundVertex[plane 1][25 wires x 50 ticks]
# RdQaroundVertex[plane 2][25 wires x 50 ticks]
# RdQaroundVertex[plane 0][30 wires x 60 ticks]
# RdQaroundVertex[plane 1][30 wires x 60 ticks]
# RdQaroundVertex[plane 2][30 wires x 60 ticks]
# RdQaroundVertex[plane 0][35 wires x 70 ticks]
# RdQaroundVertex[plane 1][35 wires x 70 ticks]
# RdQaroundVertex[plane 2][35 wires x 70 ticks]
# RdQaroundVertex[plane 0][40 wires x 80 ticks]
# RdQaroundVertex[plane 1][40 wires x 80 ticks]
# RdQaroundVertex[plane 2][40 wires x 80 ticks]
# RdQaroundVertex[plane 0][45 wires x 90 ticks]
# RdQaroundVertex[plane 1][45 wires x 90 ticks]
# RdQaroundVertex[plane 2][45 wires x 90 ticks]
# RdQaroundVertex[plane 0][50 wires x 100 ticks]
# RdQaroundVertex[plane 1][50 wires x 100 ticks]
# RdQaroundVertex[plane 2][50 wires x 100 ticks]
# RdQaroundVertex[plane 0][55 wires x 110 ticks]
# RdQaroundVertex[plane 1][55 wires x 110 ticks]
# RdQaroundVertex[plane 2][55 wires x 110 ticks]
# RdQaroundVertex[plane 0][60 wires x 120 ticks]
# RdQaroundVertex[plane 1][60 wires x 120 ticks]
# RdQaroundVertex[plane 2][60 wires x 120 ticks]
# RdQaroundVertex[plane 0][65 wires x 130 ticks]
# RdQaroundVertex[plane 1][65 wires x 130 ticks]
# RdQaroundVertex[plane 2][65 wires x 130 ticks]
# RdQaroundVertex[plane 0][70 wires x 140 ticks]
# RdQaroundVertex[plane 1][70 wires x 140 ticks]
# RdQaroundVertex[plane 2][70 wires x 140 ticks]
# RdQaroundVertex[plane 0][75 wires x 150 ticks]
# RdQaroundVertex[plane 1][75 wires x 150 ticks]
# RdQaroundVertex[plane 2][75 wires x 150 ticks]
# RdQaroundVertex[plane 0][80 wires x 160 ticks]
# RdQaroundVertex[plane 1][80 wires x 160 ticks]
# RdQaroundVertex[plane 2][80 wires x 160 ticks]
# RdQaroundVertex[plane 0][85 wires x 170 ticks]
# RdQaroundVertex[plane 1][85 wires x 170 ticks]
# RdQaroundVertex[plane 2][85 wires x 170 ticks]
# RdQaroundVertex[plane 0][90 wires x 180 ticks]
# RdQaroundVertex[plane 1][90 wires x 180 ticks]
# RdQaroundVertex[plane 2][90 wires x 180 ticks]
# RdQaroundVertex[plane 0][95 wires x 190 ticks]
# RdQaroundVertex[plane 1][95 wires x 190 ticks]
# RdQaroundVertex[plane 2][95 wires x 190 ticks]
# RdQaroundVertex[plane 0][100 wires x 200 ticks]
# RdQaroundVertex[plane 1][100 wires x 200 ticks]
# RdQaroundVertex[plane 2][100 wires x 200 ticks]
# RdQaroundVertex[plane 0][105 wires x 210 ticks]
# RdQaroundVertex[plane 1][105 wires x 210 ticks]
# RdQaroundVertex[plane 2][105 wires x 210 ticks]
# RdQaroundVertex[plane 0][110 wires x 220 ticks]
# RdQaroundVertex[plane 1][110 wires x 220 ticks]
# RdQaroundVertex[plane 2][110 wires x 220 ticks]
# RdQaroundVertex[plane 0][115 wires x 230 ticks]
# RdQaroundVertex[plane 1][115 wires x 230 ticks]
# RdQaroundVertex[plane 2][115 wires x 230 ticks]
# RdQaroundVertex[plane 0][120 wires x 240 ticks]
# RdQaroundVertex[plane 1][120 wires x 240 ticks]
# RdQaroundVertex[plane 2][120 wires x 240 ticks]
# RdQaroundVertex[plane 0][125 wires x 250 ticks]
# RdQaroundVertex[plane 1][125 wires x 250 ticks]
# RdQaroundVertex[plane 2][125 wires x 250 ticks]
# RdQaroundVertex[plane 0][130 wires x 260 ticks]
# RdQaroundVertex[plane 1][130 wires x 260 ticks]
# RdQaroundVertex[plane 2][130 wires x 260 ticks]
# RdQaroundVertex[plane 0][135 wires x 270 ticks]
# RdQaroundVertex[plane 1][135 wires x 270 ticks]
# RdQaroundVertex[plane 2][135 wires x 270 ticks]
# RdQaroundVertex[plane 0][140 wires x 280 ticks]
# RdQaroundVertex[plane 1][140 wires x 280 ticks]
# RdQaroundVertex[plane 2][140 wires x 280 ticks]
# RdQaroundVertex[plane 0][145 wires x 290 ticks]
# RdQaroundVertex[plane 1][145 wires x 290 ticks]
# RdQaroundVertex[plane 2][145 wires x 290 ticks]
# RdQaroundVertex[plane 0][150 wires x 300 ticks]
# RdQaroundVertex[plane 1][150 wires x 300 ticks]
# RdQaroundVertex[plane 2][150 wires x 300 ticks]
# RdQaroundVertex[plane 0][r=0.0cm]
# RdQaroundVertex[plane 1][r=0.0cm]
# RdQaroundVertex[plane 2][r=0.0cm]
# RdQaroundVertex[plane 0][r=0.5cm]
# RdQaroundVertex[plane 1][r=0.5cm]
# RdQaroundVertex[plane 2][r=0.5cm]
# RdQaroundVertex[plane 0][r=1.0cm]
# RdQaroundVertex[plane 1][r=1.0cm]
# RdQaroundVertex[plane 2][r=1.0cm]
# RdQaroundVertex[plane 0][r=1.5cm]
# RdQaroundVertex[plane 1][r=1.5cm]
# RdQaroundVertex[plane 2][r=1.5cm]
# RdQaroundVertex[plane 0][r=2.0cm]
# RdQaroundVertex[plane 1][r=2.0cm]
# RdQaroundVertex[plane 2][r=2.0cm]
# RdQaroundVertex[plane 0][r=2.5cm]
# RdQaroundVertex[plane 1][r=2.5cm]
# RdQaroundVertex[plane 2][r=2.5cm]
# RdQaroundVertex[plane 0][r=3.0cm]
# RdQaroundVertex[plane 1][r=3.0cm]
# RdQaroundVertex[plane 2][r=3.0cm]
# RdQaroundVertex[plane 0][r=3.5cm]
# RdQaroundVertex[plane 1][r=3.5cm]
# RdQaroundVertex[plane 2][r=3.5cm]
# RdQaroundVertex[plane 0][r=4.0cm]
# RdQaroundVertex[plane 1][r=4.0cm]
# RdQaroundVertex[plane 2][r=4.0cm]
# RdQaroundVertex[plane 0][r=4.5cm]
# RdQaroundVertex[plane 1][r=4.5cm]
# RdQaroundVertex[plane 2][r=4.5cm]
# RdQaroundVertex[plane 0][r=5.0cm]
# RdQaroundVertex[plane 1][r=5.0cm]
# RdQaroundVertex[plane 2][r=5.0cm]
# RdQaroundVertex[plane 0][r=5.5cm]
# RdQaroundVertex[plane 1][r=5.5cm]
# RdQaroundVertex[plane 2][r=5.5cm]
# RdQaroundVertex[plane 0][r=6.0cm]
# RdQaroundVertex[plane 1][r=6.0cm]
# RdQaroundVertex[plane 2][r=6.0cm]
# RdQaroundVertex[plane 0][r=6.5cm]
# RdQaroundVertex[plane 1][r=6.5cm]
# RdQaroundVertex[plane 2][r=6.5cm]
# RdQaroundVertex[plane 0][r=7.0cm]
# RdQaroundVertex[plane 1][r=7.0cm]
# RdQaroundVertex[plane 2][r=7.0cm]
# RdQaroundVertex[plane 0][r=7.5cm]
# RdQaroundVertex[plane 1][r=7.5cm]
# RdQaroundVertex[plane 2][r=7.5cm]
# RdQaroundVertex[plane 0][r=8.0cm]
# RdQaroundVertex[plane 1][r=8.0cm]
# RdQaroundVertex[plane 2][r=8.0cm]
# RdQaroundVertex[plane 0][r=8.5cm]
# RdQaroundVertex[plane 1][r=8.5cm]
# RdQaroundVertex[plane 2][r=8.5cm]
# RdQaroundVertex[plane 0][r=9.0cm]
# RdQaroundVertex[plane 1][r=9.0cm]
# RdQaroundVertex[plane 2][r=9.0cm]
# RdQaroundVertex[plane 0][r=9.5cm]
# RdQaroundVertex[plane 1][r=9.5cm]
# RdQaroundVertex[plane 2][r=9.5cm]
# RdQaroundVertex[plane 0][r=10.0cm]
# RdQaroundVertex[plane 1][r=10.0cm]
# RdQaroundVertex[plane 2][r=10.0cm]
# RdQaroundVertex[plane 0][r=10.5cm]
# RdQaroundVertex[plane 1][r=10.5cm]
# RdQaroundVertex[plane 2][r=10.5cm]
# RdQaroundVertex[plane 0][r=11.0cm]
# RdQaroundVertex[plane 1][r=11.0cm]
# RdQaroundVertex[plane 2][r=11.0cm]
# RdQaroundVertex[plane 0][r=11.5cm]
# RdQaroundVertex[plane 1][r=11.5cm]
# RdQaroundVertex[plane 2][r=11.5cm]
# RdQaroundVertex[plane 0][r=12.0cm]
# RdQaroundVertex[plane 1][r=12.0cm]
# RdQaroundVertex[plane 2][r=12.0cm]
# RdQaroundVertex[plane 0][r=12.5cm]
# RdQaroundVertex[plane 1][r=12.5cm]
# RdQaroundVertex[plane 2][r=12.5cm]
# RdQaroundVertex[plane 0][r=13.0cm]
# RdQaroundVertex[plane 1][r=13.0cm]
# RdQaroundVertex[plane 2][r=13.0cm]
# RdQaroundVertex[plane 0][r=13.5cm]
# RdQaroundVertex[plane 1][r=13.5cm]
# RdQaroundVertex[plane 2][r=13.5cm]
# RdQaroundVertex[plane 0][r=14.0cm]
# RdQaroundVertex[plane 1][r=14.0cm]
# RdQaroundVertex[plane 2][r=14.0cm]
# RdQaroundVertex[plane 0][r=14.5cm]
# RdQaroundVertex[plane 1][r=14.5cm]
# RdQaroundVertex[plane 2][r=14.5cm]
# RdQaroundVertex[plane 0][r=15.0cm]
# RdQaroundVertex[plane 1][r=15.0cm]
# RdQaroundVertex[plane 2][r=15.0cm]
# RdQaroundVertex[plane 0][r=15.5cm]
# RdQaroundVertex[plane 1][r=15.5cm]
# RdQaroundVertex[plane 2][r=15.5cm]
# RdQaroundVertex[plane 0][r=16.0cm]
# RdQaroundVertex[plane 1][r=16.0cm]
# RdQaroundVertex[plane 2][r=16.0cm]
# RdQaroundVertex[plane 0][r=16.5cm]
# RdQaroundVertex[plane 1][r=16.5cm]
# RdQaroundVertex[plane 2][r=16.5cm]
# RdQaroundVertex[plane 0][r=17.0cm]
# RdQaroundVertex[plane 1][r=17.0cm]
# RdQaroundVertex[plane 2][r=17.0cm]
# RdQaroundVertex[plane 0][r=17.5cm]
# RdQaroundVertex[plane 1][r=17.5cm]
# RdQaroundVertex[plane 2][r=17.5cm]
# RdQaroundVertex[plane 0][r=18.0cm]
# RdQaroundVertex[plane 1][r=18.0cm]
# RdQaroundVertex[plane 2][r=18.0cm]
# RdQaroundVertex[plane 0][r=18.5cm]
# RdQaroundVertex[plane 1][r=18.5cm]
# RdQaroundVertex[plane 2][r=18.5cm]
# RdQaroundVertex[plane 0][r=19.0cm]
# RdQaroundVertex[plane 1][r=19.0cm]
# RdQaroundVertex[plane 2][r=19.0cm]
# RdQaroundVertex[plane 0][r=19.5cm]
# RdQaroundVertex[plane 1][r=19.5cm]
# RdQaroundVertex[plane 2][r=19.5cm]
# ClosestFlash_YZdistance
# ClosestFlash_TotalPE
# ClosestFlash_Time
# Nflashes
# MatchedFlash_Ydistance
# MatchedFlash_Zdistance
# MatchedFlash_YZdistance
# MatchedFlash_TotalPE
# MatchedFlash_Time
# MatchedFlash_Score
# isBrokenTrajectory
# 1mu-1p
# CC 1p 0pi
# other pairs
# cosmic

# %%
mup_good_l_mu = mup[np.abs(mup['truth_l_muCandidate']-mup['l_muCandidate'])<200]
mup_bad_l_mu = mup[np.abs(mup['truth_l_muCandidate']-mup['l_muCandidate'])>200]
draw_sam = mup_bad_l_mu
fig=plt.figure(figsize=(16,12))
plot_2d_hist(draw_sam['truth_l_muCandidate'],draw_sam['l_muCandidate'],xlabel='truth l(mu)',ylabel='reco l(mu)'
             ,bins=(linspace(50,1300,50),linspace(0,500,50)),ax=fig.add_subplot(2,3,1));
plot_2d_hist(draw_sam['truth_Pmu'],draw_sam['reco_Pmu'],xlabel='truth p(mu)',ylabel='reco p(mu)'
             ,bins=(linspace(0,2,50),linspace(0,2,50)),ax=fig.add_subplot(2,3,2));
plot_2d_hist(draw_sam['truth_Q2'],draw_sam['reco_Q2'],xlabel='truth Q2',ylabel='reco Q2'
             ,bins=(linspace(0,1,50),linspace(0,1,50)),ax=fig.add_subplot(2,3,3));
plot_2d_hist(draw_sam['truth_Pmu_x'],draw_sam['reco_Pmu_x'],xlabel='truth p(mu)-x',ylabel='reco p(mu)-x'
             ,bins=(linspace(-0.5,0.5,50),linspace(-0.5,0.5,50)),ax=fig.add_subplot(2,3,4));
plot_2d_hist(draw_sam['truth_Pmu_z'],draw_sam['reco_Pmu_z'],xlabel='truth p(mu)-z',ylabel='reco p(mu)-z'
             ,bins=(linspace(-0.15,1.,50),linspace(-0.15,1.,50)),ax=fig.add_subplot(2,3,5));
plot_2d_hist(draw_sam['startz_muCandidate'],draw_sam['endz_muCandidate'],xlabel='start z mu',ylabel='end z mu'
             ,bins=(linspace(-0.15,1000,50),linspace(-0.15,1000,50)),ax=fig.add_subplot(2,3,6));



plt.tight_layout()

# %% [markdown]
# # event weight

# %%
ovrelay = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/ccqe_candidates//prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_06_21_vertices.csv')
genie = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/genie/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_06_21_genie.csv')

# %%
mup = ovrelay[ovrelay['1mu-1p']==True]

# %%
plt.hist(genie['truth_Q2'],weights=genie['evwgh_mA040'],bins=linspace(0,1,21),histtype='step',linewidth=3,normed=1,label='0.40');
plt.hist(genie['truth_Q2'],weights=genie['evwgh_mA070'],bins=linspace(0,1,21),histtype='step',linewidth=3,normed=1,label='0.70');
plt.hist(genie['truth_Q2'],weights=genie['evwgh_mA099'],bins=linspace(0,1,21),histtype='step',linewidth=3,normed=1,label='0.99');
plt.hist(genie['truth_Q2'],weights=genie['evwgh_mA135'],bins=linspace(0,1,21),histtype='step',linewidth=3,normed=1,label='1.35');
plt.hist(genie['truth_Q2'],weights=genie['evwgh_mA171'],bins=linspace(0,1,21),histtype='step',linewidth=3,normed=1,label='1.71');
plt.legend()

# %% [markdown]
# # Marco' flash-matching

# %%
ovrelay = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_uboone_overlay_mcc8_v9_vertices.csv')

# %%
mup = ovrelay[ovrelay['1mu-1p']==True]
cosmic = ovrelay[ovrelay['cosmic']==True]
print len(mup)
# Out:
# 429

# %%
fig=plt.figure(figsize=(24,16))
for ivar,(var,xlabel,bins) in enumerate(zip(['ClosestFlash_TotalPE','MatchedFlash_TotalPE','ClosestFlash_YZdistance','MatchedFlash_YZdistance']
                   ,[r'$N_{PE}$ in closest flash ',r'$N_{PE}$ in matched flash ',r'$d_{YZ}$ to closest flash [cm] ',r'$d_{YZ}$ to matched flash [cm]']
                                            ,[linspace(0,3000,50),linspace(0,3000,50),linspace(0,1000,50),linspace(0,1000,50)])):
    ax = fig.add_subplot(2,2,ivar+1)
    for sam,slabel,scolor in zip([mup,cosmic]
                          ,['$\mu-p$ pairs','cosmic pairs']
                                 ,['forestgreen','red']):
        plt.hist(sam[var],bins=bins,histtype='step',linewidth=4,color=scolor);
        plt.plot([0,0],[0,0],color=scolor,linewidth=4,label=slabel)
    set_axes(ax,xlabel,'counts',do_add_legend=True,do_add_grid=True)

plt.tight_layout()

# %% [markdown]
# # my calculation of momentum vs. momentum calculator...

# %%
ovrelay = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/from_interactive/prodgenie_bnb_nu_uboone_overlay_mcc8_v9_vertices.csv')
mup = ovrelay[ovrelay['1mu-1p']==True]
print len(mup),'pairs of 1mu-1p'
# Out:
# 354 pairs of 1mu-1p

# %%
plot_2d_hist(mup.PmuHypothesisCalc,mup.reco_Pmu);
plot_2d_hist(mup.PpHypothesisCalc,mup.reco_Pp);
# plt.hist(mup.PmuHypothesisCalc-mup.reco_Pmu)
plt.hist(mup.PmuHypothesisCalc-mup.truth_Pmu)
# Out:
# (array([   1.,    0.,    0.,    1.,    0.,    1.,    3.,   12.,   65.,  271.]),
#  array([-4.905581 , -4.4099819, -3.9143828, -3.4187837, -2.9231846,
#         -2.4275855, -1.9319864, -1.4363873, -0.9407882, -0.4451891,  0.05041  ]),
#  <a list of 10 Patch objects>)
