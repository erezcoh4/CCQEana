# %% [markdown]
# # changing the event-selection cut that is based on \dEdx\ from \PIDa\ to \ChiSqrP
# We suggest to replace the \dEdx-based cut from the slope of the \dEdx\ curve (\PIDa),
# 			to the $\chi^{2}$ of the fit to the expected proton \dEdx\ curve in LAr,
# 			on account that the latter yields better agreement with beam data.

# %%
import sys;
sys.path.insert(0, '../');sys.path.insert(0, '../../');
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
from onbeam_offbeam_notebooks import *
pd.set_option('precision', 2)
# %matplotlib inline
# Out:
# versions:
# {   'OffBeam': 'prod_reco_optfilter_extbnb_v12_mcc8_dev',
#     'OnBeam': 'prod_reco_optfilter_bnb_v12_unblind_mcc8',
#     'Overlay': 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2',
#     'data date': '2018_05_11',
#     'date': '2018_05_11',
#     'overlay date': '2018_05_11'}
# OffBeam_scaling: 0.706302660161 = N(on beam)/N(off beam) before SwT
# f(POT): 0.0512441465374 = N(POT on beam)/N(POT MC)

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/Change_dEdx_Cut/Figures/'

# %%
versions['overlay date'] = '2018_05_11'
versions['Overlay'] = 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2'

# %%
OnBeam = pd.concat([pd.read_csv(vertices_files_path+'/'+versions['date']+'/'+versions['OnBeam']+'_04_'+versions['date']+'_vertices.csv')
                    ,pd.read_csv(vertices_files_path+'/'+versions['date']+'/'+versions['OnBeam']+'_05_'+versions['date']+'_vertices.csv')])
OnBeamFV = sample_in_FV(OnBeam)
print "%d"%len(OnBeam)+' pairs from On-Beam, %d'%len(OnBeamFV)+' in Fiducial Volume'
# Out:
# 38163 pairs from On-Beam, 24323 in Fiducial Volume

# %%
_,OverlaySamples = load_MCbnbDATAcosmicSamples(date=versions['overlay date'],filename=versions['Overlay']+'_'+versions['overlay date']+'_vertices')
print "%d"%len(OverlaySamples['cosmic'])+' cosmic pairs and %d'%len(OverlaySamples['1mu-1p'])+' mu-p pairs in overlay'
# Out:
# 283762 pairs from MC-BNB + cosmic DATA overlay
# 186485 pairs in FV
# 49707 are 1mu-1p, 26.7%
# 41519 are other pairs, 22.3%
# 95259 are cosmic, 51.1%
# --------------------------------------------------------------
# 23996 are CC 1p 0pi, 12.9%
# 95259 cosmic pairs and 49707 mu-p pairs in overlay

# %%
reducedSamples,pureffOverlay,numbers = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,debug=0
                                                             ,cuts_order  = ['no cut','PIDa','ClosestFlash','length','vertex activity','delta phi','Pt & delta phi'] )
pureffOverlay
# Out:
#                 $\mu p$ eff. $\mu p$ pur. CC$0\pi 1 p$ eff. CC$0\pi 1 p$ pur.  \
# no cut                100.0%        26.7%            100.0%             12.9%
# PIDa                   66.3%        55.5%             69.7%             28.2%
# ClosestFlash           61.7%        62.2%             64.8%             31.5%
# length                 55.6%        70.5%             59.7%             36.6%
# vertex activity        39.1%        72.7%             53.0%             47.5%
# delta phi              24.9%        83.5%             39.1%             63.3%
# Pt & delta phi         21.3%        89.6%             34.8%             70.5%
#
#                            label          1mu-1p     other pairs  \
# no cut                    no cut  100.0% (49707)  100.0% (41519)
# PIDa                        PIDa   66.3% (32952)   34.3% (14249)
# ClosestFlash        ClosestFlash   61.7% (30686)   32.7% (13585)
# length                    length   55.6% (27634)    19.4% (8051)
# vertex activity  vertex activity   39.1% (19435)    12.8% (5317)
# delta phi              delta phi   24.9% (12363)     3.1% (1274)
# Pt & delta phi    Pt & delta phi   21.3% (10607)      2.0% (819)
#
#                          cosmic       CC 1p 0pi
# no cut           100.0% (95259)  100.0% (23996)
# PIDa              12.7% (12139)   69.7% (16714)
# ClosestFlash        5.3% (5047)   64.8% (15555)
# length              3.7% (3497)   59.7% (14322)
# vertex activity     2.1% (1987)   53.0% (12708)
# delta phi           1.2% (1176)    39.1% (9381)
# Pt & delta phi       0.4% (417)    34.8% (8349)

# %% [markdown]
# # overlay subsamples-scaling

# %%
f_OverlayCosmic=1.45 # by which factor should we increase the cosmic part in the overlay
overlay_scalings = dict()
overlay_scalings['only POT'] = get_samples_scaling( N_total='MC(tot) x POT' 
                                                   , OverlaySubsamples=reducedSamples['no cut'])
overlay_scalings['POT & f(Overlay-Cosmic)=%.2f'%f_OverlayCosmic] = get_samples_scaling( N_total='MC(tot) x POT' 
                                                                                       , f_OverlayCosmic=f_OverlayCosmic  # by which factor should we increase the cosmic part in the overlay                                                                         
                                                                                       , OverlaySubsamples=reducedSamples['no cut'])
f_Cosmic = 0.86
overlay_scalings['N(On) scaling and f(cosmic)=%.2f'%f_Cosmic] = get_samples_scaling( N_total= float(len(OnBeamFV)) # total integral of all overlay                                       
                                                                         , f_Cosmic=f_Cosmic  # fraction of cosmic in the overlay, need to be in the range 0-1
                                                                         , OverlaySubsamples=reducedSamples['no cut'])

print 'overlay scalings';pp.pprint(overlay_scalings)
# Out:
# overlay scalings
# {   'N(On) scaling and f(cosmic)=0.86': {   '1mu-1p': 0.03732729704250981,
#                                             'CC 1p 0pi': 0.03732729704250981,
#                                             'cosmic': 0.21958849032637334,
#                                             'other pairs': 0.03732729704250982},
#     'POT & f(Overlay-Cosmic)=1.45': {   '1mu-1p': 0.051244146537389741,
#                                         'CC 1p 0pi': 0.051244146537389741,
#                                         'cosmic': 0.7093208569053812,
#                                         'other pairs': 0.051244146537389734},
#     'only POT': {   '1mu-1p': 0.051244146537389741,
#                     'CC 1p 0pi': 0.051244146537389741,
#                     'cosmic': 0.051244146537389734,
#                     'other pairs': 0.051244146537389734}}

# %% [markdown]
# ## PIDa

# %%
cuts_order  = ['no cut','ClosestFlash','length','non-collinearity','vertex activity','delta phi','Pt & delta phi']
cuts_labels = ['preselection','PMT cuts',r'$l_\mu > l_p$ cut','collinearity','vertex activity',r'$\Delta \phi$',r'$p_t$ cut']
reducedOverlay,pureffOverlay,_ = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
# Out:
# done applying cuts to overlay

# %%
reducedOnBeam,_ = apply_cuts_to_data(OnBeamFV=OnBeamFV,cuts_order=cuts_order)
print 'done applying cuts to data'
# Out:
# done applying cuts to data

# %%
plot_nocut_finalcut(var='pidcali_PIDaYplane_pCandidate'                          
                          ,x_label= r'$PID_{a}^{p}$(Y-plane)',bins=linspace(0,30,51)                          
                          ,overlay_scalings=overlay_scalings
                          ,scaling_name='N(On) scaling and f(cosmic)=%.2f'%f_Cosmic
                          ,f_Cosmic=f_Cosmic,last_cut_name='Pt & delta phi'                    
                    ,reducedOnBeam=reducedOnBeam
                    ,reducedOverlay=reducedOverlay                          
                          ,xlim=(0,30),chi2_xrange=(0,30));
filename = figures_path + 'pidcali_PIDaYplane_pCandidate.pdf'
plt.savefig(filename)
print "saved "+filename
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/Change_dEdx_Cut/Figures/pidcali_PIDaYplane_pCandidate.pdf

# %% [markdown]
# # $\chi^2_{\mu}$, $\chi^2_{p}$

# %%
cuts_order  = ['no cut','ClosestFlash','length','non-collinearity','vertex activity','delta phi','Pt & delta phi']
cuts_labels = ['preselection','PMT cuts',r'$l_\mu > l_p$ cut','collinearity','vertex activity','delta phi',r'$p_t$ cut']
reducedOverlay,pureffOverlay,_ = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
reducedOnBeam,_ = apply_cuts_to_data(OnBeamFV=OnBeamFV,cuts_order=cuts_order)
print 'done applying cuts to data'
# Out:
# done applying cuts to overlay
# done applying cuts to data

# %% [markdown]
# # 2d $\chi^2_{p}$ of the proton vs. the muon candidate

# %%
Chi2Proton_muCandidate_min=80
Chi2Proton_muCandidate_max=10000
Chi2Proton_pCandidate_min=0
Chi2Proton_pCandidate_max=30

# %%
plot_nocut_finalcut(var='pidcali_Chi2ProtonYplane_muCandidate'
                                       ,x_label= r'$(\chi^2_{proton})^{\mu-candidate}$ (Y-plane)',bins=linspace(-1,350,41)
                                       ,overlay_scalings=overlay_scalings
                          ,scaling_name='N(On) scaling and f(cosmic)=%.2f'%f_Cosmic
                          ,f_Cosmic=f_Cosmic,last_cut_name='Pt & delta phi'
                                       ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
                                       ,xlim=(-1,350),x_varcut=(Chi2Proton_muCandidate_min,Chi2Proton_muCandidate_max)
                                       ,chi2_xrange=(0,300));
filename = figures_path + 'pidcali_Chi2ProtonYplane_muCandidate.pdf'
plt.savefig(filename)
print "saved "+filename

plot_nocut_finalcut(var='pidcali_Chi2ProtonYplane_pCandidate'
                                       ,x_label= r'$(\chi^2_{proton})^{p-candidate}$ (Y-plane)'
                          ,bins=linspace(-1,300,21)
                                       ,overlay_scalings=overlay_scalings
                          ,scaling_name='N(On) scaling and f(cosmic)=%.2f'%f_Cosmic
                          ,f_Cosmic=f_Cosmic,last_cut_name='Pt & delta phi'
                                       ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
                                       ,xlim=(-1,300),x_varcut=(Chi2Proton_pCandidate_min,Chi2Proton_pCandidate_max)
                                       ,chi2_xrange=(0,150));
filename = figures_path + 'pidcali_Chi2ProtonYplane_pCandidate.pdf'
plt.savefig(filename)
print "saved "+filename
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/Change_dEdx_Cut/Figures/pidcali_Chi2ProtonYplane_muCandidate.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/Change_dEdx_Cut/Figures/pidcali_Chi2ProtonYplane_pCandidate.pdf

# %%
bins = (linspace(-1,275,25),linspace(-1,275,25))
varx,vary =  'pidcali_Chi2ProtonYplane_muCandidate','pidcali_Chi2ProtonYplane_pCandidate'
xcut = (Chi2Proton_muCandidate_min,Chi2Proton_muCandidate_max)
ycut = (Chi2Proton_pCandidate_min,Chi2Proton_pCandidate_max)

fig=plt.figure(figsize=(20,24))
for icut,(cut_name,cut_label) in enumerate(zip(['no cut','soft Pt']
                                               ,['preselection','detection+kinematical cuts'])):
    ax = fig.add_subplot(3,2,icut+1)

    overlay = reducedOverlay[cut_name]
    for sample,color in zip([overlay['cosmic'],overlay['other pairs'],overlay['1mu-1p'],overlay['CC 1p 0pi']]
                            ,['orange','red','forestgreen','blue']):
        sample = sample[(sample[varx]!=0)&(sample[vary]!=0)]
        plt.scatter(sample[varx],sample[vary],color=color,s=8)
    set_axes(ax,x_label=r'$(\chi^2_{proton})^{\mu-candidate}$ (Y-plane)'
             ,y_label=r'$(\chi^2_{proton})^{p-candidate}$ (Y-plane)'
             ,xlim=(0,np.max(bins)),ylim=(0,np.max(bins))
             ,title=cut_label)
    plt.plot([xcut[0],xcut[0]],ycut,'-',[xcut[1],xcut[1]],ycut,'-'
             ,xcut,[ycut[0],ycut[0]],'-',xcut,[ycut[1],ycut[1]],'-',color='black')
    
    ax = fig.add_subplot(3,2,icut+3)
    overlay_all = pd.concat([overlay['cosmic'],overlay['other pairs'],overlay['1mu-1p']])
    overlay_all = overlay_all[(overlay_all[varx]!=0)&(overlay_all[vary]!=0)]
    h_T,xedges, yedges = np.histogram2d( overlay_all[varx] , overlay_all[vary] , bins=bins )    
    X, Y = np.meshgrid(xedges, yedges)
    elev_min, elev_max = np.min(h_T) , np.max(h_T)
    pcmesh = ax.pcolormesh(X, Y, h_T.T ,cmap='Blues')
    set_axes(ax,x_label=r'$(\chi^2_{\mu})^{\mu-candidate}$ (Y-plane)'
             ,y_label=r'$(\chi^2_{proton})^{p-candidate}$ (Y-plane)'
             ,xlim=(0,np.max(bins[0])),ylim=(0,np.max(bins[1]))
             ,title=cut_label+' overlay')    
    plt.plot([xcut[0],xcut[0]],ycut,'-',[xcut[1],xcut[1]],ycut,'-'
             ,xcut,[ycut[0],ycut[0]],'-',xcut,[ycut[1],ycut[1]],'-',color='black')


    
    ax = fig.add_subplot(3,2,icut+5)
    OnBeamSample = reducedOnBeam[cut_name] 
    OnBeamSample = OnBeamSample[(OnBeamSample[varx]!=0)&(OnBeamSample[vary]!=0)]
    OffBeamSample = reducedOffBeam[cut_name] 
    OffBeamSample = OffBeamSample[(OffBeamSample[varx]!=0)&(OffBeamSample[vary]!=0)]

    h_OnBeam_T,xedges, yedges = np.histogram2d( OnBeamSample[varx] , OnBeamSample[vary] , bins=bins )
    h_OffBeam_T,xedges, yedges = np.histogram2d( OffBeamSample[varx] , OffBeamSample[vary] , bins=bins )
    
    h_OnBeam_minus_OffBeam_T = h_OnBeam_T - OffBeam_scaling*h_OffBeam_T
    h_OnBeam_minus_OffBeam = h_OnBeam_minus_OffBeam_T.T
    
    X, Y = np.meshgrid(xedges, yedges)
    elev_min, elev_max = np.min(h_OnBeam_minus_OffBeam) , np.max(h_OnBeam_minus_OffBeam)
    pcmesh = ax.pcolormesh(X, Y, h_OnBeam_minus_OffBeam ,cmap='Blues'
                          )
    set_axes(ax,x_label=r'$(\chi^2_{proton})^{\mu-candidate}$ (Y-plane)'
             ,y_label=r'$(\chi^2_{proton})^{p-candidate}$ (Y-plane)'
             ,xlim=(0,np.max(bins)),ylim=(0,np.max(bins))
             ,title=cut_label+' On-Off beam')
    plt.plot([xcut[0],xcut[0]],ycut,'-',[xcut[1],xcut[1]],ycut,'-'
             ,xcut,[ycut[0],ycut[0]],'-',xcut,[ycut[1],ycut[1]],'-',color='black')

    
plt.tight_layout()

# %% [markdown]
# # what happens if we apply a cut on $\chi^2_{proton}$?

# %%
# versions['date'] = "2018_05_07"
# versions['Overlay'] = "prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2"
# OverlayPairsFV, OverlaySamples = load_MCbnbDATAcosmicSamples(date=versions['date'],filename=versions['Overlay']+'_'+versions['date']+'_vertices')
# print_and_say("%d"%len(OverlaySamples['cosmic'])+' cosmic pairs and %d'%len(OverlaySamples['1mu-1p'])+' mu-p pairs in overlay')
# Out:
# 101046 pairs from MC-BNB + cosmic DATA overlay
# 66744 pairs in FV
# 18025 are 1mu-1p, 27.0%
# 15339 are other pairs, 23.0%
# 33380 are cosmic, 50.0%
# --------------------------------------------------------------
# 8617 are CC 1p 0pi, 12.9%
# 33380 cosmic pairs and 18025 mu-p pairs in overlay

# %%
cuts_order  = ['no cut','ClosestFlash','length','non-collinearity','vertex activity','delta phi','Pt & delta phi']
cuts_labels = ['preselection','ClosestFlash',r'$l_\mu > l_p$ cut','collinearity','vertex activity',r'$\Delta \phi$',r'$p_t$ cut']
reducedOverlay,pureffOverlay,pureffOverlayNumbers = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
pureffOverlay
# Out:
# done applying cuts to overlay
#                  $\mu p$ eff. $\mu p$ pur. CC$0\pi 1 p$ eff.  \
# no cut                 100.0%        26.7%            100.0%
# ClosestFlash            92.8%        37.2%             92.8%
# length                  72.7%        53.5%             76.9%
# non-collinearity        66.1%        67.9%             72.4%
# vertex activity         46.5%        70.7%             63.6%
# delta phi               30.6%        86.8%             48.0%
# Pt & delta phi          27.0%        91.0%             43.4%
#
#                  CC$0\pi 1 p$ pur.             label          1mu-1p  \
# no cut                       12.9%            no cut  100.0% (49707)
# ClosestFlash                 17.9%      ClosestFlash   92.8% (46138)
# length                       27.3%            length   72.7% (36158)
# non-collinearity             35.9%  non-collinearity   66.1% (32851)
# vertex activity              46.7%   vertex activity   46.5% (23114)
# delta phi                    65.8%         delta phi   30.6% (15211)
# Pt & delta phi               70.6%    Pt & delta phi   27.0% (13409)
#
#                      other pairs          cosmic       CC 1p 0pi
# no cut            100.0% (41519)  100.0% (95259)  100.0% (23996)
# ClosestFlash       93.2% (38712)   41.2% (39235)   92.8% (22271)
# length             42.7% (17738)   14.4% (13672)   76.9% (18443)
# non-collinearity   27.0% (11211)     4.5% (4332)   72.4% (17375)
# vertex activity     17.3% (7174)     2.5% (2413)   63.6% (15256)
# delta phi            4.1% (1693)      0.6% (619)   48.0% (11523)
# Pt & delta phi        2.3% (952)      0.4% (381)   43.4% (10414)

# %%
table = pureffOverlay[[ u'cosmic',u'CC 1p 0pi',u'CC$0\pi 1 p$ pur.']]
print 
print "\hline \hline"
for i,row in table.iterrows(): 
    print "%s"%i + " & " + row[u'cosmic'] + " & " + row[u'CC 1p 0pi'] + " & "  +row[u'CC$0\pi 1 p$ pur.']+ "\\tabularnewline"
    print "\hline"
# Out:
# \hline \hline
# no cut & 100.0% (95259) & 100.0% (23996) & 12.9%\tabularnewline
# \hline
# ClosestFlash & 41.2% (39235) & 92.8% (22271) & 17.9%\tabularnewline
# \hline
# length & 14.4% (13672) & 76.9% (18443) & 27.3%\tabularnewline
# \hline
# non-collinearity & 4.5% (4332) & 72.4% (17375) & 35.9%\tabularnewline
# \hline
# vertex activity & 2.5% (2413) & 63.6% (15256) & 46.7%\tabularnewline
# \hline
# delta phi & 0.6% (619) & 48.0% (11523) & 65.8%\tabularnewline
# \hline
# Pt & delta phi & 0.4% (381) & 43.4% (10414) & 70.6%\tabularnewline
# \hline

# %%
cuts_order  = ['no cut','PIDa','ClosestFlash','length','non-collinearity','vertex activity','delta phi','Pt & delta phi']
cuts_labels = ['preselection',r'$PID_{a}^{proton-candidate}$','ClosestFlash',r'$l_\mu > l_p$ cut','collinearity','vertex activity',r'$\Delta \phi$',r'$p_t$ cut']
reducedOverlay,pureffOverlay,_ = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
pureffOverlay
# Out:
# done applying cuts to overlay
#                  $\mu p$ eff. $\mu p$ pur. CC$0\pi 1 p$ eff.  \
# no cut                 100.0%        26.7%            100.0%
# PIDa                    66.3%        55.5%             69.7%
# ClosestFlash            61.7%        62.2%             64.8%
# length                  55.6%        70.5%             59.7%
# non-collinearity        50.5%        77.4%             56.3%
# vertex activity         36.1%        80.2%             50.1%
# delta phi               23.5%        91.8%             37.6%
# Pt & delta phi          20.6%        93.7%             33.8%
#
#                  CC$0\pi 1 p$ pur.             label          1mu-1p  \
# no cut                       12.9%            no cut  100.0% (49707)
# PIDa                         28.2%              PIDa   66.3% (32952)
# ClosestFlash                 31.5%      ClosestFlash   61.7% (30686)
# length                       36.6%            length   55.6% (27634)
# non-collinearity             41.6%  non-collinearity   50.5% (25099)
# vertex activity              53.8%   vertex activity   36.1% (17929)
# delta phi                    70.9%         delta phi   23.5% (11688)
# Pt & delta phi               74.3%    Pt & delta phi   20.6% (10221)
#
#                      other pairs          cosmic       CC 1p 0pi
# no cut            100.0% (41519)  100.0% (95259)  100.0% (23996)
# PIDa               34.3% (14249)   12.7% (12139)   69.7% (16714)
# ClosestFlash       32.7% (13585)     5.3% (5047)   64.8% (15555)
# length              19.4% (8051)     3.7% (3497)   59.7% (14322)
# non-collinearity    13.9% (5783)     1.6% (1563)   56.3% (13500)
# vertex activity      8.8% (3639)      0.8% (794)   50.1% (12020)
# delta phi             2.0% (828)      0.2% (214)    37.6% (9030)
# Pt & delta phi        1.3% (546)      0.1% (136)    33.8% (8105)

# %%
table = pureffOverlay[[ u'cosmic',u'CC 1p 0pi',u'CC$0\pi 1 p$ pur.']]
print 
print "\hline \hline"
for i,row in table.iterrows(): 
    print "%s"%i + " & " + row[u'cosmic'] + " & " + row[u'CC 1p 0pi'] + " & "  +row[u'CC$0\pi 1 p$ pur.']+ "\\tabularnewline"
    print "\hline"
# Out:
# \hline \hline
# no cut & 100.0% (95259) & 100.0% (23996) & 12.9%\tabularnewline
# \hline
# PIDa & 12.7% (12139) & 69.7% (16714) & 28.2%\tabularnewline
# \hline
# ClosestFlash & 5.3% (5047) & 64.8% (15555) & 31.5%\tabularnewline
# \hline
# length & 3.7% (3497) & 59.7% (14322) & 36.6%\tabularnewline
# \hline
# non-collinearity & 1.6% (1563) & 56.3% (13500) & 41.6%\tabularnewline
# \hline
# vertex activity & 0.8% (794) & 50.1% (12020) & 53.8%\tabularnewline
# \hline
# delta phi & 0.2% (214) & 37.6% (9030) & 70.9%\tabularnewline
# \hline
# Pt & delta phi & 0.1% (136) & 33.8% (8105) & 74.3%\tabularnewline
# \hline

# %%
cuts_order  = ['no cut','Chi2Proton','ClosestFlash','length','non-collinearity','vertex activity','delta phi','Pt & delta phi']
cuts_labels = ['preselection',r'$\chi^{2}_{proton-assumption}$','ClosestFlash',r'$l_\mu > l_p$ cut','collinearity','vertex activity',r'$\Delta \phi$',r'$p_t$ cut']
reducedOverlay,pureffOverlay,_ = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
pureffOverlay
# Out:
# done applying cuts to overlay
#                  $\mu p$ eff. $\mu p$ pur. CC$0\pi 1 p$ eff.  \
# no cut                 100.0%        26.7%            100.0%
# Chi2Proton              63.1%        70.7%             68.7%
# ClosestFlash            58.8%        74.8%             63.9%
# length                  53.7%        80.7%             59.4%
# non-collinearity        49.0%        85.2%             56.2%
# vertex activity         35.2%        86.8%             50.0%
# delta phi               23.4%        94.8%             38.0%
# Pt & delta phi          20.6%        95.9%             34.4%
#
#                  CC$0\pi 1 p$ pur.             label          1mu-1p  \
# no cut                       12.9%            no cut  100.0% (49707)
# Chi2Proton                   37.1%        Chi2Proton   63.1% (31389)
# ClosestFlash                 39.2%      ClosestFlash   58.8% (29226)
# length                       43.1%            length   53.7% (26668)
# non-collinearity             47.2%  non-collinearity   49.0% (24339)
# vertex activity              59.6%   vertex activity   35.2% (17486)
# delta phi                    74.3%         delta phi   23.4% (11618)
# Pt & delta phi               77.0%    Pt & delta phi   20.6% (10264)
#
#                      other pairs          cosmic       CC 1p 0pi
# no cut            100.0% (41519)  100.0% (95259)  100.0% (23996)
# Chi2Proton          19.3% (8021)     5.2% (5001)   68.7% (16481)
# ClosestFlash        18.5% (7669)     2.3% (2197)   63.9% (15337)
# length              11.1% (4603)     1.9% (1775)   59.4% (14255)
# non-collinearity     8.1% (3357)      0.9% (874)   56.2% (13483)
# vertex activity      5.3% (2201)      0.5% (448)   50.0% (11992)
# delta phi             1.2% (503)      0.1% (140)    38.0% (9114)
# Pt & delta phi        0.8% (348)       0.1% (93)    34.4% (8243)

# %%
table = pureffOverlay[[ u'cosmic',u'CC 1p 0pi',u'CC$0\pi 1 p$ pur.']]
print 
print "\hline \hline"
for i,row in table.iterrows(): 
    print "%s"%i + " & " + row[u'cosmic'] + " & " + row[u'CC 1p 0pi'] + " & "  +row[u'CC$0\pi 1 p$ pur.']+ "\\tabularnewline"
    print "\hline"
# Out:
# \hline \hline
# no cut & 100.0% (95259) & 100.0% (23996) & 12.9%\tabularnewline
# \hline
# Chi2Proton & 5.2% (5001) & 68.7% (16481) & 37.1%\tabularnewline
# \hline
# ClosestFlash & 2.3% (2197) & 63.9% (15337) & 39.2%\tabularnewline
# \hline
# length & 1.9% (1775) & 59.4% (14255) & 43.1%\tabularnewline
# \hline
# non-collinearity & 0.9% (874) & 56.2% (13483) & 47.2%\tabularnewline
# \hline
# vertex activity & 0.5% (448) & 50.0% (11992) & 59.6%\tabularnewline
# \hline
# delta phi & 0.1% (140) & 38.0% (9114) & 74.3%\tabularnewline
# \hline
# Pt & delta phi & 0.1% (93) & 34.4% (8243) & 77.0%\tabularnewline
# \hline
