# %% [markdown]
# # put selected events in csv files

# %%
import sys; sys.path.insert(0, '../../../'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
from onbeam_offbeam_notebooks import *
from Xsec_tools import *
# %matplotlib inline
# Out:
# versions:
# {   'OffBeam': 'prod_reco_optfilter_extbnb_v12_mcc8_dev',
#     'OnBeam': 'prod_reco_optfilter_bnb_v12_unblind_mcc8',
#     'Overlay': 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2',
#     'data date': '2018_05_11',
#     'date': '2018_05_11',
#     'overlay date': '2018_05_11'}
# OffBeam_scaling: 0.706302660161 = N(on beam)/N(off beam) before SwT
# f(POT): 0.0512441465374 = N(POT on beam)/N(POT MC)

# %%
versions['overlay date'] = '2018_08_16'
versions['Overlay'] = 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2'
versions['data date'] = '2018_08_16'
versions['beam on'] = 'prod_reco_optfilter_bnb_v12_unblind_mcc8'
versions['beam off'] = 'prod_reco_optfilter_extbnb_v12_mcc8_dev'
selected_overlay,selected_overlay_concat,selected_CC1p,genie_CC1p,selected_beam_on,selected_beam_off = load_mc_and_data()
# Out:
# found selected_cosmic.csv, loading it...
# checked /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_selected_on_beam.csv and found the file...
# checked /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_08_16_selected_genie_CC1p.csv and found the file...
# 9933 selected CC1p events overlay

# %%
csv_name = Paths['selected events'] + versions['beam on'] + 'selected_beam_on_rse.csv'
selected_beam_on[['run','subrun','event']].to_csv(csv_name)
print 'output ',len(selected_beam_on),'beam on events to ',csv_name

csv_name = Paths['selected events'] + versions['Overlay'] + 'selected_CC1p_rse.csv'
selected_CC1p[['run','subrun','event']].to_csv(csv_name)
print 'output ',len(selected_CC1p),'CC1p events to ',csv_name
# Out:
# output  464 beam on events to  /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8selected_beam_on_rse.csv
# output  9933 CC1p events to  /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2selected_CC1p_rse.csv

# %% [markdown]
# ## How many of data our events have $\pi^0$ identified using the CC$\pi^0$ algorithms?

# %%
# interscect two data frames
dfA = pd.DataFrame({'S':[1,2,4,9],'T':[3.3,4.2,5.1,8]})
dfB = pd.DataFrame({'S':[1,3,4,8],'T':[3.3,4.1,5.1,8]})
s1 = pd.merge(dfA, dfB, how='inner', on=['S', 'T'])
s1
# Out:
#    S    T
# 0  1  3.3
# 1  4  5.1

# %%
CCpi0_one_shower_rse = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/pi0_events/onbeam_one_shower.txt',names=['run','subrun','event'],delimiter=' ')
CCpi0_two_shower_rse = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/pi0_events/onbeam_one_shower.txt',names=['run','subrun','event'],delimiter=' ')

# %%
CCpi0_one_shower_rse
# Out:
#       run  subrun  event
# 0    5185      68   3432
# 1    5385      96   4827
# 2    5929      21   1097
# 3    5272      46   2340
# 4    5929      31   1582
# 5    5851      42   2127
# 6    5654      58   2912
# 7    5609      32   1649
# 8    5730      42   2109
# 9    5263      14    704
# 10   5528      60   3038
# 11   5933      64   3218
# 12   5705     146   7316
# 13   5478      14    703
# 14   5532      16    842
# 15   5397      26   1323
# 16   5272       1     55
# 17   5654       7    373
# 18   5712      14    737
# 19   5586      94   4721
# 20   5361     104   5245
# 21   5408      30   1524
# 22   5694      17    889
# 23   5507       4    218
# 24   5710      63   3182
# 25   5436      39   1992
# 26   5215       5    268
# 27   5830     153   7658
# 28   5824     177   8874
# 29   5847      28   1416
# ..    ...     ...    ...
# 227  5184      54   2727
# 228  5168       0     30
# 229  5758      69   3491
# 230  5344      53   2665
# 231  5155      26   1314
# ...

# %%
merged_one_shower = pd.merge(CCpi0_one_shower_rse, selected_beam_on, how='inner', on=['run','subrun','event'])
len(merged_one_shower)
# merged_one_shower
# Out:
# 6

# %%
merged_two_shower = pd.merge(CCpi0_two_shower_rse, selected_beam_on, how='inner', on=['run','subrun','event'])
len(merged_two_shower)
# Out:
# 6
