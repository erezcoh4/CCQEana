# %% [markdown]
# # can we tracec the reason for the deep @ $\phi_\mu\sim0$ ? Comppare mc/mc and mc/data overlays before cuts

# %%
import sys; sys.path.insert(0, '../../../'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
from onbeam_offbeam_notebooks import *
from Xsec_tools import *
# %matplotlib inline
sns.set(font_scale=2);sns.set_style("whitegrid");
# Out:
# versions:
# {   'OffBeam': 'prod_reco_optfilter_extbnb_v12_mcc8_dev',
#     'OnBeam': 'prod_reco_optfilter_bnb_v12_unblind_mcc8',
#     'Overlay': 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2',
#     'data date': '2018_05_11',
#     'date': '2018_05_11',
#     'overlay date': '2018_05_11'}
# OffBeam_scaling: 0.706302660161 = N(on beam)/N(off beam) before SwT
# f(POT): 0.0512441465374 = N(POT on beam)/N(POT MC)

# %% [markdown]
# ## load mc and data

# %%
mc_mc_overlay = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/ccqe_candidates/2018_08_16/prodgenie_bnb_nu_cosmic_uboone_mcc8.7_reco2_dev_2018_08_16_vertices.csv')

# %%
mc_mc_overlay_cosmic = mc_mc_overlay[(mc_mc_overlay.cosmic==True) & (mc_mc_overlay['pidcali_Chi2ProtonYplane_pCandidate']>50)]
print len(mc_mc_overlay_cosmic),'cosmic pairs in mc/mc overlay'
# Out:
# 44947 cosmic pairs in mc/mc overlay

# %%
mc_data_overlay = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/ccqe_candidates/2018_08_16/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_08_16_vertices.csv')

# %%
mc_data_overlay_cosmic = mc_data_overlay[(mc_data_overlay.cosmic==True) & (mc_data_overlay['pidcali_Chi2ProtonYplane_pCandidate']>50)]
print len(mc_data_overlay_cosmic),'cosmic pairs in mc/data overlay'
# Out:
# 139348 cosmic pairs in mc/data overlay

# %%
bins = linspace(-180,180,100)
fig,ax=plt.subplots(figsize=(12.944,8))
plt.hist(180./np.pi*mc_data_overlay_cosmic['reco_Pmu_mcs_phi'],bins=bins,label='cosmic data in mc/data overlay',normed=1,histtype='step',linewidth=4);
plt.hist(180./np.pi*mc_mc_overlay_cosmic['reco_Pmu_mcs_phi'],bins=bins,label='cosmic mc in mc/mc overlay',normed=1,histtype='step',linewidth=4);
set_axes(ax,r'reco. $\phi_{\mu-\mathrm{candidate}}$ [deg.]','counts [a.u.]',do_add_legend=True,legend_loc='upper left',alpha_grid=0.2)

fig,ax=plt.subplots(figsize=(12.944,8))
plt.hist(180./np.pi*mc_data_overlay_cosmic['reco_Pp_phi'],bins=bins,label='cosmic data in mc/data overlay',normed=1,histtype='step',linewidth=4);
plt.hist(180./np.pi*mc_mc_overlay_cosmic['reco_Pp_phi'],bins=bins,label='cosmic mc in mc/mc overlay',normed=1,histtype='step',linewidth=4);
set_axes(ax,r'reco. $\phi_{p-\mathrm{candidate}}$ [deg.]','counts [a.u.]',do_add_legend=True,legend_loc='upper left',alpha_grid=0.2)
