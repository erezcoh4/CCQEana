# %% [markdown]
# # Study the distortion of the kinematical distributions when applying the event-selection cuts

# %%
import sys; sys.path.insert(0, '../..'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
from onbeam_offbeam_notebooks import *
from Xsec_tools import *
# %matplotlib inline

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/Xsec/Figures/distortion_of_distributions/'

# %%
versions['overlay date'] = '2018_08_16'
versions['Overlay'] = 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2'
OverlaySamples = load_samples(date=versions['overlay date'],filename=versions['Overlay']+'_'+versions['overlay date']+'_vertices')
print "%d"%len(OverlaySamples['cosmic'])+' cosmic pairs and %d'%len(OverlaySamples['1mu-1p'])+' mu-p pairs in overlay'
# Out:
# 285009 ccqe candidate pairs, 180070 in FV
# 74387 are 1mu-1p, 41.3%
# 55226 are other pairs, 30.7%
# 155396 are cosmic, 86.3%
# --------------------------------------------------------------
# 36843 are CC1p0pi, 20.5%
# --------------------------------------------------------------
# 40729 are CC1p, 22.6%
# I finished loading overlay samples. We have in total 285009 pairs
# 155396 cosmic pairs and 74387 mu-p pairs in overlay

# %%
cuts_order  = ['no cut','Chi2Proton','Nflashes','MatchedFlash','length'
               ,'non-collinearity','vertex activity'
               ,'delta phi','Pt & delta phi']
cutlabels = ['preselection','$dE/dx$ profile',r'$N_{flashes}>0$','optical filter','track lengths'
             ,'non-collinearity','vertex activity'
             ,'coplanarity','$p_t<0.35$ GeV/c']
reducedOverlay,pureffOverlay,pureffNumbers = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
pureffOverlay
# Out:
#                  $\mu p$ eff. $\mu p$ pur. CC$0\pi 1 p$ eff.  \
# no cut                 100.0%        26.1%            100.0%
# Chi2Proton              62.0%        73.0%             67.1%
# Nflashes                61.7%        75.2%             66.8%
# MatchedFlash            47.5%        81.1%             51.5%
# length                  43.1%        85.4%             47.3%
# non-collinearity        39.7%        89.2%             45.1%
# vertex activity         29.3%        90.6%             40.6%
# delta phi               20.2%        96.0%             32.0%
# Pt & delta phi          17.7%        96.8%             28.6%
#
#                  CC$0\pi 1 p$ pur. CC$1 p$ eff. CC$1 p$ pur.  \
# no cut                       12.9%       100.0%        14.3%
# Chi2Proton                   39.2%        66.3%        42.7%
# Nflashes                     40.3%        65.9%        44.0%
# MatchedFlash                 43.6%        51.2%        47.8%
# length                       46.5%        46.6%        50.6%
# non-collinearity             50.3%        44.2%        54.4%
# vertex activity              62.1%        38.6%        65.3%
# delta phi                    75.1%        29.9%        77.7%
# Pt & delta phi               77.5%        26.8%        80.2%
#
#                              label          1mu-1p     other pairs  \
# no cut                      no cut  100.0% (74387)  100.0% (55226)
# Chi2Proton              Chi2Proton   62.0% (46155)    17.3% (9547)
# Nflashes                  Nflashes   61.7% (45931)    17.2% (9495)
# MatchedFlash          MatchedFlash   47.5% (35339)    11.2% (6184)
# length                      length   43.1% (32061)     6.8% (3754)
# non-collinearity  non-collinearity   39.7% (29505)     5.0% (2760)
# vertex activity    vertex activity   29.3% (21829)     3.3% (1815)
# delta phi                delta phi   20.2% (15055)      0.8% (456)
# Pt & delta phi      Pt & delta phi   17.7% (13155)      0.6% (322)
#
#                            cosmic         CC1p0pi            CC1p
# no cut            100.0% (155396)  100.0% (36843)  100.0% (40729)
# Chi2Proton            4.8% (7485)   67.1% (24739)   66.3% (26989)
# Nflashes              3.6% (5664)   66.8% (24612)   65.9% (26859)
# MatchedFlash          1.3% (2050)   51.5% (18991)   51.2% (20836)
# length                1.1% (1707)   47.3% (17430)   46.6% (18980)
# non-collinearity       0.5% (795)   45.1% (16627)   44.2% (17993)
# vertex activity        0.3% (445)   40.6% (14958)   38.6% (15732)
# delta phi              0.1% (179)   32.0% (11779)   29.9% (12184)
# Pt & delta phi         0.1% (119)   28.6% (10535)   26.8% (10899)

# %% [markdown]
# # what happens to the distributions after each of the cuts?

# %%
# var,x_label,bins = 'reco_Pmu_mcs','reco. (mcs) $p_{\mu}$ (GeV/c)',Bins['Pmu']
# var,x_label,bins = 'reco_Pmu_cos_theta',r'reco. $cos(\theta_{\mu})$',Bins['cos(theta(mu))']
# var,x_label,bins = 'reco_Pp','reco. (range-based) $p_{p}$ (GeV/c)',Bins['Pp']
var,x_label,bins = 'reco_Pp_cos_theta',r'reco. $\cos(\theta_{p})$',Bins['cos(theta(p))']

mul=180./np.pi if 'deg' in x_label else 1
mid = 0.5*(bins[1:]+bins[:-1])

h,f = dict(),dict()
for cut in ['no cut','vertex activity','Pt & delta phi']:
    overlay_concat = pd.concat([reducedOverlay[cut]['1mu-1p'],reducedOverlay[cut]['cosmic'],reducedOverlay[cut]['other pairs']])
    mup = reducedOverlay[cut]['1mu-1p']
    
    for sam,slabel in zip( [overlay_concat,mup],['overlay','1$\mu$-1p']):
        h[slabel+' '+cut],_ = np.histogram( mul*sam[var] , bins=bins )
        f[slabel+' '+cut] = h[slabel+' '+cut].astype(np.float)/h[slabel+' no cut']
        
fig = plt.figure(figsize=(16,6))
for iax,(sam,slabel) in enumerate(zip( [overlay_concat,mup],['overlay','1$\mu$-1p'])):
    ax = fig.add_subplot(1,2,iax+1)
    plt.step( mid , h[slabel+' no cut'] , where='mid' , label=clabel )
    set_axes(ax,x_label,title=slabel)
plt.tight_layout()

fig = plt.figure(figsize=(16,6))
for iax,(sam,slabel) in enumerate(zip( [overlay_concat,mup],['overlay','1$\mu$-1p'])):
    ax = fig.add_subplot(1,2,iax+1)
    for cut,clabel in zip(['vertex activity','Pt & delta phi']
                          ,['detector cuts','detector+kinematical cuts']):
        plt.step( mid , f[slabel+' '+cut] , where='mid' , label=clabel )
    set_axes(ax,x_label,title=slabel,do_add_legend=True if iax==0 else False,do_add_grid=True,legend_loc='lower right'
             ,ylim=(0,1.1*np.max(f[slabel+' '+'vertex activity'])))
#     ax.set_yscale('log')
plt.tight_layout()
