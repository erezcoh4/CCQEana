# %% [markdown]
# # full chain of cross-section results - for studying the cross-section with different samples or different cut values

# %%
import sys; sys.path.insert(0, '../../../../'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
from onbeam_offbeam_notebooks import *
from Xsec_tools import *
# %matplotlib inline
# Out:
# versions:
# {   'Overlay': 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2',
#     'beam off': 'prod_reco_optfilter_extbnb_v12_mcc8_dev',
#     'beam on': 'prod_reco_optfilter_bnb_v12_unblind_mcc8',
#     'data date': '2018_08_16',
#     'overlay date': '2018_09_22'}
# OffBeam_scaling: 0.706302660161 = N(on beam)/N(off beam) before SwT
# f(POT): 0.051017899728 = N(POT on beam)/N(POT MC)

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/XsecCCQE/Figures/overlay_8.11/systematics/'

# %% [markdown]
# # full chain of cross-section extraction - nominal

# %%
def extract_Xsec_full_chain(extra_name='',deubg=0
                            ,minPEcut = None,maxdYZcut = None
                            ,delta_theta_12 = None,r_max_RdQ_CC1p = None
                            ,delta_Delta_phi = None,Pt_max =None
                            ,Chi2Proton_muCandidate_min =None,Chi2Proton_pCandidate_max = None):
    
    samples = load_mc_and_data(extra_name=extra_name
                         ,minPEcut = minPEcut,maxdYZcut = maxdYZcut
                         ,delta_theta_12 = delta_theta_12,r_max_RdQ_CC1p = r_max_RdQ_CC1p
                         ,delta_Delta_phi = delta_Delta_phi,Pt_max = Pt_max
                         ,Chi2Proton_muCandidate_min = Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max = Chi2Proton_pCandidate_max)
    selected_overlay,selected_overlay_concat,selected_CC1p,genie_CC1p,selected_beam_on,selected_beam_off = samples    
    print 'done loading samples...'
    if (("Pmu weight" not in selected_beam_on.columns) or ("Pp weight" not in selected_beam_on.columns)):
        print 'no Pmu weights, computing them'
        compute_eff_weights(beam_on=selected_beam_on,beam_off=selected_beam_off,
                                generated_CC1p=genie_CC1p,selected_CC1p=selected_CC1p,overlay=selected_overlay_concat,
                                delta_theta_12=delta_theta_12,
                                delta_Delta_phi=delta_Delta_phi,
                                Pt_max=Pt_max)     
        compute_eff_weights(beam_on=selected_beam_on,beam_off=selected_beam_off,
                                generated_CC1p=genie_CC1p,selected_CC1p=selected_CC1p,overlay=selected_overlay_concat,
                                delta_theta_12=delta_theta_12,
                                delta_Delta_phi=delta_Delta_phi,
                                Pt_max=Pt_max,
                                ob_1='Pp',ob_2='cos(theta(p))',ob_3='phi(p)',
                                reco_1='reco_Pp',reco_2='reco_Pp_cos_theta',reco_3='reco_Pp_phi',
                                true_1='truth_Pp',true_2='truth_Pp_cos_theta',true_3='truth_Pp_phi') 
        print 'done assiging Pmu weights and Pp weights and saving the files.'    
    else:
        print 'Pmu weights and Pp weights already exist.'

    
    # iterative process for correction around\phi~0
    if ('W(corr. phi~0)' not in selected_beam_on.columns):
        for sam in [selected_beam_on,selected_beam_off,selected_CC1p,selected_overlay_concat]: sam['W(corr. phi~0)'] = 1
        Xsec_dict = get_phi_Xsecs( do_corr_phi_0=False , debug=deubg , 
                                  selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p)
        correction, correction_arrays = dict(),dict()
        correction_arrays['mu'] = []; correction_arrays['p'] = [];
        correction['mu'] = correction['p'] = 1
        current_correction = 100
        while np.abs(current_correction-1)>0.0001:
            for particle,var in zip(['mu','p'],
                                    ['reco_Pmu_mcs_phi','reco_Pp_phi']):
                Xsec,Xsec_err = Xsec_dict['phi('+particle+')'],Xsec_dict['phi('+particle+') err']
                bins = Bins['phi('+particle+')']
                N = len(bins)-1; n = N/2
                Xsec_phi_0 = Xsec[n]
                Xsec_phi_not_0 = np.concatenate([Xsec[:n-1],Xsec[n+1:]])
                Xsec_err_phi_not_0 = np.concatenate([Xsec_err[:n-1],Xsec_err[n+1:]])
                mean_phi_not_0 = np.average(Xsec_phi_not_0 , weights=1./np.square(Xsec_err_phi_not_0))
                current_correction = mean_phi_not_0/Xsec_phi_0
                correction[particle] = correction[particle]*current_correction
                correction_arrays[particle].append( correction[particle] )            
                for sam in [selected_beam_on,selected_beam_off,selected_CC1p,selected_overlay_concat]:
                    indices_phi_0 = sam.index[(bins[n] <= 180./np.pi*sam[var]) & (180./np.pi*sam[var] < bins[n+1])].tolist()
                    sam.loc[indices_phi_0,'W(corr. phi~0)'] = sam.loc[indices_phi_0,'W(corr. phi~0)'] * current_correction
                Xsec_dict = get_phi_Xsecs( do_corr_phi_0=True , debug=deubg ,
                                          selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p)
        for particle in ['mu','p']: print 'correction for phi('+particle+')~0:',correction_arrays[particle][-1]
        save_selected_samples(selected_overlay_concat , selected_CC1p , selected_beam_on , selected_beam_off, extra_name=extra_name)
        print 'done performing iterative correction for phi~0 and saved the samples...'    
    else:
        print 'already performed correction for phi~0 and saved the samples...'    
    extract_Xsecs(debug=deubg,extra_name=extra_name,particle='mu',
                  selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,                  
                  selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p)
    extract_Xsecs(debug=deubg,extra_name=extra_name,particle='p',
                  selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,                  
                  selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p)

# %%
versions['Overlay']='prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2'
versions['beam on']='prod_reco_optfilter_bnb_v12_unblind_mcc8'
versions['beam off']='prod_reco_optfilter_extbnb_v12_mcc8_dev'
versions['overlay date']='2018_09_22'
versions['data date']='2018_08_16'

extra_name=''
minPEcut = 150
maxdYZcut = 200
delta_theta_12 = 55
r_max_RdQ_CC1p = 0.43
delta_Delta_phi = 35
Pt_max = 0.35
Chi2Proton_muCandidate_min = 80
Chi2Proton_pCandidate_max = 30
extract_Xsec_full_chain(extra_name='',deubg=1
                            ,minPEcut = minPEcut,maxdYZcut = maxdYZcut
                            ,delta_theta_12 = delta_theta_12,r_max_RdQ_CC1p = r_max_RdQ_CC1p
                            ,delta_Delta_phi = delta_Delta_phi,Pt_max = Pt_max
                            ,Chi2Proton_muCandidate_min = Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max = Chi2Proton_pCandidate_max)
# Out:
# found selected overlay files from , loading them...
# 9538 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# Pmu weights and Pp weights already exist.
# already performed correction for phi~0 and saved the samples...
# {   'excluding the last $\\cos\\theta_\\mu$ bin': {   'Pmu': array([ 21.42633605,  78.12092732,  60.75261811,  26.30247124,
#         10.40763262,   0.60582588,  -0.13691744]),
#                                                       'Pmu err': array([  8.85575212,  10.77717013,   7.78173778,   6.21209292,
#          4.0373398 ,   1.02463883,   0.13558009]),
#                                                       'cos(theta(mu))': array([ -3.12165034,  26.2133765 ,  10.54662386,  27.84134508,
#         30.71668792,  71.25845517,   0.        ]),
#                                                       'cos(theta(mu)) err': array([ 5.5749806 ,  6.57396129,  5.06425321,  4.88843612,  5.33363504,
#         7.79928898,  0.        ]),
#                                                       'integrated Xsec': 39.495778754878174,
#                                                       'integrated Xsec err': 7.8877837483334545,
#                                                       'mc Pmu': array([ 31.67952338,  66.62981175,  51.77909572,  26.86356244,
#          8.91644205,   1.77968095,   0.15632333]),
#                                                       'mc Pmu err': array([ 1.35273511,  1.51647801,  1.35583271,  1.13050579,  0.67947242,
#         0.27904318,  0.08249316]),
#                                                       'mc Xsec': 37.56088792516654,
#                                                       'mc Xsec err': 1.2483810718771595,
#                                                       'mc cos(theta(mu))': array([  5.47263484,   9.1843505 ,  13.77891242,  21.82861964,
#         35.60617708,  69.56216393,   0.        ]),
#                                                       'mc cos(theta(mu)) err': array([ 0.69263121,  0.73328332,  0.76102138,  0.81213081,  1.00329691,
#         1.44038993,  0.        ]),
#                                                       'mc phi(mu)': array([ 0.10430574,  0.10559173,  0.10395501,  0.10213124,  0.10369781,
#         0.10629318,  0.10437588]),
#                                                       'mc phi(mu) err': array([ 0.00388609,  0.00469273,  0.00334571,  0.00299226,  0.00354869,
#         0.0054801 ,  0.00423683]),
#                                                       'phi(mu)': array([ 0.10186715,  0.16213873,  0.08141227,  0.10494874,  0.12092174,
#         0.08653352,  0.11015133]),
#                                                       'phi(mu) err': array([ 0.01872976,  0.03607159,  0.01561595,  0.01186489,  0.01855027,
#         0.04241452,  0.02291263])},
#     'with the last $\\cos\\theta_\\mu$ bin': {   'Pmu': array([ 20.6905176 ,  80.44102972,  67.93240128,  35.27876831,
#         20.58880647,   8.77710727,   8.0368581 ]),
#                                                  'Pmu err': array([  8.91040956,  10.85067325,   8.15757343,   6.9945705 ,
#          5.68983642,   3.52717889,   3.10061877]),
#                                                  'cos(theta(mu))': array([ -3.12165034,  26.2133765 ,  10.54662386,  27.84134508,
#         30.71668792,  71.25845517,  59.02212663]),
#                                                  'cos(theta(mu)) err': array([ 5.5749806 ,  6.57396129,  5.06425321,  4.88843612,  5.33363504,
#         7.79928898,  9.97293521]),
#                                                  'integrated Xsec': 48.349097749638553,
#                                                  'integrated Xsec err': 8.5677487761953053,
#                                                  'mc Pmu': array([ 32.44310271,  71.59007116,  66.26305318,  50.73293192,
#         34.24082097,  19.60655262,   8.56170835]),
#                                                  'mc Pmu err': array([ 1.36954075,  1.54793573,  1.4756803 ,  1.39699714,  1.22464846,
#         1.02247722,  0.64814168]),
#                                                  'mc Xsec': 56.687648180564317,
#                                                  'mc Xsec err': 1.507732829691703,
#                                                  'mc cos(theta(mu))': array([   5.47263484,    9.1843505 ,   13.77891242,   21.82861964,
#          35.60617708,   69.56216393,  127.51173504]),
#                                                  'mc cos(theta(mu)) err': array([ 0.69263121,  0.73328332,  0.76102138,  0.81213081,  1.00329691,
#         1.44038993,  2.52067537]),
#                                                  'mc phi(mu)': array([ 0.15836421,  0.15983726,  0.1571016 ,  0.15431918,  0.15565194,
#         0.15873832,  0.15824731]),
#                                                  'mc phi(mu) err': array([ 0.00485377,  0.00566314,  0.00395819,  0.00357529,  0.00417946,
#         0.00657045,  0.00521333]),
#                                                  'phi(mu)': array([ 0.13928697,  0.20638518,  0.09730126,  0.13777679,  0.13652523,
#         0.10165551,  0.12119041]),
#                                                  'phi(mu) err': array([ 0.02313188,  0.03910238,  0.01748359,  0.01353647,  0.02020201,
#         0.0442197 ,  0.02518513])}}
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1D.txt
# {   'excluding the last $\\cos\\theta_\\mu$ bin': {   'Pp': array([ 44.8995387 ,  44.61435227,  74.88416184,  58.80019117,
#         56.39353327,  89.03935267,  22.87126805]),
#                                                       'Pp err': array([ 18.13836878,   8.16033083,   9.80808629,  12.69647494,
#         11.41291697,  28.37669771,  11.7273365 ]),
#                                                       'cos(theta(p))': array([  3.37025923,  27.00833235,  36.42526204,  37.34995755,
#         86.92912484,  78.14199217,  66.38456393]),
#                                                       'cos(theta(p)) err': array([  4.17988305,  12.57535639,  12.94191472,   7.789751  ,
#         25.90802809,  12.35326812,  11.09221616]),
#                                                       'integrated Xsec': 39.150239797121827,
#                                                       'integrated Xsec err': 13.137779575231004,
#                                                       'mc Pp': array([ 41.36761472,  53.79872592,  61.83430635,  63.96255993,
#         57.62904455,  46.16351387,  33.29586615]),
#                                                       'mc Pp err': array([ 2.11680905,  1.73157063,  1.93206457,  1.9715751 ,  2.14517976,
#         2.66045383,  2.73690919]),
#                                                       'mc Xsec': 35.805163147453115,
#                                                       'mc Xsec err': 1.8512072250474216,
#                                                       'mc cos(theta(p))': array([  2.95952771,   6.56435924,  14.45879442,  31.26728137,
#         63.47329998,  92.05298752,  86.42984985]),
#                                                       'mc cos(theta(p)) err': array([ 0.64226623,  1.00954568,  1.36793023,  1.63185051,  2.38906537,
#         2.67617737,  2.32278658]),
#                                                       'mc phi(p)': array([ 0.09710805,  0.09989446,  0.09927301,  0.09836313,  0.10186542,
#         0.10451769,  0.09518975]),
#                                                       'mc phi(p) err': array([ 0.00324638,  0.00451848,  0.00495887,  0.0053646 ,  0.00412169,
#         0.00431117,  0.00310958]),
#                                                       'phi(p)': array([ 0.10077685,  0.12839613,  0.15050716,  0.13438908,  0.10658986,
#         0.06200118,  0.0785944 ]),
#                                                       'phi(p) err': array([ 0.01503635,  0.02914042,  0.05390846,  0.0391692 ,  0.01909376,
#         0.02124344,  0.01394127])},
#     'with the last $\\cos\\theta_\\mu$ bin': {   'Pp': array([ 51.56295139,  75.61901338,  91.3260483 ,  65.47937575,
#         80.93476403,  93.61314866,  20.23290379]),
#                                                  'Pp err': array([ 19.43897249,  10.67342976,  11.46486767,  13.64531854,
#         14.49146996,  28.86602706,  11.86262135]),
#                                                  'cos(theta(p))': array([  17.29394934,   34.02796861,   53.02194724,   52.8703314 ,
#         115.20623767,   79.45754662,   64.73860412]),
#                                                  'cos(theta(p)) err': array([  6.7418197 ,  13.09404434,  15.25897852,   9.89832894,
#         26.87222484,  13.18407212,  11.34543913]),
#                                                  'integrated Xsec': 47.87682053065582,
#                                                  'integrated Xsec err': 14.118801889616448,
#                                                  'mc Pp': array([  79.7970458 ,   93.92626956,  101.73041102,   93.697797  ,
#          76.11743519,   59.1142672 ,   39.42955292]),
#                                                  'mc Pp err': array([ 2.87488927,  2.27881096,  2.42836154,  2.38141279,  2.47823026,
#         3.0903912 ,  2.97611234]),
#                                                  'mc Xsec': 54.381277869366521,
#                                                  'mc Xsec err': 2.2265538827041995,
#                                                  'mc cos(theta(p))': array([   7.96106436,   15.60888584,   37.06749312,   76.45813988,
#         109.64696847,  120.64954183,   97.05674438]),
#                                                  'mc cos(theta(p)) err': array([ 0.92197786,  1.36638446,  1.90130292,  2.32865297,  3.1053221 ,
#         3.05480245,  2.44507986]),
#                                                  'mc phi(p)': array([ 0.14889463,  0.15261232,  0.15132632,  0.1479126 ,  0.15555841,
#         0.15099898,  0.15011048]),
#                                                  'mc phi(p) err': array([ 0.0039223 ,  0.00550625,  0.00599847,  0.00641026,  0.00493756,
#         0.00506468,  0.00382508]),
#                                                  'phi(p)': array([ 0.1457728 ,  0.13833598,  0.18596915,  0.12306221,  0.15080459,
#         0.08392024,  0.1030732 ]),
#                                                  'phi(p) err': array([ 0.01830234,  0.03121873,  0.05666444,  0.04002189,  0.02299872,
#         0.02459664,  0.01675304])}}
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1D.txt

# %%
def Draw_Xsecs(do_corr_phi_0=True, debug=0, particle='mu',
               do_last_ctu_bin=False,
               do_P=True, do_cos_theta=True, do_phi=True,               
               extra_name="",residuals_ylim=[-2,2],residuals_yticks=[-1,0,1],residuals_ytitle=1.05):    
    infilename = Paths['1d Xsec'] + "P"+particle + "Xsecs_1D"+extra_name+".txt"
    print "drawing cross-section from",infilename
    with open(infilename, 'rb') as infile:#{
        Xsec_dicts = pickle.load(infile)
    #}
    if debug: pp.pprint(Xsec_dicts)
    for iXsec,(Xsec_title,do_draw_Xsecs) in enumerate(zip(Xsec_ctu_titles,[True,do_last_ctu_bin])):#{
        if do_draw_Xsecs==False: continue
        fig=plt.figure(figsize=(24,8))            
        Xsec_dict = Xsec_dicts[Xsec_title]
        for i,(observable,true,ivar,do_var) in enumerate(zip(['P'+particle,'cos(theta('+particle+'))','phi('+particle+')']                                                        
                                                                 ,['truth_P'+particle,'truth_P'+particle+'_cos_theta','truth_P'+particle+'_phi']
                                                                 ,[(1,4),(2,5),(3,6)]
                                                                 ,[do_P,do_cos_theta,do_phi])):#{
            var,bins,mid,bin_width,vlabel,xlabel,units = get_labels(observable=observable)

            h = dict()
            h['Xsec'],h['Xsec err'] = Xsec_dict[observable],Xsec_dict[observable+' err']
            h['mc Xsec'],h['mc Xsec err'] = Xsec_dict['mc '+observable], Xsec_dict['mc '+observable+' err']
            ax = fig.add_subplot(3,3,ivar)
            if iXsec==0 and var=='reco_Pmu_cos_theta':
                mid=mid[:-1]; bin_width=bin_width[:-1]; bins=bins[:-1]
                h['Xsec']=h['Xsec'][:-1];h['Xsec err']=h['Xsec err'][:-1]
                h['mc Xsec']=h['mc Xsec'][:-1];h['mc Xsec err']=h['mc Xsec err'][:-1]
                
            plt.errorbar(x=mid,xerr=0.5*bin_width,y=h['Xsec'],yerr=h['Xsec err'],color=Colors['beam on'],fmt='o',label='data')
            ax.bar( x=mid , height=2*h['mc Xsec err'], bottom=h['mc Xsec']-h['mc Xsec err'], width=bin_width, color=Colors['CC1p'],label='overlay') 

            
            set_axes(ax,'',y_label=(r'$\frac{d\sigma}{d'+vlabel+'}$' 
                                        +(r'$\left[10^{-39} \frac{cm^{2}}{%s}\right]$'%units if units is not None 
                                          else r'$\left[10^{-39}cm^{2}\right]$'))
                         ,do_add_grid=True,remove_ticks_x=True,do_add_legend=True if 'Pmu_cos_theta' in var else False
                         ,ylim=(0,1.1*np.max(ax.get_ylim())))
            plt.title(Xsec_title, y=1.02,fontsize=25)
                    
            # residuals plot
            den, den_err = h['Xsec']-h['mc Xsec'],np.sqrt(np.square(h['Xsec err'])+np.square(h['mc Xsec err']))
            num, num_err = h['Xsec'],h['mc Xsec err']
            ratio = np.array([den[j]/(num[j] if np.abs(num[j])>0 else 1000) for j in range(len(num))])
            ax = fig.add_subplot(3,3,7+i)
            ratio_err = ratio*np.sqrt(np.square(den_err/den) + np.square(num_err/num))
            plt.errorbar(x=mid,xerr=0.5*bin_width,y=ratio,yerr=ratio_err,fmt='o',markersize=0,color='black')
            chi2,ndf = chi2_two_data_curves(h1=h['Xsec'],h1err=h['Xsec err'],h2=h['mc Xsec'],h2err=h['mc Xsec err'],bins=bins,debug=0)
            set_axes(ax,xlabel,y_label=r'(data-mc)/data',do_add_grid=True,ylim=residuals_ylim,yticks=residuals_yticks)
            plt.plot([np.min(bins),np.max(bins)],[0,0],'--',color='royalblue')
            plt.title(r'$\chi^2/ndf=%.2f/%d$'%(chi2,ndf), fontsize=20,y=residuals_ytitle)
        #}     
        plt.tight_layout()
        plt.subplots_adjust(hspace=0.05)
    #}

# %%
# Draw_Xsecs(particle='mu',debug=0)
Draw_Xsecs(particle='p',debug=0)
# Out:
# drawing cross-section from /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1D.txt

# %% [markdown]
# # extract the cross-sections for different cut-parameter values

# %%
Nrand = 100

for irand in range(Nrand):
    if irand%(Nrand/10)==0: print '%.1f'%(100.*float(irand)/Nrand)+'%'
    Chi2Proton_muCandidate_min = np.random.normal( 80 , 10)
    Chi2Proton_pCandidate_max = np.random.normal( 30 , 5)
    minPEcut = np.random.normal( 150 , 20)
    maxdYZcut = np.random.normal( 200 , 50)
    delta_theta_12 = np.random.normal( 55 , 5 )
    r_max_RdQ_CC1p0pi = np.random.normal( 0.43 , 0.05 )
    delta_Delta_phi = np.random.normal( 35 , 5 )
    Pt_max = np.random.normal( 0.35 , 0.05 )
    print 'Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max:',Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max
    extract_Xsec_full_chain(extra_name='VaryAllCuts_%d'%irand,deubg=0
                                ,minPEcut = minPEcut,maxdYZcut = maxdYZcut
                                ,delta_theta_12 = delta_theta_12,r_max_RdQ_CC1p = r_max_RdQ_CC1p
                                ,delta_Delta_phi = delta_Delta_phi,Pt_max = Pt_max
                                ,Chi2Proton_muCandidate_min = Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max = Chi2Proton_pCandidate_max)
    print_line();print_line()
# Out:
# 0.0%
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 76.9342235627 31.1306932184
# found selected overlay files from VaryAllCuts_0, loading them...
# 8789 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.60730834593
# correction for phi(p)~0: 1.80405747769
# saved  11231 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_0selected_overlayVaryAllCuts_0.csv
# saved  8789 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_0selected_CC1pVaryAllCuts_0.csv
# saved  434 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_0selected_beam_onVaryAllCuts_0.csv
# saved  11 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_0selected_beam_offVaryAllCuts_0.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_0.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_0.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 79.2602214919 31.489705314
# found selected overlay files from VaryAllCuts_1, loading them...
# 9021 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.49255962413
# correction for phi(p)~0: 2.51292150864
# saved  11334 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_1selected_overlayVaryAllCuts_1.csv
# saved  9021 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_1selected_CC1pVaryAllCuts_1.csv
# saved  428 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_1selected_beam_onVaryAllCuts_1.csv
# saved  11 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_1selected_beam_offVaryAllCuts_1.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_1.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_1.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 64.3904031483 26.2088008161
# found selected overlay files from VaryAllCuts_2, loading them...
# 8990 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.75037369562
# correction for phi(p)~0: 1.70608619758
# saved  11161 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_2selected_overlayVaryAllCuts_2.csv
# saved  8990 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_2selected_CC1pVaryAllCuts_2.csv
# saved  395 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_2selected_beam_onVaryAllCuts_2.csv
# saved  9 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_2selected_beam_offVaryAllCuts_2.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_2.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_2.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 87.1273548205 31.6044115603
# found selected overlay files from VaryAllCuts_3, loading them...
# 9626 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.74844065758
# correction for phi(p)~0: 1.80900542356
# saved  12355 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_3selected_overlayVaryAllCuts_3.csv
# saved  9626 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_3selected_CC1pVaryAllCuts_3.csv
# saved  472 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_3selected_beam_onVaryAllCuts_3.csv
# saved  16 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_3selected_beam_offVaryAllCuts_3.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_3.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_3.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 78.3757323681 27.4444159048
# found selected overlay files from VaryAllCuts_4, loading them...
# 9197 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.02199682195
# correction for phi(p)~0: 1.36675933127
# saved  11578 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_4selected_overlayVaryAllCuts_4.csv
# saved  9197 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_4selected_CC1pVaryAllCuts_4.csv
# saved  422 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_4selected_beam_onVaryAllCuts_4.csv
# saved  16 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_4selected_beam_offVaryAllCuts_4.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_4.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_4.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 81.5025963053 27.5134780932
# found selected overlay files from VaryAllCuts_5, loading them...
# 10020 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.59951510957
# correction for phi(p)~0: 1.15364736211
# saved  13060 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_5selected_overlayVaryAllCuts_5.csv
# saved  10020 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_5selected_CC1pVaryAllCuts_5.csv
# saved  515 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_5selected_beam_onVaryAllCuts_5.csv
# saved  18 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_5selected_beam_offVaryAllCuts_5.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_5.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_5.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 72.4053175302 36.8406422165
# found selected overlay files from VaryAllCuts_6, loading them...
# 8183 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 2.81062555834
# correction for phi(p)~0: 1.33845152293
# saved  10080 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_6selected_overlayVaryAllCuts_6.csv
# saved  8183 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_6selected_CC1pVaryAllCuts_6.csv
# saved  366 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_6selected_beam_onVaryAllCuts_6.csv
# saved  11 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_6selected_beam_offVaryAllCuts_6.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_6.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_6.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 81.037485007 30.7996857158
# found selected overlay files from VaryAllCuts_7, loading them...
# 9051 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.51104705173
# correction for phi(p)~0: 2.0306785278
# saved  11326 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_7selected_overlayVaryAllCuts_7.csv
# saved  9051 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_7selected_CC1pVaryAllCuts_7.csv
# saved  427 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_7selected_beam_onVaryAllCuts_7.csv
# saved  14 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_7selected_beam_offVaryAllCuts_7.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_7.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_7.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 90.2629677976 25.9020805825
# found selected overlay files from VaryAllCuts_8, loading them...
# 9659 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.24720736848
# correction for phi(p)~0: 0.960178380783
# saved  12445 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_8selected_overlayVaryAllCuts_8.csv
# saved  9659 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_8selected_CC1pVaryAllCuts_8.csv
# saved  489 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_8selected_beam_onVaryAllCuts_8.csv
# saved  18 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_8selected_beam_offVaryAllCuts_8.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_8.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_8.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 70.036892233 31.3567791134
# found selected overlay files from VaryAllCuts_9, loading them...
# 10449 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.17528572771
# correction for phi(p)~0: 0.981339693717
# saved  13638 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_9selected_overlayVaryAllCuts_9.csv
# saved  10449 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_9selected_CC1pVaryAllCuts_9.csv
# saved  537 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_9selected_beam_onVaryAllCuts_9.csv
# saved  17 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_9selected_beam_offVaryAllCuts_9.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_9.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_9.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# 10.0%
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 71.0596637233 31.3921122683
# found selected overlay files from VaryAllCuts_10, loading them...
# 9557 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.37309601098
# correction for phi(p)~0: 1.89608942017
# saved  12130 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_10selected_overlayVaryAllCuts_10.csv
# saved  9557 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_10selected_CC1pVaryAllCuts_10.csv
# saved  459 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_10selected_beam_onVaryAllCuts_10.csv
# saved  13 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_10selected_beam_offVaryAllCuts_10.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_10.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_10.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 98.2368638809 32.5203637273
# found selected overlay files from VaryAllCuts_11, loading them...
# 9093 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.20764978938
# correction for phi(p)~0: 1.14186659275
# saved  11519 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_11selected_overlayVaryAllCuts_11.csv
# saved  9093 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_11selected_CC1pVaryAllCuts_11.csv
# saved  441 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_11selected_beam_onVaryAllCuts_11.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_11selected_beam_offVaryAllCuts_11.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_11.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_11.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 69.7080408805 18.0896574504
# found selected overlay files from VaryAllCuts_12, loading them...
# 10012 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 4.00249342588
# correction for phi(p)~0: 1.39477099845
# saved  13086 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_12selected_overlayVaryAllCuts_12.csv
# saved  10012 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_12selected_CC1pVaryAllCuts_12.csv
# saved  510 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_12selected_beam_onVaryAllCuts_12.csv
# saved  21 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_12selected_beam_offVaryAllCuts_12.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_12.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_12.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 73.5323863649 31.9925038638
# found selected overlay files from VaryAllCuts_13, loading them...
# 10207 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.51991755789
# correction for phi(p)~0: 1.14492676857
# saved  13307 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_13selected_overlayVaryAllCuts_13.csv
# saved  10207 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_13selected_CC1pVaryAllCuts_13.csv
# saved  500 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_13selected_beam_onVaryAllCuts_13.csv
# saved  22 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_13selected_beam_offVaryAllCuts_13.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_13.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_13.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 72.742923017 26.8076161899
# found selected overlay files from VaryAllCuts_14, loading them...
# 10177 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.86719487717
# correction for phi(p)~0: 1.27859156879
# saved  13144 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_14selected_overlayVaryAllCuts_14.csv
# saved  10177 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_14selected_CC1pVaryAllCuts_14.csv
# saved  515 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_14selected_beam_onVaryAllCuts_14.csv
# saved  23 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_14selected_beam_offVaryAllCuts_14.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_14.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_14.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 86.5608985354 31.8851075935
# found selected overlay files from VaryAllCuts_15, loading them...
# 9313 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.00671270388
# correction for phi(p)~0: 1.22029699794
# saved  11931 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_15selected_overlayVaryAllCuts_15.csv
# saved  9313 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_15selected_CC1pVaryAllCuts_15.csv
# saved  448 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_15selected_beam_onVaryAllCuts_15.csv
# saved  11 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_15selected_beam_offVaryAllCuts_15.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_15.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_15.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 82.5373356389 23.8473568384
# found selected overlay files from VaryAllCuts_16, loading them...
# 9200 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.1351854851
# correction for phi(p)~0: 1.43143887598
# saved  11606 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_16selected_overlayVaryAllCuts_16.csv
# saved  9200 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_16selected_CC1pVaryAllCuts_16.csv
# saved  449 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_16selected_beam_onVaryAllCuts_16.csv
# saved  14 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_16selected_beam_offVaryAllCuts_16.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_16.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_16.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 66.5114886958 33.8740828293
# found selected overlay files from VaryAllCuts_17, loading them...
# 7131 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.66377154675
# correction for phi(p)~0: 1.51942308364
# saved  8998 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_17selected_overlayVaryAllCuts_17.csv
# saved  7131 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_17selected_CC1pVaryAllCuts_17.csv
# saved  335 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_17selected_beam_onVaryAllCuts_17.csv
# saved  7 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_17selected_beam_offVaryAllCuts_17.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_17.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_17.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 74.6894391359 35.3709518593
# found selected overlay files from VaryAllCuts_18, loading them...
# 9068 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.19785278083
# correction for phi(p)~0: 2.04572903344
# saved  11340 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_18selected_overlayVaryAllCuts_18.csv
# saved  9068 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_18selected_CC1pVaryAllCuts_18.csv
# saved  438 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_18selected_beam_onVaryAllCuts_18.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_18selected_beam_offVaryAllCuts_18.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_18.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_18.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 69.715551654 24.5833239944
# found selected overlay files from VaryAllCuts_19, loading them...
# 6892 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.5507752539
# correction for phi(p)~0: 1.78238403917
# saved  8492 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_19selected_overlayVaryAllCuts_19.csv
# saved  6892 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_19selected_CC1pVaryAllCuts_19.csv
# saved  309 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_19selected_beam_onVaryAllCuts_19.csv
# saved  3 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_19selected_beam_offVaryAllCuts_19.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_19.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_19.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# 20.0%
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 75.6634416294 28.5886957299
# found selected overlay files from VaryAllCuts_20, loading them...
# 8828 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 2.87407850988
# correction for phi(p)~0: 1.90577248375
# saved  11111 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_20selected_overlayVaryAllCuts_20.csv
# saved  8828 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_20selected_CC1pVaryAllCuts_20.csv
# saved  419 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_20selected_beam_onVaryAllCuts_20.csv
# saved  11 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_20selected_beam_offVaryAllCuts_20.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_20.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_20.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 77.7997143422 28.9352817118
# found selected overlay files from VaryAllCuts_21, loading them...
# 9861 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.21597553673
# correction for phi(p)~0: 1.69358352365
# saved  12676 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_21selected_overlayVaryAllCuts_21.csv
# saved  9861 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_21selected_CC1pVaryAllCuts_21.csv
# saved  488 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_21selected_beam_onVaryAllCuts_21.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_21selected_beam_offVaryAllCuts_21.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_21.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_21.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 77.5065101654 32.6784133007
# found selected overlay files from VaryAllCuts_22, loading them...
# 9005 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.46800109268
# correction for phi(p)~0: 1.64385139962
# saved  11245 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_22selected_overlayVaryAllCuts_22.csv
# saved  9005 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_22selected_CC1pVaryAllCuts_22.csv
# saved  414 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_22selected_beam_onVaryAllCuts_22.csv
# saved  9 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_22selected_beam_offVaryAllCuts_22.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_22.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_22.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 93.6556351373 33.5087981271
# found selected overlay files from VaryAllCuts_23, loading them...
# 9504 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.73262146744
# correction for phi(p)~0: 1.84346631505
# saved  12116 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_23selected_overlayVaryAllCuts_23.csv
# saved  9504 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_23selected_CC1pVaryAllCuts_23.csv
# saved  468 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_23selected_beam_onVaryAllCuts_23.csv
# saved  17 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_23selected_beam_offVaryAllCuts_23.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_23.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_23.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 72.126449037 29.648179096
# found selected overlay files from VaryAllCuts_24, loading them...
# 8996 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 2.97989334232
# correction for phi(p)~0: 1.12116499282
# saved  11594 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_24selected_overlayVaryAllCuts_24.csv
# saved  8996 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_24selected_CC1pVaryAllCuts_24.csv
# saved  427 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_24selected_beam_onVaryAllCuts_24.csv
# saved  10 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_24selected_beam_offVaryAllCuts_24.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_24.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_24.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 65.0790217006 35.2215337993
# found selected overlay files from VaryAllCuts_25, loading them...
# 9612 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 2.8603604336
# correction for phi(p)~0: 1.56508506648
# saved  12182 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_25selected_overlayVaryAllCuts_25.csv
# saved  9612 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_25selected_CC1pVaryAllCuts_25.csv
# saved  458 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_25selected_beam_onVaryAllCuts_25.csv
# saved  12 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_25selected_beam_offVaryAllCuts_25.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_25.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_25.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 82.0806031141 32.2025607807
# found selected overlay files from VaryAllCuts_26, loading them...
# 9033 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.01985271933
# correction for phi(p)~0: 1.28294726789
# saved  11521 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_26selected_overlayVaryAllCuts_26.csv
# saved  9033 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_26selected_CC1pVaryAllCuts_26.csv
# saved  442 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_26selected_beam_onVaryAllCuts_26.csv
# saved  12 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_26selected_beam_offVaryAllCuts_26.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_26.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_26.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 98.0132819068 29.9321771797
# found selected overlay files from VaryAllCuts_27, loading them...
# 8646 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 2.52358988686
# correction for phi(p)~0: 1.24880706512
# saved  10785 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_27selected_overlayVaryAllCuts_27.csv
# saved  8646 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_27selected_CC1pVaryAllCuts_27.csv
# saved  390 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_27selected_beam_onVaryAllCuts_27.csv
# saved  10 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_27selected_beam_offVaryAllCuts_27.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_27.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_27.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 57.4619108692 25.6023456539
# found selected overlay files from VaryAllCuts_28, loading them...
# 9761 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# ...
# saved  11 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_90selected_beam_offVaryAllCuts_90.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_90.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_90.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 80.9249299541 30.5301897774
# found selected overlay files from VaryAllCuts_91, loading them...
# 9395 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.30581309535
# correction for phi(p)~0: 1.84467865542
# saved  11899 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_91selected_overlayVaryAllCuts_91.csv
# saved  9395 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_91selected_CC1pVaryAllCuts_91.csv
# saved  456 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_91selected_beam_onVaryAllCuts_91.csv
# saved  17 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_91selected_beam_offVaryAllCuts_91.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_91.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_91.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 70.6746451225 24.1686772476
# found selected overlay files from VaryAllCuts_92, loading them...
# 9729 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.6638957784
# correction for phi(p)~0: 1.17566014024
# saved  12452 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_92selected_overlayVaryAllCuts_92.csv
# saved  9729 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_92selected_CC1pVaryAllCuts_92.csv
# saved  490 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_92selected_beam_onVaryAllCuts_92.csv
# saved  22 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_92selected_beam_offVaryAllCuts_92.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_92.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_92.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 65.5186619601 22.4777753659
# found selected overlay files from VaryAllCuts_93, loading them...
# 9276 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.59236845014
# correction for phi(p)~0: 1.39009410716
# saved  11874 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_93selected_overlayVaryAllCuts_93.csv
# saved  9276 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_93selected_CC1pVaryAllCuts_93.csv
# saved  453 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_93selected_beam_onVaryAllCuts_93.csv
# saved  14 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_93selected_beam_offVaryAllCuts_93.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_93.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_93.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 87.8549097993 21.1758967603
# found selected overlay files from VaryAllCuts_94, loading them...
# 9326 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.74051264469
# correction for phi(p)~0: 1.74684693318
# saved  11815 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_94selected_overlayVaryAllCuts_94.csv
# saved  9326 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_94selected_CC1pVaryAllCuts_94.csv
# saved  460 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_94selected_beam_onVaryAllCuts_94.csv
# saved  16 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_94selected_beam_offVaryAllCuts_94.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_94.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_94.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 91.2205210483 25.1457450487
# found selected overlay files from VaryAllCuts_95, loading them...
# 7691 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.41555405879
# correction for phi(p)~0: 1.37659568525
# saved  9856 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_95selected_overlayVaryAllCuts_95.csv
# saved  7691 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_95selected_CC1pVaryAllCuts_95.csv
# saved  373 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_95selected_beam_onVaryAllCuts_95.csv
# saved  8 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_95selected_beam_offVaryAllCuts_95.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_95.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_95.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 75.9163368365 28.771120517
# found selected overlay files from VaryAllCuts_96, loading them...
# 9359 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.47956000657
# correction for phi(p)~0: 1.94367411454
# saved  11803 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_96selected_overlayVaryAllCuts_96.csv
# saved  9359 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_96selected_CC1pVaryAllCuts_96.csv
# saved  446 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_96selected_beam_onVaryAllCuts_96.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_96selected_beam_offVaryAllCuts_96.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_96.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_96.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 82.0243445169 39.3070193596
# found selected overlay files from VaryAllCuts_97, loading them...
# 8751 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.95040833548
# correction for phi(p)~0: 1.62905496834
# saved  10835 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_97selected_overlayVaryAllCuts_97.csv
# saved  8751 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_97selected_CC1pVaryAllCuts_97.csv
# saved  393 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_97selected_beam_onVaryAllCuts_97.csv
# saved  9 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_97selected_beam_offVaryAllCuts_97.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_97.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_97.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 89.4472334754 20.2179219748
# found selected overlay files from VaryAllCuts_98, loading them...
# 8188 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 4.32177516634
# correction for phi(p)~0: 1.15568502506
# saved  10866 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_98selected_overlayVaryAllCuts_98.csv
# saved  8188 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_98selected_CC1pVaryAllCuts_98.csv
# saved  411 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_98selected_beam_onVaryAllCuts_98.csv
# saved  9 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_98selected_beam_offVaryAllCuts_98.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_98.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_98.txt
# --------------------------------------------------------------
# --------------------------------------------------------------
# Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max: 83.3485850039 22.6817401224
# found selected overlay files from VaryAllCuts_99, loading them...
# 9281 selected CC1p events overlay
# found selected on beam events...
# found selected genie CC1p...
# done loading samples...
# no Pmu weights, computing them
# done.
# done.
# done assiging Pmu weights and Pp weights and saving the files.
# correction for phi(mu)~0: 3.31016161883
# correction for phi(p)~0: 2.06407886417
# saved  11622 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_99selected_overlayVaryAllCuts_99.csv
# saved  9281 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_VaryAllCuts_99selected_CC1pVaryAllCuts_99.csv
# saved  447 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_99selected_beam_onVaryAllCuts_99.csv
# saved  14 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_VaryAllCuts_99selected_beam_offVaryAllCuts_99.csv
# done performing iterative correction for phi~0 and saved the samples...
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1DVaryAllCuts_99.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1DVaryAllCuts_99.txt
# --------------------------------------------------------------
# --------------------------------------------------------------

# %% [markdown]
# # compute the mean and standard deviations of the cross-sections with different cut parameter values

# %%
varying_Xsec = dict()
mean_varying_Xsec,std_varying_Xsec = dict(), dict()

for particle in ['mu','p']:
    varying_Xsec[particle] = dict()
    mean_varying_Xsec[particle] = dict()
    std_varying_Xsec[particle] = dict()

    for iXsec,Xsec_title in enumerate(Xsec_ctu_titles):#{
        varying_Xsec[particle][Xsec_title] = dict()
        mean_varying_Xsec[particle][Xsec_title] = dict()
        std_varying_Xsec[particle][Xsec_title] = dict()
        for i,observable in enumerate(['P'+particle,'cos(theta('+particle+'))','phi('+particle+')']):#{
            var,bins,mid,bin_width,vlabel,xlabel,units = get_labels(observable=observable)
            if iXsec==0 and var=='reco_Pmu_cos_theta': bins=bins[:-1]        
            varying_Xsec[particle][Xsec_title][var] = dict()
            mean_varying_Xsec[particle][Xsec_title][var] = dict()
            std_varying_Xsec[particle][Xsec_title][var] = dict()
            for j_bin in range(len(bins)-1):#{
                varying_Xsec[particle][Xsec_title][var][j_bin] = []
            #}
        #}
    #}
    for irand in range(Nrand):
        extra_name='VaryAllCuts_%d'%irand
        infilename = Paths['1d Xsec'] + "P"+particle + "Xsecs_1D"+extra_name+".txt"
#         print "grabbing cross-section from",infilename
        with open(infilename, 'rb') as infile:#{
            Xsec_dicts = pickle.load(infile)
        #}
        for iXsec,Xsec_title in enumerate(Xsec_ctu_titles):#{
            Xsec_dict = Xsec_dicts[Xsec_title]
            for i,observable in enumerate(['P'+particle,'cos(theta('+particle+'))','phi('+particle+')']):#{
                var,bins,mid,bin_width,vlabel,xlabel,units = get_labels(observable=observable)
                h = dict()
                h['Xsec'] = Xsec_dict[observable]
                h['mc Xsec'] = Xsec_dict['mc '+observable]
                if iXsec==0 and var=='reco_Pmu_cos_theta':
                    bins=bins[:-1];h['Xsec']=h['Xsec'][:-1];h['mc Xsec']=h['mc Xsec'][:-1];
                for j_bin in range(len(bins)-1):
                    varying_Xsec[particle][Xsec_title][var][j_bin].append(h['Xsec'][j_bin])
                #}
            #}
        #}
    #}
    for iXsec,Xsec_title in enumerate(Xsec_ctu_titles):#{
        for i,observable in enumerate(['P'+particle,'cos(theta('+particle+'))','phi('+particle+')']):#{
            var,bins,mid,bin_width,vlabel,xlabel,units = get_labels(observable=observable)
            if iXsec==0 and var=='reco_Pmu_cos_theta': bins=bins[:-1]        
            for j_bin in range(len(bins)-1):
                mean_varying_Xsec[particle][Xsec_title][var][j_bin] = np.mean(varying_Xsec[particle][Xsec_title][var][j_bin])
                std_varying_Xsec[particle][Xsec_title][var][j_bin] = np.std(varying_Xsec[particle][Xsec_title][var][j_bin])
    print 'done',particle
# Out:
# done mu
# done p

# %%
do_last_ctu_bin = True
for particle in ['mu','p']:
    with open(Paths['1d Xsec'] + "P" +particle + "Xsecs_1D.txt", 'rb') as infile:#{
        nominal_Xsec_dicts = pickle.load(infile)
    #}
    for iXsec,(Xsec_title,Xsec_fname,do_draw_Xsecs) in enumerate(zip(Xsec_ctu_titles,Xsec_fnames,[True,do_last_ctu_bin])):#{
        if do_draw_Xsecs==False: continue
        fig=plt.figure(figsize=(24,8))            
        Xsec_dict = nominal_Xsec_dicts[Xsec_title]
        for i,observable in enumerate(['P'+particle,'cos(theta('+particle+'))','phi('+particle+')']):#{
            var,bins,mid,bin_width,vlabel,xlabel,units = get_labels(observable=observable)
            h = dict()
            h['Xsec'],h['Xsec err'] = Xsec_dict[observable],Xsec_dict[observable+' err']
            h['mc Xsec'],h['mc Xsec err'] = Xsec_dict['mc '+observable], Xsec_dict['mc '+observable+' err']
            ax = fig.add_subplot(1,3,i+1)
            if iXsec==0 and var=='reco_Pmu_cos_theta':
                mid=mid[:-1]; bin_width=bin_width[:-1]; bins=bins[:-1]
                h['Xsec']=h['Xsec'][:-1];h['Xsec err']=h['Xsec err'][:-1]
                h['mc Xsec']=h['mc Xsec'][:-1];h['mc Xsec err']=h['mc Xsec err'][:-1]

            plt.errorbar(x=mid,xerr=0.5*bin_width,y=h['Xsec'],yerr=h['Xsec err'],color=Colors['beam on'],fmt='o',label='data')
            ax.bar( x=mid , height=2*h['mc Xsec err'], bottom=h['mc Xsec']-h['mc Xsec err'], width=bin_width, color=Colors['CC1p'],label='overlay') 

            varying_Xsec_avg = np.array(mean_varying_Xsec[particle][Xsec_title][var].values())
            varying_Xsec_std = np.array(std_varying_Xsec[particle][Xsec_title][var].values())
            ax.bar( x=mid , height=2*varying_Xsec_std, bottom=varying_Xsec_avg-varying_Xsec_std, width=bin_width, color='green',label='varying cut values',alpha=0.5)
            set_axes(ax,xlabel,y_label=get_Xsec_label(vlabel,units)
                             ,do_add_grid=True,do_add_legend=True if 'Pmu_cos_theta' in var else False
                             ,ylim=(0,1.1*np.max(ax.get_ylim())))
            plt.title(Xsec_title, y=1.02,fontsize=25)
        plt.tight_layout(h_pad=0)
        save_figure(figures_path + 'cut_sensitivty_'+particle+'_'+Xsec_fname+'.pdf')
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/XsecCCQE/Figures/overlay_8.11/systematics/cut_sensitivty_mu_without_last_ctu_bin.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/XsecCCQE/Figures/overlay_8.11/systematics/cut_sensitivty_mu_with_last_ctu_bin.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/XsecCCQE/Figures/overlay_8.11/systematics/cut_sensitivty_p_without_last_ctu_bin.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/XsecCCQE/Figures/overlay_8.11/systematics/cut_sensitivty_p_with_last_ctu_bin.pdf

# %%
Xsec_sys_unc = dict()
for particle in ['mu','p']:
    with open(Paths['1d Xsec'] + "P" +particle + "Xsecs_1D.txt", 'rb') as infile: nominal_Xsec_dicts = pickle.load(infile)
    for iXsec,(Xsec_title,Xsec_fname) in enumerate(zip(Xsec_ctu_titles,Xsec_fnames)):#{
        Xsec_dict = nominal_Xsec_dicts[Xsec_title]
        for i,observable in enumerate(['P'+particle,'cos(theta('+particle+'))','phi('+particle+')']
                                     ):#{
            var,bins,mid,bin_width,vlabel,xlabel,units = get_labels(observable=observable)
            h = dict()
            h['Xsec'],h['Xsec err'] = Xsec_dict[observable],Xsec_dict[observable+' err']
            h['mc Xsec'],h['mc Xsec err'] = Xsec_dict['mc '+observable], Xsec_dict['mc '+observable+' err']
            if iXsec==0 and var=='reco_Pmu_cos_theta':
                mid=mid[:-1]; bin_width=bin_width[:-1]; bins=bins[:-1]
                h['Xsec']=h['Xsec'][:-1];h['Xsec err']=h['Xsec err'][:-1]
                h['mc Xsec']=h['mc Xsec'][:-1];h['mc Xsec err']=h['mc Xsec err'][:-1]
                
            varying_Xsec_avg = np.array(mean_varying_Xsec[particle][Xsec_title][var].values())
            varying_Xsec_std = np.array(std_varying_Xsec[particle][Xsec_title][var].values())            
            Xsec_sys_unc[var + Xsec_fname + ' Xsec sys. err up'] = (varying_Xsec_avg + varying_Xsec_std) - h['Xsec']
            Xsec_sys_unc[var + Xsec_fname + ' Xsec sys. err dw'] = h['Xsec'] - (varying_Xsec_avg - varying_Xsec_std )

# %%
outfilename = Paths['systematics'] + "cut_sensitivty_systemaitcal_uncertainty.txt"
with open(outfilename, 'w') as outfile:
    outfile.write(pickle.dumps(Xsec_sys_unc))
print 'saved',outfilename
# Out:
# saved /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/systematics/cut_sensitivty_systemaitcal_uncertainty.txt

# %%
with open(Paths['systematics'] + "cut_sensitivty_systemaitcal_uncertainty.txt", 'rb') as infile: 
    Xsec_sys_unc = pickle.load(infile)
Xsec_sys_unc
# Out:
# {'reco_Pmu_cos_thetawith_last_ctu_bin Xsec sys. err dw': array([ -3.12165034,  26.2133765 ,  10.54662386,  27.84134508,
#          30.71668792,  71.25845517,  59.02212663]),
#  'reco_Pmu_cos_thetawith_last_ctu_bin Xsec sys. err up': array([  3.12165034, -26.2133765 , -10.54662386, -27.84134508,
#         -30.71668792, -71.25845517, -59.02212663]),
#  'reco_Pmu_cos_thetawithout_last_ctu_bin Xsec sys. err dw': array([ -3.12165034,  26.2133765 ,  10.54662386,  27.84134508,
#          30.71668792,  71.25845517]),
#  'reco_Pmu_cos_thetawithout_last_ctu_bin Xsec sys. err up': array([  3.12165034, -26.2133765 , -10.54662386, -27.84134508,
#         -30.71668792, -71.25845517]),
#  'reco_Pmu_mcs_phiwith_last_ctu_bin Xsec sys. err dw': array([ 0.13928697,  0.20638518,  0.09730126,  0.13777679,  0.13652523,
#          0.10165551,  0.12119041]),
#  'reco_Pmu_mcs_phiwith_last_ctu_bin Xsec sys. err up': array([-0.13928697, -0.20638518, -0.09730126, -0.13777679, -0.13652523,
#         -0.10165551, -0.12119041]),
#  'reco_Pmu_mcs_phiwithout_last_ctu_bin Xsec sys. err dw': array([ 0.10186715,  0.16213873,  0.08141227,  0.10494874,  0.12092174,
#          0.08653352,  0.11015133]),
#  'reco_Pmu_mcs_phiwithout_last_ctu_bin Xsec sys. err up': array([-0.10186715, -0.16213873, -0.08141227, -0.10494874, -0.12092174,
#         -0.08653352, -0.11015133]),
#  'reco_Pmu_mcswith_last_ctu_bin Xsec sys. err dw': array([ 20.6905176 ,  80.44102972,  67.93240128,  35.27876831,
#          20.58880647,   8.77710727,   8.0368581 ]),
#  'reco_Pmu_mcswith_last_ctu_bin Xsec sys. err up': array([-20.6905176 , -80.44102972, -67.93240128, -35.27876831,
#         -20.58880647,  -8.77710727,  -8.0368581 ]),
#  'reco_Pmu_mcswithout_last_ctu_bin Xsec sys. err dw': array([ 21.42633605,  78.12092732,  60.75261811,  26.30247124,
#          10.40763262,   0.60582588,  -0.13691744]),
#  'reco_Pmu_mcswithout_last_ctu_bin Xsec sys. err up': array([-21.42633605, -78.12092732, -60.75261811, -26.30247124,
#         -10.40763262,  -0.60582588,   0.13691744]),
#  'reco_Pp_cos_thetawith_last_ctu_bin Xsec sys. err dw': array([  17.29394934,   34.02796861,   53.02194724,   52.8703314 ,
#          115.20623767,   79.45754662,   64.73860412]),
#  'reco_Pp_cos_thetawith_last_ctu_bin Xsec sys. err up': array([ -17.29394934,  -34.02796861,  -53.02194724,  -52.8703314 ,
#         -115.20623767,  -79.45754662,  -64.73860412]),
#  'reco_Pp_cos_thetawithout_last_ctu_bin Xsec sys. err dw': array([  3.37025923,  27.00833235,  36.42526204,  37.34995755,
#          86.92912484,  78.14199217,  66.38456393]),
#  'reco_Pp_cos_thetawithout_last_ctu_bin Xsec sys. err up': array([ -3.37025923, -27.00833235, -36.42526204, -37.34995755,
#         -86.92912484, -78.14199217, -66.38456393]),
#  'reco_Pp_phiwith_last_ctu_bin Xsec sys. err dw': array([ 0.1457728 ,  0.13833598,  0.18596915,  0.12306221,  0.15080459,
#          0.08392024,  0.1030732 ]),
#  'reco_Pp_phiwith_last_ctu_bin Xsec sys. err up': array([-0.1457728 , -0.13833598, -0.18596915, -0.12306221, -0.15080459,
#         -0.08392024, -0.1030732 ]),
#  'reco_Pp_phiwithout_last_ctu_bin Xsec sys. err dw': array([ 0.10077685,  0.12839613,  0.15050716,  0.13438908,  0.10658986,
#          0.06200118,  0.0785944 ]),
#  'reco_Pp_phiwithout_last_ctu_bin Xsec sys. err up': array([-0.10077685, -0.12839613, -0.15050716, -0.13438908, -0.10658986,
#         -0.06200118, -0.0785944 ]),
#  'reco_Ppwith_last_ctu_bin Xsec sys. err dw': array([ 51.56295139,  75.61901338,  91.3260483 ,  65.47937575,
#          80.93476403,  93.61314866,  20.23290379]),
#  'reco_Ppwith_last_ctu_bin Xsec sys. err up': array([-51.56295139, -75.61901338, -91.3260483 , -65.47937575,
#         -80.93476403, -93.61314866, -20.23290379]),
#  'reco_Ppwithout_last_ctu_bin Xsec sys. err dw': array([ 44.8995387 ,  44.61435227,  74.88416184,  58.80019117,
#          56.39353327,  89.03935267,  22.87126805]),
#  'reco_Ppwithout_last_ctu_bin Xsec sys. err up': array([-44.8995387 , -44.61435227, -74.88416184, -58.80019117,
#         -56.39353327, -89.03935267, -22.87126805])}

# %%
versions['Overlay']='prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2'
versions['beam on']='prod_reco_optfilter_bnb_v12_unblind_mcc8'
versions['beam off']='prod_reco_optfilter_extbnb_v12_mcc8_dev'
versions['overlay date']='2018_09_22'
versions['data date']='2018_08_16'

extra_name=''
minPEcut = 150
maxdYZcut = 200
delta_theta_12 = 55
r_max_RdQ_CC1p = 0.43
delta_Delta_phi = 35
Pt_max = 0.35
Chi2Proton_muCandidate_min = 80
Chi2Proton_pCandidate_max = 30

samples = load_mc_and_data(extra_name=''
                     ,minPEcut = minPEcut,maxdYZcut = maxdYZcut
                     ,delta_theta_12 = delta_theta_12,r_max_RdQ_CC1p = r_max_RdQ_CC1p
                     ,delta_Delta_phi = delta_Delta_phi,Pt_max = Pt_max
                     ,Chi2Proton_muCandidate_min = Chi2Proton_muCandidate_min,Chi2Proton_pCandidate_max = Chi2Proton_pCandidate_max)
selected_overlay,selected_overlay_concat,selected_CC1p,genie_CC1p,selected_beam_on,selected_beam_off = samples
# Out:
# did not find selected_cosmic.csv, so creating it...
# 285038 ccqe candidate pairs, 180092 in FV
# 74392 are 1mu-1p, 41.3%
# 55230 are other-pairs, 30.7%
# 155416 are cosmic, 86.3%
# --------------------------------------------------------------
# 37228 are CC1p, 20.7%
# I finished loading overlay samples. We have in total 285038 pairs
# applied cuts to overlay
# saved selected 1mu-1p to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_selected_1mu-1p.csv
# saved selected other-pairs to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_selected_other-pairs.csv
# saved selected cosmic to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_selected_cosmic.csv
# saved selected CC1p to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_selected_CC1p.csv
# Nevents['f(POT)']: 0.051017899728
# 12127 events in the overlay
# saved selected overlay to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_selected_overlay.csv
# checked /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_selected_on_beam.csv and there was no file there...
# loaded beam-on
# loaded beam-off
# applied cuts to data
# saved 462 events in beam on to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_selected_beam_on.csv
# saved 15 events in beam off to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_selected_beam_off.csv
# 930168 events in genie from overlay
# saved 61615 CC1p events in genie_CC1p to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_selected_genie_CC1p.csv
# 9538 selected CC1p events overlay

# %% [markdown]
# ## apply the efficiency weights - if they were not computed yet

# %%
compute_eff_weights(beam_on=selected_beam_on,beam_off=selected_beam_off,
                        generated_CC1p=genie_CC1p,selected_CC1p=selected_CC1p,overlay=selected_overlay_concat,
                        delta_theta_12=delta_theta_12,
                        delta_Delta_phi=delta_Delta_phi,
                        Pt_max=Pt_max)     
compute_eff_weights(beam_on=selected_beam_on,beam_off=selected_beam_off,
                        generated_CC1p=genie_CC1p,selected_CC1p=selected_CC1p,overlay=selected_overlay_concat,
                        delta_theta_12=delta_theta_12,
                        delta_Delta_phi=delta_Delta_phi,
                        Pt_max=Pt_max,
                        ob_1='Pp',ob_2='cos(theta(p))',ob_3='phi(p)',
                        reco_1='reco_Pp',reco_2='reco_Pp_cos_theta',reco_3='reco_Pp_phi',
                        true_1='truth_Pp',true_2='truth_Pp_cos_theta',true_3='truth_Pp_phi') 
save_selected_samples(selected_overlay_concat , selected_CC1p , selected_beam_on , selected_beam_off)
print 'done assiging Pmu weights and Pp weights and saving the files.'
# Out:
# done.
# done.
# saved  12127 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_selected_overlay.csv
# saved  9538 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_selected_CC1p.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_selected_beam_on.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_selected_beam_off.csv
# done assiging Pmu weights and Pp weights and saving the files.

# %% [markdown]
# ## apply a data-driven correction for $\phi~0$

# %%
# iterative process for correction
for sam in [selected_beam_on,selected_beam_off,selected_CC1p,selected_overlay_concat]:
    sam['W(corr. phi~0)'] = 1
Xsec_dict = get_phi_Xsecs( do_corr_phi_0=False , debug=0 )
correction, correction_arrays = dict(),dict()
correction_arrays['mu'] = []; correction_arrays['p'] = []; step=[]
correction['mu'] = correction['p'] = 1
current_correction = 10
i = 1
while np.abs(current_correction-1)>0.0001:
    step.append(i)
    for particle,var in zip(['mu','p'],
                            ['reco_Pmu_mcs_phi','reco_Pp_phi']):
        Xsec,Xsec_err = Xsec_dict['phi('+particle+')'],Xsec_dict['phi('+particle+') err']
        bins = Bins['phi('+particle+')']
        N = len(bins)-1; n = N/2
        Xsec_phi_0 = Xsec[n]
        Xsec_phi_not_0 = np.concatenate([Xsec[:n-1],Xsec[n+1:]])
        Xsec_err_phi_not_0 = np.concatenate([Xsec_err[:n-1],Xsec_err[n+1:]])
        mean_phi_not_0 = np.average(Xsec_phi_not_0 , weights=1./np.square(Xsec_err_phi_not_0))
        current_correction = mean_phi_not_0/Xsec_phi_0
        correction[particle] = correction[particle]*current_correction
        correction_arrays[particle].append( correction[particle] )
        print 'correction for phi('+particle+')~0:',current_correction
        for sam in [selected_beam_on,selected_beam_off,selected_CC1p,selected_overlay_concat]:
            indices_phi_0 = sam.index[(bins[n] <= 180./np.pi*sam[var]) & (180./np.pi*sam[var] < bins[n+1])].tolist()
            sam.loc[indices_phi_0,'W(corr. phi~0)'] = sam.loc[indices_phi_0,'W(corr. phi~0)'] * current_correction
        Xsec_dict = get_phi_Xsecs( do_corr_phi_0=True , debug=0 )
        print 'corrected samples for ',particle,', computing Xsec'
    i = i+1
print 'done performing iterative correction for phi~0'; print
save_selected_samples(selected_overlay_concat , selected_CC1p , selected_beam_on , selected_beam_off)
print; print 'saved the samples...'
# Out:
# correction for phi(mu)~0: 3.03583942037
# corrected samples for  mu , computing Xsec
# correction for phi(p)~0: 1.4395562346
# corrected samples for  p , computing Xsec
# correction for phi(mu)~0: 1.04933462848
# corrected samples for  mu , computing Xsec
# correction for phi(p)~0: 1.0145604472
# corrected samples for  p , computing Xsec
# correction for phi(mu)~0: 1.00224195433
# corrected samples for  mu , computing Xsec
# correction for phi(p)~0: 1.00068436169
# corrected samples for  p , computing Xsec
# correction for phi(mu)~0: 1.00010667019
# corrected samples for  mu , computing Xsec
# correction for phi(p)~0: 1.000032612
# corrected samples for  p , computing Xsec
# done performing iterative correction for phi~0
# saved  12127 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_selected_overlay.csv
# saved  9538 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_09_22_selected_CC1p.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_selected_beam_on.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_selected_beam_off.csv
#
# saved the samples

# %% [markdown]
# ## Extract (and draw) the cross-sections

# %%
extract_Xsecs(debug=0,extra_name=extra_name)
# Out:
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/Xsecs_1D.txt

# %%
Draw_Xsecs(particle='mu',debug=0)
