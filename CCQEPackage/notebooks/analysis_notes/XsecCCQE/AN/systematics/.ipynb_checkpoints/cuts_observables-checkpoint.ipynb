# %% [markdown]
# # data/mc comparison as a function of all observables used for event selection cuts

# %%
import sys; sys.path.insert(0, '../../../../'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
from onbeam_offbeam_notebooks import *
from Xsec_tools import *
# %matplotlib inline
# Out:
# versions:
# {   'Overlay': 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2',
#     'beam off': 'prod_reco_optfilter_extbnb_v12_mcc8_dev',
#     'beam on': 'prod_reco_optfilter_bnb_v12_unblind_mcc8',
#     'data date': '2018_08_16',
#     'overlay date': '2018_09_22'}
# OffBeam_scaling: 0.706302660161 = N(on beam)/N(off beam) before SwT
# f(POT): 0.051017899728 = N(POT on beam)/N(POT MC)

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/'

# %%
selected_overlay,selected_overlay_concat,selected_CC1p,genie_CC1p,selected_beam_on,selected_beam_off = load_mc_and_data()
# Out:
# found selected overlay files from , loading them...
# 9538 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...

# %% [markdown]
# # apply the efficiency weights - if they were not computed yet

# %%
if ("Pmu weight" not in selected_beam_on.columns):    
    print 'no Pmu weights, computing them'
    compute_eff_weights(   beam_on=selected_beam_on,beam_off=selected_beam_off,                       
                           generated_CC1p=genie_CC1p,                       
                           selected_CC1p=selected_CC1p,overlay=selected_overlay_concat)         
    save_selected_samples(selected_overlay_concat , selected_CC1p , selected_beam_on , selected_beam_off)
    print 'done assiging Pmu weights and saving the files.'
else:
     print 'Pmu weights already exist'
# Out:
# Pmu weights already exist

# %%
if ("Pp weight" not in selected_beam_on.columns):    
    print 'no Pp weights, computing them'
    compute_eff_weights( beam_on=selected_beam_on,beam_off=selected_beam_off,                       
                         generated_CC1p=genie_CC1p,                       
                         selected_CC1p=selected_CC1p,overlay=selected_overlay_concat
                        ,ob_1='Pp',ob_2='cos(theta(p))',ob_3='phi(p)'                       
                        ,reco_1='reco_Pp',reco_2='reco_Pp_cos_theta',reco_3='reco_Pp_phi'                       
                        ,true_1='truth_Pp',true_2='truth_Pp_cos_theta',true_3='truth_Pp_phi')     
    save_selected_samples(selected_overlay_concat , selected_CC1p , selected_beam_on , selected_beam_off)
    print 'done assiging Pp weights and saving the files.'
else:
     print 'Pp weights already exist'
# Out:
# Pp weights already exist

# %% [markdown]
# ## get the cross-section with and without the last bin of $\cos\theta_{\mu}$, as a function of an observable used for event selection cuts

# %% [markdown]
# # observables

# %%
# ----------------------------------------------------------
# Oct-08, 2018 (last edit Nov-18, 2018)
def draw_Xsec_variable(debug=0,evtwgt_name='',y_scale=1,
                       var='reco_Pt',mul=1,bins=linspace(0,1,5),vlabel='p_T',units=None,legend_loc='best',
                       wname='Pmu weight',
                       do_corr_phi_0=True,
                       selected_beam_on=None,selected_beam_off=None,
                       selected_overlay_concat=None,selected_CC1p=None,
                       filename=None,extra_name='',do_save_figure=True,
                       do_add_cut_lines=False,cut_Xlim=(0,1),
                       residuals_ylim=[-1,1],residuals_yticks=[-0.5,0,0.5],residuals_ytitle=1.05,residuals_xtitle='center',figures_path='~/Desktop/'):#{
    Xsec_dicts = dict()
    for Xsec_ctu_title,remove_ctu_bin in zip(Xsec_ctu_titles,remove_ctu_bools):
        Xsec_dicts[Xsec_ctu_title] = get_Xsec_variable(debug=debug,evtwgt_name=evtwgt_name,
                                                       var=var,mul=mul,bins=bins,
                                                       wname=wname,
                                                       do_corr_phi_0=do_corr_phi_0,
                                                       remove_ctu_bin=remove_ctu_bin,
                                                       selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,
                                                       selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p)

    fig=plt.figure(figsize=(20,8))
    mid = 0.5*(bins[1:]+bins[:-1]); bin_width=mid[1]-mid[0]
    for iXsec,(Xsec_ctu_title,iax) in enumerate(zip(Xsec_ctu_titles,[(1,3),(2,4)])):
        Xsec_dict = Xsec_dicts[Xsec_ctu_title]
        h = dict()
        ax = fig.add_subplot(3,2,iax)
        h['Xsec'],h['Xsec err'] = y_scale*Xsec_dict[var],y_scale*Xsec_dict[var+' err']
        plt.errorbar(x=mid,xerr=0.5*bin_width,y=h['Xsec'],yerr=h['Xsec err'],color=Colors['beam on'],fmt='o',label='data')
        
        h['mc Xsec'],h['mc Xsec err'] = y_scale*Xsec_dict['mc '+var], y_scale*Xsec_dict['mc '+var+' err']
        ax.bar( x=mid , height=2*h['mc Xsec err'], bottom=h['mc Xsec']-h['mc Xsec err'], width=bin_width, color=Colors['CC1p'],label='overlay')
        set_axes(ax,x_label='',y_label=get_Xsec_label(vlabel,units)
                 ,do_add_grid=True,remove_ticks_x=True,do_add_legend=True if iXsec==1 else False, legend_loc=legend_loc
                 ,ylim=(0,1.1*np.max(ax.get_ylim())),title=Xsec_ctu_title)
                 
        if do_add_cut_lines:#{
            plt.plot([cut_Xlim[0],cut_Xlim[0]],ax.get_ylim(),'--',color='red')
            plt.plot([cut_Xlim[1],cut_Xlim[1]],ax.get_ylim(),'--',color='red')
        #}

        # residuals plot
        den, den_err = h['Xsec']-h['mc Xsec'],np.sqrt(np.square(h['Xsec err'])+np.square(h['mc Xsec err']))
        num, num_err = h['Xsec'],h['mc Xsec err']
        ratio = den/num
        ax = fig.add_subplot(3,2,5+iXsec)
        ratio_err = ratio*np.sqrt(np.square(den_err/den) + np.square(num_err/num))
        plt.errorbar(x=mid,xerr=0.5*bin_width,y=ratio,yerr=ratio_err,fmt='o',markersize=0,color='black')
        chi2,ndf = chi2_two_data_curves(h1=h['Xsec'],h1err=h['Xsec err'],h2=h['mc Xsec'],h2err=h['mc Xsec err'],bins=bins,debug=debug)
        if units is None: x_label = '$'+vlabel+'$'
        elif '^' in units or '_' in units: x_label = '$'+vlabel+'$' + r' $%s$'%units
        else: x_label = '$'+vlabel+'$' + r' [%s]'%units
        set_axes(ax,x_label=x_label
                 ,y_label=r'(data-MC)/data',do_add_grid=True
                 ,ylim=residuals_ylim,yticks=residuals_yticks)
        plt.plot([np.min(bins),np.max(bins)],[0,0],'--',color='royalblue')
        plt.title(r'$\chi^2/ndf=%.2f/%d$'%(chi2,ndf), fontsize=20,y=residuals_ytitle,loc=residuals_xtitle)
        if do_add_cut_lines:#{
            plt.plot([cut_Xlim[0],cut_Xlim[0]],ax.get_ylim(),'--',color='red')
            plt.plot([cut_Xlim[1],cut_Xlim[1]],ax.get_ylim(),'--',color='red')
        #}
    plt.tight_layout(h_pad=0.0)
    plt.subplots_adjust(hspace=0.05)
    if filename is not None: outfilename = figures_path + filename + '.pdf'
    else: outfilename = figures_path + var + '_Xsec'+extra_name+'.pdf'
    if do_save_figure: save_figure(outfilename)
    return ax
#}
# ----------------------------------------------------------

# %%
draw_Xsec_variable(var='pidcali_Chi2ProtonYplane_muCandidate',mul=1,bins=linspace(30,430,8),vlabel=r'(\chi^2_p)^{\mu}',
                   do_add_cut_lines=True,cut_Xlim=(80,80),
                      wname='Pmu weight',
                      selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                      selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,debug=0,figures_path=figures_path);
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/pidcali_Chi2ProtonYplane_muCandidate_Xsec.pdf

# %%
draw_Xsec_variable(var='pidcali_Chi2ProtonYplane_pCandidate',mul=1,bins=linspace(0.001,35,8),vlabel=r'(\chi^2_p)^{p}',
                   do_add_cut_lines=True,cut_Xlim=(30,30),
                      wname='Pmu weight',
                      selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                      selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,debug=0,figures_path=figures_path);
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in divide
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: invalid value encountered in divide
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/pidcali_Chi2ProtonYplane_pCandidate_Xsec.pdf

# %%
draw_Xsec_variable(var='Nflashes',mul=1,bins=linspace(0.001,3,3),vlabel=r'N_{flashes}',
                   do_add_cut_lines=True,cut_Xlim=(0,0),
                      wname='Pmu weight',
                      selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                      selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,debug=0,figures_path=figures_path);
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in divide
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: invalid value encountered in divide
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/Nflashes_Xsec.pdf

# %%
draw_Xsec_variable(var='MatchedFlash_TotalPE',mul=1,bins=linspace(0.001,3000,7),vlabel=r'N_{\mathrm{PE}}',
                   do_add_cut_lines=True,cut_Xlim=(150,150),
                      wname='Pmu weight',
                      selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                      selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,debug=0,figures_path=figures_path);
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/MatchedFlash_TotalPE_Xsec.pdf

# %%
draw_Xsec_variable(var='MatchedFlash_YZdistance',mul=1,bins=linspace(0.001,220,7),vlabel=r'd_{\mathrm{YZ}}',units='cm',
                   do_add_cut_lines=True,cut_Xlim=(200,200),
                      wname='Pmu weight',
                      selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                      selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,debug=0,figures_path=figures_path);
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/MatchedFlash_YZdistance_Xsec.pdf

# %%
draw_Xsec_variable(var='l_mu-l_p',mul=1,bins=linspace(0,360,9),vlabel=r'l_\mu - l_p',units='cm',
                   do_add_cut_lines=True,cut_Xlim=(0,0),
                      wname='Pmu weight',
                      selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                      selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,debug=0,figures_path=figures_path);
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/l_mu-l_p_Xsec.pdf

# %%
draw_Xsec_variable(var='theta_12',bins=linspace(40,155,12),vlabel=r'\theta_{12}',units='deg.',legend_loc='upper left',
                   do_add_cut_lines=True,cut_Xlim=(35,145),
                      wname='Pmu weight',
                      selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                      selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,debug=0,figures_path=figures_path);
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/theta_12_Xsec.pdf

# %% [markdown]
# # Vertex activity

# %%
R_str,box_str = 'RdQaroundVertex','[%d wires x %d ticks]'%(50,100)
Ru,Rv,Ry = R_str+'[plane 0]'+box_str,R_str+'[plane 1]'+box_str,R_str+'[plane 2]'+box_str
bins=linspace(0.4,1.001,9)
draw_Xsec_variable(var=Ru,bins=bins,vlabel=r'R_{\Delta Q}^{U}',residuals_ytitle=2.9,filename='RdQ_plane0_Xsec',
                   do_add_cut_lines=True,cut_Xlim=(0.57,0.57),
                      wname='Pmu weight',
                      selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                      selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,debug=0,figures_path=figures_path);
draw_Xsec_variable(var=Rv,bins=bins,vlabel=r'R_{\Delta Q}^{V}',residuals_ytitle=2.9,filename='RdQ_plane1_Xsec',
                   do_add_cut_lines=True,cut_Xlim=(0.57,0.57),
                      wname='Pmu weight',
                      selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                      selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,debug=0,figures_path=figures_path);
draw_Xsec_variable(var=Ry,bins=bins,vlabel=r'R_{\Delta Q}^{Y}',residuals_ytitle=2.9,filename='RdQ_plane2_Xsec',
                   do_add_cut_lines=True,cut_Xlim=(0.57,0.57),
                      wname='Pmu weight',
                      selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                      selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,debug=0,figures_path=figures_path);
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/RdQ_plane0_Xsec.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/RdQ_plane1_Xsec.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/RdQ_plane2_Xsec.pdf

# %% [markdown]
# # $\Delta \phi$ and $p_T$

# %%
draw_Xsec_variable(var='delta_phi',mul=1,bins=linspace(135,225,9),vlabel=r'\Delta \phi',units='deg.',
                   do_add_cut_lines=True,cut_Xlim=(145,215),
                      wname='Pmu weight',
                      selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                      selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,debug=0,figures_path=figures_path);
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/delta_phi_Xsec.pdf

# %%
draw_Xsec_variable(var='reco_Pt_mcs',bins=linspace(0,0.4,10),vlabel=r'p_T',units='GeV/c',debug=0,
                   do_add_cut_lines=True,cut_Xlim=(0.35,0.35),
                      wname='Pmu weight',                                             
                   selected_beam_on=selected_beam_on,selected_beam_off=selected_beam_off,        
                   selected_overlay_concat=selected_overlay_concat,selected_CC1p=selected_CC1p,figures_path=figures_path);
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in divide
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: invalid value encountered in divide
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/reco_Pt_mcs_Xsec.pdf
