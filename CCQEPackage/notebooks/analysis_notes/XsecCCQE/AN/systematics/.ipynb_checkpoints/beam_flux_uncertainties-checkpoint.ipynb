# %% [markdown]
# # study beam-flux uncertainties using event-weight

# %%
import sys; sys.path.insert(0, '../../../../'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
from onbeam_offbeam_notebooks import *
from Xsec_tools import *
# %matplotlib inline
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/'
# Out:
# versions:
# {   'Overlay': 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2',
#     'beam off': 'prod_reco_optfilter_extbnb_v12_mcc8_dev',
#     'beam on': 'prod_reco_optfilter_bnb_v12_unblind_mcc8',
#     'data date': '2018_08_16',
#     'overlay date': '2018_09_22'}
# OffBeam_scaling: 0.706302660161 = N(on beam)/N(off beam) before SwT
# f(POT): 0.051017899728 = N(POT on beam)/N(POT MC)

# %%
versions['beam on']='prod_reco_optfilter_bnb_v12_unblind_mcc8'
versions['beam off']='prod_reco_optfilter_extbnb_v12_mcc8_dev'
versions['data date']='2018_08_16'

# %%
evtwgt_names = ['bnbcorrection_FluxHist','expskin_FluxUnisim','horncurrent_FluxUnisim',
                    'kminus_PrimaryHadronNormalization','kplus_PrimaryHadronFeynmanScaling',
                    'kzero_PrimaryHadronSanfordWang','nucleoninexsec_FluxUnisim','nucleonqexsec_FluxUnisim',
                    'nucleontotxsec_FluxUnisim','piminus_PrimaryHadronSWCentralSplineVariation',
                    'pioninexsec_FluxUnisim','pionqexsec_FluxUnisim',
                    'piontotxsec_FluxUnisim','piplus_PrimaryHadronSWCentralSplineVariation']

# %%
versions['Overlay']='prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2'
versions['overlay date']='2018_10_13'
for evtwgt_name in evtwgt_names:
    extract_Xsec_full_chain(evtwgt_name=evtwgt_name,extra_name=evtwgt_name,force_recalculated_weights=True)
# Out:
# found selected overlay files from bnbcorrection_FluxHist, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.28100628167
# correction for phi(p)~0: 1.68144193827
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_bnbcorrection_FluxHistselected_overlaybnbcorrection_FluxHist.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_bnbcorrection_FluxHistselected_CC1pbnbcorrection_FluxHist.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_bnbcorrection_FluxHistselected_beam_onbnbcorrection_FluxHist.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_bnbcorrection_FluxHistselected_beam_offbnbcorrection_FluxHist.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dbnbcorrection_FluxHist.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dbnbcorrection_FluxHist.txt
# found selected overlay files from expskin_FluxUnisim, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.29147755914
# correction for phi(p)~0: 1.6865425026
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_expskin_FluxUnisimselected_overlayexpskin_FluxUnisim.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_expskin_FluxUnisimselected_CC1pexpskin_FluxUnisim.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_expskin_FluxUnisimselected_beam_onexpskin_FluxUnisim.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_expskin_FluxUnisimselected_beam_offexpskin_FluxUnisim.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dexpskin_FluxUnisim.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dexpskin_FluxUnisim.txt
# found selected overlay files from horncurrent_FluxUnisim, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.32522562355
# correction for phi(p)~0: 1.68492398709
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_horncurrent_FluxUnisimselected_overlayhorncurrent_FluxUnisim.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_horncurrent_FluxUnisimselected_CC1phorncurrent_FluxUnisim.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_horncurrent_FluxUnisimselected_beam_onhorncurrent_FluxUnisim.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_horncurrent_FluxUnisimselected_beam_offhorncurrent_FluxUnisim.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dhorncurrent_FluxUnisim.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dhorncurrent_FluxUnisim.txt
# found selected overlay files from kminus_PrimaryHadronNormalization, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.30312885925
# correction for phi(p)~0: 1.68401314163
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_kminus_PrimaryHadronNormalizationselected_overlaykminus_PrimaryHadronNormalization.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_kminus_PrimaryHadronNormalizationselected_CC1pkminus_PrimaryHadronNormalization.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_kminus_PrimaryHadronNormalizationselected_beam_onkminus_PrimaryHadronNormalization.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_kminus_PrimaryHadronNormalizationselected_beam_offkminus_PrimaryHadronNormalization.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dkminus_PrimaryHadronNormalization.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dkminus_PrimaryHadronNormalization.txt
# found selected overlay files from kplus_PrimaryHadronFeynmanScaling, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.30084702825
# correction for phi(p)~0: 1.68304146674
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_kplus_PrimaryHadronFeynmanScalingselected_overlaykplus_PrimaryHadronFeynmanScaling.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_kplus_PrimaryHadronFeynmanScalingselected_CC1pkplus_PrimaryHadronFeynmanScaling.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_kplus_PrimaryHadronFeynmanScalingselected_beam_onkplus_PrimaryHadronFeynmanScaling.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_kplus_PrimaryHadronFeynmanScalingselected_beam_offkplus_PrimaryHadronFeynmanScaling.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dkplus_PrimaryHadronFeynmanScaling.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dkplus_PrimaryHadronFeynmanScaling.txt
# found selected overlay files from kzero_PrimaryHadronSanfordWang, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.30304518241
# correction for phi(p)~0: 1.68480411125
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_kzero_PrimaryHadronSanfordWangselected_overlaykzero_PrimaryHadronSanfordWang.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_kzero_PrimaryHadronSanfordWangselected_CC1pkzero_PrimaryHadronSanfordWang.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_kzero_PrimaryHadronSanfordWangselected_beam_onkzero_PrimaryHadronSanfordWang.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_kzero_PrimaryHadronSanfordWangselected_beam_offkzero_PrimaryHadronSanfordWang.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dkzero_PrimaryHadronSanfordWang.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dkzero_PrimaryHadronSanfordWang.txt
# found selected overlay files from nucleoninexsec_FluxUnisim, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.34890348254
# correction for phi(p)~0: 1.69722056678
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_nucleoninexsec_FluxUnisimselected_overlaynucleoninexsec_FluxUnisim.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_nucleoninexsec_FluxUnisimselected_CC1pnucleoninexsec_FluxUnisim.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_nucleoninexsec_FluxUnisimselected_beam_onnucleoninexsec_FluxUnisim.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_nucleoninexsec_FluxUnisimselected_beam_offnucleoninexsec_FluxUnisim.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dnucleoninexsec_FluxUnisim.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dnucleoninexsec_FluxUnisim.txt
# found selected overlay files from nucleonqexsec_FluxUnisim, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.31851458735
# correction for phi(p)~0: 1.6879859705
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_nucleonqexsec_FluxUnisimselected_overlaynucleonqexsec_FluxUnisim.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_nucleonqexsec_FluxUnisimselected_CC1pnucleonqexsec_FluxUnisim.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_nucleonqexsec_FluxUnisimselected_beam_onnucleonqexsec_FluxUnisim.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_nucleonqexsec_FluxUnisimselected_beam_offnucleonqexsec_FluxUnisim.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dnucleonqexsec_FluxUnisim.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dnucleonqexsec_FluxUnisim.txt
# found selected overlay files from nucleontotxsec_FluxUnisim, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.29895593718
# correction for phi(p)~0: 1.68292082852
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_nucleontotxsec_FluxUnisimselected_overlaynucleontotxsec_FluxUnisim.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_nucleontotxsec_FluxUnisimselected_CC1pnucleontotxsec_FluxUnisim.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_nucleontotxsec_FluxUnisimselected_beam_onnucleontotxsec_FluxUnisim.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_nucleontotxsec_FluxUnisimselected_beam_offnucleontotxsec_FluxUnisim.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dnucleontotxsec_FluxUnisim.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dnucleontotxsec_FluxUnisim.txt
# found selected overlay files from piminus_PrimaryHadronSWCentralSplineVariation, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.29675891669
# correction for phi(p)~0: 1.68388484971
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_piminus_PrimaryHadronSWCentralSplineVariationselected_overlaypiminus_PrimaryHadronSWCentralSplineVariation.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_piminus_PrimaryHadronSWCentralSplineVariationselected_CC1ppiminus_PrimaryHadronSWCentralSplineVariation.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_piminus_PrimaryHadronSWCentralSplineVariationselected_beam_onpiminus_PrimaryHadronSWCentralSplineVariation.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_piminus_PrimaryHadronSWCentralSplineVariationselected_beam_offpiminus_PrimaryHadronSWCentralSplineVariation.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dpiminus_PrimaryHadronSWCentralSplineVariation.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dpiminus_PrimaryHadronSWCentralSplineVariation.txt
# found selected overlay files from pioninexsec_FluxUnisim, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.30027124754
# correction for phi(p)~0: 1.68329010155
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_pioninexsec_FluxUnisimselected_overlaypioninexsec_FluxUnisim.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_pioninexsec_FluxUnisimselected_CC1ppioninexsec_FluxUnisim.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_pioninexsec_FluxUnisimselected_beam_onpioninexsec_FluxUnisim.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_pioninexsec_FluxUnisimselected_beam_offpioninexsec_FluxUnisim.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dpioninexsec_FluxUnisim.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dpioninexsec_FluxUnisim.txt
# found selected overlay files from pionqexsec_FluxUnisim, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.31139435924
# correction for phi(p)~0: 1.68551584105
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_pionqexsec_FluxUnisimselected_overlaypionqexsec_FluxUnisim.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_pionqexsec_FluxUnisimselected_CC1ppionqexsec_FluxUnisim.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_pionqexsec_FluxUnisimselected_beam_onpionqexsec_FluxUnisim.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_pionqexsec_FluxUnisimselected_beam_offpionqexsec_FluxUnisim.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dpionqexsec_FluxUnisim.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dpionqexsec_FluxUnisim.txt
# found selected overlay files from piontotxsec_FluxUnisim, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.29568787252
# correction for phi(p)~0: 1.68299848079
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_piontotxsec_FluxUnisimselected_overlaypiontotxsec_FluxUnisim.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_piontotxsec_FluxUnisimselected_CC1ppiontotxsec_FluxUnisim.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_piontotxsec_FluxUnisimselected_beam_onpiontotxsec_FluxUnisim.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_piontotxsec_FluxUnisimselected_beam_offpiontotxsec_FluxUnisim.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dpiontotxsec_FluxUnisim.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dpiontotxsec_FluxUnisim.txt
# found selected overlay files from piplus_PrimaryHadronSWCentralSplineVariation, loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# correction for phi(mu)~0: 3.33209981822
# correction for phi(p)~0: 1.47598285325
# done performing iterative correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_piplus_PrimaryHadronSWCentralSplineVariationselected_overlaypiplus_PrimaryHadronSWCentralSplineVariation.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_piplus_PrimaryHadronSWCentralSplineVariationselected_CC1ppiplus_PrimaryHadronSWCentralSplineVariation.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_piplus_PrimaryHadronSWCentralSplineVariationselected_beam_onpiplus_PrimaryHadronSWCentralSplineVariation.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_piplus_PrimaryHadronSWCentralSplineVariationselected_beam_offpiplus_PrimaryHadronSWCentralSplineVariation.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1Dpiplus_PrimaryHadronSWCentralSplineVariation.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1Dpiplus_PrimaryHadronSWCentralSplineVariation.txt

# %%
extract_Xsec_full_chain(force_recalculated_weights=True)
# Out:
# found selected overlay files from , loading them...
# 9544 selected CC1p events overlay
# found  462 selected on beam and 15 beam off events...
# found selected genie CC1p...
# done loading samples...
# no efficiency weights, computing them
# done assiging efficiency weights weights.
# already performed correction for phi~0 and saved the samples...
# saved  12137 selected overlay events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_selected_overlay.csv
# saved  9544 selected CC1p events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_10_13_selected_CC1p.csv
# saved  462 selected beam_on events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_selected_beam_on.csv
# saved  15 selected beam_off events to /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_selected_beam_off.csv
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PmuXsecs_1D.txt
# saved cross-sections into /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/1d_Xsec/PpXsecs_1D.txt

# %% [markdown]
# # Get the mean and standard deviation of the cross-sections for these weights

# %%
varying_Xsec = dict()
mean_varying_Xsec,std_varying_Xsec = dict(), dict()

for particle in ['mu','p']:
    varying_Xsec[particle] = dict()
    mean_varying_Xsec[particle] = dict()
    std_varying_Xsec[particle] = dict()

    for iXsec,Xsec_title in enumerate(Xsec_ctu_titles):#{
        varying_Xsec[particle][Xsec_title] = dict()
        mean_varying_Xsec[particle][Xsec_title] = dict()
        std_varying_Xsec[particle][Xsec_title] = dict()
        for i,observable in enumerate(['P'+particle,'cos(theta('+particle+'))','phi('+particle+')']):#{
            var,vtrue,bins,mid,bin_width,vlabel,xlabel,units = get_labels(observable=observable)
            if iXsec==0 and var=='reco_Pmu_cos_theta': bins=bins[:-1]        
            varying_Xsec[particle][Xsec_title][var] = dict()
            mean_varying_Xsec[particle][Xsec_title][var] = dict()
            std_varying_Xsec[particle][Xsec_title][var] = dict()
            for j_bin in range(len(bins)-1):#{
                varying_Xsec[particle][Xsec_title][var][j_bin] = []
            #}
        #}
    #}
    for evtwgt_name in evtwgt_names:
        extra_name=evtwgt_name
        infilename = Paths['1d Xsec'] + "P"+particle + "Xsecs_1D"+extra_name+".txt"
        with open(infilename, 'rb') as infile:#{
            Xsec_dicts = pickle.load(infile)
        #}
        for iXsec,Xsec_title in enumerate(Xsec_ctu_titles):#{
            Xsec_dict = Xsec_dicts[Xsec_title]
            for i,observable in enumerate(['P'+particle,'cos(theta('+particle+'))','phi('+particle+')']):#{
                var,vtrue,bins,mid,bin_width,vlabel,xlabel,units = get_labels(observable=observable)
                h = dict()
                h['Xsec'] = Xsec_dict[observable]
                h['mc Xsec'] = Xsec_dict['mc '+observable]
                if iXsec==0 and var=='reco_Pmu_cos_theta':
                    bins=bins[:-1];h['Xsec']=h['Xsec'][:-1];h['mc Xsec']=h['mc Xsec'][:-1];
                for j_bin in range(len(bins)-1):
                    varying_Xsec[particle][Xsec_title][var][j_bin].append(h['Xsec'][j_bin])
                #}
            #}
        #}
    #}
    for iXsec,Xsec_title in enumerate(Xsec_ctu_titles):#{
        for i,observable in enumerate(['P'+particle,'cos(theta('+particle+'))','phi('+particle+')']):#{
            var,vture,bins,mid,bin_width,vlabel,xlabel,units = get_labels(observable=observable)
            if iXsec==0 and var=='reco_Pmu_cos_theta': bins=bins[:-1]        
            for j_bin in range(len(bins)-1):
                mean_varying_Xsec[particle][Xsec_title][var][j_bin] = np.mean(varying_Xsec[particle][Xsec_title][var][j_bin])
                std_varying_Xsec[particle][Xsec_title][var][j_bin] = np.std(varying_Xsec[particle][Xsec_title][var][j_bin])
    print 'done',particle
# Out:
# done mu
# done p

# %%
do_last_ctu_bin = True
for particle in ['mu','p']:
    with open(Paths['1d Xsec'] + "P" +particle + "Xsecs_1D.txt", 'rb') as infile:#{
        nominal_Xsec_dicts = pickle.load(infile)
    #}
    for iXsec,(Xsec_title,Xsec_fname,do_draw_Xsecs) in enumerate(zip(Xsec_ctu_titles,Xsec_fnames,[True,do_last_ctu_bin])):#{
        if do_draw_Xsecs==False: continue
        fig=plt.figure(figsize=(24,8))            
        Xsec_dict = nominal_Xsec_dicts[Xsec_title]
        for i,observable in enumerate(['P'+particle,'cos(theta('+particle+'))','phi('+particle+')']):#{
            var,vtrue,bins,mid,bin_width,vlabel,xlabel,units = get_labels(observable=observable)
            h = dict()
            h['Xsec'],h['Xsec err'] = Xsec_dict[observable],Xsec_dict[observable+' err']
            h['mc Xsec'],h['mc Xsec err'] = Xsec_dict['mc '+observable], Xsec_dict['mc '+observable+' err']
            ax = fig.add_subplot(1,3,i+1)
            if iXsec==0 and var=='reco_Pmu_cos_theta':
                mid=mid[:-1]; bin_width=bin_width[:-1]; bins=bins[:-1]
                h['Xsec']=h['Xsec'][:-1];h['Xsec err']=h['Xsec err'][:-1]
                h['mc Xsec']=h['mc Xsec'][:-1];h['mc Xsec err']=h['mc Xsec err'][:-1]

            plt.errorbar(x=mid,xerr=0.5*bin_width,y=h['Xsec'],yerr=h['Xsec err'],color=Colors['beam on'],fmt='o',label='data')
            ax.bar( x=mid , height=2*h['mc Xsec err'], bottom=h['mc Xsec']-h['mc Xsec err'], width=bin_width, color=Colors['CC1p'],label='overlay') 

            varying_Xsec_avg = np.array(mean_varying_Xsec[particle][Xsec_title][var].values())
            varying_Xsec_std = np.array(std_varying_Xsec[particle][Xsec_title][var].values())
            ax.bar( x=mid , height=2*varying_Xsec_std, bottom=varying_Xsec_avg-varying_Xsec_std, width=bin_width, color='green',label='beam-flux variation',alpha=0.5)
            set_axes(ax,xlabel,y_label=get_Xsec_label(vlabel,units)
                             ,do_add_grid=True,do_add_legend=True if 'Pmu_cos_theta' in var else False
                             ,ylim=(0,1.1*np.max(ax.get_ylim())))
            plt.title(Xsec_title, y=1.02,fontsize=25)
        plt.tight_layout(h_pad=0)
        save_figure(figures_path + 'beam_flux_uncertainty_'+particle+'_'+Xsec_fname+'.pdf')
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/beam_flux_uncertainty_mu_without_last_ctu_bin.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/beam_flux_uncertainty_mu_with_last_ctu_bin.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/beam_flux_uncertainty_p_without_last_ctu_bin.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/AN-XsecCCQE/Figures/overlay_8.11/systematics/beam_flux_uncertainty_p_with_last_ctu_bin.pdf

# %% [markdown]
# # save the differences as systematical uncertainties into a csv

# %%
Xsec_sys_unc = dict()
for particle in ['mu','p']:
    with open(Paths['1d Xsec'] + "P" +particle + "Xsecs_1D.txt", 'rb') as infile: nominal_Xsec_dicts = pickle.load(infile)
    for iXsec,(Xsec_title,Xsec_fname) in enumerate(zip(Xsec_ctu_titles,Xsec_fnames)):#{
        Xsec_dict = nominal_Xsec_dicts[Xsec_title]
        for i,observable in enumerate(['P'+particle,'cos(theta('+particle+'))','phi('+particle+')']
                                     ):#{
            var,vture,bins,mid,bin_width,vlabel,xlabel,units = get_labels(observable=observable)
            h = dict()
            h['Xsec'],h['Xsec err'] = Xsec_dict[observable],Xsec_dict[observable+' err']
            h['mc Xsec'],h['mc Xsec err'] = Xsec_dict['mc '+observable], Xsec_dict['mc '+observable+' err']
            if iXsec==0 and var=='reco_Pmu_cos_theta':
                mid=mid[:-1]; bin_width=bin_width[:-1]; bins=bins[:-1]
                h['Xsec']=h['Xsec'][:-1];h['Xsec err']=h['Xsec err'][:-1]
                h['mc Xsec']=h['mc Xsec'][:-1];h['mc Xsec err']=h['mc Xsec err'][:-1]
                
            varying_Xsec_avg = np.array(mean_varying_Xsec[particle][Xsec_title][var].values())
            varying_Xsec_std = np.array(std_varying_Xsec[particle][Xsec_title][var].values())            
            Xsec_sys_unc[var + Xsec_fname + ' Xsec sys. err up'] = (varying_Xsec_avg + varying_Xsec_std) - h['Xsec']
            Xsec_sys_unc[var + Xsec_fname + ' Xsec sys. err dw'] = h['Xsec'] - (varying_Xsec_avg - varying_Xsec_std )

# %%
outfilename = Paths['systematics'] + "beam_flux_uncertainty_systemaitcal_uncertainty.txt"
with open(outfilename, 'w') as outfile:
    outfile.write(pickle.dumps(Xsec_sys_unc))
print 'saved',outfilename
# Out:
# saved /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/systematics/beam_flux_uncertainty_systemaitcal_uncertainty.txt
