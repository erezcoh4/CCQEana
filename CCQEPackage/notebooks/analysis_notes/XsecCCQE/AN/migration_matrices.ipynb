# %% [markdown]
# # plot the migration matrices for all kinematical variables

# %%
import sys; sys.path.insert(0, '../../../'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
from onbeam_offbeam_notebooks import *
from Xsec_tools import *
# %matplotlib inline
# Out:
# versions:
# {   'OffBeam': 'prod_reco_optfilter_extbnb_v12_mcc8_dev',
#     'OnBeam': 'prod_reco_optfilter_bnb_v12_unblind_mcc8',
#     'Overlay': 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2',
#     'data date': '2018_05_11',
#     'date': '2018_05_11',
#     'overlay date': '2018_05_11'}
# OffBeam_scaling: 0.706302660161 = N(on beam)/N(off beam) before SwT
# f(POT): 0.0512441465374 = N(POT on beam)/N(POT MC)

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/XsecCCQE/Figures/overlay_8.11/Xsec_extraction/'

# %%
versions['overlay date'] = '2018_08_16'
versions['Overlay'] = 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2'
versions['data date'] = '2018_08_16'
versions['beam on'] = 'prod_reco_optfilter_bnb_v12_unblind_mcc8'
versions['beam off'] = 'prod_reco_optfilter_extbnb_v12_mcc8_dev'
selected_overlay,selected_overlay_concat,selected_CC1p,genie_CC1p,selected_beam_on,selected_beam_off = load_mc_and_data()
# Out:
# found selected_cosmic.csv, loading it...
# checked /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prod_reco_optfilter_bnb_v12_unblind_mcc8_2018_08_16_selected_on_beam.csv and found the file...
# checked /Users/erezcohen/Desktop/uBoone/CCQEanalysis/Xsec/selected_events/prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2_2018_08_16_selected_genie_CC1p.csv and found the file...
# 9819 selected CC1p events overlay

# %% [markdown]
# # $CC 1p$ migration matrices before all cuts

# %%
sns.set(font_scale=2);
migration_maps=dict()

# %%
migration_maps['Pmu']=build_migration_map(sam=selected_CC1p,bins=Bins['Pmu'],xvar='truth_Pmu',yvar='reco_Pmu_mcs')
save_figure(figures_path+'migration_map_Pmu.pdf')

migration_maps['Pmu_cos_theta']=build_migration_map(sam=selected_CC1p,bins=Bins['cos(theta(mu))'],xvar='truth_Pmu_cos_theta',yvar='reco_Pmu_cos_theta')
save_figure(figures_path+'migration_map_Pmu_cos_theta.pdf')

migration_maps['Pp']=build_migration_map(sam=selected_CC1p,bins=Bins['Pp'],xvar='truth_Pp',yvar='reco_Pp')
save_figure(figures_path+'migration_map_Pp.pdf')

migration_maps['Pp_cos_theta']=build_migration_map(sam=selected_CC1p,bins=Bins['cos(theta(p))'],xvar='truth_Pp_cos_theta',yvar='reco_Pp_cos_theta')
save_figure(figures_path+'migration_map_Pp_cos_theta.pdf')
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/XsecCCQE/Figures/overlay_8.11/Xsec_extraction/migration_map_Pmu.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/XsecCCQE/Figures/overlay_8.11/Xsec_extraction/migration_map_Pmu_cos_theta.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/XsecCCQE/Figures/overlay_8.11/Xsec_extraction/migration_map_Pp.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/XsecCCQE/Figures/overlay_8.11/Xsec_extraction/migration_map_Pp_cos_theta.pdf
