# %%
import sys; sys.path.insert(0, '../../'); sys.path.insert(0,'../../../mac/ndtest/')
from ccqe_notebook_tools import * 
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

# %% [markdown]
# # optimization of the box dimensions for $\frac{\Delta Q_{track}}{\Delta Q_{total}}$

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/RdQaroundVertex/Figures/BoxOptimization/'

# %% [markdown]
# # pairs of 2-tracks at close proximity

# %%
pairs = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/ccqe_candidates/prodgenie_bnb_nu_uboone_overlay_reco2_vertices.csv')
pairsFV = sample_in_FV(pairs)
print len(pairs),'pairs from MC-BNB + cosmic DATA overlay'
print len(pairsFV),'pairs in FV'
samples=dict()
for pair_type in pair_types:
    samples[pair_type] = pairsFV[pairsFV[pair_type]==True]
    Ntype = len(samples[pair_type])
    if pair_type=='CC 1p 0pi': print_line()
    print Ntype,'are '+pair_type+', %.1f'%(100.*float(Ntype)/len(pairsFV))+'%'
# Out:
# 49383 pairs from MC-BNB + cosmic DATA overlay
# 29475 pairs in FV
# 3699 are 1mu-1p, 12.5%
# 3876 are other pairs, 13.2%
# 21900 are cosmic, 74.3%
# --------------------------------------------------------------
# 1196 are CC 1p 0pi, 4.1%

# %%
N_box_sizes = 30
MinNwiresBox = 5
dNwiresBox = 5
MinNticksBox = 10
dNticksBox = 10
NwiresBox,NticksBox=[],[]
for i_box_size in range(N_box_sizes):
    NwiresBox.append(MinNwiresBox + i_box_size * dNwiresBox)
    NticksBox.append(MinNticksBox + i_box_size * dNticksBox)

# %%
# - - -- - -- - -- -- - -- - - - - -- - -- - -- -- - -- - - - - -- - -- - -- -- - -- - - - - -- - -- - -- -- - -- - -
pur_eff = pd.DataFrame()

def get_pur_eff_cut(cut_name = '${PID}_A$' , reduced = dict()):
    # return eff_CC1p0pi,pur_CC1p0pi 
    global pur_eff
    Noriginal , Nreducted , freducted = dict() , dict() , dict()
    for pair_type in pair_types:
        sam = samples[pair_type]
        Noriginal[pair_type] = len(samples[pair_type])
        Nreducted[pair_type] = float(len(reduced[pair_type]))
        freducted[pair_type] = 100.0 * Nreducted[pair_type]/Noriginal[pair_type]
    pur_eff_cut = pd.DataFrame({'$\mu p$ eff.':'%.1f'%freducted['1mu-1p']+'%'
                               ,'$\mu p$ pur.':'%.1f'%(100.*Nreducted['1mu-1p']/(Nreducted['1mu-1p']+Nreducted['cosmic']+Nreducted['other pairs']) if (Nreducted['1mu-1p']+Nreducted['cosmic']+Nreducted['other pairs'])>0 else 0)+'%'
                               ,'CC$0\pi 1 p$ eff.':'%.1f'%freducted['CC 1p 0pi']+'%'
                               ,'CC$0\pi 1 p$ pur.':'%.1f'%(100.*Nreducted['CC 1p 0pi']/(Nreducted['1mu-1p']+Nreducted['cosmic']+Nreducted['other pairs']) if (Nreducted['1mu-1p']+Nreducted['cosmic']+Nreducted['other pairs'])>0 else 0)+'%'}
                               , index=[cut_name]
                              )
    for pair_type in pair_types: pur_eff_cut[pair_type] = '%.1f'%freducted[pair_type]+'%' +' (%.0f)'%Nreducted[pair_type]
    pur_eff = pur_eff.append(pur_eff_cut)
    reduced_samples[cut_name] = reduced  
    return freducted['CC 1p 0pi'],(100.*Nreducted['CC 1p 0pi']/(Nreducted['1mu-1p']+Nreducted['cosmic']+Nreducted['other pairs']) if (Nreducted['1mu-1p']+Nreducted['cosmic']+Nreducted['other pairs'])>0 else 0)
# - - -- - -- - -- -- - -- - - - - -- - -- - -- -- - -- - - - - -- - -- - -- -- - -- - - - - -- - -- - -- -- - -- - -
reduced_samples=dict(dict())
pur_eff = pd.DataFrame()
reduced = dict()
for pair_type in pair_types: reduced[pair_type] = samples[pair_type]
reduced_samples['no cut'] = reduced
# before cuts
reduced = dict()
for pair_type in pair_types:
    sam = reduced_samples['no cut'][pair_type]
    reduced[pair_type] = sam
get_pur_eff_cut(cut_name = 'no cut', reduced = reduced)

# cut 1: PIDa
reduced = dict()
for pair_type in pair_types:
    sam = reduced_samples['no cut'][pair_type]
    reduced[pair_type] = sam[sam['PIDa_assigned_proton']>8]
get_pur_eff_cut(cut_name = '${PID}_a$', reduced = reduced)


# cut 2.5: require that the longer track is the one with larger PIDa
reduced = dict()
for pair_type in pair_types:
    sam = reduced_samples['${PID}_a$'][pair_type]
    reduced[pair_type] = sam[sam['PIDa_long'] < sam['PIDa_short']]
get_pur_eff_cut(cut_name = '$l_{\\mu}>l_{p}$', reduced = reduced)



# cut 3: |\theta_{1,2}-90^0|<60^0$
reduced = dict()
for pair_type in pair_types:
    sam = reduced_samples['$l_{\\mu}>l_{p}$'][pair_type]
    reduced[pair_type] = sam[np.abs(sam['theta_12']-90)<60]
get_pur_eff_cut(cut_name = '$|\theta_{1,2}-90^0|<60^0$', reduced = reduced)

pur_eff
# Out:
#                            $\mu p$ eff. $\mu p$ pur. CC$0\pi 1 p$ eff.  \
# no cut                           100.0%        12.5%            100.0%
# ${PID}_a$                         93.5%        31.9%             92.4%
# $l_{\mu}>l_{p}$                   74.3%        47.1%             77.3%
# $|\theta_{1,2}-90^0|<60^0$        68.0%        66.7%             74.3%
#
#                            CC$0\pi 1 p$ pur.         1mu-1p    other pairs  \
# no cut                                  4.1%  100.0% (3699)  100.0% (3876)
# ${PID}_a$                              10.2%   93.5% (3460)   58.2% (2256)
# $l_{\mu}>l_{p}$                        15.8%   74.3% (2750)   28.6% (1110)
# $|\theta_{1,2}-90^0|<60^0$             23.6%   68.0% (2515)    18.4% (712)
#
#                                     cosmic      CC 1p 0pi
# no cut                      100.0% (21900)  100.0% (1196)
# ${PID}_a$                     23.4% (5115)   92.4% (1105)
# $l_{\mu}>l_{p}$                9.0% (1978)    77.3% (925)
# $|\theta_{1,2}-90^0|<60^0$      2.5% (544)    74.3% (889)

# %% [markdown]
# # compare between 3D distributions:
# We want to find the optimal box dimensions by the ones with the largest difference (separation of CCQE from others)
# in order to do that we compare between distributions using the 3D energy test

# %%
from scipy.spatial.distance import pdist, cdist
def Etest(x, y, method='log', epsilon=0.0001 ,debug=0):
    '''
     Energy distance statistics test.
     Reference
     ---------
     Aslan, B, Zech, G (2005) Statistical energy as a tool for binning-free
       multivariate goodness-of-fit tests, two-sample comparison and unfolding.
       Nuc Instr and Meth in Phys Res A 537: 626-636
     Szekely, G, Rizzo, M (2014) Energy statistics: A class of statistics
       based on distances. J Stat Planning & Infer 143: 1249-1272
     Brian Lau, multdist, https://github.com/brian-lau/multdist
     ---------
    Parameters: x: np.array()
                y:  np.array()
                method: method for energy-test function calculation
                        'log' : ln(r+ε)
                epsilon: for method 'log', this is the cutoff ε
                
    Returns:    Psi: ln(r(xy)+ε)/Nx*Ny - ln(r(xx)+ε)/Nx*Nx - ln(r(yy)+ε)/Ny*Ny
    '''
    if debug: print "energy(x, y, method='log')"
    r_xx, r_yy, r_xy = pdist(x), pdist(y), cdist(x, y)
    if debug:
        print "dx:",r_xx,'\n log(r_xx+ε):',np.log(r_xx+epsilon)
        print "r_yy:",r_yy,'\n log(r_yy+ε):',np.log(r_yy+epsilon)
        print "r_xy:",r_xy,'\n log(r_xy+ε):',np.log(r_xy+epsilon)
        
    Nx, Ny = len(x), len(y)
    
    if method == 'log':
        log_r_xx, log_r_yy, log_r_xy = np.log(r_xx+epsilon), np.log(r_yy+epsilon), np.log(r_xy+epsilon)
        Phi = log_r_xy.sum() / (Nx*Ny) - log_r_xx.sum() / (Nx*Nx) - log_r_yy.sum() / (Ny*Ny)
        
    elif method == 'gaussian':
        raise NotImplementedError
    elif method == 'linear':
        pass
    else:
        raise ValueError
        
    return Phi

# %%
x=np.array([[0.,1.,1.],[0.,2.2,1.],[0.,1.4,1.2],[10.,1.4,1.2],[10.,14.,1.2]])
y=np.array([[0.,1.,1.05],[0.,2.,1.],[0.,1.4,1.25],[0.2,0.4,1.2]])
y_close=np.array([[0.,1.,1.051],[0.,2.,1.01],[0.,1.4,1.26],[0.2,0.4,1.21]])
print "Etest(x, y, debug=0):",Etest(x, y, debug=0)
print "Etest(y, y_close, debug=0):",Etest(y, y_close, debug=0)
# Out:
# Etest(x, y, debug=0): -0.0603350848024
# Etest(y, y_close, debug=0): -1.28735912288

# %%
def Etest_CC1p0pi_vs_other_pair_types_per_box_size( samples=samples, i_box_size = 0 , debug=0 ):

    RdQ_xyz, RdQ_3D_array = dict(), dict()

    for i_pair_type in range(4):
        pair_type = pair_types[i_pair_type]; sample = samples[pair_type]     

        varx = 'RdQaroundVertex[plane 0][%d wires x %d ticks]'%(NwiresBox[i_box_size],NticksBox[i_box_size])
        vary = 'RdQaroundVertex[plane 1][%d wires x %d ticks]'%(NwiresBox[i_box_size],NticksBox[i_box_size])
        varz = 'RdQaroundVertex[plane 2][%d wires x %d ticks]'%(NwiresBox[i_box_size],NticksBox[i_box_size])

        sample = sample[(sample[varx]>-0.01)&(sample[vary]>-0.01)&(sample[varz]>-0.01)]
        x,y,z = sample[varx], sample[vary], sample[varz]
        RdQ_xyz[pair_type] = (x,y,z)
        RdQ_3D_array[pair_type] = np.array([[x_p,y_p,z_p] for x_p,y_p,z_p in zip(x,y,z)])
        if debug>1: print "created a 3D array for",pair_type
        
    PsiEtest = dict()
    for pair_type in (pair_types[0:3]):
        PsiEtest[pair_type+'/'+'CC 1p 0pi'] = Etest( RdQ_3D_array[pair_type], RdQ_3D_array['CC 1p 0pi'], debug=debug-1 )
    if debug: 
        print 'box size: [%d wires x %d ticks]'%(NwiresBox[i_box_size],NticksBox[i_box_size])
        print PsiEtest
    return PsiEtest

# %%
Etest_CC1p0pi_vs_other_pair_types_per_box_size( i_box_size = 7 , debug = 1 )
# Out:
# box size: [40 wires x 80 ticks]
# {'1mu-1p/CC 1p 0pi': 0.099181163542515938, 'other pairs/CC 1p 0pi': 0.088122877818425538, 'cosmic/CC 1p 0pi': 0.12401310036412616}
# {'1mu-1p/CC 1p 0pi': 0.099181163542515938,
#  'cosmic/CC 1p 0pi': 0.12401310036412616,
#  'other pairs/CC 1p 0pi': 0.088122877818425538}

# %%
debug = 1
box_size_indices = []
pd_Etest_results = pd.DataFrame()
for i_box_size in range(N_box_sizes):
    box_size_indices.append(i_box_size)
    PsiEtest = Etest_CC1p0pi_vs_other_pair_types_per_box_size( samples=reduced_samples['no cut'], i_box_size=i_box_size , debug=debug )
    pd_Etest = pd.DataFrame({'box dimensions':'%d wires$\\times$%d ticks'%(NwiresBox[i_box_size],NticksBox[i_box_size])
                             ,'1mu-1p/CC 1p 0pi':PsiEtest['1mu-1p/CC 1p 0pi']
                             ,'other pairs/CC 1p 0pi':PsiEtest['other pairs/CC 1p 0pi']
                             ,'cosmic/CC 1p 0pi':PsiEtest['cosmic/CC 1p 0pi']}
                            ,index=[i_box_size])
    pd_Etest_results = pd_Etest_results.append(pd_Etest)
    
pd_Etest_results
# Out:
# box size: [5 wires x 10 ticks]
# {'1mu-1p/CC 1p 0pi': 0.017284794061800668, 'other pairs/CC 1p 0pi': 0.052446619216474588, 'cosmic/CC 1p 0pi': 0.081476359701095513}
# box size: [10 wires x 20 ticks]
# {'1mu-1p/CC 1p 0pi': 0.042585004467393273, 'other pairs/CC 1p 0pi': 0.013562160515849131, 'cosmic/CC 1p 0pi': 0.01178834249015448}
# box size: [15 wires x 30 ticks]
# {'1mu-1p/CC 1p 0pi': 0.063462418088190531, 'other pairs/CC 1p 0pi': 0.030594288155781357, 'cosmic/CC 1p 0pi': 0.038115400829524249}
# box size: [20 wires x 40 ticks]
# {'1mu-1p/CC 1p 0pi': 0.073489548361624135, 'other pairs/CC 1p 0pi': 0.047243663241135048, 'cosmic/CC 1p 0pi': 0.065536141144770355}
# box size: [25 wires x 50 ticks]
# {'1mu-1p/CC 1p 0pi': 0.080715071724279719, 'other pairs/CC 1p 0pi': 0.057440274669222857, 'cosmic/CC 1p 0pi': 0.08707468156851883}
# box size: [30 wires x 60 ticks]
# {'1mu-1p/CC 1p 0pi': 0.092373300289064764, 'other pairs/CC 1p 0pi': 0.071473121365124737, 'cosmic/CC 1p 0pi': 0.10656096084496047}
# box size: [35 wires x 70 ticks]
# {'1mu-1p/CC 1p 0pi': 0.094558253352347577, 'other pairs/CC 1p 0pi': 0.077554677631912816, 'cosmic/CC 1p 0pi': 0.11264947375105161}
# box size: [40 wires x 80 ticks]
# {'1mu-1p/CC 1p 0pi': 0.099181163542515938, 'other pairs/CC 1p 0pi': 0.088122877818425538, 'cosmic/CC 1p 0pi': 0.12401310036412616}
# box size: [45 wires x 90 ticks]
# {'1mu-1p/CC 1p 0pi': 0.10384604866043257, 'other pairs/CC 1p 0pi': 0.096759742620361022, 'cosmic/CC 1p 0pi': 0.13431341359697191}
# box size: [50 wires x 100 ticks]
# {'1mu-1p/CC 1p 0pi': 0.10743289252846222, 'other pairs/CC 1p 0pi': 0.10766269622856561, 'cosmic/CC 1p 0pi': 0.14794493142406639}
# box size: [55 wires x 110 ticks]
# {'1mu-1p/CC 1p 0pi': 0.1089967086709267, 'other pairs/CC 1p 0pi': 0.11466189625036216, 'cosmic/CC 1p 0pi': 0.15584510468366675}
# box size: [60 wires x 120 ticks]
# {'1mu-1p/CC 1p 0pi': 0.1084252540124101, 'other pairs/CC 1p 0pi': 0.11819116716847555, 'cosmic/CC 1p 0pi': 0.16075259671664177}
# box size: [65 wires x 130 ticks]
# {'1mu-1p/CC 1p 0pi': 0.10903957001683506, 'other pairs/CC 1p 0pi': 0.12002272710851192, 'cosmic/CC 1p 0pi': 0.16339669043069638}
# box size: [70 wires x 140 ticks]
# {'1mu-1p/CC 1p 0pi': 0.1094315503850346, 'other pairs/CC 1p 0pi': 0.12477709380686097, 'cosmic/CC 1p 0pi': 0.16655737907177592}
# box size: [75 wires x 150 ticks]
# {'1mu-1p/CC 1p 0pi': 0.1091095182815246, 'other pairs/CC 1p 0pi': 0.12684526722120359, 'cosmic/CC 1p 0pi': 0.16925174608939053}
# box size: [80 wires x 160 ticks]
# {'1mu-1p/CC 1p 0pi': 0.10525738910230276, 'other pairs/CC 1p 0pi': 0.127046765367131, 'cosmic/CC 1p 0pi': 0.16700607315045846}
# box size: [85 wires x 170 ticks]
# {'1mu-1p/CC 1p 0pi': 0.10461412109474311, 'other pairs/CC 1p 0pi': 0.12888009497905017, 'cosmic/CC 1p 0pi': 0.17077543016704355}
# box size: [90 wires x 180 ticks]
# {'1mu-1p/CC 1p 0pi': 0.10196634845452557, 'other pairs/CC 1p 0pi': 0.12756407573067885, 'cosmic/CC 1p 0pi': 0.16759225060622818}
# box size: [95 wires x 190 ticks]
# {'1mu-1p/CC 1p 0pi': 0.099412564539826498, 'other pairs/CC 1p 0pi': 0.12710348060822807, 'cosmic/CC 1p 0pi': 0.16530745578312722}
# box size: [100 wires x 200 ticks]
# {'1mu-1p/CC 1p 0pi': 0.097727404410318464, 'other pairs/CC 1p 0pi': 0.12815355434728004, 'cosmic/CC 1p 0pi': 0.16480288834922741}
# box size: [105 wires x 210 ticks]
# {'1mu-1p/CC 1p 0pi': 0.094987962672459791, 'other pairs/CC 1p 0pi': 0.12864526996642689, 'cosmic/CC 1p 0pi': 0.16310797411343292}
# box size: [110 wires x 220 ticks]
# {'1mu-1p/CC 1p 0pi': 0.092520900625662539, 'other pairs/CC 1p 0pi': 0.12888312545265068, 'cosmic/CC 1p 0pi': 0.16118645943551141}
# box size: [115 wires x 230 ticks]
# {'1mu-1p/CC 1p 0pi': 0.092113125357470627, 'other pairs/CC 1p 0pi': 0.12997918237164585, 'cosmic/CC 1p 0pi': 0.16104758351444354}
# box size: [120 wires x 240 ticks]
# {'1mu-1p/CC 1p 0pi': 0.088128750930072108, 'other pairs/CC 1p 0pi': 0.12746082024936545, 'cosmic/CC 1p 0pi': 0.15593420457894114}
# box size: [125 wires x 250 ticks]
# {'1mu-1p/CC 1p 0pi': 0.086943920612725711, 'other pairs/CC 1p 0pi': 0.12758128511818145, 'cosmic/CC 1p 0pi': 0.15472677152874442}
# box size: [130 wires x 260 ticks]
# {'1mu-1p/CC 1p 0pi': 0.086490524588672568, 'other pairs/CC 1p 0pi': 0.13003595159545867, 'cosmic/CC 1p 0pi': 0.15501953230499982}
# box size: [135 wires x 270 ticks]
# {'1mu-1p/CC 1p 0pi': 0.084668893688069402, 'other pairs/CC 1p 0pi': 0.12948943635723886, 'cosmic/CC 1p 0pi': 0.152989155654425}
# box size: [140 wires x 280 ticks]
# {'1mu-1p/CC 1p 0pi': 0.084219996042825707, 'other pairs/CC 1p 0pi': 0.13102811281121607, 'cosmic/CC 1p 0pi': 0.15442086930431936}
# box size: [145 wires x 290 ticks]
# {'1mu-1p/CC 1p 0pi': 0.082740103883236271, 'other pairs/CC 1p 0pi': 0.13066902650298096, 'cosmic/CC 1p 0pi': 0.15306276197545204}
# box size: [150 wires x 300 ticks]
# {'1mu-1p/CC 1p 0pi': 0.081530850351748119, 'other pairs/CC 1p 0pi': 0.13095412545223523, 'cosmic/CC 1p 0pi': 0.152769738377037}
#     1mu-1p/CC 1p 0pi              box dimensions  cosmic/CC 1p 0pi  \
# 0           0.017285     5 wires$\times$10 ticks          0.081476
# 1           0.042585    10 wires$\times$20 ticks          0.011788
# 2           0.063462    15 wires$\times$30 ticks          0.038115
# 3           0.073490    20 wires$\times$40 ticks          0.065536
# 4           0.080715    25 wires$\times$50 ticks          0.087075
# 5           0.092373    30 wires$\times$60 ticks          0.106561
# 6           0.094558    35 wires$\times$70 ticks          0.112649
# 7           0.099181    40 wires$\times$80 ticks          0.124013
# 8           0.103846    45 wires$\times$90 ticks          0.134313
# 9           0.107433   50 wires$\times$100 ticks          0.147945
# 10          0.108997   55 wires$\times$110 ticks          0.155845
# 11          0.108425   60 wires$\times$120 ticks          0.160753
# 12          0.109040   65 wires$\times$130 ticks          0.163397
# 13          0.109432   70 wires$\times$140 ticks          0.166557
# 14          0.109110   75 wires$\times$150 ticks          0.169252
# 15          0.105257   80 wires$\times$160 ticks          0.167006
# 16          0.104614   85 wires$\times$170 ticks          0.170775
# 17          0.101966   90 wires$\times$180 ticks          0.167592
# 18          0.099413   95 wires$\times$190 ticks          0.165307
# 19          0.097727  100 wires$\times$200 ticks          0.164803
# 20          0.094988  105 wires$\times$210 ticks          0.163108
# 21          0.092521  110 wires$\times$220 ticks          0.161186
# 22          0.092113  115 wires$\times$230 ticks          0.161048
# 23          0.088129  120 wires$\times$240 ticks          0.155934
# 24          0.086944  125 wires$\times$250 ticks          0.154727
# 25          0.086491  130 wires$\times$260 ticks          0.155020
# 26          0.084669  135 wires$\times$270 ticks          0.152989
# 27          0.084220  140 wires$\times$280 ticks          0.154421
# 28          0.082740  145 wires$\times$290 ticks          0.153063
# 29          0.081531  150 wires$\times$300 ticks          0.152770
#
#     other pairs/CC 1p 0pi
# 0                0.052447
# 1                0.013562
# 2                0.030594
# 3                0.047244
# 4                0.057440
# 5                0.071473
# 6                0.077555
# 7                0.088123
# 8                0.096760
# 9                0.107663
# 10               0.114662
# 11               0.118191
# 12               0.120023
# 13               0.124777
# 14               0.126845
# 15               0.127047
# 16               0.128880
# 17               0.127564
# 18               0.127103
# 19               0.128154
# 20               0.128645
# 21               0.128883
# 22               0.129979
# 23               0.127461
# 24               0.127581
# 25               0.130036
# 26               0.129489
# 27               0.131028
# 28               0.130669
# 29               0.130954

# %%
fig,ax=plt.subplots(figsize=(12,8))
for i_pair_type in range(3):
    pair_type=pair_types[i_pair_type];color=colors[i_pair_type];label=labels[i_pair_type]
    y = pd_Etest_results[pair_type+'/'+'CC 1p 0pi'];
    plt.plot( y , '--o' , color=color , label=label+'/CC1p0$\pi$')
# plt.legend(loc='lower center',fontsize=20)
leg=plt.legend(bbox_to_anchor=(1.05,1),loc=2,fontsize=20)
xticks=[0,5,10,15,20,25,29]
set_axes( ax , 'box dimensions [$N_{wires} \\times N_{ticks}$]' , '$\Phi_{Etest}$ [a.u.]',xticks=xticks ,do_add_grid=True)
ax.yaxis.set_major_locator(LinearLocator(5))
tick_labels = [item.get_text() for item in ax.get_xticklabels()]
# tick_labels[0] = pd_Etest_results['box dimensions'][0]
for i,i_box_size in enumerate(xticks):
    tick_labels[i] = '%d$\\times$%d'%(NwiresBox[i_box_size],NticksBox[i_box_size])
ax.set_xticklabels(tick_labels, rotation=65);
ax.xaxis.labelpad = -150
plt.tight_layout()
plt.savefig(figures_path+'EtestPsi_vs_box_dimensions.pdf',bbox_extra_artists=(leg,), bbox_inches='tight')

# %% [markdown]
# # now after cuts

# %%
debug = 1
box_size_indices = []
pd_Etest_results = pd.DataFrame()
for i_box_size in range(N_box_sizes):
    box_size_indices.append(i_box_size)
    PsiEtest = Etest_CC1p0pi_vs_other_pair_types_per_box_size( reduced_samples['$|\theta_{1,2}-90^0|<60^0$'],i_box_size=i_box_size , debug=debug )
    pd_Etest = pd.DataFrame({'box dimensions':'%d wires$\\times$%d ticks'%(NwiresBox[i_box_size],NticksBox[i_box_size])
                             ,'1mu-1p/CC 1p 0pi':PsiEtest['1mu-1p/CC 1p 0pi']
                             ,'other pairs/CC 1p 0pi':PsiEtest['other pairs/CC 1p 0pi']
                             ,'cosmic/CC 1p 0pi':PsiEtest['cosmic/CC 1p 0pi']}
                            ,index=[i_box_size])
    pd_Etest_results = pd_Etest_results.append(pd_Etest)
    
pd_Etest_results
# Out:
# box size: [5 wires x 10 ticks]
# {'1mu-1p/CC 1p 0pi': 0.023161787019318592, 'other pairs/CC 1p 0pi': 0.04209253774105759, 'cosmic/CC 1p 0pi': 0.22602396845985812}
# box size: [10 wires x 20 ticks]
# {'1mu-1p/CC 1p 0pi': 0.049001906033856069, 'other pairs/CC 1p 0pi': 0.11040110812271547, 'cosmic/CC 1p 0pi': 0.32752094937136822}
# box size: [15 wires x 30 ticks]
# {'1mu-1p/CC 1p 0pi': 0.066866492158780377, 'other pairs/CC 1p 0pi': 0.13773422718714845, 'cosmic/CC 1p 0pi': 0.38618193377027099}
# box size: [20 wires x 40 ticks]
# {'1mu-1p/CC 1p 0pi': 0.074895656243056385, 'other pairs/CC 1p 0pi': 0.17054504428417605, 'cosmic/CC 1p 0pi': 0.39825852331388162}
# box size: [25 wires x 50 ticks]
# {'1mu-1p/CC 1p 0pi': 0.077898864756738018, 'other pairs/CC 1p 0pi': 0.18427847173854733, 'cosmic/CC 1p 0pi': 0.40468211068981147}
# box size: [30 wires x 60 ticks]
# {'1mu-1p/CC 1p 0pi': 0.090405992257038381, 'other pairs/CC 1p 0pi': 0.2055900261803516, 'cosmic/CC 1p 0pi': 0.41090779854668524}
# box size: [35 wires x 70 ticks]
# {'1mu-1p/CC 1p 0pi': 0.092534410750814811, 'other pairs/CC 1p 0pi': 0.21439070829452089, 'cosmic/CC 1p 0pi': 0.41173216223356957}
# box size: [40 wires x 80 ticks]
# {'1mu-1p/CC 1p 0pi': 0.096320894081522335, 'other pairs/CC 1p 0pi': 0.22311568009214616, 'cosmic/CC 1p 0pi': 0.41257311619627168}
# box size: [45 wires x 90 ticks]
# {'1mu-1p/CC 1p 0pi': 0.10159330219036655, 'other pairs/CC 1p 0pi': 0.23266510547889185, 'cosmic/CC 1p 0pi': 0.41744779696346512}
# box size: [50 wires x 100 ticks]
# {'1mu-1p/CC 1p 0pi': 0.1056595948884308, 'other pairs/CC 1p 0pi': 0.24922976430601906, 'cosmic/CC 1p 0pi': 0.42666868262253366}
# box size: [55 wires x 110 ticks]
# {'1mu-1p/CC 1p 0pi': 0.1077221036952235, 'other pairs/CC 1p 0pi': 0.25382010792760168, 'cosmic/CC 1p 0pi': 0.4255930987763451}
# box size: [60 wires x 120 ticks]
# {'1mu-1p/CC 1p 0pi': 0.10798202631953679, 'other pairs/CC 1p 0pi': 0.25713980568155509, 'cosmic/CC 1p 0pi': 0.41658913859922531}
# box size: [65 wires x 130 ticks]
# {'1mu-1p/CC 1p 0pi': 0.11017211895901347, 'other pairs/CC 1p 0pi': 0.26058212517234086, 'cosmic/CC 1p 0pi': 0.41846987191929702}
# box size: [70 wires x 140 ticks]
# {'1mu-1p/CC 1p 0pi': 0.11077149956672994, 'other pairs/CC 1p 0pi': 0.26920889872232145, 'cosmic/CC 1p 0pi': 0.37637863639137109}
# box size: [75 wires x 150 ticks]
# {'1mu-1p/CC 1p 0pi': 0.10933096241639073, 'other pairs/CC 1p 0pi': 0.26560377588669515, 'cosmic/CC 1p 0pi': 0.37201791977777399}
# box size: [80 wires x 160 ticks]
# {'1mu-1p/CC 1p 0pi': 0.10390508977600765, 'other pairs/CC 1p 0pi': 0.25655351976483159, 'cosmic/CC 1p 0pi': 0.36213118372340897}
# box size: [85 wires x 170 ticks]
# {'1mu-1p/CC 1p 0pi': 0.10184916924835707, 'other pairs/CC 1p 0pi': 0.25466763679255161, 'cosmic/CC 1p 0pi': 0.3680437094573526}
# box size: [90 wires x 180 ticks]
# {'1mu-1p/CC 1p 0pi': 0.098041035671737053, 'other pairs/CC 1p 0pi': 0.2439256947936671, 'cosmic/CC 1p 0pi': 0.35821220549817506}
# box size: [95 wires x 190 ticks]
# {'1mu-1p/CC 1p 0pi': 0.094044475676391737, 'other pairs/CC 1p 0pi': 0.23948464858030133, 'cosmic/CC 1p 0pi': 0.34847437749642829}
# box size: [100 wires x 200 ticks]
# {'1mu-1p/CC 1p 0pi': 0.091742437527427501, 'other pairs/CC 1p 0pi': 0.23587331506202197, 'cosmic/CC 1p 0pi': 0.33740160493189369}
# box size: [105 wires x 210 ticks]
# {'1mu-1p/CC 1p 0pi': 0.089486608399834355, 'other pairs/CC 1p 0pi': 0.2381320079848987, 'cosmic/CC 1p 0pi': 0.33917364007410461}
# box size: [110 wires x 220 ticks]
# {'1mu-1p/CC 1p 0pi': 0.086461146593313054, 'other pairs/CC 1p 0pi': 0.23767121390105767, 'cosmic/CC 1p 0pi': 0.3354847336931906}
# box size: [115 wires x 230 ticks]
# {'1mu-1p/CC 1p 0pi': 0.085831156805408426, 'other pairs/CC 1p 0pi': 0.23492878722256527, 'cosmic/CC 1p 0pi': 0.33970631289165615}
# box size: [120 wires x 240 ticks]
# {'1mu-1p/CC 1p 0pi': 0.081726798375711729, 'other pairs/CC 1p 0pi': 0.22710242903782885, 'cosmic/CC 1p 0pi': 0.34690512405420915}
# box size: [125 wires x 250 ticks]
# {'1mu-1p/CC 1p 0pi': 0.080636758992519542, 'other pairs/CC 1p 0pi': 0.22444059606564759, 'cosmic/CC 1p 0pi': 0.34789094233829865}
# box size: [130 wires x 260 ticks]
# {'1mu-1p/CC 1p 0pi': 0.080951723470890857, 'other pairs/CC 1p 0pi': 0.22448123900773437, 'cosmic/CC 1p 0pi': 0.35359560817926589}
# box size: [135 wires x 270 ticks]
# {'1mu-1p/CC 1p 0pi': 0.07952411862312625, 'other pairs/CC 1p 0pi': 0.22095693164480473, 'cosmic/CC 1p 0pi': 0.35990594844344864}
# box size: [140 wires x 280 ticks]
# {'1mu-1p/CC 1p 0pi': 0.079183992285091875, 'other pairs/CC 1p 0pi': 0.21951592900259376, 'cosmic/CC 1p 0pi': 0.35627265122321572}
# box size: [145 wires x 290 ticks]
# {'1mu-1p/CC 1p 0pi': 0.078587114719052553, 'other pairs/CC 1p 0pi': 0.21981120682283734, 'cosmic/CC 1p 0pi': 0.35839770375535301}
# box size: [150 wires x 300 ticks]
# {'1mu-1p/CC 1p 0pi': 0.077592282321469974, 'other pairs/CC 1p 0pi': 0.21998607476066773, 'cosmic/CC 1p 0pi': 0.36313147647837352}
#     1mu-1p/CC 1p 0pi              box dimensions  cosmic/CC 1p 0pi  \
# 0           0.023162     5 wires$\times$10 ticks          0.226024
# 1           0.049002    10 wires$\times$20 ticks          0.327521
# 2           0.066866    15 wires$\times$30 ticks          0.386182
# 3           0.074896    20 wires$\times$40 ticks          0.398259
# 4           0.077899    25 wires$\times$50 ticks          0.404682
# 5           0.090406    30 wires$\times$60 ticks          0.410908
# 6           0.092534    35 wires$\times$70 ticks          0.411732
# 7           0.096321    40 wires$\times$80 ticks          0.412573
# 8           0.101593    45 wires$\times$90 ticks          0.417448
# 9           0.105660   50 wires$\times$100 ticks          0.426669
# 10          0.107722   55 wires$\times$110 ticks          0.425593
# 11          0.107982   60 wires$\times$120 ticks          0.416589
# 12          0.110172   65 wires$\times$130 ticks          0.418470
# 13          0.110771   70 wires$\times$140 ticks          0.376379
# 14          0.109331   75 wires$\times$150 ticks          0.372018
# 15          0.103905   80 wires$\times$160 ticks          0.362131
# 16          0.101849   85 wires$\times$170 ticks          0.368044
# 17          0.098041   90 wires$\times$180 ticks          0.358212
# 18          0.094044   95 wires$\times$190 ticks          0.348474
# 19          0.091742  100 wires$\times$200 ticks          0.337402
# 20          0.089487  105 wires$\times$210 ticks          0.339174
# 21          0.086461  110 wires$\times$220 ticks          0.335485
# 22          0.085831  115 wires$\times$230 ticks          0.339706
# 23          0.081727  120 wires$\times$240 ticks          0.346905
# 24          0.080637  125 wires$\times$250 ticks          0.347891
# 25          0.080952  130 wires$\times$260 ticks          0.353596
# 26          0.079524  135 wires$\times$270 ticks          0.359906
# 27          0.079184  140 wires$\times$280 ticks          0.356273
# 28          0.078587  145 wires$\times$290 ticks          0.358398
# 29          0.077592  150 wires$\times$300 ticks          0.363131
#
#     other pairs/CC 1p 0pi
# 0                0.042093
# 1                0.110401
# 2                0.137734
# 3                0.170545
# 4                0.184278
# 5                0.205590
# 6                0.214391
# 7                0.223116
# 8                0.232665
# 9                0.249230
# 10               0.253820
# 11               0.257140
# 12               0.260582
# 13               0.269209
# 14               0.265604
# 15               0.256554
# 16               0.254668
# 17               0.243926
# 18               0.239485
# 19               0.235873
# 20               0.238132
# 21               0.237671
# 22               0.234929
# 23               0.227102
# 24               0.224441
# 25               0.224481
# 26               0.220957
# 27               0.219516
# 28               0.219811
# 29               0.219986

# %%
xticks=[0,5,10,15,20,25,29] 
fig=plt.figure(figsize=(16,16))
for i_pair_type in range(3):
    ax = fig.add_subplot(3,1,i_pair_type+1)
    pair_type=pair_types[i_pair_type];color=colors[i_pair_type];label=labels[i_pair_type]
    y = pd_Etest_results[pair_type+'/'+'CC 1p 0pi'];
    plt.plot( y , '--o' , color=color , label=label+'/CC1p0$\pi$')
# plt.legend(loc='lower center',fontsize=20)
    leg=plt.legend(fontsize=20)#,bbox_to_anchor=(1.05,1),loc=2
    set_axes( ax , 'box dimensions [$N_{wires} \\times N_{ticks}$]' if i_pair_type==2 else ''
             , '$\Phi_{Etest}$ [a.u.]',xticks=xticks ,do_add_grid=True)
    ax.yaxis.set_major_locator(LinearLocator(5))
    tick_labels = [item.get_text() for item in ax.get_xticklabels()]
    # tick_labels[0] = pd_Etest_results['box dimensions'][0]
    for i,i_box_size in enumerate(xticks):
          tick_labels[i] = '%d$\\times$%d'%(NwiresBox[i_box_size],NticksBox[i_box_size]) if i_pair_type==2 else ''
    ax.set_xticklabels(tick_labels, rotation=65);
    ax.xaxis.labelpad = -150
# ax.set_yscale('log')
plt.tight_layout()
plt.savefig(figures_path+'EtestPsi_vs_box_dimensions_after_detection_cuts.pdf',bbox_extra_artists=(leg,), bbox_inches='tight')

# %% [markdown]
# # A cut on \RdQ for the optimized box dimensions

# %%
i_box_size = 13
print 'optimal box dimensions: [%d wires x %d ticks]'%(NwiresBox[i_box_size],NticksBox[i_box_size])
RdQ_xyz, RdQ_3D_array = dict(), dict()

for i_pair_type in range(4):
    pair_type = pair_types[i_pair_type]; color=colors[i_pair_type]; label=labels[i_pair_type]; 
    sample = reduced_samples['$|\theta_{1,2}-90^0|<60^0$'][pair_type]     

    varx = 'RdQaroundVertex[plane 0][%d wires x %d ticks]'%(NwiresBox[i_box_size],NticksBox[i_box_size])
    vary = 'RdQaroundVertex[plane 1][%d wires x %d ticks]'%(NwiresBox[i_box_size],NticksBox[i_box_size])
    varz = 'RdQaroundVertex[plane 2][%d wires x %d ticks]'%(NwiresBox[i_box_size],NticksBox[i_box_size])

    sample = sample[(sample[varx]>-0.01)&(sample[vary]>-0.01)&(sample[varz]>-0.01)]
    x,y,z = sample[varx], sample[vary], sample[varz]
    RdQ_xyz[pair_type] = (x,y,z)
    RdQ_3D_array[pair_type] = np.array([[x_p,y_p,z_p] for x_p,y_p,z_p in zip(x,y,z)])
    print "created a 3D array for",pair_type
# Out:
# optimal box dimensions: [70 wires x 140 ticks]
# created a 3D array for 1mu-1p
# created a 3D array for other pairs
# created a 3D array for cosmic
# created a 3D array for CC 1p 0pi

# %% [markdown]
# # find the optimal cut

# %%
def draw_plane_projections(axes=None , a_x=None , a_y=None , a_0=None ,color='black'):
    '''
    draw the projections of the 3D plane
    z = a_0 + a_x*x + a_y*y 
    onto the xy/xz/yz 2D planes
     '''
    if a_x==0: a_x=0.01
    if a_y==0: a_y=0.01
        
    # for z=0 the plane is y = (-1/a_y)*(a_0 + a_x * x)
    x = np.linspace((-a_y-a_0)/a_x,1,100)
    axes.plot(x, (-1./a_y)*(a_0 + a_x * x), color=color, zdir='z', zs=-0.5 )
    
    # for y=0 the plane is z = a_0 + a_x * x
    x = np.linspace((1-a_0)/a_x,1,100)
    axes.plot(x, a_0 + a_x * x, color=color, zdir='y', zs=1.5 ) 

    # for x=0 the plane is z = a_0 + a_y * y
    y = np.linspace((1-a_0)/a_y,1,100)
    axes.plot(y, a_0 + a_y * y, color=color, zdir='x', zs=-0.5 )

# %%
def pureff_above_RdQ_plane(a_x=0 , a_y=0 , a_0=0, i_optimal_box_size=13, debug=0):    
    # return purity*efficiency of CC 1p 0π
    if debug>1: print 'computing impact of cut on optimal box dimensions: (%d wires x %d ticks)'%(NwiresBox[i_optimal_box_size],NticksBox[i_optimal_box_size])
    varx = 'RdQaroundVertex[plane 0][%d wires x %d ticks]'%(NwiresBox[i_optimal_box_size],NticksBox[i_optimal_box_size])
    vary = 'RdQaroundVertex[plane 1][%d wires x %d ticks]'%(NwiresBox[i_optimal_box_size],NticksBox[i_optimal_box_size])
    varz = 'RdQaroundVertex[plane 2][%d wires x %d ticks]'%(NwiresBox[i_optimal_box_size],NticksBox[i_optimal_box_size])    
    # cut 4: RdQ
    reduced = dict()
    for pair_type in pair_types:
        sam = reduced_samples['$|\theta_{1,2}-90^0|<60^0$'][pair_type]
        reduced[pair_type] = sam[(sam[vary] > (-1./a_y)*(a_x*sam[varx] + a_0))&
                                 (sam[varz] > (a_x*sam[varx] + a_0))&
                                 (sam[varz] > (a_y*sam[vary] + a_0))]
    eff_CC1p0pi,pur_CC1p0pi = get_pur_eff_cut(cut_name = '$\\frac{\\Delta Q_{tracks}}{\\Delta Q_{total}}$', reduced = reduced)
    if debug:
        print "a_x, a_y, a_0:",a_x, a_y, a_0
        print "pur_CC1p0pi,eff_CC1p0pi,(eff_CC1p0pi*pur_CC1p0pi):",pur_CC1p0pi,eff_CC1p0pi,(eff_CC1p0pi*pur_CC1p0pi)
    return (eff_CC1p0pi*pur_CC1p0pi)

def pureff_above_RdQ_plane_axy(axy=0 , a0=0, i_optimal_box_size=13, debug=0): 
    return pureff_above_RdQ_plane(a_x=axy , a_y=axy , a_0=a0, i_optimal_box_size=i_optimal_box_size, debug=debug)

# %% [markdown]
# ## look for the optimal cut, for a a_x=a_y

# %%
debug=0
a_xy_array = np.linspace(-1.5,0.5,75)
a_0_array = np.linspace(-0.5,2.5,75)
pureff_CC1p0pi = np.zeros((len(a_xy_array),len(a_0_array)))
for i_a_xy,a_xy in enumerate(a_xy_array):
    if (i_a_xy%(10)==0): print 'i_a_xy:',i_a_xy
    for i_a0,a_0 in enumerate(a_0_array):
        fpureff_CC1p0pi = pureff_above_RdQ_plane_axy(axy=a_xy, a0=a_0, i_optimal_box_size=13, debug=debug )
        pureff_CC1p0pi[i_a_xy][i_a0] = fpureff_CC1p0pi    
print 'done'
# Out:
# i_a_xy: 0
# i_a_xy: 10
# i_a_xy: 20
# i_a_xy: 30
# i_a_xy: 40
# i_a_xy: 50
# i_a_xy: 60
# i_a_xy: 70
# done

# %%
np.max(pureff_CC1p0pi)
# Out:
# 2484.8218409673955

# %%
# print pureff_CC1p0pi
fig,ax=plt.subplots(figsize=(12,8))
X,Y = np.meshgrid(a_xy_array,a_0_array)
plt.contourf( X , Y , pureff_CC1p0pi.T , cmap='hot_r' )
Xmax = -1.
Ymax = 1.6
plt.plot([Xmax,Xmax],ax.get_ylim(),'--',color='royalblue',linewidth=1)
plt.plot(ax.get_xlim(),[Ymax,Ymax],'--',color='royalblue',linewidth=1)
# plt.colorbar()
set_axes(ax,'$a_U=a_V=a$','$a_0$',do_add_grid=True)
plt.savefig(figures_path+'cut_optimization_axy_a0.pdf')

# %%
for i_pair_type in range(4):
    pair_type = pair_types[i_pair_type]; color=colors[i_pair_type]; label=labels[i_pair_type]; sample = samples[pair_type]     
    x, y, z = RdQ_xyz[pair_type]
    fig3D = plt.figure(figsize=(14,8)).gca(projection='3d')
    fig3D.scatter( x , y , z , c=color, s=20 , alpha=0.5 )
    fig3D.scatter(x, z, color=color, zdir='y', s=5, zs=1.5 , edgecolors='black') 
    fig3D.scatter(y, z, color=color, zdir='x', s=5, zs=-0.5 , edgecolors='black')
    fig3D.scatter(x, y, color=color, zdir='z', s=5, zs=-0.5 , edgecolors='black')
    
    fig3D.set_xlim(-0.3,1.3);fig3D.set_ylim(-0.3,1.3);fig3D.set_zlim(-0.3,1.3)
    set_axes(fig3D,x_label='$U$ plane',y_label='$V$ plane',z_label='$Y$ plane'
             ,xticks=[0,0.25,0.5,0.75,1],yticks=[0,0.25,0.5,0.75,1],zticks=[0,0.3,0.6,0.9])
    fig3D.xaxis.labelpad = 30 ; fig3D.yaxis.labelpad = 30 ; fig3D.zaxis.labelpad = 30
    plt.tight_layout()
    # optimal cut
    a_x=-1 ; a_y=a_x ; a_0=1.6
    # --- - - -- --- - -- --- 
    draw_plane_projections(axes=fig3D , a_x=a_x , a_y=a_y , a_0=a_0,color='red')
    plt.savefig(figures_path + 'ChosenBoxDimensions_pairtype_%d.pdf'%i_pair_type)
pureff_above_RdQ_plane(a_x=a_x , a_y=a_y , a_0=a_0, i_optimal_box_size=13 )
# Out:
# 2207.511671231798

# %%
for i_pair_type in range(3,4):
    pair_type = pair_types[i_pair_type]; color=colors[i_pair_type]; label=labels[i_pair_type]; sample = samples[pair_type]     
    x, y, z = RdQ_xyz[pair_type]
    fig3D = plt.figure(figsize=(14,8)).gca(projection='3d')
    fig3D.scatter( x , y , z , c=color, s=20 , alpha=0.5 )
    fig3D.scatter(x, z, color=color, zdir='y', s=5, zs=1.5 , edgecolors='black') 
    fig3D.scatter(y, z, color=color, zdir='x', s=5, zs=-0.5 , edgecolors='black')
    fig3D.scatter(x, y, color=color, zdir='z', s=5, zs=-0.5 , edgecolors='black')
    
    fig3D.set_xlim(-0.3,1.3);fig3D.set_ylim(-0.3,1.3);fig3D.set_zlim(-0.3,1.3)
    set_axes(fig3D,x_label='$U$ plane',y_label='$V$ plane',z_label='$Y$ plane'
             ,xticks=[0,0.25,0.5,0.75,1],yticks=[0,0.25,0.5,0.75,1],zticks=[0,0.3,0.6,0.9])
    fig3D.xaxis.labelpad = 30 ; fig3D.yaxis.labelpad = 30 ; fig3D.zaxis.labelpad = 30
    plt.tight_layout()    
    # look at the impact of a cut on a plane
    # RdQ(Y) = a_0 + a_x * RdQ(U) + a_y * RdQ(V)
    a_x=-1 ; a_y=a_x 
    a_0=1.6
    draw_plane_projections(axes=fig3D , a_x=a_x , a_y=a_y , a_0=a_0,color='red')
pureff_above_RdQ_plane(a_x=a_x , a_y=a_y , a_0=a_0, i_optimal_box_size=13 , debug=1 )
# Out:
# a_x, a_y, a_0: -1 -1 1.6
# pur_CC1p0pi,eff_CC1p0pi,(eff_CC1p0pi*pur_CC1p0pi): 44.076526858 50.0836120401 2207.51167123
# 2207.511671231798
