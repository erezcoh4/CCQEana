# %%
import sys; sys.path.insert(0, '../../'); sys.path.insert(0,'../../../mac/ndtest/')
sys.path.insert(0, '../mupClassification/'); 
from mupClassification_notebooks import *
from ccqe_notebook_tools import * 
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

# %% [markdown]
# # optimization of the box dimensions for $\frac{\Delta Q_{track}}{\Delta Q_{total}}$

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/mupClassification/Figures/DetectionObservables/VertexActivity/BoxOptimization/'

# %% [markdown]
# # pairs of 2-tracks at close proximity

# %%
N_r_around_vertex = 30
Min_r_around_vertex = 0
dr_around_vertex  = 0.5
r_around_vertex=[]
for i_r_around_vertex in range(N_r_around_vertex):
    r_around_vertex.append( Min_r_around_vertex + i_r_around_vertex * dr_around_vertex)

# %%
MCbnbDATAcosmicPairsFV, MCbnbDATAcosmicSamples = load_MCbnbDATAcosmicSamples(filename='ecohen_physical_files_adi_prodgenie_bnb_nu_uboone_overlay_cosmic_data_100K_reco2_2018_02_23_vertices')
cuts_pureff = apply_cuts_MCbnbDATAcosmic()
pureff_MCbnbDATAcosmic,pureff_MCbnbDATAcosmic_numbers = cuts_pureff
pureff_MCbnbDATAcosmic
# Out:
# 28674 pairs from MC-BNB + cosmic DATA overlay
# 18908 pairs in FV
# 5087 are 1mu-1p, 26.9%
# 4335 are other pairs, 22.9%
# 9486 are cosmic, 50.2%
# --------------------------------------------------------------
# 2514 are CC 1p 0pi, 13.3%
#                        $\mu p$ eff. $\mu p$ pur. CC$0\pi 1 p$ eff.  \
# no cut                       100.0%        26.9%            100.0%
# PIDa                          85.4%        53.6%             84.5%
# flashes                       85.1%        55.9%             84.2%
# flash                         80.4%        57.9%             79.3%
# length                        66.6%        67.4%             69.5%
# non-collinearity              59.7%        73.4%             64.6%
# vertex activity               40.7%        76.9%             55.5%
# delta phi                     27.1%        90.6%             42.5%
# Pt no Delta phi               30.7%        84.9%             45.7%
# soft Pt                       23.8%        93.0%             38.2%
# tight Pt                      12.7%        94.2%             21.6%
# non-collinearity first        88.0%        43.1%             91.9%
# theta_pq                      19.6%        93.9%             33.3%
# l_p_min_10                    14.6%        93.7%             23.3%
# soft Pmiss                    20.4%        93.4%             34.1%
# PIDa-                         90.1%        50.3%             89.4%
# PIDa+                         85.4%        53.6%             84.5%
# theta12-                      57.0%        74.4%             62.4%
# theta12+                      61.5%        72.2%             66.0%
# RdQ-                          37.8%        77.2%             52.2%
# RdQ+                          42.1%        76.8%             56.3%
# delta_phi-                    27.1%        90.6%             42.5%
# delta_phi+                    29.8%        89.0%             45.4%
# Pt-                           22.5%        93.3%             36.4%
# Pt+                           24.9%        92.4%             39.9%
# theta_pq-                     13.1%        94.1%             22.9%
# theta_pq+                     23.2%        93.4%             38.2%
#
#                        CC$0\pi 1 p$ pur.  \
# no cut                             13.3%
# PIDa                               26.2%
# flashes                            27.3%
# flash                              28.3%
# length                             34.7%
# non-collinearity                   39.3%
# vertex activity                    51.9%
# delta phi                          70.3%
# Pt no Delta phi                    62.5%
# soft Pt                            73.8%
# tight Pt                           79.5%
# non-collinearity first             22.2%
# theta_pq                           78.8%
# l_p_min_10                         74.0%
# soft Pmiss                         77.3%
# PIDa-                              24.7%
# PIDa+                              26.2%
# theta12-                           40.2%
# theta12+                           38.3%
# RdQ-                               52.7%
# RdQ+                               50.8%
# delta_phi-                         70.3%
# delta_phi+                         67.0%
# Pt-                                74.6%
# Pt+                                73.1%
# theta_pq-                          81.1%
# theta_pq+                          76.0%
#
#                                                                     label  \
# no cut                                                             no cut
# PIDa                                                         ${PID}_a>13$
# flashes                                                   $N_{flashes}>0$
# flash                                                      optical filter
# length                                                    $l_{\mu}>l_{p}$
# non-collinearity                               $|\theta_{1,2}-90^0|<55^0$
# vertex activity         $\sqrt{\sum_{p=0,1,2}(R_{\Delta Q}^{p}-1)^2}<0...
# delta phi                                      $|\Delta \phi - \pi|<35^0$
# Pt no Delta phi                                        $p_{t}<0.35$ GeV/c
# soft Pt                                                $p_{t}<0.35$ GeV/c
# tight Pt                                               $p_{t}<0.15$ GeV/c
# non-collinearity first                         $|\theta_{1,2}-90^0|<55^0$
# theta_pq                                               $\theta_{pq}<25^0$
# l_p_min_10                                                    $l_p>10$ cm
# soft Pmiss                                          $p_{miss}<0.30$ GeV/c
# PIDa-                                                        ${PID}_a>11$
# PIDa+                                                        ${PID}_a>13$
# theta12-                                       $|\theta_{1,2}-90^0|<50^0$
# theta12+                                       $|\theta_{1,2}-90^0|<60^0$
# RdQ-                    $\sqrt{\sum_{p=0,1,2}(R_{\Delta Q}^{p}-1)^2}<0...
# RdQ+                    $\sqrt{\sum_{p=0,1,2}(R_{\Delta Q}^{p}-1)^2}<0...
# delta_phi-                                     $|\Delta \phi - \pi|<35^0$
# delta_phi+                                     $|\Delta \phi - \pi|<45^0$
# Pt-                                                    $p_{t}<0.30$ GeV/c
# Pt+                                                    $p_{t}<0.40$ GeV/c
# theta_pq-                                         $\theta_{pq}<15^0$ deg.
# theta_pq+                                         $\theta_{pq}<35^0$ deg.
#
#                                1mu-1p    other pairs         cosmic  \
# no cut                  100.0% (5087)  100.0% (4335)  100.0% (9486)
# PIDa                     85.4% (4345)   55.3% (2398)   14.4% (1368)
# flashes                  85.1% (4328)   55.1% (2390)   10.8% (1020)
# flash                    80.4% (4089)   53.2% (2306)     7.0% (662)
# length                   66.6% (3390)   29.3% (1271)     3.9% (370)
# non-collinearity         59.7% (3039)    20.7% (899)     2.1% (202)
# vertex activity          40.7% (2068)    11.8% (513)     1.1% (107)
# delta phi                27.1% (1377)     2.7% (118)      0.3% (25)
# Pt no Delta phi          30.7% (1562)     5.3% (229)      0.5% (49)
# soft Pt                  23.8% (1210)      1.7% (75)      0.2% (16)
# tight Pt                  12.7% (644)      0.8% (33)       0.1% (7)
# non-collinearity first   88.0% (4479)   59.9% (2598)   34.9% (3308)
# theta_pq                  19.6% (997)      1.2% (51)      0.1% (14)
# l_p_min_10                14.6% (743)      1.0% (43)       0.1% (7)
# soft Pmiss               20.4% (1036)      1.4% (59)      0.1% (14)
# PIDa-                    90.1% (4584)   61.5% (2666)   19.6% (1861)
# PIDa+                    85.4% (4345)   55.3% (2398)   14.4% (1368)
# theta12-                 57.0% (2899)    18.7% (812)     2.0% (186)
# theta12+                 61.5% (3129)    22.7% (983)     2.4% (223)
# RdQ-                     37.8% (1923)    10.9% (471)      1.0% (98)
# RdQ+                     42.1% (2141)    12.4% (537)     1.1% (109)
# delta_phi-               27.1% (1377)     2.7% (118)      0.3% (25)
# delta_phi+               29.8% (1515)     3.6% (155)      0.3% (33)
# Pt-                      22.5% (1144)      1.6% (68)      0.1% (14)
# Pt+                      24.9% (1267)      2.0% (85)      0.2% (19)
# theta_pq-                 13.1% (668)      0.8% (34)       0.1% (8)
# theta_pq+                23.2% (1180)      1.6% (68)      0.2% (15)
#
#                             CC 1p 0pi
# no cut                  100.0% (2514)
# PIDa                     84.5% (2124)
# flashes                  84.2% (2116)
# flash                    79.3% (1994)
# length                   69.5% (1746)
# non-collinearity         64.6% (1625)
# vertex activity          55.5% (1395)
# delta phi                42.5% (1069)
# Pt no Delta phi          45.7% (1150)
# soft Pt                   38.2% (960)
# tight Pt                  21.6% (544)
# non-collinearity first   91.9% (2310)
# theta_pq                  33.3% (837)
# l_p_min_10                23.3% (587)
# soft Pmiss                34.1% (857)
# PIDa-                    89.4% (2247)
# PIDa+                    84.5% (2124)
# theta12-                 62.4% (1568)
# theta12+                 66.0% (1659)
# RdQ-                     52.2% (1313)
# RdQ+                     56.3% (1416)
# delta_phi-               42.5% (1069)
# delta_phi+               45.4% (1141)
# Pt-                       36.4% (915)
# Pt+                      39.9% (1002)
# theta_pq-                 22.9% (576)
# theta_pq+                 38.2% (960)

# %% [markdown]
# # compare between 3D distributions:
# We want to find the optimal box dimensions by the ones with the largest difference (separation of CCQE from others)
# in order to do that we compare between distributions using the 3D energy test

# %%
from scipy.spatial.distance import pdist, cdist
def Etest(x, y, method='log', epsilon=0.0001 ,debug=0):
    '''
     Energy distance statistics test.
     Reference
     ---------
     Aslan, B, Zech, G (2005) Statistical energy as a tool for binning-free
       multivariate goodness-of-fit tests, two-sample comparison and unfolding.
       Nuc Instr and Meth in Phys Res A 537: 626-636
     Szekely, G, Rizzo, M (2014) Energy statistics: A class of statistics
       based on distances. J Stat Planning & Infer 143: 1249-1272
     Brian Lau, multdist, https://github.com/brian-lau/multdist
     ---------
    Parameters: x: np.array()
                y:  np.array()
                method: method for energy-test function calculation
                        'log' : ln(r+ε)
                epsilon: for method 'log', this is the cutoff ε
                
    Returns:    Psi: ln(r(xy)+ε)/Nx*Ny - ln(r(xx)+ε)/Nx*Nx - ln(r(yy)+ε)/Ny*Ny
    '''
    if debug: print "energy(x, y, method='log')"
    r_xx, r_yy, r_xy = pdist(x), pdist(y), cdist(x, y)
    if debug:
        print "dx:",r_xx,'\n log(r_xx+ε):',np.log(r_xx+epsilon)
        print "r_yy:",r_yy,'\n log(r_yy+ε):',np.log(r_yy+epsilon)
        print "r_xy:",r_xy,'\n log(r_xy+ε):',np.log(r_xy+epsilon)
        
    Nx, Ny = len(x), len(y)
    
    if method == 'log':
        log_r_xx, log_r_yy, log_r_xy = np.log(r_xx+epsilon), np.log(r_yy+epsilon), np.log(r_xy+epsilon)
        Phi = log_r_xy.sum() / (Nx*Ny) - log_r_xx.sum() / (Nx*Nx) - log_r_yy.sum() / (Ny*Ny)
        
    elif method == 'gaussian':
        raise NotImplementedError
    elif method == 'linear':
        pass
    else:
        raise ValueError
        
    return Phi

# %%
def Etest_CC1p0pi_vs_other_pair_types_per_sphere_size( samples=None, i_r_around_vertex=1 , debug=0 ):

    RdQ_xyz, RdQ_3D_array = dict(), dict()

    for i_pair_type in range(4):
        pair_type = pair_types[i_pair_type]; sample = samples[pair_type]     
        r = r_around_vertex[i_r_around_vertex]
        Ru,Rv,Ry = 'RdQaroundVertex[plane 0][r=%.1fcm]'%r,'RdQaroundVertex[plane 1][r=%.1fcm]'%r,'RdQaroundVertex[plane 2][r=%.1fcm]'%r
        sample = sample[(sample[Ru]>-0.01)&(sample[Rv]>-0.01)&(sample[Ry]>-0.01)]
        x,y,z = sample[Ru], sample[Rv], sample[Ry]
        RdQ_xyz[pair_type] = (x,y,z)
        RdQ_3D_array[pair_type] = np.array([[x_p,y_p,z_p] for x_p,y_p,z_p in zip(x,y,z)])
        if debug>1: print "created a 3D array for",pair_type
        
    PsiEtest = dict()
    for pair_type in (pair_types[0:3]):
        PsiEtest[pair_type+'/'+'CC 1p 0pi'] = Etest( RdQ_3D_array[pair_type], RdQ_3D_array['CC 1p 0pi'], debug=debug-1 )
    if debug: 
        print 'sphere radius: r=%.1fcm'%r_around_vertex[i_r_around_vertex]
        print PsiEtest
    return PsiEtest

# %%
debug = 1
sphere_size_indices = []
pd_Etest_results = pd.DataFrame()
for i_r_around_vertex in range(1,N_r_around_vertex):
    sphere_size_indices.append(i_r_around_vertex)
    PsiEtest = Etest_CC1p0pi_vs_other_pair_types_per_sphere_size( samples=reduced_MCbnbDATAcosmicSamples['no cut'], i_r_around_vertex=i_r_around_vertex , debug=debug )
    pd_Etest = pd.DataFrame({'sphere size':'r=%1fcm'%r_around_vertex[i_r_around_vertex]
                             ,'1mu-1p/CC 1p 0pi':PsiEtest['1mu-1p/CC 1p 0pi']
                             ,'other pairs/CC 1p 0pi':PsiEtest['other pairs/CC 1p 0pi']
                             ,'cosmic/CC 1p 0pi':PsiEtest['cosmic/CC 1p 0pi']}
                            ,index=[i_r_around_vertex])
    pd_Etest_results = pd_Etest_results.append(pd_Etest)
    
pd_Etest_results
# Out:
# len(sample): 5087
# len(sample): 3335
# len(sample): 4335
# len(sample): 2746
# len(sample): 9486
# len(sample): 6014
# len(sample): 2514
# len(sample): 1768
# sphere radius: r=0.5cm
# {'1mu-1p/CC 1p 0pi': 0.01327136488297187, 'other pairs/CC 1p 0pi': 0.010067204874119828, 'cosmic/CC 1p 0pi': 0.032625859594449969}
# len(sample): 5087
# len(sample): 4125
# len(sample): 4335
# len(sample): 3400
# len(sample): 9486
# len(sample): 7911
# len(sample): 2514
# len(sample): 2089
# sphere radius: r=1.0cm
# {'1mu-1p/CC 1p 0pi': 0.023696233578612502, 'other pairs/CC 1p 0pi': 0.0028590327742644694, 'cosmic/CC 1p 0pi': 0.0028055587865430942}
# len(sample): 5087
# len(sample): 4291
# len(sample): 4335
# len(sample): 3584
# len(sample): 9486
# len(sample): 8346
# len(sample): 2514
# len(sample): 2169
# sphere radius: r=1.5cm
# {'1mu-1p/CC 1p 0pi': 0.030307360898510938, 'other pairs/CC 1p 0pi': 0.0087137793464221458, 'cosmic/CC 1p 0pi': 0.0078562815402120068}
# len(sample): 5087
# len(sample): 4440
# len(sample): 4335
# len(sample): 3729
# len(sample): 9486
# len(sample): 8634
# len(sample): 2514
# len(sample): 2235
# sphere radius: r=2.0cm
# {'1mu-1p/CC 1p 0pi': 0.037317993978843278, 'other pairs/CC 1p 0pi': 0.017070772992571981, 'cosmic/CC 1p 0pi': 0.020285015702326215}
# len(sample): 5087
# len(sample): 4565
# len(sample): 4335
# len(sample): 3881
# len(sample): 9486
# len(sample): 8833
# len(sample): 2514
# len(sample): 2279
# sphere radius: r=2.5cm
# {'1mu-1p/CC 1p 0pi': 0.043234418984795187, 'other pairs/CC 1p 0pi': 0.026383077298198443, 'cosmic/CC 1p 0pi': 0.034154866403070749}
# len(sample): 5087
# len(sample): 4644
# len(sample): 4335
# len(sample): 3968
# len(sample): 9486
# len(sample): 8979
# len(sample): 2514
# len(sample): 2305
# sphere radius: r=3.0cm
# {'1mu-1p/CC 1p 0pi': 0.047658582707661101, 'other pairs/CC 1p 0pi': 0.036358679252269321, 'cosmic/CC 1p 0pi': 0.047938386783358378}
# len(sample): 5087
# len(sample): 4706
# len(sample): 4335
# len(sample): 4028
# len(sample): 9486
# len(sample): 9068
# len(sample): 2514
# len(sample): 2329
# sphere radius: r=3.5cm
# {'1mu-1p/CC 1p 0pi': 0.051043226407399556, 'other pairs/CC 1p 0pi': 0.044519878613695107, 'cosmic/CC 1p 0pi': 0.061335975761339978}
# len(sample): 5087
# len(sample): 4751
# len(sample): 4335
# len(sample): 4077
# len(sample): 9486
# len(sample): 9134
# len(sample): 2514
# len(sample): 2345
# sphere radius: r=4.0cm
# {'1mu-1p/CC 1p 0pi': 0.052117705002666104, 'other pairs/CC 1p 0pi': 0.049578252138056222, 'cosmic/CC 1p 0pi': 0.069615587261857459}
# len(sample): 5087
# len(sample): 4799
# len(sample): 4335
# len(sample): 4116
# len(sample): 9486
# len(sample): 9182
# len(sample): 2514
# len(sample): 2364
# sphere radius: r=4.5cm
# {'1mu-1p/CC 1p 0pi': 0.053078546892535883, 'other pairs/CC 1p 0pi': 0.054589658235407179, 'cosmic/CC 1p 0pi': 0.077501058534865996}
# len(sample): 5087
# len(sample): 4834
# len(sample): 4335
# len(sample): 4147
# len(sample): 9486
# len(sample): 9229
# len(sample): 2514
# len(sample): 2385
# sphere radius: r=5.0cm
# {'1mu-1p/CC 1p 0pi': 0.053108607285124787, 'other pairs/CC 1p 0pi': 0.059316291953126599, 'cosmic/CC 1p 0pi': 0.086156273869703703}
# len(sample): 5087
# len(sample): 4870
# len(sample): 4335
# len(sample): 4191
# len(sample): 9486
# len(sample): 9259
# len(sample): 2514
# len(sample): 2406
# sphere radius: r=5.5cm
# {'1mu-1p/CC 1p 0pi': 0.053337756325210428, 'other pairs/CC 1p 0pi': 0.063855104491292725, 'cosmic/CC 1p 0pi': 0.09252894228299946}
# len(sample): 5087
# len(sample): 4892
# len(sample): 4335
# len(sample): 4206
# len(sample): 9486
# len(sample): 9284
# len(sample): 2514
# len(sample): 2415
# sphere radius: r=6.0cm
# {'1mu-1p/CC 1p 0pi': 0.054209426432844765, 'other pairs/CC 1p 0pi': 0.068938861115593886, 'cosmic/CC 1p 0pi': 0.10011075335018393}
# len(sample): 5087
# len(sample): 4911
# len(sample): 4335
# len(sample): 4216
# len(sample): 9486
# len(sample): 9300
# len(sample): 2514
# len(sample): 2427
# sphere radius: r=6.5cm
# {'1mu-1p/CC 1p 0pi': 0.054327884797082393, 'other pairs/CC 1p 0pi': 0.072397656244529207, 'cosmic/CC 1p 0pi': 0.10522239490138541}
# len(sample): 5087
# len(sample): 4934
# len(sample): 4335
# len(sample): 4224
# len(sample): 9486
# len(sample): 9321
# len(sample): 2514
# len(sample): 2436
# sphere radius: r=7.0cm
# {'1mu-1p/CC 1p 0pi': 0.054468619232270865, 'other pairs/CC 1p 0pi': 0.076742041086640511, 'cosmic/CC 1p 0pi': 0.10988235283748493}
# len(sample): 5087
# len(sample): 4951
# len(sample): 4335
# len(sample): 4237
# len(sample): 9486
# len(sample): 9333
# len(sample): 2514
# len(sample): 2443
# sphere radius: r=7.5cm
# {'1mu-1p/CC 1p 0pi': 0.055005208023082286, 'other pairs/CC 1p 0pi': 0.08098744552690218, 'cosmic/CC 1p 0pi': 0.11428591069970417}
# len(sample): 5087
# len(sample): 4964
# len(sample): 4335
# len(sample): 4244
# len(sample): 9486
# len(sample): 9345
# len(sample): 2514
# len(sample): 2450
# sphere radius: r=8.0cm
# {'1mu-1p/CC 1p 0pi': 0.054868264375954157, 'other pairs/CC 1p 0pi': 0.084383570201376767, 'cosmic/CC 1p 0pi': 0.11841263330436824}
# len(sample): 5087
# len(sample): 4977
# len(sample): 4335
# len(sample): 4252
# len(sample): 9486
# len(sample): 9360
# len(sample): 2514
# len(sample): 2457
# sphere radius: r=8.5cm
# {'1mu-1p/CC 1p 0pi': 0.055205010719889591, 'other pairs/CC 1p 0pi': 0.088811841582843609, 'cosmic/CC 1p 0pi': 0.12227486221235251}
# len(sample): 5087
# len(sample): 4987
# len(sample): 4335
# len(sample): 4261
# len(sample): 9486
# len(sample): 9369
# len(sample): 2514
# len(sample): 2463
# sphere radius: r=9.0cm
# {'1mu-1p/CC 1p 0pi': 0.055481924367451918, 'other pairs/CC 1p 0pi': 0.092322941612203557, 'cosmic/CC 1p 0pi': 0.12523498674765676}
# len(sample): 5087
# len(sample): 4994
# len(sample): 4335
# len(sample): 4269
# len(sample): 9486
# len(sample): 9382
# len(sample): 2514
# len(sample): 2465
# sphere radius: r=9.5cm
# {'1mu-1p/CC 1p 0pi': 0.055608578935830266, 'other pairs/CC 1p 0pi': 0.095250952121963217, 'cosmic/CC 1p 0pi': 0.12766841564853881}
# len(sample): 5087
# len(sample): 5001
# len(sample): 4335
# len(sample): 4272
# len(sample): 9486
# len(sample): 9385
# len(sample): 2514
# len(sample): 2469
# sphere radius: r=10.0cm
# {'1mu-1p/CC 1p 0pi': 0.055504995017266467, 'other pairs/CC 1p 0pi': 0.098667708944881305, 'cosmic/CC 1p 0pi': 0.13048009827389495}
# len(sample): 5087
# len(sample): 5006
# len(sample): 4335
# len(sample): 4282
# len(sample): 9486
# len(sample): 9392
# len(sample): 2514
# len(sample): 2470
# sphere radius: r=10.5cm
# {'1mu-1p/CC 1p 0pi': 0.055256878914620056, 'other pairs/CC 1p 0pi': 0.10169263660822481, 'cosmic/CC 1p 0pi': 0.13217885259003859}
# len(sample): 5087
# len(sample): 5017
# len(sample): 4335
# len(sample): 4288
# len(sample): 9486
# len(sample): 9399
# len(sample): 2514
# len(sample): 2473
# sphere radius: r=11.0cm
# {'1mu-1p/CC 1p 0pi': 0.05526221871867798, 'other pairs/CC 1p 0pi': 0.10451539571967172, 'cosmic/CC 1p 0pi': 0.13418181141158914}
# len(sample): 5087
# len(sample): 5021
# len(sample): 4335
# len(sample): 4293
# len(sample): 9486
# len(sample): 9404
# len(sample): 2514
# len(sample): 2477
# sphere radius: r=11.5cm
# {'1mu-1p/CC 1p 0pi': 0.05477911046883055, 'other pairs/CC 1p 0pi': 0.10773693495883818, 'cosmic/CC 1p 0pi': 0.13536204372638416}
# len(sample): 5087
# len(sample): 5025
# len(sample): 4335
# len(sample): 4297
# len(sample): 9486
# len(sample): 9409
# len(sample): 2514
# len(sample): 2479
# sphere radius: r=12.0cm
# {'1mu-1p/CC 1p 0pi': 0.054320953551092566, 'other pairs/CC 1p 0pi': 0.11025430437361783, 'cosmic/CC 1p 0pi': 0.13668211714277989}
# len(sample): 5087
# len(sample): 5029
# len(sample): 4335
# len(sample): 4299
# len(sample): 9486
# len(sample): 9412
# len(sample): 2514
# len(sample): 2481
# sphere radius: r=12.5cm
# {'1mu-1p/CC 1p 0pi': 0.05366816813960873, 'other pairs/CC 1p 0pi': 0.11229246171327056, 'cosmic/CC 1p 0pi': 0.1375410743559079}
# len(sample): 5087
# len(sample): 5036
# len(sample): 4335
# len(sample): 4300
# len(sample): 9486
# len(sample): 9418
# len(sample): 2514
# len(sample): 2486
# sphere radius: r=13.0cm
# {'1mu-1p/CC 1p 0pi': 0.052914584698317446, 'other pairs/CC 1p 0pi': 0.11361003113009505, 'cosmic/CC 1p 0pi': 0.13750852722284213}
# len(sample): 5087
# len(sample): 5043
# len(sample): 4335
# len(sample): 4306
# len(sample): 9486
# len(sample): 9423
# len(sample): 2514
# len(sample): 2491
# sphere radius: r=13.5cm
# {'1mu-1p/CC 1p 0pi': 0.052422366381494778, 'other pairs/CC 1p 0pi': 0.11570799337735738, 'cosmic/CC 1p 0pi': 0.13790593928200723}
# len(sample): 5087
# len(sample): 5047
# len(sample): 4335
# len(sample): 4314
# len(sample): 9486
# len(sample): 9427
# len(sample): 2514
# len(sample): 2491
# sphere radius: r=14.0cm
# {'1mu-1p/CC 1p 0pi': 0.052306725849242341, 'other pairs/CC 1p 0pi': 0.11915530083754133, 'cosmic/CC 1p 0pi': 0.13918030578642338}
# len(sample): 5087
# len(sample): 5050
# len(sample): 4335
# len(sample): 4315
# len(sample): 9486
# len(sample): 9430
# len(sample): 2514
# len(sample): 2492
# sphere radius: r=14.5cm
# {'1mu-1p/CC 1p 0pi': 0.051981509845990925, 'other pairs/CC 1p 0pi': 0.12235507713386617, 'cosmic/CC 1p 0pi': 0.13991877581796985}
#     1mu-1p/CC 1p 0pi  cosmic/CC 1p 0pi  other pairs/CC 1p 0pi    sphere size
# 1           0.013271          0.032626               0.010067   r=0.500000cm
# 2           0.023696          0.002806               0.002859   r=1.000000cm
# 3           0.030307          0.007856               0.008714   r=1.500000cm
# 4           0.037318          0.020285               0.017071   r=2.000000cm
# 5           0.043234          0.034155               0.026383   r=2.500000cm
# 6           0.047659          0.047938               0.036359   r=3.000000cm
# 7           0.051043          0.061336               0.044520   r=3.500000cm
# 8           0.052118          0.069616               0.049578   r=4.000000cm
# 9           0.053079          0.077501               0.054590   r=4.500000cm
# 10          0.053109          0.086156               0.059316   r=5.000000cm
# 11          0.053338          0.092529               0.063855   r=5.500000cm
# 12          0.054209          0.100111               0.068939   r=6.000000cm
# 13          0.054328          0.105222               0.072398   r=6.500000cm
# 14          0.054469          0.109882               0.076742   r=7.000000cm
# 15          0.055005          0.114286               0.080987   r=7.500000cm
# 16          0.054868          0.118413               0.084384   r=8.000000cm
# 17          0.055205          0.122275               0.088812   r=8.500000cm
# 18          0.055482          0.125235               0.092323   r=9.000000cm
# 19          0.055609          0.127668               0.095251   r=9.500000cm
# 20          0.055505          0.130480               0.098668  r=10.000000cm
# 21          0.055257          0.132179               0.101693  r=10.500000cm
# 22          0.055262          0.134182               0.104515  r=11.000000cm
# 23          0.054779          0.135362               0.107737  r=11.500000cm
# 24          0.054321          0.136682               0.110254  r=12.000000cm
# 25          0.053668          0.137541               0.112292  r=12.500000cm
# 26          0.052915          0.137509               0.113610  r=13.000000cm
# 27          0.052422          0.137906               0.115708  r=13.500000cm
# 28          0.052307          0.139180               0.119155  r=14.000000cm
# 29          0.051982          0.139919               0.122355  r=14.500000cm

# %%
xticks=[0,5,10,15,20,25,29] 
fig=plt.figure(figsize=(16,16))
for i_pair_type in range(3):
    ax = fig.add_subplot(3,1,i_pair_type+1)
    pair_type=pair_types[i_pair_type];color=MCcolors[i_pair_type];label=MClabels[i_pair_type]
    y = pd_Etest_results[pair_type+'/'+'CC 1p 0pi'];
    plt.plot( y , '--o' , color=color , label=label+'/CC1p0$\pi$')
    leg=plt.legend(fontsize=20,loc='lower right')#,bbox_to_anchor=(1.05,1),loc=2
    set_axes( ax , 'sphere radius r [cm]' if i_pair_type==2 else ''
             , '$\Phi_{Etest}$ [a.u.]',xticks=xticks ,do_add_grid=True)
    ax.yaxis.set_major_locator(LinearLocator(5))

    tick_labels = [item.get_text() for item in ax.get_xticklabels()]
    for i,i_r_around_vertex in enumerate(xticks):
          tick_labels[i] = '%.1f'%(r_around_vertex[i_r_around_vertex]) if i_pair_type==2 else ''
    ax.set_xticklabels(tick_labels, rotation=0);
    ax.xaxis.labelpad = -75
plt.tight_layout()
plt.savefig(figures_path+'EtestPsi_vs_sphere_radius.pdf',bbox_extra_artists=(leg,), bbox_inches='tight')

# %% [markdown]
# # now after cuts

# %%
sphere_size_indices = []
pd_Etest_results = pd.DataFrame()
for i_r_around_vertex in range(1,N_r_around_vertex):
    sphere_size_indices.append(i_r_around_vertex)
    PsiEtest = Etest_CC1p0pi_vs_other_pair_types_per_sphere_size( samples=reduced_MCbnbDATAcosmicSamples['non-collinearity'], i_r_around_vertex=i_r_around_vertex , debug=debug )
    pd_Etest = pd.DataFrame({'sphere size':'r=%1fcm'%r_around_vertex[i_r_around_vertex]
                             ,'1mu-1p/CC 1p 0pi':PsiEtest['1mu-1p/CC 1p 0pi']
                             ,'other pairs/CC 1p 0pi':PsiEtest['other pairs/CC 1p 0pi']
                             ,'cosmic/CC 1p 0pi':PsiEtest['cosmic/CC 1p 0pi']}
                            ,index=[i_r_around_vertex])
    pd_Etest_results = pd_Etest_results.append(pd_Etest)

pd_Etest_results
# Out:
# sphere radius: r=0.5cm
# {'1mu-1p/CC 1p 0pi': 0.0089644890671266575, 'other pairs/CC 1p 0pi': 0.0032051954119998172, 'cosmic/CC 1p 0pi': -0.0094935230735584408}
# sphere radius: r=1.0cm
# {'1mu-1p/CC 1p 0pi': 0.017897010577850703, 'other pairs/CC 1p 0pi': 0.018670220910692981, 'cosmic/CC 1p 0pi': 0.081122188674725149}
# sphere radius: r=1.5cm
# {'1mu-1p/CC 1p 0pi': 0.026524607269406197, 'other pairs/CC 1p 0pi': 0.039919651038866744, 'cosmic/CC 1p 0pi': 0.10441293697868465}
# sphere radius: r=2.0cm
# {'1mu-1p/CC 1p 0pi': 0.032595124275142551, 'other pairs/CC 1p 0pi': 0.054328073874316263, 'cosmic/CC 1p 0pi': 0.14489095728461232}
# sphere radius: r=2.5cm
# {'1mu-1p/CC 1p 0pi': 0.037465291792195488, 'other pairs/CC 1p 0pi': 0.061606871431066357, 'cosmic/CC 1p 0pi': 0.16872756927537813}
# sphere radius: r=3.0cm
# {'1mu-1p/CC 1p 0pi': 0.041412774289110943, 'other pairs/CC 1p 0pi': 0.078142788630636839, 'cosmic/CC 1p 0pi': 0.19087530641384809}
# sphere radius: r=3.5cm
# {'1mu-1p/CC 1p 0pi': 0.044520726436925728, 'other pairs/CC 1p 0pi': 0.090608371311807767, 'cosmic/CC 1p 0pi': 0.20537488041204288}
# sphere radius: r=4.0cm
# {'1mu-1p/CC 1p 0pi': 0.045242368595450166, 'other pairs/CC 1p 0pi': 0.096643497116442489, 'cosmic/CC 1p 0pi': 0.2047714750021643}
# sphere radius: r=4.5cm
# {'1mu-1p/CC 1p 0pi': 0.046580927167824804, 'other pairs/CC 1p 0pi': 0.10608616639608071, 'cosmic/CC 1p 0pi': 0.21222706134034597}
# sphere radius: r=5.0cm
# {'1mu-1p/CC 1p 0pi': 0.046654610124853946, 'other pairs/CC 1p 0pi': 0.11610042031000523, 'cosmic/CC 1p 0pi': 0.22891780599314981}
# sphere radius: r=5.5cm
# {'1mu-1p/CC 1p 0pi': 0.046972830365440421, 'other pairs/CC 1p 0pi': 0.12201034315363346, 'cosmic/CC 1p 0pi': 0.23943767699855778}
# sphere radius: r=6.0cm
# {'1mu-1p/CC 1p 0pi': 0.047644112751825229, 'other pairs/CC 1p 0pi': 0.13062937311839817, 'cosmic/CC 1p 0pi': 0.24505076432669426}
# sphere radius: r=6.5cm
# {'1mu-1p/CC 1p 0pi': 0.047698205219994461, 'other pairs/CC 1p 0pi': 0.13444284303215281, 'cosmic/CC 1p 0pi': 0.24949932078130721}
# sphere radius: r=7.0cm
# {'1mu-1p/CC 1p 0pi': 0.047752687247569092, 'other pairs/CC 1p 0pi': 0.13780206571192888, 'cosmic/CC 1p 0pi': 0.24961966510542444}
# sphere radius: r=7.5cm
# {'1mu-1p/CC 1p 0pi': 0.048321068273457612, 'other pairs/CC 1p 0pi': 0.1434855219485176, 'cosmic/CC 1p 0pi': 0.25322106086898954}
# sphere radius: r=8.0cm
# {'1mu-1p/CC 1p 0pi': 0.048139426265277785, 'other pairs/CC 1p 0pi': 0.14666433937936796, 'cosmic/CC 1p 0pi': 0.25977157006895779}
# sphere radius: r=8.5cm
# {'1mu-1p/CC 1p 0pi': 0.048710775123156691, 'other pairs/CC 1p 0pi': 0.15334814087878956, 'cosmic/CC 1p 0pi': 0.26697454426439304}
# sphere radius: r=9.0cm
# {'1mu-1p/CC 1p 0pi': 0.049273702107340389, 'other pairs/CC 1p 0pi': 0.15970776384513297, 'cosmic/CC 1p 0pi': 0.27282022548334994}
# sphere radius: r=9.5cm
# {'1mu-1p/CC 1p 0pi': 0.049634358358409125, 'other pairs/CC 1p 0pi': 0.16310751245043076, 'cosmic/CC 1p 0pi': 0.27679541019955856}
# sphere radius: r=10.0cm
# {'1mu-1p/CC 1p 0pi': 0.049601182807863964, 'other pairs/CC 1p 0pi': 0.1665997714311841, 'cosmic/CC 1p 0pi': 0.28051076416633236}
# sphere radius: r=10.5cm
# {'1mu-1p/CC 1p 0pi': 0.049436483597701364, 'other pairs/CC 1p 0pi': 0.17215896823312837, 'cosmic/CC 1p 0pi': 0.28614465053485261}
# sphere radius: r=11.0cm
# {'1mu-1p/CC 1p 0pi': 0.049173905586011424, 'other pairs/CC 1p 0pi': 0.17607035498139634, 'cosmic/CC 1p 0pi': 0.28817046472068952}
# sphere radius: r=11.5cm
# {'1mu-1p/CC 1p 0pi': 0.048742657787038568, 'other pairs/CC 1p 0pi': 0.18055020135922639, 'cosmic/CC 1p 0pi': 0.28738452328027009}
# sphere radius: r=12.0cm
# {'1mu-1p/CC 1p 0pi': 0.048405626235114241, 'other pairs/CC 1p 0pi': 0.18288027150625885, 'cosmic/CC 1p 0pi': 0.28693753478321871}
# sphere radius: r=12.5cm
# {'1mu-1p/CC 1p 0pi': 0.047982582129098117, 'other pairs/CC 1p 0pi': 0.18604947724870702, 'cosmic/CC 1p 0pi': 0.29150971729651048}
# sphere radius: r=13.0cm
# {'1mu-1p/CC 1p 0pi': 0.047641887968139285, 'other pairs/CC 1p 0pi': 0.18973626192063342, 'cosmic/CC 1p 0pi': 0.29040914667750622}
# sphere radius: r=13.5cm
# {'1mu-1p/CC 1p 0pi': 0.047462138236933571, 'other pairs/CC 1p 0pi': 0.19208333326796245, 'cosmic/CC 1p 0pi': 0.2874094559131371}
# sphere radius: r=14.0cm
# {'1mu-1p/CC 1p 0pi': 0.047481564293195055, 'other pairs/CC 1p 0pi': 0.19580574271247153, 'cosmic/CC 1p 0pi': 0.28626293611507103}
# sphere radius: r=14.5cm
# {'1mu-1p/CC 1p 0pi': 0.047304369541018687, 'other pairs/CC 1p 0pi': 0.1992838589632282, 'cosmic/CC 1p 0pi': 0.28710656409838797}
#     1mu-1p/CC 1p 0pi  cosmic/CC 1p 0pi  other pairs/CC 1p 0pi    sphere size
# 1           0.008964         -0.009494               0.003205   r=0.500000cm
# 2           0.017897          0.081122               0.018670   r=1.000000cm
# 3           0.026525          0.104413               0.039920   r=1.500000cm
# 4           0.032595          0.144891               0.054328   r=2.000000cm
# 5           0.037465          0.168728               0.061607   r=2.500000cm
# 6           0.041413          0.190875               0.078143   r=3.000000cm
# 7           0.044521          0.205375               0.090608   r=3.500000cm
# 8           0.045242          0.204771               0.096643   r=4.000000cm
# 9           0.046581          0.212227               0.106086   r=4.500000cm
# 10          0.046655          0.228918               0.116100   r=5.000000cm
# 11          0.046973          0.239438               0.122010   r=5.500000cm
# 12          0.047644          0.245051               0.130629   r=6.000000cm
# 13          0.047698          0.249499               0.134443   r=6.500000cm
# 14          0.047753          0.249620               0.137802   r=7.000000cm
# 15          0.048321          0.253221               0.143486   r=7.500000cm
# 16          0.048139          0.259772               0.146664   r=8.000000cm
# 17          0.048711          0.266975               0.153348   r=8.500000cm
# 18          0.049274          0.272820               0.159708   r=9.000000cm
# 19          0.049634          0.276795               0.163108   r=9.500000cm
# 20          0.049601          0.280511               0.166600  r=10.000000cm
# 21          0.049436          0.286145               0.172159  r=10.500000cm
# 22          0.049174          0.288170               0.176070  r=11.000000cm
# 23          0.048743          0.287385               0.180550  r=11.500000cm
# 24          0.048406          0.286938               0.182880  r=12.000000cm
# 25          0.047983          0.291510               0.186049  r=12.500000cm
# 26          0.047642          0.290409               0.189736  r=13.000000cm
# 27          0.047462          0.287409               0.192083  r=13.500000cm
# 28          0.047482          0.286263               0.195806  r=14.000000cm
# 29          0.047304          0.287107               0.199284  r=14.500000cm

# %%
xticks=[0,5,10,15,20,25,29] 
fig=plt.figure(figsize=(16,16))
i_max=0
r_max=0
for i_pair_type in range(3):
    ax = fig.add_subplot(3,1,i_pair_type+1)
    pair_type=pair_types[i_pair_type];color=MCcolors[i_pair_type];label=MClabels[i_pair_type]
    y = pd_Etest_results[pair_type+'/'+'CC 1p 0pi'];
    plt.plot( y , '--o' , color=color , label=label+'/CC1p0$\pi$')
    leg=plt.legend(fontsize=20,loc='lower right')#,bbox_to_anchor=(1.05,1),loc=2
    set_axes( ax , 'sphere radius r [cm]' if i_pair_type==2 else ''
             , '$\Phi_{Etest}$ [a.u.]',xticks=xticks ,do_add_grid=True)
    ax.yaxis.set_major_locator(LinearLocator(5))

    tick_labels = [item.get_text() for item in ax.get_xticklabels()]
    for i,i_r_around_vertex in enumerate(xticks):
          tick_labels[i] = '%.1f'%(r_around_vertex[i_r_around_vertex]) if i_pair_type==2 else ''
    ax.set_xticklabels(tick_labels, rotation=0);
#     ax.xaxis.labelpad = -75
    
    # What is the optimal size?
    if i_pair_type==0:
        i_max = np.argmax(y)
        print 'i_max:',i_max
        r_max = r_around_vertex[i_max]
        plt.text(i_max-6.5,0.15*np.max(ax.get_ylim()),'$r_{optimal}=%.1f$ cm'%r_max,fontsize=25)
    plt.plot([i_max,i_max],[np.min(ax.get_ylim()),y[i_max]],'--',color='black')

    
plt.tight_layout()
plt.savefig(figures_path+'EtestPsi_vs_sphere_radius_after_detection_cuts.pdf',bbox_extra_artists=(leg,), bbox_inches='tight')
# Out:
# i_max: 19
