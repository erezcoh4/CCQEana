# %% [markdown]
# # extract $m_A$ from MC with $Q^2$-dependent correction

# %%
import sys; sys.path.insert(0, '../../'); sys.path.insert(0, '../mupClassification/');  sys.path.insert(0, '../off_beam_on_beam_5e19/'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
from onbeam_offbeam_notebooks import *
import seaborn as sns; sns.set(style="white", color_codes=True ,font_scale=2);
from axial_mass_tools import *
import scipy.linalg
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
from scipy.optimize import curve_fit

# %%
def fill_2d_histogram( xbins , ybins , samlpe , varx , vary ):
    '''
    return: 
            histo: np.array((len(xbins),len(ybins))) 
    '''
    histo = np.zeros((len(xbins),len(ybins)))
    for i_xbin,xbin in zip(range(len(xbins)-1),xbins):
        xmin,xmax = xbins[i_xbin],xbins[i_xbin+1]
        for j_ybin,ybin in zip(range(len(ybins)-1),ybins):
            ymin,ymax = ybins[j_ybin],ybins[j_ybin+1]

            histo[i_xbin][j_ybin] = len(samlpe[(samlpe[varx]>xmin)
                                                  &(samlpe[varx]<xmax)
                                                  &(samlpe[vary]>ymin)
                                                  &(samlpe[vary]<ymax)]) 
    return histo

# %%
def plot_Q2_Ev_distribution_in_reQ2_bins(histo_array=None,histtitle=''):
    fig = plt.figure(figsize=(20,20))
    for i,recQ2bin in zip(range(len(Q2bins)-1),Q2bins):
        ax = fig.add_subplot(len(Q2bins)/3,3,i+1)
        sns.heatmap(histo_array[i].T,cmap='hot_r'#                 ,annot=True#,fmt='%.1f'            
                    ,xticklabels=['%.1f'%largeQ2bins[j] if j%3==0 else '' for j in range(len(largeQ2bins)-1)]
                    ,yticklabels=['%.1f'%largeEvbins[j] if j%3==0 else '' for j in range(len(largeEvbins)-1)]
               )
        ax.invert_yaxis()
        set_axes(ax
             ,title=r"%s $%.2f<Q^{2}_{rec.}<%.2f$"%(histtitle,Q2bins[i],Q2bins[i+1])
             ,x_label=r'$Q^2_{gen.}$ (GeV/c)$^2$' if i>=(len(Q2bins)-1-3) else ''
             ,y_label=r'$E^\nu_{gen.}$ (GeV)' if i%3==0 else ''
             ,fontsize=25,do_add_grid=True,do_add_legend=True
            )
        if i%3>0: ax.yaxis.set_major_formatter(ticker.NullFormatter())    
    plt.tight_layout()

# %%
Evbins = np.linspace(0.1,1.5,10)
Q2bins = np.linspace(0,0.8,10)
largeQ2bins = Q2bins #np.linspace(0,1.2,15)
largeEvbins = Evbins #np.linspace(0,2.,20)
largeQ2bins_centers = 0.5*(largeQ2bins[1:] + largeQ2bins[:-1])
largeEvbins_centers = 0.5*(largeEvbins[1:] + largeEvbins[:-1])

# largeQ2bins = np.linspace(0,1.2,5)
# largeEvbins = np.linspace(0,2,4)
# largeQ2bins = np.linspace(0,1.2,15)
# largeEvbins = np.linspace(0,2.,20)

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/OnBeamOffBeam5e19/Figures/mA_extraction/'

# %%
MCbnbDATAcosmicPairsFV, MCbnbDATAcosmicSamples = load_MCbnbDATAcosmicSamples()
# Out:
# 50939 pairs from MC-BNB + cosmic DATA overlay
# 30377 pairs in FV
# 3814 are 1mu-1p, 12.6%
# 4001 are other pairs, 13.2%
# 22562 are cosmic, 74.3%
# --------------------------------------------------------------
# 1234 are CC 1p 0pi, 4.1%

# %%
cuts_pureff = apply_cuts_MCbnbDATAcosmic(PIDa_p_min=12,                                                                             
                         delta_Delta_phi=40,                         
                         r_max_RdQ_CC1p0pi=0.33)
pureff_MCbnbDATAcosmic,pureff_MCbnbDATAcosmic_numbers = cuts_pureff
pureff_MCbnbDATAcosmic
# Out:
#                        $\mu p$ eff. $\mu p$ pur. CC$0\pi 1 p$ eff.  \
# no cut                       100.0%        12.6%            100.0%
# non-collinearity first        90.4%        45.3%             94.8%
# PIDa                          79.9%        45.6%             76.1%
# length                        64.0%        59.4%             63.9%
# non-collinearity              58.5%        70.8%             61.4%
# vertex activity               34.2%        78.3%             53.2%
# delta phi                     24.1%        87.7%             47.9%
# theta_pq                      17.5%        95.4%             39.4%
# Pt no Delta phi               24.7%        88.7%             46.1%
# soft Pt                       20.2%        94.6%             42.9%
# soft Pmiss                    16.3%        95.4%             37.3%
# tight Pt                       9.3%        95.7%             22.4%
# l_p_min_10                    16.6%        95.0%             34.5%
# ...

# %% [markdown]
# # the acceptance of CC$1p0\pi$ events

# %%
GENIEall = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/genie/prodgenie_bnb_nu_uboone_overlay_mcc8_reco2_genie.csv')
print len(GENIEall),'CC interactions pairs in GENIE'

GENIE_CC1p0pi = GENIEall[GENIEall['IsCC_1p_200MeVc_0pi']==1]
GENIE_CC1p0pi_contained = GENIE_CC1p0pi[GENIE_CC1p0pi['IsVertexContained']==1]
GENIE_CC1p0pi_mu = GENIE_CC1p0pi_contained[GENIE_CC1p0pi_contained['Is_mu_TrackReconstructed']==1]
GENIE_CC1p0pi_mup = GENIE_CC1p0pi_contained[GENIE_CC1p0pi_contained['IsVertexReconstructed']==1]

CC1p0pi_samlpes = [GENIE_CC1p0pi,GENIE_CC1p0pi_contained,GENIE_CC1p0pi_mu,GENIE_CC1p0pi_mup]
CC1p0pi_labels = [r'all CC$1p0\pi$',r'$\nu$-int. contained',r'$\mu$-reconstructed',r'$\mu,p$-reconstructed']
CC1p0pi_colors = ['blue','black','red','forestgreen']
# Out:
# 73444 CC interactions pairs in GENIE

# %%
# fig:?
fig,ax = plt.subplots(figsize=(12,8))
h_CC1p0pi_all,bins = np.histogram(GENIE_CC1p0pi['truth_Q2'],bins=largeQ2bins)
acc_corr,acc_corr_err = dict(),dict()

for i,(sample,label,color) in enumerate(zip(CC1p0pi_samlpes,CC1p0pi_labels,CC1p0pi_colors)):
    h,bins = np.histogram(sample['truth_Q2'],bins=largeQ2bins); largeQ2bins_centers = 0.5*(bins[1:] + bins[:-1])
    ratio = h.astype(np.float)/h_CC1p0pi_all
    acc_corr[label] = 1./ratio
    ratio_err = ratio*np.sqrt( 1./h + 1./h_CC1p0pi_all ) if i>0 else 0
    acc_corr_err[label] = ratio_err/np.square(ratio)

    ax.errorbar( largeQ2bins_centers, y=ratio, yerr=ratio_err if i>0 else None
                , xerr=0, fmt='--o' if i>0 else '-'
                , markersize=7, color=color , ecolor=color
                , capthick=2 if i>0 else 0
                ,label=label)
set_axes(ax,x_label=r'$Q^2_{gen.}$ (GeV/c)$^2$'
         ,y_label=r'ratio to all generated CC$1p0\pi$'
         ,fontsize=25
#          ,xticks=np.linspace(0,1.2,5)
         ,ylim=(1e-2,1.5)
         ,do_add_grid=True,do_add_legend=True
        )
ax.set_yscale('log');

fig,ax = plt.subplots(figsize=(12,8))

ax.errorbar( largeQ2bins_centers, y=acc_corr[r'$\mu,p$-reconstructed'], yerr=acc_corr_err[r'$\mu,p$-reconstructed'] 
                , xerr=0, fmt='--o' if i>0 else '-'
                , markersize=7, color=color , ecolor=color
                , capthick=2 if i>0 else 0
                ,label=label)
set_axes(ax,title='acceptance-correction'
         ,x_label=r'$Q^2_{gen.}$ (GeV/c)$^2$'
         ,y_label=r'acceptance-correction to all generated CC$1p0\pi$'
         ,fontsize=25
#          ,xticks=np.linspace(0,1.2,5)
         ,do_add_grid=True,do_add_legend=True
        )

# %% [markdown]
# # $Q^2$ reconstruction

# %%
fig,ax = plt.subplots(figsize=(16,8))
pair_type, cut_name  = 'CC 1p 0pi' , 'no cut'#'1mu-1p'
sample  = reduced_MCbnbDATAcosmicSamples[cut_name][pair_type]
for var,label,color in zip(['truth_Q2','reco_Q2']                   
                           ,[r'$Q^{2}_{gen.}$',r'$Q^{2}_{rec.}$']
                           ,['forestgreen','royalblue']):
    h,bins = np.histogram(sample[var],bins=Q2bins); Q2_centers = 0.5*(bins[1:] + bins[:-1])
    plt.errorbar( x = Q2_centers, xerr=0, markersize=12             
             ,y=h , yerr=np.sqrt(h)             
             ,fmt='--o', label=label)
set_axes(ax,r'$Q^{2}$ (GeV/c)$^{2}$','counts [a.u.]',do_add_legend=True)

# %% [markdown]
# # $Q^2_{rec.}$ vs. $(Q^2_{gen.})^{acceptance-corrected}$

# %%
fig,ax = plt.subplots(figsize=(16,8))
sample  = reduced_MCbnbDATAcosmicSamples['no cut']['CC 1p 0pi']

h_GENIE_CC1p0pi,_ = np.histogram(GENIE_CC1p0pi['truth_Q2'],bins=Q2bins); 
h_GENIE_CC1p0pi_err = np.sqrt(h_GENIE_CC1p0pi)
h_GENIE_CC1p0pi,h_GENIE_CC1p0pi_err = normalize_yield(h_GENIE_CC1p0pi,h_GENIE_CC1p0pi_err,'generated-Q2')


h_GENIE_CC1p0pi_mup,_ = np.histogram(GENIE_CC1p0pi_mup['truth_Q2'],bins=Q2bins); 
h_GENIE_CC1p0pi_mup_err = np.sqrt(h_GENIE_CC1p0pi_mup)
h_GENIE_CC1p0pi_mup,h_GENIE_CC1p0pi_mup_err = normalize_yield(h_GENIE_CC1p0pi_mup,h_GENIE_CC1p0pi_mup_err,'generated-Q2 (after detector)')


h_recQ2,_ = np.histogram(sample['reco_Q2'],bins=Q2bins); 
h_recQ2_err = np.sqrt(h_recQ2)
h_recQ2,h_recQ2_err = normalize_yield(h_recQ2,h_recQ2_err,'rec-Q2')

h_Q2_acceptance_corrected = h_recQ2*acc_corr[r'$\mu,p$-reconstructed']
h_Q2_acceptance_corrected_err = h_Q2_acceptance_corrected*np.sqrt( 1./h_recQ2 + np.square(acc_corr_err[r'$\mu,p$-reconstructed']/acc_corr[r'$\mu,p$-reconstructed']) )
h_Q2_acceptance_corrected,h_Q2_acceptance_corrected_err = normalize_yield(h_Q2_acceptance_corrected,h_Q2_acceptance_corrected_err,'acc. corr. Q2')


for y,yerr,label in zip([h_GENIE_CC1p0pi,h_GENIE_CC1p0pi_mup,h_recQ2,h_Q2_acceptance_corrected]
                   ,[h_GENIE_CC1p0pi_err,h_GENIE_CC1p0pi_mup_err,h_recQ2_err,h_Q2_acceptance_corrected_err]
                   ,['generated (before detector)','generated (after detector)','reconstructed','acceptance-corrected']):
    plt.errorbar( x = Q2_centers, xerr=0, markersize=12             
                 ,y=y , yerr=yerr
                 ,fmt='--o', label=label)
set_axes(ax,r'$Q^{2}$ (GeV/c)$^{2}$','yield [%]',do_add_legend=True)
# Out:
# generated-Q2
# ['13.1+/-0.3%', '20.5+/-0.3%', '18.7+/-0.3%', '14.7+/-0.3%', '10.9+/-0.3%', '8.0+/-0.2%', '5.9+/-0.2%', '4.6+/-0.2%', '3.5+/-0.1%']
# generated-Q2 (after detector)
# ['5.0+/-0.4%', '14.4+/-0.7%', '17.4+/-0.8%', '15.7+/-0.8%', '13.8+/-0.7%', '11.5+/-0.6%', '8.9+/-0.6%', '7.7+/-0.5%', '5.8+/-0.5%']
# rec-Q2
# ['28.9+/-1.5%', '26.7+/-1.5%', '15.7+/-1.1%', '10.9+/-0.9%', '7.8+/-0.8%', '4.2+/-0.6%', '2.7+/-0.5%', '1.8+/-0.4%', '1.2+/-0.3%']
# acc. corr. Q2
# ['49.1+/-10.1%', '24.8+/-5.0%', '11.0+/-2.8%', '6.7+/-2.1%', '4.0+/-1.5%', '1.9+/-0.9%', '1.2+/-0.7%', '0.7+/-0.5%', '0.5+/-0.4%']

# %%
def y_yup_ydw_polynomial(x,a,a_err):
    y = [np.sum([a[i]*np.power(_x_,i) for i in range(len(a))]) for _x_ in x]
    yup = [np.sum([(a[i]+a_err[i])*np.power(_x_,i) for i in range(len(a))]) for _x_ in x]
    ydw = [np.sum([(a[i]-a_err[i])*np.power(_x_,i) for i in range(len(a))]) for _x_ in x]
    return y , yup, ydw

# %%
def polynomial_2(x, a0,a1,a2):
    return (a0 + a1*x + a2*x*x)

def polynomial_3(x, a0,a1,a2,a3):
    return (a0 + a1*x + a2*x*x + a3*x*x*x)

# %%
acc_geant = reduced_MCbnbDATAcosmicSamples['no cut']['CC 1p 0pi']
acc_geant=acc_geant[(acc_geant['truth_Q2']>0)&(acc_geant['truth_Q2']<3)
                    &(acc_geant['reco_Q2']>0)&(acc_geant['reco_Q2']<3)
                    &(acc_geant['truth_Ev']>0)&(acc_geant['truth_Ev']<3)
                    &(acc_geant['reco_Ev']>0)&(acc_geant['reco_Ev']<3)]


fig = plt.figure(figsize=(12,6))

# Q2
ax = fig.add_subplot(1,2,1)
x,y = acc_geant['reco_Q2'],acc_geant['truth_Q2']
# plt.scatter(x,y,label=r'$Q^2_{gen.}$ vs. $Q^2_{gen.}$');
plot_2d_hist(x,y,bins=(np.linspace(0,1.2,50),np.linspace(0,1.5,50)),ax=ax);

h_genQ2_in_xbins = dict()
# # profile
# rec_averages,rec_stds,gen_averages,gen_stds=[],[],[],[]
bins = np.concatenate([np.linspace(0,0.4,10),np.linspace(0.4,1.6,10)])
print 'bins:',bins
for i,bin in zip(range(len(bins)-1),bins):
    xmin,xmax = bins[i],bins[i+1]
#     plt.plot([xmin,xmin],ax.get_ylim(),'-',color='black',alpha=0.2)
    acc_in_xbin = acc_geant[(acc_geant['reco_Q2']>xmin)&(acc_geant['reco_Q2']<xmax)]
    h_genQ2_in_xbins[r'$%.2f<Q^2<%.2f$'%(xmin,xmax)],edges_genQ2_in_xbins = np.histogram(acc_in_xbin['truth_Q2'],bins=np.linspace(0.,1.6,20)) 
    print 'filled',r'$%.2f<Q^2<%.2f$'%(xmin,xmax)
#     if len(acc_in_xbin)<2: continue
#     x_in_xbin = acc_in_xbin['reco_Q2']
#     rec_averages.append( np.mean(x_in_xbin) )
#     rec_stds.append( np.std(x_in_xbin) )
#     y_in_xbin = acc_in_xbin['truth_Q2']
#     gen_averages.append( np.mean(y_in_xbin) )
#     gen_stds.append( np.std(y_in_xbin) )
# plt.errorbar( x=rec_averages, xerr=rec_stds , y=gen_averages, yerr=gen_stds 
#              ,fmt='o',markersize=10,capthick=2,capsize=2,label=r'Gaussian profile')

# x,y,yerr = np.array(rec_averages), np.array(gen_averages),np.array(gen_stds)
# popt , pcov = curve_fit(polynomial_2, x, y, sigma=yerr, p0=[0.2,0.4,0.2])
# a,a_err = popt , [np.sqrt(pcov[i,i]) for  i in range(len(pcov))]
# # print 'popt:\n',popt,'\n pcov:\n' , pcov
# a,a_err = popt , [np.sqrt(pcov[i,i]) for  i in range(len(pcov))]
# print ['a(%d)=%.1f+/-%.1f'%(i,a[i],a_err[i]) for i in range(len(a))]
# x_fit = np.linspace(0,1.5,100)
# y_fit , yup_fit, ydw_fit = y_yup_ydw_polynomial(x_fit,a,a_err)
# plt.plot( x_fit, y_fit , '-',color='purple', label='best fit')
# plt.fill_between( x_fit, ydw_fit , yup_fit , color='purple', label=None , alpha=0.2)
set_axes(ax
         ,x_label=r'$Q^2_{rec.}$ (GeV/c)$^2$' ,y_label=r'$Q^2_{gen.}$ (GeV/c)$^2$' 
         ,xlim=(0,1.2),ylim=(0,1.5)        )
# # plt.legend(bbox_to_anchor=(1,1.05),loc=2.,fontsize=25)

# Ev
ax = fig.add_subplot(1,2,2)
x,y = acc_geant['reco_Ev'], acc_geant['truth_Ev']
# plt.scatter(x,y,label=r'$Q^2_{gen.}$ vs. $Q^2_{gen.}$');
xbins,ybins = np.linspace(0,1.5,50),np.linspace(0,2.5,50)
plot_2d_hist(x,y,bins=(xbins,ybins),ax=ax);

# # profile
# rec_averages,rec_stds,gen_averages,gen_stds=[],[],[],[]
# gen_mpvs,gen_mpv_errdw,gen_mpv_errup=[],[],[]

# bins = np.concatenate([np.linspace(0,0.3,2),np.linspace(0.3,0.7,10),np.linspace(0.7,2.0,10)])
# for i,bin in zip(range(len(bins)-1),bins):
#     xmin,xmax = bins[i],bins[i+1]
#     plt.plot([xmin,xmin],ax.get_ylim(),'-',color='black',alpha=0.2)
#     acc_in_xbin = acc_geant[(acc_geant['reco_Ev']>xmin)&(acc_geant['reco_Ev']<xmax)]
#     if len(acc_in_xbin)<2: continue
#     x_in_xbin = acc_in_xbin['reco_Ev']
#     rec_averages.append( np.mean(x_in_xbin) )
#     rec_stds.append( np.std(x_in_xbin) )
    

#     y_in_xbin = acc_in_xbin['truth_Ev']
#     gen_averages.append( np.mean(y_in_xbin) )
#     gen_stds.append( np.std(y_in_xbin) )
    
#     hy_in_xbin,edges = np.histogram(y_in_xbin, bins=ybins)
#     arg_mpv =  np.argmax( hy_in_xbin )
#     gen_mpvs.append( edges[arg_mpv] )
#     gen_mpv_errdw.append( 1*( np.std(y_in_xbin) - np.abs(gen_mpvs[-1]-np.mean(y_in_xbin)) ) )
#     gen_mpv_errup.append( (np.mean(y_in_xbin)-gen_mpvs[-1]) + np.std(y_in_xbin) )

# # plt.errorbar( x=rec_averages+0.01*np.ones(len(rec_averages)), xerr=rec_stds , y=gen_averages, yerr=gen_stds 
# #              ,fmt='o',markersize=10,capthick=2,capsize=2,label=r'Gaussian profile')
# plt.errorbar( x=rec_averages, xerr=rec_stds , y=gen_mpvs, yerr=[gen_mpv_errdw,gen_mpv_errup]
#              ,fmt='o',markersize=7,capthick=2,capsize=2,label=r'MPVs profile')

# x,y = np.array(rec_averages), np.array(gen_mpvs)
# popt , pcov = curve_fit(polynomial_2, x, y,  p0=[0.2,0.4,0.2])
# a,a_err = popt , [np.sqrt(pcov[i,i]) for  i in range(len(pcov))]
# # print ['a(%d)=%.1f+/-%.1f'%(i,a[i],a_err[i]) for i in range(len(a))]
# x_fit = np.linspace(0.2,2,100)
# y_fit , yup_fit, ydw_fit = y_yup_ydw_polynomial(x_fit,a,a_err)
# plt.plot( x_fit, y_fit , '-',color='purple', label='best fit')
# plt.fill_between( x_fit, ydw_fit , yup_fit , color='purple', label=None , alpha=0.1)

set_axes(ax
         ,x_label=r'$E^\nu_{rec.}$ (GeV)' 
         ,y_label=r'$E^\nu_{gen.}$ (GeV)' 
         ,xlim=(0.2,1.5)
         ,ylim=(0.2,2.)        
#          ,do_add_grid=True
         )
plt.legend(bbox_to_anchor=(1,1.05),loc=2.,fontsize=25)

plt.tight_layout()
# Out:
# bins: [ 0.          0.04444444  0.08888889  0.13333333  0.17777778  0.22222222
#   0.26666667  0.31111111  0.35555556  0.4         0.4         0.53333333
#   0.66666667  0.8         0.93333333  1.06666667  1.2         1.33333333
#   1.46666667  1.6       ]
# filled $0.00<Q^2<0.04$
# filled $0.04<Q^2<0.09$
# filled $0.09<Q^2<0.13$
# filled $0.13<Q^2<0.18$
# filled $0.18<Q^2<0.22$
# filled $0.22<Q^2<0.27$
# filled $0.27<Q^2<0.31$
# filled $0.31<Q^2<0.36$
# filled $0.36<Q^2<0.40$
# filled $0.40<Q^2<0.40$
# filled $0.40<Q^2<0.53$
# filled $0.53<Q^2<0.67$
# filled $0.67<Q^2<0.80$
# filled $0.80<Q^2<0.93$
# filled $0.93<Q^2<1.07$
# filled $1.07<Q^2<1.20$
# filled $1.20<Q^2<1.33$
# filled $1.33<Q^2<1.47$
# filled $1.47<Q^2<1.60$

# %%
fig,ax = plt.subplots(figsize=(12,6))
mid = 0.5*(edges_genQ2_in_xbins[1:] + edges_genQ2_in_xbins[:-1])
# plt.step(mid,h_genQ2_in_xbins[r'$0.00<Q^2<0.04$'],label=r'$0.00<Q^2<0.04$')
plt.step(mid,h_genQ2_in_xbins[r'$0.04<Q^2<0.09$'],label=r'$0.04<Q^2_{rec.}<0.09$')
plt.step(mid,h_genQ2_in_xbins[r'$0.18<Q^2<0.22$'],label=r'$0.18<Q^2_{rec.}<0.22$')
set_axes(ax,x_label=r'$Q^2_{gen.}$ (GeV)',do_add_legend=True,ylim=(0,45))

# %% [markdown]
# # from reconstructed $Q^2$ to generated $Q^2$ after acceptance correction

# %% [markdown]
# ## acceptance in 2D: $Q^2$ and $E_\nu$

# %%
h_CC1p0pi_gen = np.zeros((len(largeQ2bins),len(largeEvbins)))
h_CC1p0pi_acc = np.zeros((len(largeQ2bins),len(largeEvbins)))
acc_corr_Q2Ev = np.zeros((len(largeQ2bins),len(largeEvbins)))
print 'largeQ2bins:',largeQ2bins

h_CC1p0pi_gen = fill_2d_histogram( largeQ2bins , largeEvbins , GENIE_CC1p0pi , varx='truth_Q2' , vary='truth_Ev' )
h_CC1p0pi_acc = fill_2d_histogram( largeQ2bins , largeEvbins , GENIE_CC1p0pi_mup , varx='truth_Q2' , vary='truth_Ev' )




for i in range(len(largeQ2bins)-1):
    for j in range(len(largeEvbins)-1):
        if h_CC1p0pi_acc[i][j]>1: acc_corr_Q2Ev[i][j] = h_CC1p0pi_gen[i][j]/h_CC1p0pi_acc[i][j]
        else: acc_corr_Q2Ev[i][j] = 1

fig = plt.figure(figsize=(20,6))
for i,h,title in zip(range(3)
                     ,[h_CC1p0pi_gen,h_CC1p0pi_acc,acc_corr_Q2Ev]
                     ,['generated','accepted','acc. corr.: generated/accepted']):
    h = h.T
    ax = fig.add_subplot(1,3,i+1)    
    sns.heatmap(h,cmap='hot_r'
                ,xticklabels=['%.1f'%largeQ2bins[j] if j%3==0 else '' for j in range(len(largeQ2bins))]
                ,yticklabels=['%.1f'%largeEvbins[j] if j%3==0 else '' for j in range(len(largeEvbins))]
               )
    set_axes(ax
             ,title=title
             ,x_label=r'$Q^2_{gen.}$ (GeV/c)$^2$' 
             ,y_label=r'$E^\nu_{gen.}$ (GeV)' if i==0 else ''
             ,fontsize=25,do_add_grid=True,do_add_legend=True
            )
    ax.invert_yaxis()
    if i>0: ax.yaxis.set_major_formatter(ticker.NullFormatter())    
plt.tight_layout()

fig,ax = plt.subplots(figsize=(12,6))
sns.heatmap(acc_corr_Q2Ev.T
            ,cmap='hot_r'
                ,xticklabels=['%.1f'%largeQ2bins[j] if j%3==0 else '' for j in range(len(largeQ2bins))]
                ,yticklabels=['%.1f'%largeEvbins[j] if j%3==0 else '' for j in range(len(largeEvbins))]
               )
set_axes(ax
             ,title='acceptance correction'
             ,x_label=r'$Q^2_{gen.}$ (GeV/c)$^2$' 
             ,y_label=r'$E^\nu_{gen.}$ (GeV)' 
             ,fontsize=25,do_add_grid=True,do_add_legend=True
            )
ax.invert_yaxis()
# Out:
# largeQ2bins: [ 0.          0.08888889  0.17777778  0.26666667  0.35555556  0.44444444
#   0.53333333  0.62222222  0.71111111  0.8       ]

# %% [markdown]
# # from reconstructed $Q^2$ to generated $(Q^2,E_\nu)$ after acceptance correction

# %%
results_dict = dict()

# %%
mA = 0.7
N_rand = 1000
debug = 1
Nmax_attempts = N_rand*10
acc_geant = reduced_MCbnbDATAcosmicSamples['no cut']['CC 1p 0pi']
Q2_averages,Q2_stds=[],[]
N_generated , N_generated_err = [],[] 
N_measured , N_measured_err = [],[]
N_calculated , N_calculated_err = [],[]
N_calculated_rec , N_calculated_rec_err = [],[]
h_accepted_array , h_acceptance_corrected_array , h_random_array = [], [] , []

Nmax_Q2 = len(largeQ2bins)-1
Nmax_Ev = len(largeEvbins)-1


for i,recQ2bin in zip(range(len(Q2bins)-1),Q2bins): # 
    GENIE_CC1p0pi_genQ2bin = GENIE_CC1p0pi[(GENIE_CC1p0pi['truth_Q2']>Q2bins[i]) & (GENIE_CC1p0pi['truth_Q2']<Q2bins[i+1])]

    # generated (before detector acceptance)
    # -- - - -- -- -- - -- - - - -- -- - - ---- 
    N_generated.append( len(GENIE_CC1p0pi_genQ2bin) )
    N_generated_err.append( np.sqrt( len(GENIE_CC1p0pi_genQ2bin) ) )


    acc_geant_recQ2bin = acc_geant[(acc_geant['reco_Q2']>Q2bins[i]) & (acc_geant['reco_Q2']<Q2bins[i+1])]
    acc_geant_recQ2bin = acc_geant_recQ2bin[acc_geant_recQ2bin['truth_Q2']>0]
    if debug: 
        print 'recQ2bin:',recQ2bin
        
    if debug>1:
        print 'len(acc_geant_recQ2bin):',len(acc_geant_recQ2bin)
    
    # mean Q2 value in bin
    # -- - - -- -- -- - -- - - - -- -- - - ---- 
    Q2_averages.append( np.mean(acc_geant_recQ2bin['reco_Q2']) )
    Q2_stds.append( np.std(acc_geant_recQ2bin['reco_Q2']) )

    # measured (not really measured here since its MC)
    # -- - - -- -- -- - -- - - - -- -- - - ---- 
    N_measured.append( len(acc_geant_recQ2bin) )
    N_measured_err.append( np.sqrt( len(acc_geant_recQ2bin) ) )


    # calculated  with Q2(rec.)
    # -- - - -- -- -- - -- - - - -- -- - - ---- 
    h_recEv,_ = np.histogram(acc_geant_recQ2bin['reco_Ev'],bins=largeEvbins); 
    i_rand,i_attempt=0,0
    rand_Ev_N_Xsec_array = []
    while (i_rand<N_rand and i_attempt<Nmax_attempts):
        i_attempt += 1
        rand_bin_Ev = np.random.randint(Nmax_Ev)
        bin_content = h_recEv[rand_bin_Ev]
        rand_val = np.random.uniform(np.max(h_recEv))
        if (rand_val <= bin_content):
            i_rand += 1
            rand_Ev = largeEvbins_centers[rand_bin_Ev]
            rand_Ev_N_Xsec = CCelasticXsec( Q2=Q2_averages[-1], Ev=rand_Ev, mA=mA )
            rand_Ev_N_Xsec_array.append(rand_Ev_N_Xsec)
    N_calculated_rec.append( np.mean( rand_Ev_N_Xsec_array ) )
    N_calculated_rec_err.append( np.std( rand_Ev_N_Xsec_array ) )

    
    # calculated (form the CC-elastic Xsec.)
    # -- - - -- -- -- - -- - - - -- -- - - ---- 
    h_random = np.zeros((len(largeQ2bins),len(largeEvbins)))
    
    h_accepted = fill_2d_histogram( largeQ2bins , largeEvbins , acc_geant_recQ2bin , varx='truth_Q2' , vary='truth_Ev' )
    h_accepted_array.append( h_accepted )
    h_acceptance_corrected = h_accepted * acc_corr_Q2Ev
    h_acceptance_corrected_array.append(h_acceptance_corrected)

    rand_Q2_N_Xsec_array = []
    max_rand_val = np.max(h_acceptance_corrected)
    # sample N_rand random pair of (Q2,Ev)
    i_rand=0
    i_attempt=0
    rand_Q2_array, rand_Ev_array = [] , [] 
    if debug>1:
        print 'h_acceptance_corrected.shape:',h_acceptance_corrected.shape
        print 'h_random.shape:',h_random.shape
        print '(Nmax_Q2,Nmax_Ev):',Nmax_Q2,Nmax_Ev
    while (i_rand<N_rand and i_attempt<Nmax_attempts):
        i_attempt += 1
        rand_bin_Q2 = np.random.randint(Nmax_Q2)
        rand_bin_Ev = np.random.randint(Nmax_Ev)
        bin_content = h_acceptance_corrected[rand_bin_Q2][rand_bin_Ev]
        # select a random number
        rand_val = np.random.uniform(max_rand_val)
        # check if the number is smaller or equal the bin-content at (Q2,Ev) 
        if debug>1:
            print 'Q2 bin:',i,',i_rand:',i_rand,',i_attempt:',i_attempt # if i_rand%100==0: 
            print 'h_acceptance_corrected[',rand_bin_Q2,'][',rand_bin_Ev,']:',bin_content,',rand_val:',rand_val

        if (rand_val <= bin_content):
            i_rand += 1
            h_random[rand_bin_Q2][rand_bin_Ev] += 1
            rand_Q2 = largeQ2bins_centers[rand_bin_Q2]
            rand_Ev = largeEvbins_centers[rand_bin_Ev]
            # for each point, calculate the expected cross-section
            rand_Q2_N_Xsec = CCelasticXsec( Q2=rand_Q2, Ev=rand_Ev, mA=mA )
            rand_Q2_N_Xsec_array.append(rand_Q2_N_Xsec)
            if debug>1: 
                print 'filling h_random[',rand_bin_Q2,'][',rand_bin_Ev,']'
                print "rand_Q2_N_Xsec_array[-1]:",rand_Q2_N_Xsec_array[-1]
            
    N_calculated.append( np.mean(rand_Q2_N_Xsec_array) )
    N_calculated_err.append( np.std( rand_Q2_N_Xsec_array ) )
    h_random_array.append(h_random)   
    
    print "Q2_averages[-1]:",Q2_averages[-1],",np.mean(acc_geant_recQ2bin['truth_Q2']):",np.mean(acc_geant_recQ2bin['truth_Q2'])

print 'done calculation - start plotting'
# Out:
# recQ2bin: 0.0
# Q2_averages[-1]: 0.049230426408 ,np.mean(acc_geant_recQ2bin['truth_Q2']): 0.305829357816
# recQ2bin: 0.0888888888889
# Q2_averages[-1]: 0.128158484112 ,np.mean(acc_geant_recQ2bin['truth_Q2']): 0.346428437695
# recQ2bin: 0.177777777778
# Q2_averages[-1]: 0.216947951872 ,np.mean(acc_geant_recQ2bin['truth_Q2']): 0.383584841176
# recQ2bin: 0.266666666667
# Q2_averages[-1]: 0.30350730303 ,np.mean(acc_geant_recQ2bin['truth_Q2']): 0.405922959091
# recQ2bin: 0.355555555556
# Q2_averages[-1]: 0.398696715789 ,np.mean(acc_geant_recQ2bin['truth_Q2']): 0.481905956316
# recQ2bin: 0.444444444444
# Q2_averages[-1]: 0.481662764706 ,np.mean(acc_geant_recQ2bin['truth_Q2']): 0.592536078431
# recQ2bin: 0.533333333333
# Q2_averages[-1]: 0.572071666667 ,np.mean(acc_geant_recQ2bin['truth_Q2']): 0.698071454545
# recQ2bin: 0.622222222222
# Q2_averages[-1]: 0.669867818182 ,np.mean(acc_geant_recQ2bin['truth_Q2']): 0.802524409091
# recQ2bin: 0.711111111111
# ...

# %%
N_generated,N_generated_err = normalize_yield(N_generated,N_generated_err,"generated (MC)")
N_measured,N_measured_err = normalize_yield(N_measured,N_measured_err,"'measured' (MC)")
N_calculated,N_calculated_err = normalize_yield(N_calculated,N_calculated_err, r"calculated from $Q^2_{gen.}$")
N_calculated_rec,N_calculated_rec_err = normalize_yield(N_calculated_rec,N_calculated_rec_err,r"calculated from $Q^2_{rec.}$")
# Out:
# generated (MC)
# ['13.1+/-0.3%', '20.5+/-0.3%', '18.7+/-0.3%', '14.7+/-0.3%', '10.9+/-0.3%', '8.0+/-0.2%', '5.9+/-0.2%', '4.6+/-0.2%', '3.5+/-0.1%']
# 'measured' (MC)
# ['28.9+/-1.5%', '26.7+/-1.5%', '15.5+/-1.1%', '11.0+/-1.0%', '7.9+/-0.8%', '4.2+/-0.6%', '2.7+/-0.5%', '1.8+/-0.4%', '1.2+/-0.3%']
# calculated from $Q^2_{gen.}$
# ['19.4+/-5.9%', '16.5+/-5.3%', '14.9+/-4.3%', '12.8+/-3.5%', '10.5+/-3.4%', '8.5+/-2.6%', '6.7+/-1.3%', '5.8+/-1.0%', '5.0+/-0.3%']
# calculated from $Q^2_{rec.}$
# ['21.8+/-1.0%', '18.0+/-1.5%', '14.5+/-1.4%', '11.7+/-1.1%', '9.5+/-0.8%', '8.2+/-0.6%', '6.5+/-0.4%', '5.3+/-0.3%', '4.6+/-0.3%']

# %%
results_dict['mA=%.1f'%mA] = pd.DataFrame({'N_generated':N_generated
                                           ,'N_generated_err':N_generated_err
                                           ,'N_measured':N_measured
                                           ,'N_measured_err':N_measured_err
                                           ,'N_calculated':N_calculated
                                           ,'N_calculated_err':N_calculated_err
                                           ,'N_calculated_rec':N_calculated_rec
                                           ,'N_calculated_rec_err':N_calculated_rec_err})

# %%
N_generated = results_dict['mA=%.1f'%mA]['N_generated']
N_measured = results_dict['mA=%.1f'%mA]['N_measured']
N_calculated = results_dict['mA=%.1f'%mA]['N_calculated']
N_calculated_rec = results_dict['mA=%.1f'%mA]['N_calculated_rec']
N_generated_err = results_dict['mA=%.1f'%mA]['N_generated_err']
N_measured_err = results_dict['mA=%.1f'%mA]['N_measured_err']
N_calculated_err = results_dict['mA=%.1f'%mA]['N_calculated_err']
N_calculated_rec_err = results_dict['mA=%.1f'%mA]['N_calculated_rec_err']


yield_array = [N_generated,N_measured,N_calculated,N_calculated_rec]
yield_unc_array = [N_generated_err,N_measured_err,N_calculated_err,N_calculated_rec_err]
labels_array = ["generated (MC)","'measured' (MC)" , r"calculated from $Q^2_{gen.}$",r"calculated from $Q^2_{rec.}$"]

# %%
fig,ax = plt.subplots(figsize=(16,8))
for y,yerr,label in zip(yield_array, yield_unc_array,labels_array):
    plt.errorbar(x=Q2_averages,xerr=Q2_stds
                 ,y=y,yerr=yerr
                 ,fmt='o'
                 ,markersize=10,capthick=2,capsize=2
                 ,label=label)
set_axes(ax,r'$Q^2$ (GeV/c)$^2$','yield [%]',title="$m_A=%.1f$ GeV/c$^2$"%mA
         ,do_add_grid=True,do_add_legend=True)

# %%
plot_Q2_Ev_distribution_in_reQ2_bins(histo_array=h_accepted_array,histtitle='accepted')
plot_Q2_Ev_distribution_in_reQ2_bins(histo_array=h_acceptance_corrected_array,histtitle='acc. corr.')
plot_Q2_Ev_distribution_in_reQ2_bins(histo_array=h_random_array,histtitle='random')

# %% [markdown]
# # The sensitivity to the axial mass
# # This is the best we can do (we won't get better than this)
# ## So - do we have a sensitivity to the axial mass??
# 1. we probably have to cut out $Q^2<0.1$ (GeV/c$^2$)
# 2. lets see what is the slope of each line + uncertainty, and see if we can distinguish between them

# %%
fig,ax = plt.subplots(figsize=(16,8))
Q2min = 0.1
for i_mA,(mA,color) in enumerate(zip([0.7,1.0,1.3],['red','forestgreen','blue'])):
    label="$m_A=%.1f$ GeV/c$^2$"%mA
    x = Q2_averages
    y = results_dict['mA=%.1f'%mA]['N_calculated']
    yerr = results_dict['mA=%.1f'%mA]['N_calculated_err']
    plt.errorbar(x=x+0.005*i_mA*np.ones(len(x)),xerr=Q2_stds
                 ,y=y,yerr=yerr,color=color
                 ,fmt='o'
                 ,markersize=10,capthick=2,capsize=2
                 ,label=None)#label="$m_A=%.1f$ GeV/c$^2$"%mA)
    
    # we fit x[1:] and y[1:] since we want only Q2>0.1, which means, here, above the first bin
    popt,cov = np.polyfit(x[1:],y[1:],1,cov=True)
    print 'cov:\n',cov
    slope,intercept = popt[0],popt[1]
    slope_err,intercept_err = np.sqrt(cov[0,0]),np.sqrt(cov[1,1])
    poly = np.poly1d(popt)
    print 'poly:',poly
    x_fit=np.linspace(Q2min,0.8,100)
    y_fit=poly(x_fit)
    label = r'%s: $%.2f(%.2f)Q^2+%.2f(%.2f)$'%(label,slope,slope_err,intercept,intercept_err)
    plt.plot(x_fit,y_fit,'-',color=color,label=label)
plt.plot([Q2min,Q2min],ax.get_ylim(),'--',color='black')
set_axes(ax,r'$Q^2$ (GeV/c)$^2$','yield [%]',title=r"calculated from $Q^2_{gen.}$",do_add_grid=True,do_add_legend=True)

# fig,ax = plt.subplots(figsize=(16,8))
# for i_mA,mA in enumerate([0.7,1.0,1.3]):
#     y=results_dict['mA=%.1f'%mA]['N_calculated_rec']
#     yerr=results_dict['mA=%.1f'%mA]['N_calculated_rec_err']
#     plt.errorbar(x=Q2_averages+0.005*i_mA*np.ones(len(Q2_averages)),xerr=Q2_stds
#                  ,y=y,yerr=yerr
#                  ,fmt='o'
#                  ,markersize=10,capthick=2,capsize=2
#                  ,label="$m_A=%.1f$ GeV/c$^2$"%mA)
# set_axes(ax,r'$Q^2$ (GeV/c)$^2$','yield [%]',title=r"calculated from $Q^2_{rec.}$",do_add_grid=True,do_add_legend=True)
# Out:
# cov:
# [[ 1.99183769 -0.87600164]
#  [-0.87600164  0.46839071]]
# poly:
# -19.52 x + 18.66
# cov:
# [[ 0.90876856 -0.3996725 ]
#  [-0.3996725   0.21370152]]
# poly:
# -16.55 x + 17.72
# cov:
# [[ 0.49698689 -0.21857269]
#  [-0.21857269  0.11686898]]
# poly:
# -13.22 x + 16.49

# %%
Q2_averages,Q2_stds=[],[]
debug = 0
N_rand = 1000
acc_geant = reduced_MCbnbDATAcosmicSamples['no cut']['CC 1p 0pi']
fig = plt.figure(figsize=(20,20))
mA = 1.0
NormFact = 30


for i,Q2bin in zip(range(len(Q2bins)-1),Q2bins):
    
    acc_geant_recQ2bin = acc_geant[(acc_geant['reco_Q2']>Q2bins[i]) & (acc_geant['reco_Q2']<Q2bins[i+1])]

    Q2_averages.append( np.mean(acc_geant_recQ2bin['reco_Q2']) )
    Q2_stds.append( np.std(acc_geant_recQ2bin['reco_Q2']) )
    
    ax = fig.add_subplot(len(Q2bins)/3,3,i+1)
    h_accepted,bins=np.histogram(acc_geant_recQ2bin['truth_Q2'],bins=largeQ2bins)
    h_accepted = (h_accepted).astype(np.float)/np.sum(h_accepted)
    largeQ2bins_centers = 0.5*(bins[1:] + bins[:-1])
    plt.step(largeQ2bins_centers, h_accepted ,label='reconstructed')

    h_acceptance_corrected = h_accepted * acc_corr[r'$\mu,p$-reconstructed']
    h_acceptance_corrected = (h_acceptance_corrected).astype(np.float)/np.sum(h_acceptance_corrected)
    plt.step(largeQ2bins_centers, h_acceptance_corrected ,label='acc. corrected')

    # randomly sample from the acceptance-corrected distribution
    h2generate_Q2 = h_acceptance_corrected
    gen_weights = h2generate_Q2.astype(np.float32)
    gen_weights = gen_weights/np.sum(gen_weights)
    rand_Q2 = []
    for i_rand in range(N_rand):
        rand_Q2.append( np.random.choice( largeQ2bins_centers, p=h_acceptance_corrected) )        
        # for each point, calculate the expected        
        rand_Qacc_geant_recQ2bin2_N_Xsec = N_CCelasticXsec( Q2=rand_Q2, Ev=0.7, mA=mA , NormFact=NormFact)
    h_rand_Q2,bins=np.histogram(rand_Q2,bins=largeQ2bins)
    h_rand_Q2 = (h_rand_Q2).astype(np.float)/np.sum(h_rand_Q2)
    plt.step( largeQ2bins_centers, h_rand_Q2 ,label='random $Q^2_{gen.}$')



    set_axes(ax,r'$Q^{2}_{gen.}$ (GeV/c)$^{2}$','counts [a.u.]'
             ,title=r"$%.2f<Q^{2}_{rec.}<%.2f$"%(Q2bins[i],Q2bins[i+1])
             ,do_add_legend=True if i==0 else '')
    if debug:
        print 'Q2bin: %.2f<Q2<%.2f, <Q2>=%.2f+/-%.2f GeV/c2'%(Q2bins[i],Q2bins[i+1],Q2_averages[-1],Q2_stds[-1])
        print 'h_accepted:',h_accepted
        print 'h_acceptance_corrected:',h_acceptance_corrected
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-c8c62a9ae9bd> in <module>()
#      33         rand_Q2.append( np.random.choice( largeQ2bins_centers, p=h_acceptance_corrected) )
#      34         # for each point, calculate the expected
# ---> 35         rand_Qacc_geant_recQ2bin2_N_Xsec = N_CCelasticXsec( Q2=rand_Q2, Ev=0.7, mA=mA , NormFact=NormFact)
#      36     h_rand_Q2,bins=np.histogram(rand_Q2,bins=largeQ2bins)
#      37     h_rand_Q2 = (h_rand_Q2).astype(np.float)/np.sum(h_rand_Q2)
#
# /Users/erezcohen/larlite/UserDev/CCQEana/CCQEPackage/notebooks/analysis_notes/axial_mass_from_run1_data/axial_mass_tools.py in N_CCelasticXsec(Q2, Ev, mA, NormFact)
#     163 def N_CCelasticXsec( Q2 , Ev, mA , NormFact ):
#     164     # normalization factor for the data mutiplies the CCelastic Xsec
# ...
