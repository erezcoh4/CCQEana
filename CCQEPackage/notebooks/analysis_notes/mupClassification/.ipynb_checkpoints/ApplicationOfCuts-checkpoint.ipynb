# %%
import sys; sys.path.insert(0, '../../'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
# %matplotlib inline

# %% [markdown]
# # 5 Application of detection and kinematical related cuts
# Aug 30, 2017

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/mupClassification/Figures/ApplicationOfCuts/'

# %% [markdown]
# # pairs of tracks at close proximity

# %%
MCbnbMCcosmicPairsFV, MCbnbMCcosmicSamples = load_MCbnbMCcosmicSamples()
# pur_eff,pur_eff_numbers = apply_cuts(PIDa_p_min=8)
# Out:
# 139258 pairs from MC-BNB + cosmic MC overlay
# 96025 pairs in FV
# 19649 are 1mu-1p, 20.5%
# 16331 are other pairs, 17.0%
# 60155 are cosmic, 62.6%
# --------------------------------------------------------------
# 7586 are CC 1p 0pi, 7.9%

# %%
MCbnbDATAcosmicPairsFV, MCbnbDATAcosmicSamples = load_MCbnbDATAcosmicSamples()
# Out:
# 50939 pairs from MC-BNB + cosmic DATA overlay
# 30377 pairs in FV
# 3814 are 1mu-1p, 12.6%
# 4001 are other pairs, 13.2%
# 22562 are cosmic, 74.3%
# --------------------------------------------------------------
# 1234 are CC 1p 0pi, 4.1%

# %%
MCbnbDATAcosmicPairsFV['ClosestFlash_TotalPE_assigned_proton']
# Out:
# 0       -1.0
# 2       -1.0
# 3       -1.0
# 4       -1.0
# 5       -1.0
# 6       -1.0
# 7       -1.0
# 8       -1.0
# 9       -1.0
# 10      -1.0
# 11      -1.0
# 12      -1.0
# 13      -1.0
# 14      -1.0
# 15      -1.0
# 16      -1.0
# 17      -1.0
# 18      -1.0
# 19      -1.0
# 20      -1.0
# 21      -1.0
# 22      -1.0
# 23      -1.0
# 25      -1.0
# 26      -1.0
# 28      -1.0
# 29      -1.0
# 30      -1.0
# 31      -1.0
# 32      -1.0
#         ...
# 50900   -1.0
# 50903   -1.0
# 50904   -1.0
# 50905   -1.0
# 50906   -1.0
# 50908   -1.0
# 50909   -1.0
# 50910   -1.0
# 50911   -1.0
# 50912   -1.0
# 50913   -1.0
# 50914   -1.0
# 50915   -1.0
# 50916   -1.0
# 50918   -1.0
# 50920   -1.0
# 50923   -1.0
# 50924   -1.0
# 50925   -1.0
# 50927   -1.0
# 50928   -1.0
# 50929   -1.0
# 50931   -1.0
# 50932   -1.0
# 50933   -1.0
# 50934   -1.0
# 50935   -1.0
# 50936   -1.0
# 50937   -1.0
# 50938   -1.0
# Name: ClosestFlash_TotalPE_assigned_proton, dtype: float64

# %%
pureff_MCbnbDATAcosmic,pureff_MCbnbDATAcosmic_numbers,pureff_MCbnbMCcosmic,pureff_MCbnbMCcosmic_numbers = apply_cuts(PIDa_p_min=10, delta_Delta_phi=40 ,Rmin = (0.,0.,0.))

# %%
pureff_MCbnbDATAcosmic
# Out:
#                  $\mu p$ eff. $\mu p$ pur. CC$0\pi 1 p$ eff.  \
# no cut                 100.0%        12.6%            100.0%
# PIDa                    87.1%        40.7%             84.4%
# length                  70.2%        55.3%             71.5%
# non-collinearity        64.4%        69.3%             68.9%
# vertex activity         61.8%        69.4%             65.1%
# delta phi               36.3%        77.8%             56.3%
# theta_pq                26.1%        90.3%             47.6%
# soft Pt                 29.7%        85.9%             50.6%
# tight Pt                13.9%        94.5%             28.8%
#
#                  CC$0\pi 1 p$ pur.  \
# no cut                        4.1%
# PIDa                         12.8%
# length                       18.2%
# non-collinearity             24.0%
# vertex activity              23.7%
# delta phi                    39.1%
# theta_pq                     53.4%
# soft Pt                      47.4%
# tight Pt                     63.3%
#
#                                                          label         1mu-1p  \
# no cut                                                    None  100.0% (3814)
# PIDa                                              ${PID}_a>10$   87.1% (3323)
# length                                         $l_{\mu}>l_{p}$   70.2% (2676)
# non-collinearity                    $|\theta_{1,2}-90^0|<60^0$   64.4% (2456)
# vertex activity   $(-0.01,-0.01,-0.01)<R_{\Delta Q}^{(U,V,Y)}$   61.8% (2357)
# delta phi                           $|\Delta \phi - \pi|<40^0$   36.3% (1383)
# theta_pq                                    $\theta_{pq}<25^0$    26.1% (994)
# soft Pt                                     $p_{t}<0.35$ GeV/c   29.7% (1132)
# tight Pt                                    $p_{t}<0.15$ GeV/c    13.9% (530)
#
#                     other pairs          cosmic      CC 1p 0pi
# no cut            100.0% (4001)  100.0% (22562)  100.0% (1234)
# PIDa               44.3% (1771)    13.6% (3062)   84.4% (1041)
# length              22.9% (918)     5.5% (1249)    71.5% (882)
# non-collinearity    15.8% (632)      2.0% (455)    68.9% (850)
# vertex activity     15.2% (607)      1.9% (430)    65.1% (803)
# delta phi            4.8% (193)      0.9% (201)    56.3% (695)
# theta_pq              2.1% (86)       0.1% (21)    47.6% (588)
# soft Pt              2.8% (111)       0.3% (75)    50.6% (625)
# tight Pt              0.7% (27)        0.0% (4)    28.8% (355)

# %%
pur_eff
# Out:
#                  $\mu p$ eff. $\mu p$ pur. CC$0\pi 1 p$ eff.  \
# no cut                 100.0%        12.6%            100.0%
# PIDa                    93.6%        32.0%             92.5%
# length                  74.4%        47.1%             77.2%
# non-collinearity        68.1%        66.6%             74.3%
# vertex activity         45.2%        69.1%             61.2%
# delta phi               29.5%        76.8%             53.6%
# theta_pq                22.3%        90.6%             45.6%
# soft Pt                 24.6%        86.1%             48.1%
# tight Pt                12.4%        94.4%             27.5%
#
#                  CC$0\pi 1 p$ pur.                       label         1mu-1p  \
# no cut                        4.1%                        None  100.0% (3814)
# PIDa                         10.2%                 ${PID}_a>8$   93.6% (3569)
# length                       15.8%             $l_{\mu}>l_{p}$   74.4% (2838)
# non-collinearity             23.5%  $|\theta_{1,2}-90^0|<60^0$   68.1% (2599)
# vertex activity              30.3%           vertex $\Delta Q$   45.2% (1724)
# delta phi                    45.1%  $|\Delta \phi - \pi|<40^0$   29.5% (1126)
# theta_pq                     60.0%          $\theta_{pq}<25^0$    22.3% (850)
# soft Pt                      54.4%          $p_{t}<0.35$ GeV/c    24.6% (939)
# tight Pt                     67.5%          $p_{t}<0.15$ GeV/c    12.4% (474)
#
#                     other pairs          cosmic      CC 1p 0pi
# no cut            100.0% (4001)  100.0% (22562)  100.0% (1234)
# PIDa               58.3% (2333)    23.3% (5261)   92.5% (1141)
# length             28.7% (1149)     9.0% (2034)    77.2% (953)
# non-collinearity    18.4% (736)      2.5% (569)    74.3% (917)
# vertex activity     10.4% (418)      1.6% (352)    61.2% (755)
# delta phi            3.3% (134)      0.9% (207)    53.6% (662)
# theta_pq              1.5% (62)       0.1% (26)    45.6% (563)
# soft Pt               1.8% (73)       0.4% (79)    48.1% (594)
# tight Pt              0.4% (18)       0.0% (10)    27.5% (339)

# %%
pur_eff_numbers
# Out:
#                   \CCIpOpi    \mup   cosmic  \
# no cut              1234.0  3814.0  22562.0
# \CutPIDa             939.0  3046.0   2102.0
# \Cutlmup             789.0  2440.0    855.0
# non-collinearity     759.0  2235.0    359.0
# vertex activity      724.0  2158.0    334.0
# \CutDeltaPhi         626.0  1258.0    132.0
# theta_pq             523.0   894.0     17.0
# soft Pt              560.0  1022.0     21.0
# tight Pt             314.0   470.0      4.0
#
#                                                      cut label  \
# no cut                                                    None
# \CutPIDa                                          ${PID}_a>12$
# \Cutlmup                                       $l_{\mu}>l_{p}$
# non-collinearity                    $|\theta_{1,2}-90^0|<60^0$
# vertex activity   $(-0.01,-0.01,-0.01)<R_{\Delta Q}^{(U,V,Y)}$
# \CutDeltaPhi                        $|\Delta \phi - \pi|<40^0$
# theta_pq                                    $\theta_{pq}<25^0$
# soft Pt                                     $p_{t}<0.35$ GeV/c
# tight Pt                                    $p_{t}<0.15$ GeV/c
#
#                           cut name  eff \CCIpOpi    eff \mup  other pairs  \
# no cut                      no cut    100.000000  100.000000       4001.0
# \CutPIDa                  \CutPIDa     76.094003   79.863660       1536.0
# \Cutlmup                  \Cutlmup     63.938412   63.974830        812.0
# non-collinearity  non-collinearity     61.507293   58.599895        570.0
# vertex activity    vertex activity     58.670989   56.581017        548.0
# \CutDeltaPhi          \CutDeltaPhi     50.729335   32.983744        174.0
# theta_pq                  theta_pq     42.382496   23.439958         80.0
# soft Pt                    soft Pt     45.380875   26.796015        101.0
# tight Pt                  tight Pt     25.445705   12.323020         27.0
#
#                   pur \CCIpOpi   pur \mup
# no cut                4.062284  12.555552
# \CutPIDa             14.048474  45.571514
# \Cutlmup             19.211103  59.410762
# non-collinearity     23.988622  70.638432
# vertex activity      23.815789  70.986842
# \CutDeltaPhi         40.025575  80.434783
# theta_pq             52.774975  90.211907
# soft Pt              48.951049  89.335664
# tight Pt             62.674651  93.812375

# %%
# plug in table tab:FiveCuts in report (ApplicationOfCuts.tex)
print "plug in table tab:FiveCuts in report (ApplicationOfCuts.tex)"
print 
print "			\hline"
print "			cut	 					& \\textcolor{orange}{cosmic}		& \\textcolor{red}{other pairs} 		& \\textcolor{teal}{\mup} 		& \\textcolor{blue}{\CCIpOpi}  			& purity \\textcolor{teal}{\mup} (\\textcolor{blue}{\CCIpOpi}) 	& efficiency \\textcolor{teal}{\mup} (\\textcolor{blue}{\CCIpOpi}) 		\\tabularnewline"
print "\hline \hline"
for i,row in pur_eff_numbers.iterrows():    
#     print row[]
    Ncosmic = int(row['cosmic'])
    print "			"+row['cut name']+"\
    & \\textcolor{orange}{%d"%row['cosmic']+"}\
    & \\textcolor{red}{%d"%row['other pairs']+"}\
    & \\textcolor{teal}{%d"%row['\mup']+"}\
    & \\textcolor{blue}{%d"%row['\CCIpOpi']+"}\
    & \\textcolor{teal}{%.1f"%(float(row['pur \mup']))+"\%"+"}"+"(\\textcolor{blue}{%.1f"%(float(row['pur \CCIpOpi']))+"\%"+")}\
    & \\textcolor{teal}{%.1f"%(float(row['eff \mup']))+"\%"+"}"+"(\\textcolor{blue}{%.1f"%(float(row['eff \CCIpOpi']))+"\%"+")}\
    \\tabularnewline"
    print "\hline"

print
print
# Out:
# plug in table tab:FiveCuts in report (ApplicationOfCuts.tex)
#
# 			\hline
# 			cut	 					& \textcolor{orange}{cosmic}		& \textcolor{red}{other pairs} 		& \textcolor{teal}{\mup} 		& \textcolor{blue}{\CCIpOpi}  			& purity \textcolor{teal}{\mup} (\textcolor{blue}{\CCIpOpi}) 	& efficiency \textcolor{teal}{\mup} (\textcolor{blue}{\CCIpOpi}) 		\tabularnewline
# \hline \hline
# 			no cut    & \textcolor{orange}{22562}    & \textcolor{red}{4001}    & \textcolor{teal}{3814}    & \textcolor{blue}{1234}    & \textcolor{teal}{12.6\%}(\textcolor{blue}{4.1\%)}    & \textcolor{teal}{100.0\%}(\textcolor{blue}{100.0\%)}    \tabularnewline
# \hline
# 			\CutPIDa    & \textcolor{orange}{5261}    & \textcolor{red}{2333}    & \textcolor{teal}{3569}    & \textcolor{blue}{1141}    & \textcolor{teal}{32.0\%}(\textcolor{blue}{10.2\%)}    & \textcolor{teal}{93.6\%}(\textcolor{blue}{92.5\%)}    \tabularnewline
# \hline
# 			\Cutlmup    & \textcolor{orange}{2034}    & \textcolor{red}{1149}    & \textcolor{teal}{2838}    & \textcolor{blue}{953}    & \textcolor{teal}{47.1\%}(\textcolor{blue}{15.8\%)}    & \textcolor{teal}{74.4\%}(\textcolor{blue}{77.2\%)}    \tabularnewline
# \hline
# 			non-collinearity    & \textcolor{orange}{569}    & \textcolor{red}{736}    & \textcolor{teal}{2599}    & \textcolor{blue}{917}    & \textcolor{teal}{66.6\%}(\textcolor{blue}{23.5\%)}    & \textcolor{teal}{68.1\%}(\textcolor{blue}{74.3\%)}    \tabularnewline
# \hline
# 			$\Delta Q$    & \textcolor{orange}{352}    & \textcolor{red}{418}    & \textcolor{teal}{1724}    & \textcolor{blue}{755}    & \textcolor{teal}{69.1\%}(\textcolor{blue}{30.3\%)}    & \textcolor{teal}{45.2\%}(\textcolor{blue}{61.2\%)}    \tabularnewline
# \hline
# 			\CutDeltaPhi    & \textcolor{orange}{207}    & \textcolor{red}{134}    & \textcolor{teal}{1126}    & \textcolor{blue}{662}    & \textcolor{teal}{76.8\%}(\textcolor{blue}{45.1\%)}    & \textcolor{teal}{29.5\%}(\textcolor{blue}{53.6\%)}    \tabularnewline
# \hline

# %% [markdown]
# ## 5.II The impact of the cuts on the $Q^2$ -dependence of the sample

# %%
# Q2 before and after the cuts
bins = np.linspace(0.,2,41)
cuts   = ['no cut','vertex $\Delta Q$', '$|\Delta \phi - \pi|<40^{0}$' , '$p_{t}<0.15$' ]                                
labels = ['No selection cuts','with detection cuts','detection cuts and $\\Delta \\phi$', 'additional cut on $p_{t}<0.15$ GeV/c']
colors = ['tomato','royalblue','teal','Orchid']

fig,ax=plt.subplots(figsize=(16,8))
for cut_name,label,color in zip(cuts,labels,colors):
    sample = reduced_MCsamples[cut_name]['1mu-1p']
    truth_Q2 = sample['truth_Q2']
    h,bins,_=plt.hist( truth_Q2 , bins=bins, histtype='step',linewidth=3,normed=1,color=color);
    plt.plot([0,0],'-',color=color,label=label,linewidth=3)
set_axes(ax,'$Q^{2}_{gen.}$ (GeV/c)$^2$',ticks_color='black',fontsize=45,do_add_grid=True)
ax.legend(loc='upper right',fontsize=25)
ax.yaxis.set_major_formatter(ticker.NullFormatter())
plt.tight_layout()
fig.savefig(figures_path+'Q2_truth_before_after_cuts.pdf')

# %%
# reconstructed Q2 before and after the cuts
bins = np.linspace(-0.5,1.2,60)
fig_reco=plt.figure(figsize=(16,8))
ax_reco = fig_reco.add_subplot(111)
for cut_name,label,color in zip(cuts,labels,colors):
    sample = reduced_MCsamples[cut_name]['1mu-1p']
    truth_Q2 = sample['closest_genie_Q2']
    reco_Q2 = sample['reco_Q2']
    dQ2 = truth_Q2 - reco_Q2
    h,bins,_=plt.hist( dQ2 , bins=bins, histtype='step',linewidth=3,normed=1,color=color);
    plt.plot([0,0],'-',color=color,label=label,linewidth=3)
ax_reco.plot([0,0],ax_reco.get_ylim(),'--',color='black')
set_axes(ax_reco,'$Q^{2}_{gen.} - Q^{2}_{rec.}$ (GeV/c)$^2$',ticks_color='black',fontsize=45,do_add_grid=True)
ax_reco.legend(loc='upper right',fontsize=25)
ax_reco.yaxis.set_major_formatter(ticker.NullFormatter())
plt.tight_layout()
fig_reco.savefig(figures_path+'Q2_reco_before_after_cuts.pdf')

# %%
# reconstructed Q2 before and after the cuts
bins = np.linspace(-100,100,60)
fig_reco=plt.figure(figsize=(16,8))
ax_reco = fig_reco.add_subplot(111)
for cut_name,label,color in zip(cuts,labels,colors):
    sample = reduced_MCsamples[cut_name]['1mu-1p']
    truth_Q2 = sample['truth_Q2']
    reco_Q2 = sample['reco_Q2']
    dQ2 = truth_Q2 - reco_Q2
    ratio = 100*dQ2/[Q2 if Q2>0.01 else 0.01 for Q2 in truth_Q2]
    h,bins,_=plt.hist( ratio , bins=bins, histtype='step',linewidth=3,normed=1,color=color);
    plt.plot([0,0],'-',color=color,label=label,linewidth=3)
ax_reco.plot([0,0],ax_reco.get_ylim(),'--',color='black')
set_axes(ax_reco,'$(Q^{2}_{gen.} - Q^{2}_{rec.})/Q^{2}_{gen.}$ [%]',ticks_color='black',fontsize=45,do_add_grid=True)
ax_reco.legend(loc='upper left',fontsize=25)
ax_reco.yaxis.set_major_formatter(ticker.NullFormatter())
plt.tight_layout()
fig_reco.savefig(figures_path+'Q2_reco_ratio_before_after_cuts.pdf')
