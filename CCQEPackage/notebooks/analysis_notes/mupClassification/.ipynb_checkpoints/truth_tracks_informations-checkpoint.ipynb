# %%
import sys; sys.path.insert(0, '../../'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
# %matplotlib inline

# %% [markdown]
# # truth informations on tracks in which we are interested
# Oct-11, 2017

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/mupClassification/Figures/truth_tracks_information/'

# %% [markdown]
# # pairs of tracks at close proximity

# %%
tracks_MCbnbDATAcosmic = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/tracks/prodgenie_bnb_nu_uboone_overlay_mcc8_reco2_tracks.csv')
print len(tracks_MCbnbDATAcosmic),'tracks'
tracks_MCbnbMCcosmic = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/tracks/prodgenie_bnb_nu_cosmic_uboone_mcc8.2_reco2_tracks.csv')
print len(tracks_MCbnbMCcosmic),'tracks'
# Out:
# 502227 tracks
# 22244 tracks

# %% [markdown]
# # $PID_a$ of $\mu,p,\pi,K$?

# %%
sam = tracks_MCbnbDATAcosmic
# sam = tracks_MCbnbMCcosmic
pions = sam[(sam['pdg']==211) | (sam['pdg']==-211)]
print 'len(pions):',len(pions)
protons = sam[sam['pdg']==2212]
print 'len(protons):',len(protons)
muons = sam[(sam['pdg']==13) | (sam['pdg']==-13)]
print 'len(muons):',len(muons)
Kaons = sam[(sam['pdg']==130) | (sam['pdg']==310) | (sam['pdg']==311) | (sam['pdg']==321)| (sam['pdg']==-321)]
print 'len(Kaons):',len(Kaons)
cosmic = sam[sam['pdg']==-9999]
print 'len(cosmic):',len(cosmic)
deuterons = sam[sam['pdg']==1000010020]
print 'len(deuterons):',len(deuterons)
alphas = sam[sam['pdg']==1000020040]
print 'len(alphas):',len(alphas)
Ar40 = sam[sam['pdg']==1000180400]
print 'len(Ar40):',len(Ar40)
electrons = sam[(sam['pdg']==11)|(sam['pdg']==-11)]
print 'len(electrons):',len(electrons)
empty = sam[sam['pdg']==-101010101]
print 'len(empty):',len(empty)
# Out:
# len(pions): 4733
# len(protons): 19198
# len(muons): 42301
# len(Kaons): 31
# len(cosmic): 410317
# len(deuterons): 50
# len(alphas): 56
# len(Ar40): 1429
# len(electrons): 23282
# len(empty): 0

# %%
fig,ax=plt.subplots(figsize=(12,8))
for particle,name,color in zip([muons,pions,protons,empty,cosmic]
                               ,[r'$\mu^{\pm}$ simulation',r'$\pi^{\pm}$ simulation',r'$p$ simulation','',r'cosmic data'] #,r'$e^{\pm}$'
                               ,['black','red','blue','black','purple']):
    PIDa = particle[particle['PIDa']<100]['PIDa']
    plt.hist(PIDa,bins=np.linspace(0,30,100),normed=1,histtype='step',linewidth=3,color=color)
    mean = np.mean(PIDa)
    std = np.std(PIDa)
    label=name+', mean=%.1f'%(mean) if name is not '' else ' '
    plt.plot([0,0],[0,0],label=label,linewidth=3,color=color)
set_axes(ax,r'$PID_a$','counts [a.u.]',do_add_legend=True)
plt.savefig('/Users/erezcohen/Desktop/Projects/uBoone/write-ups/mupClassification/Figures/PIDa/PIDaOfTruthParticles.pdf')

fig,ax=plt.subplots(figsize=(12,8))
for particle,name,color in zip([Kaons,deuterons,alphas,Ar40]
                               ,[r'$K^{\pm}$',r'deuteron',r'$\alpha$',r'$^{40}$Ar']
                               ,['green','orange','blue','black']):
    PIDa = particle[particle['PIDa']<100]['PIDa']
    plt.hist(PIDa,bins=np.linspace(0,50,100),normed=1,histtype='step',linewidth=3,color=color)
    mean = np.mean(PIDa)
    std = np.std(PIDa)
    plt.plot([0,0],[0,0],label=name+', mean=%.1f'%(mean),linewidth=3,color=color)
set_axes(ax,r'$PID_a$','counts [a.u.]',do_add_legend=True)
plt.savefig('/Users/erezcohen/Desktop/Projects/uBoone/write-ups/mupClassification/Figures/PIDa/PIDaOfTruthParticles_FewStatistics.pdf')

# %%
# fig,ax=plt.subplots(figsize=(12,8))
pdg = tracks_MCbnbDATAcosmic[tracks_MCbnbDATAcosmic['pdg']>1e9]['pdg']
pdg.groupby()
# plt.hist(pdg,bins=100);
# ax.set_yscale('log')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-7301a80c6aac> in <module>()
#       1 # fig,ax=plt.subplots(figsize=(12,8))
#       2 pdg = tracks_MCbnbDATAcosmic[tracks_MCbnbDATAcosmic['pdg']>1e9]['pdg']
# ----> 3 pdg.groupby()
#       4 # plt.hist(pdg,bins=100);
#       5 # ax.set_yscale('log')
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3772
#    3773         if level is None and by is None:
# -> 3774             raise TypeError("You have to supply one of 'by' and 'level'")
#    3775         axis = self._get_axis_number(axis)
#    3776         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
pdg_groups = tracks_MCbnbDATAcosmic.groupby('pdg')
pdg_groups

# %%
pdg_groups.first()
# Out:
#              run  subrun   event  track_id    start_x    start_y    start_z  \
# pdg
# -9999          1    2756  137751         2  186.18100 -115.26800   272.5550
# -321           1    2644  132176         1  175.23800  -68.53910   758.5700
# -211           1    2763  138125         1  236.02900  -78.39830   640.1740
# -13            1    2762  138097         3  228.48500   -7.09467   911.3980
# -11            1    2758  137885         1   10.25370  -66.09910   871.1920
#  11            1    2756  137751         0  230.15800  117.02300   432.7780
#  13            1    2756  137759         1   80.70130   88.50270   323.6420
#  22            1    2756  137794         0    5.32405  -62.53940   419.1630
#  211           1    2756  137775         7  126.84500  107.53700   601.8000
#  321           1    2844  142180         5  219.17800  -78.14490  1010.1600
#  2212          1    2756  137767         3  159.80900   76.73700   141.5570
#  1000010020    1    2756  137754         1  217.57700   59.23240   516.8040
#  1000010030    1    2652  132599         1  194.04700  -23.18040   641.9290
#  1000020030    1    3763  188150        11  213.10400  103.31400   903.2560
#  1000020040    1    2772  138593         1   97.90770   96.87170   878.7740
#  1000120240    1    2164  108195         3  114.00400  -52.98830   564.2820
#  1000160320    1    3683  184139         1  138.05500   36.57520   696.3200
#  1000160340    1    3792  189556         0   91.07360   43.70150   739.3640
#  1000170350    1    2808  140381         1  124.97200  106.49300    85.3847
#  1000170360    1    2254  112676         3  138.24900   84.15900   780.4090
#  1000170370    1    2666  133287        10  141.84600  -38.96340   499.0350
#  1000180360    1    2756  137751         1   45.16700   12.72530   417.8500
#  1000180370    1    2798  139883         1  104.82700   83.11320   576.9820
#  1000180380    1    2774  138660         3  217.95200  -52.15060   285.0050
#  1000180390    1    2777  138801         0  102.91600   56.75380   630.4990
#  1000180400    1    2763  138102         0  183.20500 -114.90600   502.8830
#
#                 end_x     end_y     end_z      PIDa     length          origin
# pdg
# -9999        137.1300  -23.6025   335.465   6.50012  121.54500  unknown origin
# -321         143.4300  -66.7993   831.661  23.01100   79.86760   beam neutrino
# -211         198.8340 -102.5190   771.810  19.64220  139.19400   beam neutrino
# -13          255.7260   21.8458   927.177   5.79272   42.77080   beam neutrino
# -11          183.4340  112.5830   907.639   6.11641  251.67800   beam neutrino
#  11          156.0440  -80.8193   551.110   5.52710  242.75700   beam neutrino
#  13           64.4339  115.7320   521.590   5.19986  204.98400   beam neutrino
#  22          109.8110  115.7030   530.361   5.03873  235.15900   beam neutrino
#  211         112.1140  112.1180   604.405   7.35422   15.65430   beam neutrino
#  321         219.1810  -77.0253  1008.560   2.36840    1.95564   beam neutrino
#  2212        165.2970   67.3575   182.674  11.04730   42.57420   beam neutrino
#  1000010020  212.7700  105.0250   573.679   1.36062   80.28820   beam neutrino
#  1000010030  136.4640  108.8230   614.157   4.35236  146.70300   beam neutrino
#  1000020030  213.7810  104.2750   904.988  18.84310    2.09334   beam neutrino
#  1000020040   74.3547  -92.2336   914.279   5.14146  193.98100   beam neutrino
#  1000120240  217.7630   58.4364   571.013   5.89450  152.92500   beam neutrino
#  1000160320  107.1320  108.5870   679.331   8.00327   80.19490   beam neutrino
#  1000160340   61.8262  -96.5127   925.423   3.51919  326.97600   beam neutrino
#  1000170350  141.8560 -100.6030   118.611   5.24225  211.56800   beam neutrino
#  1000170360  160.2390 -115.1100   694.563   5.21030  218.24100   beam neutrino
#  1000170370  135.0650  -33.8021   486.310   3.83756   15.31820   beam neutrino
#  1000180360   52.0650 -107.0080   650.375   4.64151  262.33800   beam neutrino
#  1000180370   74.7877  -93.9103   616.156   9.22410  187.24000   beam neutrino
#  1000180380  153.9540 -104.5100   289.874   3.12208   82.83560   beam neutrino
#  1000180390  178.6980  -67.0294   487.835   7.54757  204.30400   beam neutrino
#  1000180400   91.4088   88.3288   628.422   7.41369  255.96500   beam neutrino
