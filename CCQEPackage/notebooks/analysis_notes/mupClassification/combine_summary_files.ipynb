# %%
import sys; sys.path.insert(0, '../../'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
# %matplotlib inline

# %% [markdown]
# # combine summary files

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/mupClassification/Figures/'

# %%
summary = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/ccqe_candidates/ccqe_ana_MCBNBCosmicDATA_2018_01_28_summary.csv')

# %%
Nfiles_tot = len(summary)
print Nfiles_tot,'files in total'

POT_tot = np.sum(summary.POT)
print POT_tot,'POT in total'

Nevents_tot = np.sum(summary.Nevents)
print Nevents_tot,'events in total'
# Out:
# 136 files in total
# 7.5107006e+18 POT in total
# 6816 events in total

# %%
fig=plt.figure(figsize=(14,8))
ax=fig.add_subplot(2,2,1)
plt.hist(summary.Nvertices);
set_axes(ax,'N(vertices)',xticks=[10,15,20])

ax=fig.add_subplot(2,2,2)
plt.hist(summary.Nevents);
set_axes(ax,'N(events)')

ax=fig.add_subplot(2,2,3)
plt.hist(summary.POT);
set_axes(ax,'N(POT)')

plt.tight_layout()
