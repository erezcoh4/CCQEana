# %%
import sys; sys.path.insert(0, '../../'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
# %matplotlib inline

# %% [markdown]
# # combine summary files

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/mupClassification/Figures/'

# %%
summary = pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/summary/ecohen_physical_files_adi_prodgenie_bnb_nu_uboone_overlay_cosmic_data_100K_reco2_2018_02_23_summary.csv')

# %%
Nfiles_tot = len(summary)
print Nfiles_tot,'files in total'

POT_tot = np.sum(summary.POT)
print POT_tot,'POT in total'

Nevents_tot = np.sum(summary[(summary['Nevents']>0)&(summary['Nevents']<100000)]['Nevents'])
print Nevents_tot,'events in total'
# Out:
# 185 files in total
# 9.59913295e+19 POT in total
# 91446 events in total

# %%
fig=plt.figure(figsize=(14,8))
ax=fig.add_subplot(2,2,1)
plt.hist(summary.Nvertices);
set_axes(ax,'N(vertices)')

ax=fig.add_subplot(2,2,2)
plt.hist(summary[(summary['Nevents']>0)&(summary['Nevents']<100000)]['Nevents']);
set_axes(ax,'N(events)')

ax=fig.add_subplot(2,2,3)
plt.hist(summary.POT);
set_axes(ax,'N(POT)')

plt.tight_layout()

# %%
summaryBeamOn = pd.concat([pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/summary/prod_reco_optfilter_bnb_v11_unblind_mcc8_v04_2018_03_04_summary.csv')
                           ,pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/summary/prod_reco_optfilter_bnb_v11_unblind_mcc8_v05_2018_02_12_summary.csv')])

# %%
Nfiles_tot = len(summaryBeamOn)
print Nfiles_tot,'files in total'
Nevents_tot = np.sum(summaryBeamOn[(summaryBeamOn['Nevents']>0)&(summaryBeamOn['Nevents']<100000)]['Nevents'])
print Nevents_tot,'events in total'
# the POTs can not be counted directly from the files, since the SwT may not always fire on the first event
# and the stored POT is always underestimated the total POT
# Out:
# 403 files in total
# 191185 events in total

# %%
summaryBeamOff = pd.concat([pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/summary/prod_reco_optfilter_extbnb_v11_mcc8_dev_v04_2018_02_27_summary.csv')
                           ,pd.read_csv('/Users/erezcohen/Desktop/uBoone/CCQEanalysis/csvFiles/summary/prod_reco_optfilter_extbnb_v11_mcc8_dev_v05_2018_02_27_summary.csv')])

# %%
Nfiles_tot = len(summaryBeamOff)
print Nfiles_tot,'files in total'
Nevents_tot = np.sum(summaryBeamOff[(summaryBeamOff['Nevents']>0)&(summaryBeamOff['Nevents']<100000)]['Nevents'])
print Nevents_tot,'events in total'
# Out:
# 444 files in total
# 200898 events in total
