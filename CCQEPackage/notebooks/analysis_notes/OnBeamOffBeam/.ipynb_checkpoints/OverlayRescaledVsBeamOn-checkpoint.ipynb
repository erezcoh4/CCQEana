# %% [markdown]
# # compare OnBeam BNB data to MC-BNB/DATA cosmic overlay
# This is done by fixing two factors:
# 1. area-normalizing the overlay to match the OnBeam data
# 2. reweighting the cosmic in the overlay, to match the OnBeam in the preselection stage
#
# and then studying what happens to the OnBeam/overlay comparison after all cuts

# %%
import sys; sys.path.insert(0, '../../'); 
from ccqe_notebook_tools import * 
from mupClassification_notebooks import *
from onbeam_offbeam_notebooks import *
# %matplotlib inline
# Out:
# versions:
# {   'OffBeam': 'prod_reco_optfilter_extbnb_v12_mcc8_dev',
#     'OnBeam': 'prod_reco_optfilter_bnb_v12_unblind_mcc8',
#     'Overlay': 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2',
#     'data date': '2018_05_11',
#     'date': '2018_05_11',
#     'overlay date': '2018_05_11'}
# OffBeam_scaling: 0.706302660161 = N(on beam)/N(off beam) before SwT
# f(POT): 0.0512441465374 = N(POT on beam)/N(POT MC)

# %%
figures_path = '/Users/erezcohen/Desktop/Projects/uBoone/write-ups/OnBeamOffBeam5e19/Figures/overlay_rescaled_vs_BeamOn/'

# %%
versions['data date'] = '2018_05_11'
versions['overlay date'] = '2018_05_11'
versions['Overlay'] = 'prodgenie_bnb_nu_uboone_overlay_mcc8.11_reco2'

# %%
OnBeam = pd.concat([pd.read_csv(vertices_files_path+'/'+versions['data date']+'/'+versions['OnBeam']+'_04_'+versions['data date']+'_vertices.csv')
                    ,pd.read_csv(vertices_files_path+'/'+versions['data date']+'/'+versions['OnBeam']+'_05_'+versions['data date']+'_vertices.csv')])
OnBeamFV = sample_in_FV(OnBeam)
print "%d"%len(OnBeam)+' pairs from On-Beam, %d'%len(OnBeamFV)+' in Fiducial Volume'

OverlayPairsFV, OverlaySamples = load_MCbnbDATAcosmicSamples(date=versions['overlay date'],filename=versions['Overlay']+'_'+versions['overlay date']+'_vertices')
print "%d"%len(OverlaySamples['cosmic'])+' cosmic pairs and %d'%len(OverlaySamples['1mu-1p'])+' mu-p pairs in overlay'
# Out:
# 38163 pairs from On-Beam, 24323 in Fiducial Volume
# 283762 pairs from MC-BNB + cosmic DATA overlay
# 186485 pairs in FV
# 49707 are 1mu-1p, 26.7%
# 41519 are other pairs, 22.3%
# 95259 are cosmic, 51.1%
# --------------------------------------------------------------
# 23996 are CC 1p 0pi, 12.9%
# 95259 cosmic pairs and 49707 mu-p pairs in overlay

# %%
cuts_order  = ['no cut'
               ,'Chi2Proton'               
               ,'MatchedFlash'               
               ,'length'
               ,'non-collinearity'               
               ,'vertex activity'               
               ,'delta phi'               
               ,'Pt no delta phi'               
               ,'Pt & delta phi'
              ]


cutlabels = ['preselection'
             ,'$dE/dx$ profile'
             ,'optical filter'
             ,'track lengths'
             ,'collinearity'
             ,'vertex activity'
             ,'coplanarity'
             ,'$p_t$ imbalance'
             ,r'$\Delta \phi $ \&  $p_{t}$'
            ]

reducedOverlay,pureffOverlay,pureffNumbers = apply_cuts_to_overlay(OverlaySamples=OverlaySamples, cuts_order=cuts_order)
pureffOverlay
# Out:
#                  $\mu p$ eff. $\mu p$ pur. CC$0\pi 1 p$ eff.  \
# no cut                 100.0%        26.7%            100.0%
# Chi2Proton              63.1%        70.7%             68.7%
# MatchedFlash            51.6%        78.1%             56.3%
# length                  47.2%        83.5%             52.5%
# non-collinearity        43.1%        87.4%             49.7%
# vertex activity         31.0%        89.1%             44.2%
# delta phi               20.6%        95.3%             33.7%
# Pt no delta phi         23.3%        92.4%             36.0%
# Pt & delta phi          18.2%        96.3%             30.4%
#
#                  CC$0\pi 1 p$ pur.             label          1mu-1p  \
# no cut                       12.9%            no cut  100.0% (49707)
# Chi2Proton                   37.1%        Chi2Proton   63.1% (31389)
# MatchedFlash                 41.2%      MatchedFlash   51.6% (25634)
# length                       44.8%            length   47.2% (23459)
# non-collinearity             48.7%  non-collinearity   43.1% (21412)
# vertex activity              61.5%   vertex activity   31.0% (15391)
# delta phi                    75.2%         delta phi   20.6% (10241)
# Pt no delta phi              69.0%   Pt no delta phi   23.3% (11582)
# Pt & delta phi               77.8%    Pt & delta phi    18.2% (9035)
#
#                      other pairs          cosmic       CC 1p 0pi
# no cut            100.0% (41519)  100.0% (95259)  100.0% (23996)
# Chi2Proton          19.3% (8021)     5.2% (5001)   68.7% (16481)
# MatchedFlash        13.2% (5491)     1.8% (1688)   56.3% (13510)
# length               7.9% (3281)     1.4% (1369)   52.5% (12600)
# non-collinearity     5.8% (2409)      0.7% (673)   49.7% (11926)
# vertex activity      3.7% (1538)      0.4% (346)   44.2% (10616)
# delta phi             0.9% (382)      0.1% (118)    33.7% (8080)
# Pt no delta phi       1.8% (767)      0.2% (185)    36.0% (8646)
# Pt & delta phi        0.7% (270)       0.1% (79)    30.4% (7304)

# %%
reducedOnBeam,_ = apply_cuts_to_data(OnBeamFV=OnBeamFV,cuts_order=cuts_order)
print 'done applying cuts to data'
# Out:
# done applying cuts to data

# %% [markdown]
# ## 2.II Changing the cosmic to beam ratio in overlay

# %% [markdown]
# ### collinearity as a test observable for cosmic rescaling

# %%
var='theta_12'
x_label=r'$\theta_{1,2}$ angle between the two tracks [deg.]'
bins=np.linspace(0,180,81)

# %%
ax=plot_feature_pairs(var=var,x_label=x_label,reduced_samples=reducedOverlay['no cut']
                              ,bins=bins,do_add_legend=True
                              ,figsize=(12,8),fontsize=35,legend_loc='upper center',legend_fontsize=25)
plt.savefig(figures_path+'theta_12_overlay_no_cut.pdf')

# %% [markdown]
# # overlay subsamples-scaling

# %%
overlay_scalings = dict()
overlay_scalings['N(On) scaling'] = get_samples_scaling( N_total= float(len(OnBeamFV)) # total integral of all overlay                                                                              
                                                        , f_Cosmic=None  # fraction of cosmic in the overlay, need to be in the range 0-1
                                                        , OverlaySubsamples=reducedOverlay['no cut'])

# %%
fig,ax=plt.subplots(figsize=(12,8))
plot_stacked_MCsamples( reducedOverlay=reducedOverlay,cut_name='no cut'
                       , overlay_scaling=overlay_scalings['N(On) scaling']
                       , ax=ax, var=var, x_label=x_label,y_label='counts', bins=bins 
                       , fontsize=25                       
                       , do_add_legend=True, stackColor='black',stackLabel='overlay'
                      );
plt.savefig(figures_path+'theta_12_overlay_stacked.pdf')

# %% [markdown]
# # and after choosing the optimal $f_{cosmic}$

# %%
f_Cosmic=0.866
overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic] = get_samples_scaling( N_total= float(len(OnBeamFV)) # total integral of all overlay                                                                        
                                                                                    , f_Cosmic=f_Cosmic  # fraction of cosmic in the overlay, need to be in the range 0-1
                                                                                    , OverlaySubsamples=reducedOverlay['no cut'])
print 'overlay scalings';pp.pprint(overlay_scalings)
# Out:
# overlay scalings
# {   'N(On) scaling': {   '1mu-1p': 0.13042872080864412,
#                          'CC 1p 0pi': 0.13042872080864415,
#                          'N(Ovelay)/N(On)': 7.667022982362373,
#                          'cosmic': 0.13042872080864412,
#                          'other pairs': 0.13042872080864415},
#     'N(On) scaling and f(cosmic)=0.866': {   '1mu-1p': 0.035727555740687963,
#                                              'CC 1p 0pi': 0.035727555740687963,
#                                              'N(Ovelay)/N(On)': 7.667022982362373,
#                                              'cosmic': 0.2211205030495806,
#                                              'other pairs': 0.035727555740687963}}

# %%
fig,ax=plt.subplots(figsize=(12,8))
h_stack,_=plot_stacked_MCsamples( reducedOverlay=reducedOverlay,cut_name='no cut'
                       , overlay_scaling=overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic]
                       , ax=ax, var=var, x_label=x_label,y_label='counts', bins=bins 
                       , fontsize=25                       
                       , stackColor='black',stackLabel='overlay'
                      );
_,h_OnBeam = plot_OnBeam(OnBeamSample=reducedOnBeam['no cut'],OnBeamFV=reducedOnBeam['no cut'],markersize=8
                                 ,color='purple',x_label=x_label, var=var, bins=bins, ax=ax)
chi2 , ndf = chi2_two_histograms( bins=bins, chi2_xrange=(np.min(bins),np.max(bins))
                                     , h1=h_OnBeam , h2=h_stack
                                     , h1err=np.sqrt(h_OnBeam), h2err=np.sqrt(h_stack)
                                     , debug=0 )
chi2_txt = r'$\chi^2/ndf=%.1f/%d$'%(chi2,ndf)
ax.set_title(chi2_txt,y=1.02,fontsize=25)
ax.legend(fontsize=25)
plt.tight_layout()
plt.savefig(figures_path+'theta_12_overlay_cosmicRescaled_with_BeamOn.pdf')

# %% [markdown]
# # now lets plot all observables before and after the cuts

# %%
df_chi2_ndf = pd.DataFrame(columns={'var','$\chi^2$','ndf','$\chi^2_{shape}$'})

# %% [markdown]
# ## $\chi^2_{proton-hypothesis}$

# %%
cuts_order  = ['no cut'
               ,'MatchedFlash'               
               ,'length'
               ,'non-collinearity'               
               ,'vertex activity'               
               ,'delta phi'               
               ,'Pt & delta phi'
              ]
reducedOverlay,pureffOverlay,pureffNumbers = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
reducedOnBeam,_ = apply_cuts_to_data(OnBeamFV=OnBeamFV,cuts_order=cuts_order)
print 'done applying cuts to data'
# Out:
# done applying cuts to overlay
# done applying cuts to data

# %%
var='pidcali_Chi2ProtonYplane_muCandidate'
_,_,chi2_res=plot_before_after_cuts(var=var
                       ,x_label=r'$(\chi^2_{proton})^{\mu-candidate}$',y_label=''
                       ,bins_before_cuts=linspace(-1,350,51)
                       ,last_cut_name='Pt & delta phi'
                       ,bins_after_cuts=linspace(-1,350,45)
                       ,overlay_scaling=overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic]                    
                       ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
                       ,chi2_xrange=(-1,350),debug=0,x_varcut=(80,80),do_area_normalized_after_cuts=True
                   );
print 'chi2_res:',chi2_res
plt.savefig(figures_path+'Chi2Proton_muCandidate_before_after_cuts.pdf')
df_chi2_ndf = df_chi2_ndf.append(pd.DataFrame({'var':var,'$\chi^2$':chi2_res['chi2 after cuts'],'ndf':chi2_res['ndf after cuts'],'$\chi^2_{shape}$':chi2_res['chi2(shape) after cuts']}
                                              ,index=['\ChiSqrP\ for the muon candidate']))
# Out:
# chi2_res: {'chi2(shape) after cuts': 55.777738540485906, 'chi2 after cuts': 54.676052630485422, 'ndf after cuts': 43}

# %%
var='pidcali_Chi2ProtonYplane_pCandidate'
_,_,chi2_res=plot_before_after_cuts(var=var
                       ,x_label=r'$(\chi^2_{proton})^{p-candidate}$',y_label=''
                       ,bins_before_cuts=linspace(-1,350,51)
                       ,last_cut_name='Pt & delta phi'
                       ,bins_after_cuts=linspace(0,200,21)
                       ,overlay_scaling=overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic]                    
                       ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
                       ,xlim_before_cuts=(-1,350)
                       ,xlim_after_cuts=(-1,200)
                       ,chi2_xrange=(-1,350),debug=0,x_varcut=(30,30),dx=10
                                    ,do_area_normalized_after_cuts=True
                   );
plt.savefig(figures_path+'Chi2Proton_pCandidate_before_after_cuts.pdf')
df_chi2_ndf = df_chi2_ndf.append(pd.DataFrame({'var':var,'$\chi^2$':chi2_res['chi2 after cuts'],'ndf':chi2_res['ndf after cuts'],'$\chi^2_{shape}$':chi2_res['chi2(shape) after cuts']}
                                              ,index=['\ChiSqrP\ for the proton candidate']))
print 'chi2_res:',chi2_res
# Out:
# chi2_res: {'chi2(shape) after cuts': 43.487862361185151, 'chi2 after cuts': 42.983862268552386, 'ndf after cuts': 19}

# %% [markdown]
# ## collinearity

# %%
cuts_order  = ['no cut'
               ,'Chi2Proton'               
               ,'MatchedFlash'               
               ,'length'
               ,'vertex activity'               
               ,'delta phi'               
               ,'Pt & delta phi'
              ]
reducedOverlay,pureffOverlay,pureffNumbers = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
reducedOnBeam,_ = apply_cuts_to_data(OnBeamFV=OnBeamFV,cuts_order=cuts_order)
print 'done applying cuts to data'
# Out:
# done applying cuts to overlay
# done applying cuts to data

# %%
var='theta_12'
_,_,chi2_res=plot_before_after_cuts(var=var,x_label= r'$\theta_{1,2}$ [deg.]',y_label=''
                       ,bins_before_cuts=linspace(0,180,81)
                       ,last_cut_name='Pt & delta phi'
                       ,bins_after_cuts=linspace(0,180,35)
                       ,overlay_scaling=overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic]                    
                       ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
                       ,chi2_xrange=(0,180),debug=2,x_varcut=(35,145),dx=15
                   );
plt.savefig(figures_path+'theta_12_before_after_cuts.pdf')
df_chi2_ndf = df_chi2_ndf.append(pd.DataFrame({'var':var,'$\chi^2$':chi2_res['chi2 after cuts'],'ndf':chi2_res['ndf after cuts'],'$\chi^2_{shape}$':chi2_res['chi2(shape) after cuts']}
                                              ,index=['$\\theta_{1,2}$']))
# Out:
# preselection : sum of h_OnBeam: 24323 ,sum of h_stack: 24323.0
# comparing in bin: 0.0 h1: 0.0+/-0.0, h2: 0.1+/-0.4
# num = 0.0 den = 1.0
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 5.29411764706 h1: 1.0+/-1.0, h2: 0.4+/-0.6
# num = 0.4 den = 1.4
# chi2 this bin: num/den = 0.3
# chi2 : 0.3
# comparing in bin: 10.5882352941 h1: 0.0+/-0.0, h2: 0.5+/-0.7
# num = 0.3 den = 1.0
# chi2 this bin: num/den = 0.3
# chi2 : 0.3
# comparing in bin: 15.8823529412 h1: 0.0+/-0.0, h2: 0.4+/-0.6
# num = 0.2 den = 1.0
# chi2 this bin: num/den = 0.2
# chi2 : 0.2
# comparing in bin: 21.1764705882 h1: 1.0+/-1.0, h2: 0.6+/-0.8
# num = 0.2 den = 1.6
# chi2 this bin: num/den = 0.1
# chi2 : 0.1
# comparing in bin: 26.4705882353 h1: 0.0+/-0.0, h2: 0.8+/-0.9
# num = 0.6 den = 1.0
# chi2 this bin: num/den = 0.6
# chi2 : 0.6
# comparing in bin: 31.7647058824 h1: 1.0+/-1.0, h2: 1.4+/-1.2
# num = 0.2 den = 2.4
# chi2 this bin: num/den = 0.1
# chi2 : 0.1
# comparing in bin: 37.0588235294 h1: 2.0+/-1.4, h2: 2.3+/-1.5
# num = 0.1 den = 4.3
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 42.3529411765 h1: 2.0+/-1.4, h2: 3.5+/-1.9
# num = 2.2 den = 5.5
# chi2 this bin: num/den = 0.4
# chi2 : 0.4
# comparing in bin: 47.6470588235 h1: 5.0+/-2.2, h2: 5.1+/-2.3
# num = 0.0 den = 10.1
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 52.9411764706 h1: 5.0+/-2.2, h2: 6.6+/-2.6
# num = 2.6 den = 11.6
# chi2 this bin: num/den = 0.2
# chi2 : 0.2
# comparing in bin: 58.2352941176 h1: 8.0+/-2.8, h2: 9.3+/-3.1
# num = 1.8 den = 17.3
# chi2 this bin: num/den = 0.1
# chi2 : 0.1
# comparing in bin: 63.5294117647 h1: 5.0+/-2.2, h2: 15.1+/-3.9
# num = 101.7 den = 20.1
# chi2 this bin: num/den = 5.1
# chi2 : 5.1
# comparing in bin: 68.8235294118 h1: 12.0+/-3.5, h2: 21.6+/-4.6
# num = 91.3 den = 33.6
# chi2 this bin: num/den = 2.7
# chi2 : 2.7
# comparing in bin: 74.1176470588 h1: 18.0+/-4.2, h2: 27.4+/-5.2
# num = 88.3 den = 45.4
# chi2 this bin: num/den = 1.9
# chi2 : 1.9
# comparing in bin: 79.4117647059 h1: 20.0+/-4.5, h2: 32.4+/-5.7
# num = 153.3 den = 52.4
# chi2 this bin: num/den = 2.9
# chi2 : 2.9
# comparing in bin: 84.7058823529 h1: 33.0+/-5.7, h2: 36.7+/-6.1
# num = 13.5 den = 69.7
# chi2 this bin: num/den = 0.2
# chi2 : 0.2
# comparing in bin: 90.0 h1: 32.0+/-5.7, h2: 33.2+/-5.8
# num = 1.5 den = 65.2
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 95.2941176471 h1: 36.0+/-6.0, h2: 31.0+/-5.6
# num = 25.0 den = 67.0
# chi2 this bin: num/den = 0.4
# chi2 : 0.4
# comparing in bin: 100.588235294 h1: 35.0+/-5.9, h2: 26.2+/-5.1
# num = 76.8 den = 61.2
# chi2 this bin: num/den = 1.3
# chi2 : 1.3
# comparing in bin: 105.882352941 h1: 29.0+/-5.4, h2: 22.1+/-4.7
# num = 47.4 den = 51.1
# chi2 this bin: num/den = 0.9
# chi2 : 0.9
# comparing in bin: 111.176470588 h1: 26.0+/-5.1, h2: 17.7+/-4.2
# num = 68.2 den = 43.7
# chi2 this bin: num/den = 1.6
# chi2 : 1.6
# comparing in bin: 116.470588235 h1: 16.0+/-4.0, h2: 16.1+/-4.0
# num = 0.0 den = 32.1
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 121.764705882 h1: 15.0+/-3.9, h2: 12.3+/-3.5
# num = 7.1 den = 27.3
# chi2 this bin: num/den = 0.3
# chi2 : 0.3
# comparing in bin: 127.058823529 h1: 17.0+/-4.1, h2: 10.1+/-3.2
# num = 47.3 den = 27.1
# chi2 this bin: num/den = 1.7
# chi2 : 1.7
# comparing in bin: 132.352941176 h1: 14.0+/-3.7, h2: 10.0+/-3.2
# num = 15.7 den = 24.0
# chi2 this bin: num/den = 0.7
# chi2 : 0.7
# comparing in bin: 137.647058824 h1: 13.0+/-3.6, h2: 7.8+/-2.8
# num = 27.2 den = 20.8
# chi2 this bin: num/den = 1.3
# chi2 : 1.3
# comparing in bin: 142.941176471 h1: 10.0+/-3.2, h2: 7.3+/-2.7
# num = 7.3 den = 17.3
# chi2 this bin: num/den = 0.4
# chi2 : 0.4
# comparing in bin: 148.235294118 h1: 7.0+/-2.6, h2: 9.0+/-3.0
# num = 3.8 den = 16.0
# chi2 this bin: num/den = 0.2
# chi2 : 0.2
# comparing in bin: 153.529411765 h1: 8.0+/-2.8, h2: 7.7+/-2.8
# num = 0.1 den = 15.7
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 158.823529412 h1: 9.0+/-3.0, h2: 5.7+/-2.4
# num = 10.6 den = 14.7
# chi2 this bin: num/den = 0.7
# chi2 : 0.7
# comparing in bin: 164.117647059 h1: 5.0+/-2.2, h2: 4.0+/-2.0
# num = 1.0 den = 9.0
# chi2 this bin: num/den = 0.1
# chi2 : 0.1
# comparing in bin: 169.411764706 h1: 1.0+/-1.0, h2: 1.9+/-1.4
# num = 0.7 den = 2.9
# chi2 this bin: num/den = 0.3
# chi2 : 0.3
# comparing in bin: 174.705882353 h1: 3.0+/-1.7, h2: 0.8+/-0.9
# num = 5.0 den = 3.8
# chi2 this bin: num/den = 1.3
# chi2 : 1.3
# chi2,ndf: 26.2961600205 33
# all other cuts : sum of h_OnBeam: 389 ,sum of h_stack: 387.131477123
# comparing in bin: 0.0 h1: 0.0+/-0.0, h2: 0.1+/-0.4
# num = 0.0 den = 1.0
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 5.29411764706 h1: 1.0+/-1.0, h2: 0.4+/-0.6
# num = 0.4 den = 1.4
# chi2 this bin: num/den = 0.3
# chi2 : 0.3
# comparing in bin: 10.5882352941 h1: 0.0+/-0.0, h2: 0.5+/-0.7
# num = 0.3 den = 1.0
# chi2 this bin: num/den = 0.3
# chi2 : 0.3
# comparing in bin: 15.8823529412 h1: 0.0+/-0.0, h2: 0.4+/-0.6
# num = 0.2 den = 1.0
# chi2 this bin: num/den = 0.2
# chi2 : 0.2
# comparing in bin: 21.1764705882 h1: 1.0+/-1.0, h2: 0.6+/-0.8
# num = 0.2 den = 1.6
# chi2 this bin: num/den = 0.1
# chi2 : 0.1
# comparing in bin: 26.4705882353 h1: 0.0+/-0.0, h2: 0.8+/-0.9
# num = 0.6 den = 1.0
# chi2 this bin: num/den = 0.6
# chi2 : 0.6
# comparing in bin: 31.7647058824 h1: 1.0+/-1.0, h2: 1.4+/-1.2
# num = 0.2 den = 2.4
# chi2 this bin: num/den = 0.1
# chi2 : 0.1
# comparing in bin: 37.0588235294 h1: 2.0+/-1.4, h2: 2.3+/-1.5
# num = 0.1 den = 4.3
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 42.3529411765 h1: 2.0+/-1.4, h2: 3.5+/-1.9
# num = 2.2 den = 5.5
# chi2 this bin: num/den = 0.4
# chi2 : 0.4
# comparing in bin: 47.6470588235 h1: 5.0+/-2.2, h2: 5.1+/-2.3
# num = 0.0 den = 10.1
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 52.9411764706 h1: 5.0+/-2.2, h2: 6.7+/-2.6
# num = 2.7 den = 11.7
# chi2 this bin: num/den = 0.2
# chi2 : 0.2
# comparing in bin: 58.2352941176 h1: 8.0+/-2.8, h2: 9.4+/-3.1
# num = 1.9 den = 17.4
# chi2 this bin: num/den = 0.1
# chi2 : 0.1
# comparing in bin: 63.5294117647 h1: 5.0+/-2.2, h2: 15.2+/-3.9
# num = 103.2 den = 20.2
# chi2 this bin: num/den = 5.1
# chi2 : 5.1
# comparing in bin: 68.8235294118 h1: 12.0+/-3.5, h2: 21.7+/-4.7
# num = 93.3 den = 33.7
# chi2 this bin: num/den = 2.8
# chi2 : 2.8
# comparing in bin: 74.1176470588 h1: 18.0+/-4.2, h2: 27.5+/-5.2
# num = 90.8 den = 45.5
# chi2 this bin: num/den = 2.0
# chi2 : 2.0
# comparing in bin: 79.4117647059 h1: 20.0+/-4.5, h2: 32.5+/-5.7
# num = 157.2 den = 52.5
# chi2 this bin: num/den = 3.0
# chi2 : 3.0
# comparing in bin: 84.7058823529 h1: 33.0+/-5.7, h2: 36.8+/-6.1
# num = 14.8 den = 69.8
# chi2 this bin: num/den = 0.2
# chi2 : 0.2
# comparing in bin: 90.0 h1: 32.0+/-5.7, h2: 33.4+/-5.8
# num = 1.9 den = 65.4
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 95.2941176471 h1: 36.0+/-6.0, h2: 31.2+/-5.6
# num = 23.5 den = 67.2
# chi2 this bin: num/den = 0.3
# chi2 : 0.3
# comparing in bin: 100.588235294 h1: 35.0+/-5.9, h2: 26.4+/-5.1
# num = 74.6 den = 61.4
# chi2 this bin: num/den = 1.2
# chi2 : 1.2
# comparing in bin: 105.882352941 h1: 29.0+/-5.4, h2: 22.2+/-4.7
# num = 46.0 den = 51.2
# chi2 this bin: num/den = 0.9
# chi2 : 0.9
# comparing in bin: 111.176470588 h1: 26.0+/-5.1, h2: 17.8+/-4.2
# num = 66.8 den = 43.8
# chi2 this bin: num/den = 1.5
# chi2 : 1.5
# comparing in bin: 116.470588235 h1: 16.0+/-4.0, h2: 16.2+/-4.0
# num = 0.0 den = 32.2
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 121.764705882 h1: 15.0+/-3.9, h2: 12.4+/-3.5
# num = 6.8 den = 27.4
# chi2 this bin: num/den = 0.2
# chi2 : 0.2
# comparing in bin: 127.058823529 h1: 17.0+/-4.1, h2: 10.2+/-3.2
# num = 46.6 den = 27.2
# chi2 this bin: num/den = 1.7
# chi2 : 1.7
# comparing in bin: 132.352941176 h1: 14.0+/-3.7, h2: 10.1+/-3.2
# num = 15.3 den = 24.1
# chi2 this bin: num/den = 0.6
# chi2 : 0.6
# comparing in bin: 137.647058824 h1: 13.0+/-3.6, h2: 7.8+/-2.8
# num = 26.8 den = 20.8
# chi2 this bin: num/den = 1.3
# chi2 : 1.3
# comparing in bin: 142.941176471 h1: 10.0+/-3.2, h2: 7.3+/-2.7
# num = 7.1 den = 17.3
# chi2 this bin: num/den = 0.4
# chi2 : 0.4
# comparing in bin: 148.235294118 h1: 7.0+/-2.6, h2: 9.0+/-3.0
# num = 4.0 den = 16.0
# chi2 this bin: num/den = 0.2
# chi2 : 0.2
# comparing in bin: 153.529411765 h1: 8.0+/-2.8, h2: 7.7+/-2.8
# num = 0.1 den = 15.7
# chi2 this bin: num/den = 0.0
# chi2 : 0.0
# comparing in bin: 158.823529412 h1: 9.0+/-3.0, h2: 5.8+/-2.4
# num = 10.4 den = 14.8
# chi2 this bin: num/den = 0.7
# chi2 : 0.7
# comparing in bin: 164.117647059 h1: 5.0+/-2.2, h2: 4.0+/-2.0
# num = 1.0 den = 9.0
# chi2 this bin: num/den = 0.1
# chi2 : 0.1
# comparing in bin: 169.411764706 h1: 1.0+/-1.0, h2: 1.9+/-1.4
# num = 0.8 den = 2.9
# chi2 this bin: num/den = 0.3
# chi2 : 0.3
# comparing in bin: 174.705882353 h1: 3.0+/-1.7, h2: 0.8+/-0.9
# num = 5.0 den = 3.8
# chi2 this bin: num/den = 1.3
# chi2 : 1.3
# chi2,ndf: 26.348861646 33

# %% [markdown]
# ## PMT information

# %%
cuts_order  = ['no cut'
               ,'Chi2Proton'               
               ,'length'
               ,'non-collinearity'               
               ,'vertex activity'               
               ,'delta phi'               
               ,'Pt & delta phi'
              ]
reducedOverlay,pureffOverlay,pureffNumbers = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
reducedOnBeam,_ = apply_cuts_to_data(OnBeamFV=OnBeamFV,cuts_order=cuts_order)
print 'done applying cuts to data'
# Out:
# done applying cuts to overlay
# done applying cuts to data

# %%
for ivar,(var,xlabel,bins_before_cuts
          ,bins_after_cuts,chi2_xrange
          ,x_varcut,dx
          ,vname) in enumerate(zip(['TotalPE','TotalPE']                                                                            
                                            ,[r'$N_{PE}^{matched-flash}$',r'$N_{PE}^{matched-flash}$']
                                            ,[linspace(-1,4000,61),linspace(-1,4000,61)]                                            
                                            ,[linspace(-1,3000,31),linspace(-1,3000,31)]                                            
                                            ,[(0,4000),(0,4000)]                                            
                                            ,[(150,150),(150,150)],[300,300]                                           
                                            ,['$N_{PE}$ in the associated PMT flash','$N_{PE}$ in the associated PMT flash'])):
    var = 'MatchedFlash_' + var
    _,_,chi2_res=plot_before_after_cuts(var=var,x_label=xlabel,y_label=''
                           ,bins_before_cuts=bins_before_cuts
                           ,last_cut_name='Pt & delta phi'
                           ,bins_after_cuts=bins_after_cuts
                           ,overlay_scaling=overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic]                    
                           ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
                           ,chi2_xrange=chi2_xrange
                                        ,debug=2 if ivar==2 else 0
                                        ,x_varcut=x_varcut
                           ,dx=dx
                           ,yscale='log' if ivar==1 else 'linear'
                       );
    filename=figures_path + var + '_log_before_after_cuts.pdf' if ivar==1 else figures_path + var + '_before_after_cuts.pdf'
    plt.savefig(filename)    
    print 'saved ',filename
    if ivar==1: df_chi2_ndf = df_chi2_ndf.append(pd.DataFrame({'var':var,'$\chi^2$':chi2_res['chi2 after cuts'],'ndf':chi2_res['ndf after cuts'],'$\chi^2_{shape}$':chi2_res['chi2(shape) after cuts']}
                                                              ,index=[vname]))
# Out:
# saved  /Users/erezcohen/Desktop/Projects/uBoone/write-ups/OnBeamOffBeam5e19/Figures/overlay_rescaled_vs_BeamOn/MatchedFlash_TotalPE_before_after_cuts.pdf
# saved  /Users/erezcohen/Desktop/Projects/uBoone/write-ups/OnBeamOffBeam5e19/Figures/overlay_rescaled_vs_BeamOn/MatchedFlash_TotalPE_log_before_after_cuts.pdf

# %%
(var,xlabel,bins_before_cuts
          ,bins_after_cuts,chi2_xrange
          ,x_varcut,dx
          ,vname)=('YZdistance',r'$d_{YZ}^{matched-flash}$ [cm]'
                   ,linspace(-1,500,61) #61
                   ,linspace(-1,500,41) #41
                   ,(0,400),(0,200),20,'$d_{y-z}$ to the associated PMT flash ')
var = 'MatchedFlash_' + var
_,_,chi2_res=plot_before_after_cuts(var=var,x_label=xlabel,y_label=''
                           ,bins_before_cuts=bins_before_cuts
                           ,last_cut_name='Pt & delta phi'
                           ,bins_after_cuts=bins_after_cuts
                           ,overlay_scaling=overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic]                    
                           ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
                           ,chi2_xrange=chi2_xrange
                                        ,debug=0
                                        ,x_varcut=x_varcut
                           ,dx=dx
                           ,yscale='linear'
                       );
filename=figures_path + var + '_before_after_cuts.pdf'
plt.savefig(filename)    
print 'saved ',filename
if ivar==1: df_chi2_ndf = df_chi2_ndf.append(pd.DataFrame({'var':var,'$\chi^2$':chi2_res['chi2 after cuts'],'ndf':chi2_res['ndf after cuts'],'$\chi^2_{shape}$':chi2_res['chi2(shape) after cuts']}
                                                              ,index=[vname]))
print 'chi2_res:',chi2_res
# Out:
# saved  /Users/erezcohen/Desktop/Projects/uBoone/write-ups/OnBeamOffBeam5e19/Figures/overlay_rescaled_vs_BeamOn/MatchedFlash_YZdistance_before_after_cuts.pdf
# chi2_res: {'chi2(shape) after cuts': 25.888674199549286, 'chi2 after cuts': 27.196100314847669, 'ndf after cuts': 39}

# %%
# for var,xlabel,bins_before_cuts,bins_after_cuts,chi2_xrange,x_varcut in zip(['TotalPE','YZdistance']
#                                                                             ,[r'$N_{PE}^{matched-flash}$',r'$d_{YZ}^{matched-flash}$ [cm]']
#                                                                             ,[linspace(-1,4000,61),linspace(-1,500,61)]
#                                                                             ,[linspace(-1,4000,41),linspace(-1,500,41)]
#                                                                             ,[(0,4000),(0,400)]
#                                                                             ,[(150,150),(0,200)]):
#     var = 'ClosestFlash_' + var
#     _,_,chi2_res=plot_before_after_cuts(var=var,x_label=xlabel
#                            ,bins_before_cuts=bins_before_cuts
#                            ,last_cut_name='Pt & delta phi'
#                            ,bins_after_cuts=bins_after_cuts
#                            ,overlay_scaling=overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic]                    
#                            ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
#                            ,chi2_xrange=chi2_xrange,debug=0,x_varcut=x_varcut
#                        );

# %% [markdown]
# ## length ($l_\mu - l_p$)

# %%
cuts_order  = ['no cut'
               ,'Chi2Proton'               
               ,'MatchedFlash'               
               ,'non-collinearity'               
               ,'vertex activity'               
               ,'delta phi'               
               ,'Pt & delta phi'
              ]
reducedOverlay,pureffOverlay,pureffNumbers = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
reducedOnBeam,_ = apply_cuts_to_data(OnBeamFV=OnBeamFV,cuts_order=cuts_order)
print 'done applying cuts to data'
# Out:
# done applying cuts to overlay
# done applying cuts to data

# %%
var='l_mu-l_p'
_,_,chi2_res=plot_before_after_cuts(var=var,x_label= r'$l_{\mu}-l_p$ [cm]',y_label=''
                       ,bins_before_cuts=linspace(-500,500,31)
                       ,last_cut_name='Pt & delta phi'
                       ,bins_after_cuts=linspace(-100,500,25)
                       ,overlay_scaling=overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic]                    
                       ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
                       ,chi2_xrange=(-100,500),debug=0,x_varcut=(0,0),dx=50
                   );
plt.savefig(figures_path+'length_before_after_cuts.pdf')
df_chi2_ndf = df_chi2_ndf.append(pd.DataFrame({'var':var,'$\chi^2$':chi2_res['chi2 after cuts'],'ndf':chi2_res['ndf after cuts'],'$\chi^2_{shape}$':chi2_res['chi2(shape) after cuts']}
                                              ,index=['$l_{\mu-candidate} - l_{p-candidate}$']))
print 'chi2_res:',chi2_res
# Out:
# chi2_res: {'chi2(shape) after cuts': 15.289197670253916, 'chi2 after cuts': 15.253456010952123, 'ndf after cuts': 23}

# %% [markdown]
# ## vertex activity

# %%
cuts_order  = ['no cut'
               ,'Chi2Proton'               
               ,'MatchedFlash'               
               ,'length'
               ,'non-collinearity'               
               ,'delta phi'               
               ,'Pt & delta phi'
              ]
reducedOverlay,pureffOverlay,pureffNumbers = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
reducedOnBeam,_ = apply_cuts_to_data(OnBeamFV=OnBeamFV,cuts_order=cuts_order)
print 'done applying cuts to data'
# Out:
# done applying cuts to overlay
# done applying cuts to data

# %%
for plane,pname in zip([0,1,2],['U','V','Y']):
    var='RdQaroundVertex[plane %d'%plane+'][50 wires x 100 ticks]'
    _,_,chi2_res=plot_before_after_cuts(var=var,figsize=(24,6),where='pre'
                           ,x_label=  r'$R_{\Delta Q}^{'+pname+'-plane}$',y_label=''
                           ,bins_before_cuts=linspace(-0.01,1.01,61)
                           ,bins_after_cuts=linspace(-0.01,1.01,51)
                           ,x_varcut=(0.61,0.61)
                           ,last_cut_name='Pt & delta phi'
                           ,overlay_scaling=overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic]                    
                           ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
                           ,chi2_xrange=(0,1)
                   )
    plt.savefig(figures_path+'RdQ_plane_%d'%plane+'_before_after_cuts.pdf')
    print 'saved',figures_path+'RdQ_plane_%d'%plane+'_before_after_cuts.pdf'
    df_chi2_ndf = df_chi2_ndf.append(pd.DataFrame({'var':var,'$\chi^2$':chi2_res['chi2 after cuts'],'ndf':chi2_res['ndf after cuts'],'$\chi^2_{shape}$':chi2_res['chi2(shape) after cuts']}
                                                  ,index=['\RdQ\ in the '+pname+'-plane']))
# Out:
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/OnBeamOffBeam5e19/Figures/overlay_rescaled_vs_BeamOn/RdQ_plane_0_before_after_cuts.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/OnBeamOffBeam5e19/Figures/overlay_rescaled_vs_BeamOn/RdQ_plane_1_before_after_cuts.pdf
# saved /Users/erezcohen/Desktop/Projects/uBoone/write-ups/OnBeamOffBeam5e19/Figures/overlay_rescaled_vs_BeamOn/RdQ_plane_2_before_after_cuts.pdf

# %% [markdown]
# ## $\Delta \phi$

# %%
cuts_order  = ['no cut'
               ,'Chi2Proton'               
               ,'MatchedFlash'               
               ,'length'
               ,'non-collinearity'               
               ,'vertex activity'               
            ,'Pt no delta phi'
              ]
reducedOverlay,pureffOverlay,pureffNumbers = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
reducedOnBeam,_ = apply_cuts_to_data(OnBeamFV=OnBeamFV,cuts_order=cuts_order)
print 'done applying cuts to data'
# Out:
# done applying cuts to overlay
# done applying cuts to data

# %%
var='delta_phi'
_,_,chi2_res=plot_before_after_cuts(var=var,x_label= r'$\Delta \phi$ [deg.]',y_label=''
                       ,bins_before_cuts=linspace(-1,361,31)
                       ,last_cut_name='Pt no delta phi'
                       ,bins_after_cuts=linspace(-1,361,25)
                       ,overlay_scaling=overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic]                    
                       ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
                       ,chi2_xrange=(-1,361)
                       ,x_varcut=(145,215),dx=10,debug=0
                   );
plt.savefig(figures_path+'delta_phi_before_after_cuts.pdf')
df_chi2_ndf = df_chi2_ndf.append(pd.DataFrame({'var':var,'$\chi^2$':chi2_res['chi2 after cuts'],'ndf':chi2_res['ndf after cuts'],'$\chi^2_{shape}$':chi2_res['chi2(shape) after cuts']}
                                              ,index=['$\Delta \phi$']))
print 'chi2_res:',chi2_res
# Out:
# chi2_res: {'chi2(shape) after cuts': 45.126591716122242, 'chi2 after cuts': 72.906766427348728, 'ndf after cuts': 23}

# %% [markdown]
# ## $p_t$

# %%
cuts_order  = ['no cut'
               ,'Chi2Proton'               
               ,'MatchedFlash'               
               ,'length'
               ,'non-collinearity'               
               ,'vertex activity'               
               ,'delta phi'               
              ]
reducedOverlay,pureffOverlay,pureffNumbers = apply_cuts_to_overlay(OverlaySamples=OverlaySamples,cuts_order=cuts_order)
print 'done applying cuts to overlay'
reducedOnBeam,_ = apply_cuts_to_data(OnBeamFV=OnBeamFV,cuts_order=cuts_order)
print 'done applying cuts to data'
# Out:
# done applying cuts to overlay
# done applying cuts to data

# %%
var='reco_Pt'
_,_,chi2_res=plot_before_after_cuts(var=var,x_label=r'$p_{t}$ [GeV/c]',y_label=''
                       ,bins_before_cuts=linspace(0,1.75,31)
                       ,last_cut_name='delta phi'
                       ,bins_after_cuts=linspace(0,0.9,19)
                       ,overlay_scaling=overlay_scalings['N(On) scaling and f(cosmic)=%.3f'%f_Cosmic]                    
                       ,reducedOnBeam=reducedOnBeam,reducedOverlay=reducedOverlay
                       ,chi2_xrange=(0,1.)
                       ,x_varcut=(0,0.35),dx=0.05,debug=0
                   );
plt.savefig(figures_path+'Pt_before_after_cuts.pdf')
df_chi2_ndf = df_chi2_ndf.append(pd.DataFrame({'var':var,'$\chi^2$':chi2_res['chi2 after cuts'],'ndf':chi2_res['ndf after cuts'],'$\chi^2_{shape}$':chi2_res['chi2(shape) after cuts']}
                                              ,index=['$p_{t}$']))

# %% [markdown]
# # summary

# %%
from scipy import stats
Pval = []
Pval_shape = []
for i,row in df_chi2_ndf.iterrows():
    Pval.append( 1 - stats.chi2.cdf(row[r'$\chi^2$'], row['ndf'] ) )         
    Pval_shape.append( 1 - stats.chi2.cdf(row[r'$\chi^2_{shape}$'], row['ndf'] ) )         
df_chi2_ndf['Pval'] = Pval    
df_chi2_ndf['Pval_shape'] = Pval_shape

# %%
print "plug in table tab:summary_observables in tab:OverlayRescaledVsBeamOn.tex"
print 
print 
print "\hline \hline"
for i,row in df_chi2_ndf[:].iterrows():
    Pval = row['Pval']
    Pval_label = "%.3f"%Pval if Pval>0.01 else "\\textcolor{red}{%.3f}"%Pval if Pval>0.001 else "\\textcolor{red}{$<0.001$}"
    Pval_shape = row['Pval_shape']
    Pval_shape_label = "%.3f"%Pval_shape if Pval_shape>0.01 else "\\textcolor{red}{%.3f}"%Pval_shape if Pval_shape>0.001 else "\\textcolor{red}{$<0.001$}"
    print "			"+i+"  & %.1f"%row[r'$\chi^2$']+"/%d"%row['ndf']+"  & " + Pval_label +"  & %.1f"%row[r'$\chi^2_{shape}$']+"/%d"%row['ndf']+"  & " + Pval_shape_label + "\\tabularnewline"
    print "\hline"        
print
print
# Out:
# plug in table tab:summary_observables in tab:OverlayRescaledVsBeamOn.tex
#
#
# \hline \hline
# 			\ChiSqrP\ for the muon candidate  & 54.7/43  & 0.109  & 55.8/43  & 0.092\tabularnewline
# \hline
# 			\ChiSqrP\ for the proton candidate  & 43.0/19  & \textcolor{red}{0.001}  & 43.5/19  & \textcolor{red}{0.001}\tabularnewline
# \hline
# 			$\theta_{1,2}$  & 26.3/33  & 0.790  & 26.3/33  & 0.787\tabularnewline
# \hline
# 			$N_{PE}$ in the associated PMT flash  & 27.1/29  & 0.565  & 27.3/29  & 0.556\tabularnewline
# \hline
# 			$d_{y-z}$ to the associated PMT flash   & 27.2/39  & 0.923  & 25.9/39  & 0.947\tabularnewline
# \hline
# 			$l_{\mu-candidate} - l_{p-candidate}$  & 15.3/23  & 0.885  & 15.3/23  & 0.884\tabularnewline
# \hline
# 			\RdQ\ in the U-plane  & 134.5/49  & \textcolor{red}{$<0.001$}  & 138.5/49  & \textcolor{red}{$<0.001$}\tabularnewline
# \hline
# 			\RdQ\ in the V-plane  & 56.9/49  & 0.204  & 49.9/49  & 0.437\tabularnewline
# \hline
# 			\RdQ\ in the Y-plane  & 50.9/49  & 0.400  & 44.3/49  & 0.664\tabularnewline
# \hline
# 			$\Delta \phi$  & 72.9/23  & \textcolor{red}{$<0.001$}  & 45.1/23  & \textcolor{red}{0.004}\tabularnewline
# \hline
# 			$p_{t}$  & 18.1/17  & 0.384  & 18.1/17  & 0.381\tabularnewline
# \hline

# %%
bad_obsevables = df_chi2_ndf[df_chi2_ndf['Pval']<0.05]
good_obsevables = df_chi2_ndf[df_chi2_ndf['Pval']>0.05]
good_obsevables
# Out:
#                                          $\chi^2$  $\chi^2_{shape}$ ndf  \
# \ChiSqrP\ for the muon candidate        54.676053         55.777739  43
# $\theta_{1,2}$                          26.296160         26.348862  33
# $N_{PE}$ in the associated PMT flash    27.120850         27.284486  29
# $d_{y-z}$ to the associated PMT flash   27.196100         25.888674  39
# $l_{\mu-candidate} - l_{p-candidate}$   15.253456         15.289198  23
# \RdQ\ in the V-plane                    56.933385         49.913464  49
# \RdQ\ in the Y-plane                    50.873425         44.302927  49
# $p_{t}$                                 18.069911         18.118664  17
#
#                                                                                    var  \
# \ChiSqrP\ for the muon candidate                  pidcali_Chi2ProtonYplane_muCandidate
# $\theta_{1,2}$                                                                theta_12
# $N_{PE}$ in the associated PMT flash                              MatchedFlash_TotalPE
# $d_{y-z}$ to the associated PMT flash                          MatchedFlash_YZdistance
# $l_{\mu-candidate} - l_{p-candidate}$                                         l_mu-l_p
# \RdQ\ in the V-plane                    RdQaroundVertex[plane 1][50 wires x 100 ticks]
# \RdQ\ in the Y-plane                    RdQaroundVertex[plane 2][50 wires x 100 ticks]
# $p_{t}$                                                                        reco_Pt
#
#                                             Pval  Pval_shape
# \ChiSqrP\ for the muon candidate        0.109200    0.091532
# $\theta_{1,2}$                          0.789631    0.787449
# $N_{PE}$ in the associated PMT flash    0.565185    0.556359
# $d_{y-z}$ to the associated PMT flash   0.922782    0.946945
# $l_{\mu-candidate} - l_{p-candidate}$   0.885320    0.883970
# \RdQ\ in the V-plane                    0.203732    0.436830
# \RdQ\ in the Y-plane                    0.399716    0.663701
# $p_{t}$                                 0.384443    0.381392

# %%
var='theta_12'
x_label=r'$\theta_{1,2}$ angle between the two tracks [deg.]'
bins=np.linspace(0,180,41)

# %%
fig,ax=plt.subplots(figsize=(12,8))
h_stack,_=plot_stacked_MCsamples( reducedOverlay=reducedOverlay,cut_name='no cut'
                       , overlay_scaling=overlay_scalings['N(On) scaling']
                       , ax=ax, var=var, x_label=x_label,y_label='counts', bins=bins 
                       , fontsize=25                       
                       , stackColor='black',stackLabel='overlay'
                      );
_,h_OnBeam = plot_OnBeam(OnBeamSample=reducedOnBeam['no cut'],OnBeamFV=reducedOnBeam['no cut'],markersize=8
                                 ,color='purple',x_label=x_label, var=var, bins=bins, ax=ax)
ax.legend(fontsize=25)
chi2 , ndf = chi2_two_histograms( bins=bins, chi2_xrange=(np.min(bins),np.max(bins))
                                     , h1=h_OnBeam , h2=h_stack
                                     , h1err=np.sqrt(h_OnBeam), h2err=np.sqrt(h_stack)
                                     , debug=0 )
chi2_txt = r'$\chi^2/ndf=%.1f/%d$'%(chi2,ndf)
ax.set_title(chi2_txt,y=1.02,fontsize=25)
plt.tight_layout()
plt.savefig(figures_path+'theta_12_overlay_stacked_with_BeamOn.pdf')

# %% [markdown]
# ## optimize the matching using $\chi^2$ test

# %% [markdown]
# f_cosmic_array = linspace(0,1,100)
# chi2_array = []
#
# for f_Cosmic in f_cosmic_array:
#     x = reducedOnBeam['no cut'][var]
#     h_OnBeam,edges = np.histogram( x , bins=bins )
#
#     overlay_scalings['N(On) scaling and f(cosmic)=%.2f'%f_Cosmic] = get_samples_scaling( N_total= float(len(OnBeamFV)), f_Cosmic=f_Cosmic , OverlaySubsamples=reducedOverlay['no cut'])
#     overlay_scaling = overlay_scalings['N(On) scaling and f(cosmic)=%.2f'%f_Cosmic]
#     h = dict()
#     for i_pair_type,pair_type in enumerate(pair_types):
#         sample = reducedOverlay['no cut'][pair_type]
#         x = sample[var]; x = x[x<1e5];
#         h[pair_type],edges = np.histogram(x,bins=bins)
#         h[pair_type+' scaled'] = overlay_scaling[pair_type]*h[pair_type] if overlay_scaling else h[pair_type]
#     # -- - - - --------- - - -- ---- -  - --- -- -- -- --
#     h_stack = h['cosmic scaled']+h['other pairs scaled']+h['1mu-1p scaled']
#     chi2 , ndf = chi2_two_histograms( bins=bins, chi2_xrange=(np.min(bins),np.max(bins))
#                                      , h1=h_OnBeam , h2=h_stack
#                                      , h1err=np.sqrt(h_OnBeam), h2err=np.sqrt(h_stack)
#                                      , debug=0 )
#     chi2_array.append(chi2)
#
# chi2_array = np.array(chi2_array)
# print 'done.'

# %% [markdown]
# fig,ax=plt.subplots(figsize=(12,8))
# plt.plot(f_cosmic_array,chi2_array/ndf)
# set_axes(ax,r'$f_{cosmic}$',r'$\chi^2_{red}$',do_add_grid='True')
# ax.set_yscale('log')
#
# # best point
# i_min = np.argmin(chi2_array)
# f_min = f_cosmic_array[i_min]
# print 'f_min:',f_min
# plt.plot([f_min,f_min],[np.min(ax.get_ylim()),chi2_array[i_min]],'--',color='black')
# plt.text(0.6,1.05*chi2_array[i_min],r'$f _{cosmic}^{min} = %.3f$'%f_min,fontsize=35 ,color='black')
# plt.savefig(figures_path+'f_cosmic_vs_chi2.pdf')
